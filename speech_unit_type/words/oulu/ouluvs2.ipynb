# %%
import os
import pandas as pd
from collections import defaultdict

dir = "../../../models/DC-TCN/datasets/ouluvs2_words_v2"

def create_df(dir):
    word_data_counts = defaultdict(lambda: defaultdict(lambda: defaultdict(int)))
    
    for word in os.listdir(dir):
        word_path = os.path.join(dir, word)
        
        if not os.path.isdir(word_path):
            print(f"Skipping {word}: not a directory.")
            continue
    
        for split in ['train', 'val', 'test']:
            split_path = os.path.join(word_path, split)
            
            if not os.path.isdir(split_path):
                continue
        
            file_count = sum(1 for file in os.listdir(split_path) if file.endswith(".npz"))
            word_data_counts[word][split]["total"] = file_count
            
            for file in os.listdir(split_path):
                if file.endswith(".npz"):
                    try:
                        version = file.split("_")[2].replace(".npz", "")
                        word_data_counts[word][split][version] += 1
                    except IndexError:
                        print(f"Error processing file: {file} in {split_path}")
    
    df = pd.DataFrame(columns=["train", "val", "test"] + [f"v{i}" for i in range(1, 6)])
    
    for word, splits in word_data_counts.items():
        row = {}
        row["train"] = splits["train"]["total"]
        row["val"] = splits["val"]["total"]
        row["test"] = splits["test"]["total"]
        
        for version in range(1, 6):
            v_key = f"v{version}"
            row[v_key] = {
                "train": splits["train"].get(v_key, 0),
                "val": splits["val"].get(v_key, 0),
                "test": splits["test"].get(v_key, 0),
            }
        df.loc[word] = row
    
    df['total'] = df[['train', 'val', 'test']].sum(axis=1)
    return df

# %%
df = create_df("../../../models/DC-TCN/datasets/ouluvs2_words_v2")

# %%
print("\nWord and File Counts per Subfolder and Versions:")
print(df)
# Out:
# Word and File Counts per Subfolder and Versions:
#           train  val  test                                 v1  \
# GUNPOINT      8    2     5  {'train': 2, 'val': 0, 'test': 1}
# THEIR        24    6     5  {'train': 6, 'val': 0, 'test': 1}
# PROVOKED      3    1     1  {'train': 1, 'val': 0, 'test': 0}
# CLEANERS      3    1     1  {'train': 0, 'val': 1, 'test': 0}
# CHOSE         4    1     5  {'train': 0, 'val': 1, 'test': 1}
# ...         ...  ...   ...                                ...
# EARLY        24    6    10  {'train': 4, 'val': 2, 'test': 2}
# BRIGHT        4    1    10  {'train': 1, 'val': 0, 'test': 2}
# SPRING       10    2     3  {'train': 3, 'val': 0, 'test': 0}
# THIS         44   11    15  {'train': 8, 'val': 3, 'test': 3}
# BALLS         3    1     1  {'train': 1, 'val': 0, 'test': 0}
#
#                                          v2  \
# GUNPOINT  {'train': 2, 'val': 0, 'test': 1}
# THEIR     {'train': 4, 'val': 2, 'test': 1}
# PROVOKED  {'train': 0, 'val': 0, 'test': 1}
# CLEANERS  {'train': 1, 'val': 0, 'test': 0}
# CHOSE     {'train': 1, 'val': 0, 'test': 1}
# ...                                     ...
# EARLY     {'train': 5, 'val': 1, 'test': 2}
# BRIGHT    {'train': 1, 'val': 0, 'test': 2}
# SPRING    {'train': 2, 'val': 0, 'test': 1}
# THIS      {'train': 8, 'val': 3, 'test': 3}
# BALLS     {'train': 0, 'val': 1, 'test': 0}
#
#                                          v3  \
# GUNPOINT  {'train': 1, 'val': 1, 'test': 1}
# THEIR     {'train': 4, 'val': 2, 'test': 1}
# PROVOKED  {'train': 0, 'val': 1, 'test': 0}
# CLEANERS  {'train': 0, 'val': 0, 'test': 1}
# CHOSE     {'train': 1, 'val': 0, 'test': 1}
# ...                                     ...
# EARLY     {'train': 5, 'val': 1, 'test': 2}
# BRIGHT    {'train': 1, 'val': 0, 'test': 2}
# SPRING    {'train': 2, 'val': 0, 'test': 1}
# THIS      {'train': 9, 'val': 2, 'test': 3}
# BALLS     {'train': 1, 'val': 0, 'test': 0}
#
#                                          v4  \
# GUNPOINT  {'train': 2, 'val': 0, 'test': 1}
# THEIR     {'train': 6, 'val': 0, 'test': 1}
# PROVOKED  {'train': 1, 'val': 0, 'test': 0}
# CLEANERS  {'train': 1, 'val': 0, 'test': 0}
# CHOSE     {'train': 1, 'val': 0, 'test': 1}
# ...                                     ...
# EARLY     {'train': 4, 'val': 2, 'test': 2}
# BRIGHT    {'train': 0, 'val': 1, 'test': 2}
# SPRING    {'train': 1, 'val': 1, 'test': 1}
# THIS      {'train': 9, 'val': 2, 'test': 3}
# BALLS     {'train': 1, 'val': 0, 'test': 0}
#
#                                           v5
# GUNPOINT   {'train': 1, 'val': 1, 'test': 1}
# THEIR      {'train': 4, 'val': 2, 'test': 1}
# PROVOKED   {'train': 1, 'val': 0, 'test': 0}
# CLEANERS   {'train': 1, 'val': 0, 'test': 0}
# CHOSE      {'train': 1, 'val': 0, 'test': 1}
# ...                                      ...
# EARLY      {'train': 6, 'val': 0, 'test': 2}
# BRIGHT     {'train': 1, 'val': 0, 'test': 2}
# SPRING     {'train': 2, 'val': 1, 'test': 0}
# THIS      {'train': 10, 'val': 1, 'test': 3}
# BALLS      {'train': 0, 'val': 0, 'test': 1}
#
# [1203 rows x 8 columns]

# %%
print("\nWord and File Counts per Subfolder:")
sorted_df = df.sort_index()
sorted_df['total'] = sorted_df[['train', 'val', 'test']].sum(axis=1)
sorted_df = sorted_df.sort_values(by='total', ascending=False)
print(sorted_df[['train', 'val', 'test', 'total']])
# Out:
# Word and File Counts per Subfolder:
#           train  val  test  total
# YOU        2564  641   935   4140
# ARE        1068  268   380   1716
# A           732  183   305   1220
# THE         768  192   255   1215
# TO          720  180   270   1170
# ...         ...  ...   ...    ...
# WILLOWY       3    1     1      5
# WINDOW        3    1     1      5
# WITHDRAW      3    1     1      5
# WOMAN         3    1     1      5
# WOOL          3    1     1      5
#
# [1203 rows x 4 columns]

# %%
total_train = df['train'].sum()
total_val = df['val'].sum()
total_test = df['test'].sum()

print(f"Total train: {total_train}")
print(f"Total val: {total_val}")
print(f"Total test: {total_test}")
# Out:
# Total train: 24001
# Total val: 5895
# Total test: 9466

# %%
gunpoint_v1_total = df.loc['GUNPOINT', 'v1']
total_v1 = sum(gunpoint_v1_total.values())

print(f"Total count of v1 for 'GUNPOINT': {total_v1}")
# Out:
# Total count of v1 for 'GUNPOINT': 3

# %%
total_v1_across_all_words = df['v1'].apply(lambda x: sum(x.values())).sum()
total_v2_across_all_words = df['v2'].apply(lambda x: sum(x.values())).sum()
total_v3_across_all_words = df['v3'].apply(lambda x: sum(x.values())).sum()
total_v4_across_all_words = df['v4'].apply(lambda x: sum(x.values())).sum()
total_v5_across_all_words = df['v5'].apply(lambda x: sum(x.values())).sum()
print(f"Total count of v1 across all words: {total_v1_across_all_words}")
print(f"Total count of v2 across all words: {total_v2_across_all_words}")
print(f"Total count of v3 across all words: {total_v3_across_all_words}")
print(f"Total count of v4 across all words: {total_v4_across_all_words}")
print(f"Total count of v5 across all words: {total_v5_across_all_words}")
# Out:
# Total count of v1 across all words: 7872
# Total count of v2 across all words: 7873
# Total count of v3 across all words: 7872
# Total count of v4 across all words: 7872
# Total count of v5 across all words: 7873

# %%
version_columns = ['v1', 'v2', 'v3', 'v4', 'v5']
split_columns = ['train', 'val', 'test']

total_versions_per_split = {split: {version: df[version].apply(lambda x: x.get(split, 0)).sum() for version in version_columns} for split in split_columns}

print("Total counts for each version per split:")
for split, versions in total_versions_per_split.items():
    print(f"\n{split.capitalize()}:")
    for version, count in versions.items():
        print(f"  {version}: {count}")
# Out:
# Total counts for each version per split:
#
# Train:
#   v1: 4728
#   v2: 4845
#   v3: 4799
#   v4: 4810
#   v5: 4819
#
# Val:
#   v1: 1203
#   v2: 1177
#   v3: 1186
#   v4: 1166
#   v5: 1163
#
# Test:
#   v1: 1941
#   v2: 1851
#   v3: 1887
#   v4: 1896
#   v5: 1891

# %%
total_train_zeros = (df['train'] == 0).sum()
total_val_zeros = (df['val'] == 0).sum()
total_test_zeros = (df['test'] == 0).sum()

print(f"Total train = 0: {total_train_zeros}")
print(f"Total val = 0: {total_val_zeros}")
print(f"Total test = 0: {total_test_zeros}")
# Out:
# Total train = 0: 0
# Total val = 0: 0
# Total test = 0: 0

# %%
# Find words where test or val count is higher than train
problematic_words = df[(df['test'] >= df['train']) | (df['val'] >= df['train'])]

print("Problematic words:\n", problematic_words[['train', 'val', 'test']])
# Out:
# Problematic words:
#                   train  val  test
# CHOSE                4    1     5
# PLACED               4    1     5
# FEW                  4    1     5
# HUGE                 4    1    10
# CARTOONS             4    1     5
# WASTE                4    1     5
# CLAY                 4    1     5
# BEANS                4    1     5
# THROUGH              8    2    15
# PRIORITY             4    1     5
# GENERALS             4    1     5
# HOURS               12    3    15
# ORGANIZATIONS        4    1     5
# ILLUMINATING         8    2    15
# IDENTICAL            4    1     5
# DECORATE             4    1     5
# ADDITION             4    1     5
# CLASSROOMS           4    1     5
# GARDEN              12    3    15
# BOX                 12    3    15
# CONSUMING            4    1     5
# CREATE               8    2    15
# KEEP                 8    2    15
# COMPILE              8    2    10
# BOWL                 4    1    10
# MAKES                4    1    15
# VEGETABLE            4    1     5
# ENTER                4    1     5
# HANDBAG              8    2    10
# REGULAR              4    1     5
# CIGARETTES           4    1     5
# SUGAR                4    1    10
# STEVE                4    1     5
# ECONOMIC             4    1     5
# SPRAINED             4    1     5
# ATE                  8    2    10
# NEGLECT              4    1     5
# BUSINESS             4    1     5
# STOLE                8    2    15
# FASHION              4    1     5
# SLOPE                4    1     5
# EXTRA               12    3    15
# GARDENS              4    1     5
# YOUNG                8    2    10
# LEATHER              8    2    10
# GOOSE                4    1     5
# STRAW                4    1     5
# CHILDREN             4    1     5
# OVERFLOWED           4    1     5
# KINDERGARTEN         4    1     5
# TAPESTRY             4    1     5
# AFTERNOON            4    1     5
# WITHOUT              8    2    15
# GROWS                4    1     5
# HALLWAY              4    1    10
# RABBITS              4    1    10
# HOLIDAYS             4    1     5
# DIAGRAM              4    1     5
# SHOWERS              4    1     5
# PRICE                8    2    10
# DIME                 8    2    15
# SHOULDER             4    1     5
# CUTBACKS             4    1     5
# SHIMMERS             4    1    10
# CYCLICAL             8    2    10
# OVER                 4    1     5
# REMEMBER             4    1     5
# TOP                  4    1     5
# SUBTRACTION          4    1     5
# OAK                  4    1     5
# CATASTROPHIC         4    1     5
# TRISH                4    1     5
# GEORGE               4    1     5
# FIRST                8    2    10
# CONFIRM              4    1     5
# MANY                 4    1     5
# COOK                 4    1    10
# HUNG                 4    1     5
# OUTGREW              4    1     5
# SKILLS               4    1     5
# SENSE                4    1     5
# COLLECTS             4    1     5
# AFTER                4    1    10
# STUDENTS             4    1     5
# GREEN                4    1     5
# LIVE                 4    1    10
# TOM                  4    1     5
# FOUR                 8    2    10
# MUSICIANS            4    1    10
# PROGRAMS             8    2    10
# GREGORY              4    1     5
# VERY                 4    1     5
# UPBRINGING           4    1     5
# MUSEUM               4    1    10
# ATTACKED             4    1     5
# REMOVAL              4    1     5
# ASHTRAY              4    1     5
# PLACE                8    2    10
# ANSWERS              4    1     5
# HEALTHIER            4    1    10
# GROWING              4    1     5
# GWEN                 4    1     5
# REGARDING            4    1     5
# EXAMPLES            20    5    20
# BREAKFAST            8    2    10
# HATS                 4    1     5
# OCEAN                4    1    10
# LEARNED              4    1     5
# TWINS                4    1     5
# MERGERS              4    1     5
# SUNSHINE             4    1    10
# INSTRUCTIONS         4    1     5
# STEEP                8    2    10
# USED                 4    1     5
# ONTO                 4    1     5
# LAY                  4    1     5
# THINK                4    1     5
# APRONS               4    1     5
# HOLIDAY              4    1     5
# CAREFULLY            4    1     5
# REQUIRED             4    1     5
# POLICY               4    1     5
# GRANDMOTHER          4    1     5
# PETTICOATS           4    1     5
# RARE                 4    1     5
# WHO                  4    1     5
# BIKE                 4    1     5
# FIXED                4    1     5
# RISE                 4    1    10
# NOVEL                4    1     5
# BROKEN               4    1     5
# EGGS                 8    2    10
# DETERMINATION        4    1     5
# GETTING              4    1     5
# THOSE               12    3    20
# STRAIGHTFORWARD      4    1     5
# SCULPTURE            4    1    10
# ATTENDANCE           4    1     5
# TOOK                 4    1     5
# FELT                 4    1     5
# HIRES                4    1     5
# TODD                 4    1     5
# WORD                 4    1     5
# COINS                4    1     5
# SUITABLE             8    2    10
# ANKLE                4    1     5
# BRIGHT               4    1    10

# %%
print(problematic_words.index)
# Out:
# Index(['CHOSE', 'PLACED', 'FEW', 'HUGE', 'CARTOONS', 'WASTE', 'CLAY', 'BEANS',
#        'THROUGH', 'PRIORITY',
#        ...
#        'ATTENDANCE', 'TOOK', 'FELT', 'HIRES', 'TODD', 'WORD', 'COINS',
#        'SUITABLE', 'ANKLE', 'BRIGHT'],
#       dtype='object', length=147)

# %%
import shutil
source_dir = "../../../models/DC-TCN/datasets/ouluvs2_words_v2"

moved = 0
for word in problematic_words.index:
    word_folder = os.path.join(source_dir, word)
    moved_files = 0
    
    if os.path.exists(word_folder):
        train_folder = os.path.join(word_folder, 'train')
        val_folder = os.path.join(word_folder, 'val')
        test_folder = os.path.join(word_folder, 'test')
        
        if not os.path.exists(train_folder):
            os.makedirs(train_folder)
        
        if os.path.exists(val_folder):
            for filename in os.listdir(val_folder):
                src_path = os.path.join(val_folder, filename)
                dest_path = os.path.join(train_folder, filename)
                if os.path.isfile(src_path):
                    shutil.move(src_path, dest_path)
                    moved_files += 1
        
        if os.path.exists(test_folder):
            for filename in os.listdir(test_folder):
                src_path = os.path.join(test_folder, filename)
                dest_path = os.path.join(train_folder, filename)
                if os.path.isfile(src_path):
                    shutil.move(src_path, dest_path)
                    moved_files += 1
        if moved_files > 0:
            moved += 1
            print(f"Moved files for word: {word}. Total moved: {moved_files}")
    else:
        print(f"Word folder not found: {word_folder}")

print(f"\nTotal words processed with files moved: {moved}")
# Out:
# Moved files for word: CHOSE. Total moved: 12
# Moved files for word: PLACED. Total moved: 12
# Moved files for word: FEW. Total moved: 12
# Moved files for word: HUGE. Total moved: 22
# Moved files for word: CARTOONS. Total moved: 12
# Moved files for word: WASTE. Total moved: 12
# Moved files for word: CLAY. Total moved: 12
# Moved files for word: BEANS. Total moved: 12
# Moved files for word: THROUGH. Total moved: 34
# Moved files for word: PRIORITY. Total moved: 12
# Moved files for word: GENERALS. Total moved: 12
# Moved files for word: HOURS. Total moved: 36
# Moved files for word: ORGANIZATIONS. Total moved: 12
# Moved files for word: ILLUMINATING. Total moved: 34
# Moved files for word: IDENTICAL. Total moved: 12
# Moved files for word: DECORATE. Total moved: 12
# Moved files for word: ADDITION. Total moved: 12
# Moved files for word: CLASSROOMS. Total moved: 12
# Moved files for word: GARDEN. Total moved: 36
# Moved files for word: BOX. Total moved: 36
# Moved files for word: CONSUMING. Total moved: 12
# Moved files for word: CREATE. Total moved: 34
# Moved files for word: KEEP. Total moved: 34
# Moved files for word: COMPILE. Total moved: 24
# Moved files for word: BOWL. Total moved: 22
# Moved files for word: MAKES. Total moved: 32
# Moved files for word: VEGETABLE. Total moved: 12
# Moved files for word: ENTER. Total moved: 12
# Moved files for word: HANDBAG. Total moved: 24
# Moved files for word: REGULAR. Total moved: 12
# Moved files for word: CIGARETTES. Total moved: 12
# Moved files for word: SUGAR. Total moved: 22
# Moved files for word: STEVE. Total moved: 12
# Moved files for word: ECONOMIC. Total moved: 12
# Moved files for word: SPRAINED. Total moved: 12
# Moved files for word: ATE. Total moved: 24
# Moved files for word: NEGLECT. Total moved: 12
# Moved files for word: BUSINESS. Total moved: 12
# Moved files for word: STOLE. Total moved: 34
# Moved files for word: FASHION. Total moved: 12
# Moved files for word: SLOPE. Total moved: 12
# Moved files for word: EXTRA. Total moved: 36
# Moved files for word: GARDENS. Total moved: 12
# Moved files for word: YOUNG. Total moved: 24
# Moved files for word: LEATHER. Total moved: 24
# Moved files for word: GOOSE. Total moved: 12
# Moved files for word: STRAW. Total moved: 12
# Moved files for word: CHILDREN. Total moved: 12
# Moved files for word: OVERFLOWED. Total moved: 12
# Moved files for word: KINDERGARTEN. Total moved: 12
# Moved files for word: TAPESTRY. Total moved: 12
# Moved files for word: AFTERNOON. Total moved: 12
# Moved files for word: WITHOUT. Total moved: 34
# Moved files for word: GROWS. Total moved: 12
# Moved files for word: HALLWAY. Total moved: 22
# Moved files for word: RABBITS. Total moved: 22
# Moved files for word: HOLIDAYS. Total moved: 12
# Moved files for word: DIAGRAM. Total moved: 12
# Moved files for word: SHOWERS. Total moved: 12
# Moved files for word: PRICE. Total moved: 24
# Moved files for word: DIME. Total moved: 34
# Moved files for word: SHOULDER. Total moved: 12
# Moved files for word: CUTBACKS. Total moved: 12
# Moved files for word: SHIMMERS. Total moved: 22
# Moved files for word: CYCLICAL. Total moved: 24
# Moved files for word: OVER. Total moved: 12
# Moved files for word: REMEMBER. Total moved: 12
# Moved files for word: TOP. Total moved: 12
# Moved files for word: SUBTRACTION. Total moved: 12
# Moved files for word: OAK. Total moved: 12
# Moved files for word: CATASTROPHIC. Total moved: 12
# Moved files for word: TRISH. Total moved: 12
# Moved files for word: GEORGE. Total moved: 12
# Moved files for word: FIRST. Total moved: 24
# Moved files for word: CONFIRM. Total moved: 12
# Moved files for word: MANY. Total moved: 12
# Moved files for word: COOK. Total moved: 22
# Moved files for word: HUNG. Total moved: 12
# Moved files for word: OUTGREW. Total moved: 12
# Moved files for word: SKILLS. Total moved: 12
# Moved files for word: SENSE. Total moved: 12
# Moved files for word: COLLECTS. Total moved: 12
# Moved files for word: AFTER. Total moved: 22
# Moved files for word: STUDENTS. Total moved: 12
# Moved files for word: GREEN. Total moved: 12
# Moved files for word: LIVE. Total moved: 22
# Moved files for word: TOM. Total moved: 12
# Moved files for word: FOUR. Total moved: 24
# Moved files for word: MUSICIANS. Total moved: 22
# Moved files for word: PROGRAMS. Total moved: 24
# Moved files for word: GREGORY. Total moved: 12
# Moved files for word: VERY. Total moved: 12
# Moved files for word: UPBRINGING. Total moved: 12
# Moved files for word: MUSEUM. Total moved: 22
# Moved files for word: ATTACKED. Total moved: 12
# Moved files for word: REMOVAL. Total moved: 12
# Moved files for word: ASHTRAY. Total moved: 12
# Moved files for word: PLACE. Total moved: 24
# Moved files for word: ANSWERS. Total moved: 12
# Moved files for word: HEALTHIER. Total moved: 22
# Moved files for word: GROWING. Total moved: 12
# Moved files for word: GWEN. Total moved: 12
# Moved files for word: REGARDING. Total moved: 12
# Moved files for word: EXAMPLES. Total moved: 50
# Moved files for word: BREAKFAST. Total moved: 24
# Moved files for word: HATS. Total moved: 12
# Moved files for word: OCEAN. Total moved: 22
# Moved files for word: LEARNED. Total moved: 12
# Moved files for word: TWINS. Total moved: 12
# Moved files for word: MERGERS. Total moved: 12
# Moved files for word: SUNSHINE. Total moved: 22
# Moved files for word: INSTRUCTIONS. Total moved: 12
# Moved files for word: STEEP. Total moved: 24
# Moved files for word: USED. Total moved: 12
# Moved files for word: ONTO. Total moved: 12
# Moved files for word: LAY. Total moved: 12
# Moved files for word: THINK. Total moved: 12
# Moved files for word: APRONS. Total moved: 12
# Moved files for word: HOLIDAY. Total moved: 12
# Moved files for word: CAREFULLY. Total moved: 12
# Moved files for word: REQUIRED. Total moved: 12
# Moved files for word: POLICY. Total moved: 12
# Moved files for word: GRANDMOTHER. Total moved: 12
# Moved files for word: PETTICOATS. Total moved: 12
# Moved files for word: RARE. Total moved: 12
# Moved files for word: WHO. Total moved: 12
# Moved files for word: BIKE. Total moved: 12
# Moved files for word: FIXED. Total moved: 12
# Moved files for word: RISE. Total moved: 22
# Moved files for word: NOVEL. Total moved: 12
# Moved files for word: BROKEN. Total moved: 12
# Moved files for word: EGGS. Total moved: 24
# Moved files for word: DETERMINATION. Total moved: 12
# Moved files for word: GETTING. Total moved: 12
# Moved files for word: THOSE. Total moved: 46
# Moved files for word: STRAIGHTFORWARD. Total moved: 12
# Moved files for word: SCULPTURE. Total moved: 22
# Moved files for word: ATTENDANCE. Total moved: 12
# Moved files for word: TOOK. Total moved: 12
# Moved files for word: FELT. Total moved: 12
# Moved files for word: HIRES. Total moved: 12
# Moved files for word: TODD. Total moved: 12
# Moved files for word: WORD. Total moved: 12
# Moved files for word: COINS. Total moved: 12
# Moved files for word: SUITABLE. Total moved: 24
# Moved files for word: ANKLE. Total moved: 12
# Moved files for word: BRIGHT. Total moved: 22
#
# Total words processed with files moved: 147

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

source_dir = "../../../models/DC-TCN/datasets/ouluvs2_words_v2"
train_count = 0
val_count = 0
test_count = 0
moved = 0
for word in problematic_words.index:
    word_folder = os.path.join(source_dir, word)
    
    if os.path.isdir(word_folder):
        train_folder = os.path.join(word_folder, 'train')
        val_folder = os.path.join(word_folder, 'val')
        test_folder = os.path.join(word_folder, 'test')

        os.makedirs(train_folder, exist_ok=True)
        os.makedirs(val_folder, exist_ok=True)
        os.makedirs(test_folder, exist_ok=True)

        video_files = [f for f in os.listdir(train_folder) if f.endswith('.npz')]
        
        if len(video_files) > 1:
            # Split into train (70%), val (15%), test (15%)
            train_files, temp_files = train_test_split(video_files, test_size=0.3, random_state=42)
            val_files, test_files = train_test_split(temp_files, test_size=0.5, random_state=42)
        else:
            continue
            train_files, val_files, test_files = video_files, [], []  # Keep everything in train if only one file

        # Move files
        for split, file_list, dest_folder in [('train', train_files, train_folder),
                                              ('val', val_files, val_folder),
                                              ('test', test_files, test_folder)]:
            for file in file_list:
                src_video = os.path.join(train_folder, file)
                dst_video = os.path.join(dest_folder, file)
                shutil.move(src_video, dst_video)

                txt_file = file.replace('.npz', '.txt')
                src_txt = os.path.join(train_folder, txt_file)
                dst_txt = os.path.join(dest_folder, txt_file)

                if os.path.exists(src_txt):
                    shutil.move(src_txt, dst_txt)

                if split == 'train':
                    train_count += 1
                elif split == 'val':
                    val_count += 1
                elif split == 'test':
                    test_count += 1

        print(f"Processed {word_folder} - Train: {len(train_files)}, Val: {len(val_files)}, Test: {len(test_files)}")
        moved += 1

print("✅ Done! Processed: ", moved)
# Out:
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/CHOSE - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/PLACED - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/FEW - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/HUGE - Train: 10, Val: 2, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/CARTOONS - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/WASTE - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/CLAY - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/BEANS - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/THROUGH - Train: 17, Val: 4, Test: 4
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/PRIORITY - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/GENERALS - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/HOURS - Train: 21, Val: 4, Test: 5
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/ORGANIZATIONS - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/ILLUMINATING - Train: 17, Val: 4, Test: 4
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/IDENTICAL - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/DECORATE - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/ADDITION - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/CLASSROOMS - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/GARDEN - Train: 21, Val: 4, Test: 5
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/BOX - Train: 21, Val: 4, Test: 5
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/CONSUMING - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/CREATE - Train: 17, Val: 4, Test: 4
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/KEEP - Train: 17, Val: 4, Test: 4
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/COMPILE - Train: 14, Val: 3, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/BOWL - Train: 10, Val: 2, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/MAKES - Train: 14, Val: 3, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/VEGETABLE - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/ENTER - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/HANDBAG - Train: 14, Val: 3, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/REGULAR - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/CIGARETTES - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/SUGAR - Train: 10, Val: 2, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/STEVE - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/ECONOMIC - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/SPRAINED - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/ATE - Train: 14, Val: 3, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/NEGLECT - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/BUSINESS - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/STOLE - Train: 17, Val: 4, Test: 4
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/FASHION - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/SLOPE - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/EXTRA - Train: 21, Val: 4, Test: 5
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/GARDENS - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/YOUNG - Train: 14, Val: 3, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/LEATHER - Train: 14, Val: 3, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/GOOSE - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/STRAW - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/CHILDREN - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/OVERFLOWED - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/KINDERGARTEN - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/TAPESTRY - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/AFTERNOON - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/WITHOUT - Train: 17, Val: 4, Test: 4
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/GROWS - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/HALLWAY - Train: 10, Val: 2, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/RABBITS - Train: 10, Val: 2, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/HOLIDAYS - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/DIAGRAM - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/SHOWERS - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/PRICE - Train: 14, Val: 3, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/DIME - Train: 17, Val: 4, Test: 4
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/SHOULDER - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/CUTBACKS - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/SHIMMERS - Train: 10, Val: 2, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/CYCLICAL - Train: 14, Val: 3, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/OVER - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/REMEMBER - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/TOP - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/SUBTRACTION - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/OAK - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/CATASTROPHIC - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/TRISH - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/GEORGE - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/FIRST - Train: 14, Val: 3, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/CONFIRM - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/MANY - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/COOK - Train: 10, Val: 2, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/HUNG - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/OUTGREW - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/SKILLS - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/SENSE - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/COLLECTS - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/AFTER - Train: 10, Val: 2, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/STUDENTS - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/GREEN - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/LIVE - Train: 10, Val: 2, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/TOM - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/FOUR - Train: 14, Val: 3, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/MUSICIANS - Train: 10, Val: 2, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/PROGRAMS - Train: 14, Val: 3, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/GREGORY - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/VERY - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/UPBRINGING - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/MUSEUM - Train: 10, Val: 2, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/ATTACKED - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/REMOVAL - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/ASHTRAY - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/PLACE - Train: 14, Val: 3, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/ANSWERS - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/HEALTHIER - Train: 10, Val: 2, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/GROWING - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/GWEN - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/REGARDING - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/EXAMPLES - Train: 31, Val: 7, Test: 7
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/BREAKFAST - Train: 14, Val: 3, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/HATS - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/OCEAN - Train: 10, Val: 2, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/LEARNED - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/TWINS - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/MERGERS - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/SUNSHINE - Train: 10, Val: 2, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/INSTRUCTIONS - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/STEEP - Train: 14, Val: 3, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/USED - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/ONTO - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/LAY - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/THINK - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/APRONS - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/HOLIDAY - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/CAREFULLY - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/REQUIRED - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/POLICY - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/GRANDMOTHER - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/PETTICOATS - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/RARE - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/WHO - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/BIKE - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/FIXED - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/RISE - Train: 10, Val: 2, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/NOVEL - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/BROKEN - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/EGGS - Train: 14, Val: 3, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/DETERMINATION - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/GETTING - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/THOSE - Train: 24, Val: 5, Test: 6
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/STRAIGHTFORWARD - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/SCULPTURE - Train: 10, Val: 2, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/ATTENDANCE - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/TOOK - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/FELT - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/HIRES - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/TODD - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/WORD - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/COINS - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/SUITABLE - Train: 14, Val: 3, Test: 3
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/ANKLE - Train: 7, Val: 1, Test: 2
# Processed ../../../models/DC-TCN/datasets/ouluvs2_words_v2/BRIGHT - Train: 10, Val: 2, Test: 3
# ✅ Done! Processed:  147

# %%
v3_df = create_df("../../../models/DC-TCN/datasets/ouluvs2_words_v2")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 v3_df = create_df("../../../models/DC-TCN/datasets/ouluvs2_words_v2")
#
# NameError: name 'create_df' is not defined

# %%
# Find words where test or val count is higher than train
v3_problematic_words = v3_df[(v3_df['test'] >= v3_df['train']) | (v3_df['val'] >= v3_df['train'])]

print("Problematic words:\n", v3_problematic_words[['train', 'val', 'test']])
# Out:
# Problematic words:
#  Empty DataFrame
# Columns: [train, val, test]
# Index: []

# %%
v3_total_versions_per_split = {split: {version: v3_df[version].apply(lambda x: x.get(split, 0)).sum() for version in version_columns} for split in split_columns}

print("Total counts for each version per split:")
for split, versions in v3_total_versions_per_split.items():
    print(f"\n{split.capitalize()}:")
    for version, count in versions.items():
        print(f"  {version}: {count}")
# Out:
# Total counts for each version per split:
#
# Train:
#   v1: 4867
#   v2: 4955
#   v3: 4921
#   v4: 4926
#   v5: 4959
#
# Val:
#   v1: 1211
#   v2: 1182
#   v3: 1201
#   v4: 1189
#   v5: 1168
#
# Test:
#   v1: 1794
#   v2: 1736
#   v3: 1750
#   v4: 1757
#   v5: 1746

# %%
v3_total_train = v3_df['train'].sum()
v3_total_val = v3_df['val'].sum()
v3_total_test = v3_df['test'].sum()

print(f"Total train: {v3_total_train}")
print(f"Total val: {v3_total_val}")
print(f"Total test: {v3_total_test}")
# Out:
# Total train: 24628
# Total val: 5951
# Total test: 8783

# %%
# Find words where test or val count is higher than train
v3_problematic_words = v3_df[(v3_df['test'] > (v3_df['val'] + 1))]

print("Problematic words:\n", v3_problematic_words[['train', 'val', 'test']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Find words where test or val count is higher than train
# ----> 2 v3_problematic_words = v3_df[(v3_df['test'] +1 < (v3_df['val']))]
#       4 print("Problematic words:\n", v3_problematic_words[['train', 'val', 'test']])
#
# NameError: name 'v3_df' is not defined

# %%
print(v3_problematic_words.index)
# Out:
# Index(['GUNPOINT', 'THAT', 'MOISTURE', 'ASSUME', 'YOUR', 'LARGER', 'DAMAGE',
#        'THIN', 'JUICE', 'PLEASE',
#        ...
#        'SLIPPED', 'HER', 'THIEVES', 'NOTICES', 'INTO', 'IN', 'THOMAS', 'AM',
#        'EARLY', 'THIS'],
#       dtype='object', length=193)

# %%
import os
import shutil
import random

source_dir = "../../../models/DC-TCN/datasets/ouluvs2_words_dupe_v2"

moved = 0
for word in v4_problematic_words.index:
    word_folder = os.path.join(source_dir, word)
    moved_files = 0
    
    if os.path.exists(word_folder):
        train_folder = os.path.join(word_folder, 'train')
        val_folder = os.path.join(word_folder, 'val')
        test_folder = os.path.join(word_folder, 'test')
        
        if not os.path.exists(train_folder):
            os.makedirs(train_folder)
        
        num_val = len([f for f in os.listdir(val_folder) if f.endswith('.npz')]) if os.path.exists(val_folder) else 0
        num_test = len([f for f in os.listdir(test_folder) if f.endswith('.npz')]) if os.path.exists(test_folder) else 0
        
        files_needed = max(0, num_test - num_val)

        if files_needed > 0:
            test_files = [f for f in os.listdir(test_folder) if f.endswith('.npz')]
            if len(test_files) > files_needed:
                test_files = random.sample(test_files, files_needed)  # Randomly select files
            
            for npz_file in test_files:
                npz_path = os.path.join(test_folder, npz_file)
                txt_path = npz_path.replace('.npz', '.txt')
                
                shutil.move(npz_path, os.path.join(train_folder, npz_file))
                moved_files += 1
                
                if os.path.exists(txt_path):
                    shutil.move(txt_path, os.path.join(train_folder, os.path.basename(txt_path)))
                    moved_files += 1
        
        if moved_files > 0:
            moved += 1
            print(f"Moved {moved_files} files for word: {word}")
    else:
        print(f"Word folder not found: {word_folder}")

print(f"\nTotal words processed with files moved: {moved}")
# Out:
# Moved 6 files for word: GUNPOINT
# Moved 26 files for word: THAT
# Moved 6 files for word: MOISTURE
# Moved 6 files for word: ASSUME
# Moved 22 files for word: YOUR
# Moved 6 files for word: LARGER
# Moved 6 files for word: DAMAGE
# Moved 6 files for word: THIN
# Moved 4 files for word: JUICE
# Moved 14 files for word: PLEASE
# Moved 14 files for word: WATCH
# Moved 8 files for word: IF
# Moved 14 files for word: WHENEVER
# Moved 6 files for word: SOYBEANS
# Moved 6 files for word: SHOCKED
# Moved 4 files for word: THINKS
# Moved 6 files for word: JEWELS
# Moved 14 files for word: OUR
# Moved 4 files for word: ABOUT
# Moved 14 files for word: HAND
# Moved 6 files for word: TWICE
# Moved 16 files for word: IT
# Moved 10 files for word: WITH
# Moved 4 files for word: TAXICAB
# Moved 14 files for word: ACHES
# Moved 244 files for word: A
# Moved 4 files for word: DROP
# Moved 6 files for word: FROM
# Moved 4 files for word: TABLE
# Moved 6 files for word: ANSWER
# Moved 6 files for word: SUGGESTION
# Moved 6 files for word: RACCOONS
# Moved 10 files for word: GIFT
# Moved 4 files for word: STUDY
# Moved 6 files for word: PROCESSED
# Moved 6 files for word: MY
# Moved 6 files for word: ACCOMPLISHED
# Moved 6 files for word: NIGHT
# Moved 6 files for word: SHEILA
# Moved 6 files for word: SELDOM
# Moved 40 files for word: OF
# Moved 14 files for word: JUST
# Moved 6 files for word: WIRE
# Moved 14 files for word: PRESSURE
# Moved 28 files for word: WILL
# Moved 6 files for word: SYSTEM
# Moved 6 files for word: UNDER
# Moved 14 files for word: PROJECT
# Moved 4 files for word: ANY
# Moved 98 files for word: HOW
# Moved 6 files for word: TRY
# Moved 8 files for word: DEVELOPMENT
# Moved 6 files for word: NEVER
# Moved 18 files for word: WOULD
# Moved 4 files for word: THREE
# Moved 6 files for word: THIRTY
# Moved 14 files for word: CHANGES
# Moved 4 files for word: PATHOLOGICAL
# Moved 4 files for word: BROTHER
# Moved 6 files for word: AWAY
# Moved 6 files for word: QUESTION
# Moved 24 files for word: HIS
# Moved 32 files for word: AS
# Moved 4 files for word: PAYS
# Moved 6 files for word: DRINK
# Moved 6 files for word: THANKSGIVING
# Moved 4 files for word: DANNY
# Moved 112 files for word: ME
# Moved 28 files for word: HE
# Moved 120 files for word: GOODBYE
# Moved 14 files for word: SAW
# Moved 6 files for word: BEFORE
# Moved 6 files for word: FAILURE
# Moved 6 files for word: GUNMAN
# Moved 6 files for word: WALL
# Moved 6 files for word: SOLVES
# Moved 4 files for word: ORANGE
# Moved 14 files for word: BAROMETRIC
# Moved 10 files for word: WERE
# Moved 6 files for word: HORSERADISH
# Moved 14 files for word: ELSE
# Moved 6 files for word: TOFU
# Moved 6 files for word: ANNOYING
# Moved 6 files for word: COLORFUL
# Moved 6 files for word: REPAINTED
# Moved 26 files for word: IS
# Moved 24 files for word: EVERY
# Moved 22 files for word: NEAR
# Moved 14 files for word: CAN
# Moved 6 files for word: TAKES
# Moved 6 files for word: EIGHT
# Moved 4 files for word: BROKE
# Moved 10 files for word: AND
# Moved 10 files for word: CREAM
# Moved 20 files for word: BIG
# Moved 6 files for word: SLOWLY
# Moved 120 files for word: THANK
# Moved 18 files for word: MOST
# Moved 6 files for word: EVENTS
# Moved 4 files for word: QUALITY
# Moved 20 files for word: NOT
# Moved 6 files for word: TOOTHPASTE
# Moved 6 files for word: COST
# Moved 22 files for word: RIGHT
# Moved 116 files for word: I
# Moved 6 files for word: COACH
# Moved 14 files for word: CAUSED
# Moved 128 files for word: TIME
# Moved 38 files for word: FOR
# Moved 224 files for word: ARE
# Moved 6 files for word: RODENTS
# Moved 6 files for word: CLAMP
# Moved 116 files for word: MEET
# Moved 126 files for word: SEE
# Moved 6 files for word: TEAM
# Moved 6 files for word: SURPLUS
# Moved 6 files for word: FEATHERS
# Moved 6 files for word: SOLD
# Moved 6 files for word: DISCOUNT
# Moved 126 files for word: THE
# Moved 14 files for word: HIGH
# Moved 4 files for word: DID
# Moved 4 files for word: OTHERS
# Moved 38 files for word: ALL
# Moved 142 files for word: HAVE
# Moved 16 files for word: EACH
# Moved 6 files for word: ORDER
# Moved 6 files for word: HULL
# Moved 6 files for word: RELISH
# Moved 6 files for word: CORY
# Moved 6 files for word: YEAR
# Moved 4 files for word: AVAILABLE
# Moved 14 files for word: MOVIES
# Moved 6 files for word: STORE
# Moved 6 files for word: FOOTBALL
# Moved 120 files for word: EXCUSE
# Moved 6 files for word: OCCURS
# Moved 4 files for word: AT
# Moved 6 files for word: DUCKS
# Moved 14 files for word: LARGE
# Moved 12 files for word: LONG
# Moved 8 files for word: PEOPLE
# Moved 6 files for word: CAST
# Moved 6 files for word: DEPARTURE
# Moved 4 files for word: OFTEN
# Moved 4 files for word: OPEN
# Moved 6 files for word: WEEK
# Moved 4 files for word: POPULARITY
# Moved 4 files for word: CLOTHING
# Moved 6 files for word: SUDDEN
# Moved 18 files for word: EASY
# Moved 126 files for word: GOOD
# Moved 6 files for word: GOVERNMENT
# Moved 588 files for word: YOU
# Moved 118 files for word: WELCOME
# Moved 6 files for word: CORNERED
# Moved 120 files for word: HELLO
# Moved 6 files for word: CALICO
# Moved 180 files for word: TO
# Moved 6 files for word: CAT
# Moved 6 files for word: MORNING
# Moved 4 files for word: HOT
# Moved 6 files for word: JOB
# Moved 4 files for word: NEED
# Moved 6 files for word: CHRONOLOGICAL
# Moved 6 files for word: TIM
# Moved 120 files for word: SORRY
# Moved 6 files for word: ARM
# Moved 6 files for word: DOOR
# Moved 6 files for word: FEET
# Moved 6 files for word: OBTAIN
# Moved 6 files for word: GUESS
# Moved 6 files for word: BEST
# Moved 14 files for word: THEY
# Moved 6 files for word: NOW
# Moved 6 files for word: RECALL
# Moved 6 files for word: SWING
# Moved 6 files for word: WEBBED
# Moved 4 files for word: JAM
# Moved 138 files for word: NICE
# Moved 12 files for word: ONLY
# Moved 6 files for word: VICTIM
# Moved 6 files for word: PROCEEDING
# Moved 14 files for word: SLIPPED
# Moved 56 files for word: HER
# Moved 6 files for word: THIEVES
# Moved 6 files for word: NOTICES
# Moved 12 files for word: INTO
# Moved 14 files for word: IN
# Moved 6 files for word: THOMAS
# Moved 118 files for word: AM
# Moved 8 files for word: EARLY
# Moved 8 files for word: THIS
#
# Total words processed with files moved: 193

# %%
v4_df = create_df("../../../models/DC-TCN/datasets/ouluvs2_words_dupe_v2")

# %%
v4_total_train = v4_df['train'].sum()
v4_total_val = v4_df['val'].sum()
v4_total_test = v4_df['test'].sum()

print(f"Total train: {v4_total_train}")
print(f"Total val: {v4_total_val}")
print(f"Total test: {v4_total_test}")
# Out:
# Total train: 27088
# Total val: 5951
# Total test: 6323

# %%
v4_problematic_words = v4_df[(v4_df['test'] > (v4_df['val'] + 1))]

print("Problematic words:\n", v4_problematic_words[['train', 'val', 'test']])
# Out:
# Problematic words:
#  Empty DataFrame
# Columns: [train, val, test]
# Index: []

# %%
version_columns = ['v1', 'v2', 'v3', 'v4', 'v5']
split_columns = ['train', 'val', 'test']
v4_total_versions_per_split = {split: {version: v4_df[version].apply(lambda x: x.get(split, 0)).sum() for version in version_columns} for split in split_columns}

print("Total counts for each version per split:")
for split, versions in v4_total_versions_per_split.items():
    print(f"\n{split.capitalize()}:")
    for version, count in versions.items():
        print(f"  {version}: {count}")
# Out:
# Total counts for each version per split:
#
# Train:
#   v1: 5362
#   v2: 5450
#   v3: 5388
#   v4: 5454
#   v5: 5434
#
# Val:
#   v1: 1211
#   v2: 1182
#   v3: 1201
#   v4: 1189
#   v5: 1168
#
# Test:
#   v1: 1299
#   v2: 1241
#   v3: 1283
#   v4: 1229
#   v5: 1271

# %%
v4_total_train_zeros = (v4_df['train'] == 0).sum()
v4_total_val_zeros = (v4_df['val'] == 0).sum()
v4_total_test_zeros = (v4_df['test'] == 0).sum()

print(f"\nTotal V4 train = 0: {v4_total_train_zeros}")
print(f"Total V4 val = 0: {v4_total_val_zeros}")
print(f"Total V4 test = 0: {v4_total_test_zeros}")
# Out:
# Total V4 train = 0: 0
# Total V4 val = 0: 0
# Total V4 test = 0: 0

# %%
print("\nWord and File Counts per Subfolder and Versions:")

pd.set_option('display.max_rows', None)
print(v4_df)
# Out:
# Word and File Counts per Subfolder and Versions:
#                  train  val  test                                       v1  \
# GUNPOINT            11    2     2        {'train': 3, 'val': 0, 'test': 0}
# THEIR               24    6     5        {'train': 6, 'val': 0, 'test': 1}
# PROVOKED             3    1     1        {'train': 1, 'val': 0, 'test': 0}
# CLEANERS             3    1     1        {'train': 0, 'val': 1, 'test': 0}
# CHOSE                7    1     2        {'train': 1, 'val': 0, 'test': 1}
# UNTIL               10    2     3        {'train': 2, 'val': 0, 'test': 1}
# PLACED               7    1     2        {'train': 2, 'val': 0, 'test': 0}
# BACKED               3    1     1        {'train': 0, 'val': 0, 'test': 1}
# ACCORDING            7    1     2        {'train': 2, 'val': 0, 'test': 0}
# CHIP                10    2     3        {'train': 2, 'val': 0, 'test': 1}
# SPLINTER             3    1     1        {'train': 1, 'val': 0, 'test': 0}
# FREQUENTLY          16    4     5        {'train': 2, 'val': 2, 'test': 1}
# THAT                41    7     7        {'train': 8, 'val': 1, 'test': 2}
# TECHNIQUES          16    4     5        {'train': 3, 'val': 1, 'test': 1}
# CLEAR                7    1     2        {'train': 1, 'val': 1, 'test': 0}
# MOISTURE            11    2     2        {'train': 3, 'val': 0, 'test': 0}
# WITHDRAW             3    1     1        {'train': 1, 'val': 0, 'test': 0}
# OUTCOME              7    1     2        {'train': 1, 'val': 1, 'test': 0}
# EVEN                14    3     3        {'train': 4, 'val': 0, 'test': 0}
# STRAY                3    1     1        {'train': 1, 'val': 0, 'test': 0}
# BLOCK                7    1     2        {'train': 1, 'val': 0, 'test': 1}
# GLUE                 3    1     1        {'train': 0, 'val': 1, 'test': 0}
# EMPEROR              3    1     1        {'train': 1, 'val': 0, 'test': 0}
# SAUCE                7    1     2        {'train': 1, 'val': 0, 'test': 1}
# FEW                  7    1     2        {'train': 2, 'val': 0, 'test': 0}
# ASSUME              11    2     2        {'train': 1, 'val': 1, 'test': 1}
# YOUR                47    9     9       {'train': 10, 'val': 1, 'test': 2}
# BEGIN                7    1     2        {'train': 1, 'val': 0, 'test': 1}
# BONGOS              10    2     3        {'train': 2, 'val': 0, 'test': 1}
# EXPRESSION           3    1     1        {'train': 0, 'val': 0, 'test': 1}
# CAMP                 3    1     1        {'train': 0, 'val': 1, 'test': 0}
# FARMLAND             3    1     1        {'train': 0, 'val': 0, 'test': 1}
# TUBE                10    2     3        {'train': 1, 'val': 0, 'test': 2}
# HOME                 7    1     2        {'train': 2, 'val': 0, 'test': 0}
# FORCE                3    1     1        {'train': 1, 'val': 0, 'test': 0}
# FORGERY              3    1     1        {'train': 1, 'val': 0, 'test': 0}
# SPIDER              17    4     4        {'train': 2, 'val': 0, 'test': 3}
# ZIRCONS              7    1     2        {'train': 2, 'val': 0, 'test': 0}
# DISPLAY              3    1     1        {'train': 1, 'val': 0, 'test': 0}
# TOXIC                3    1     1        {'train': 1, 'val': 0, 'test': 0}
# PURE                 7    1     2        {'train': 2, 'val': 0, 'test': 0}
# PREVENTED           10    2     3        {'train': 1, 'val': 1, 'test': 1}
# GET                 32    8     5        {'train': 5, 'val': 3, 'test': 1}
# TEMPER               3    1     1        {'train': 1, 'val': 0, 'test': 0}
# LARGER              11    2     2        {'train': 2, 'val': 0, 'test': 1}
# INGREDIENTS          7    1     2        {'train': 2, 'val': 0, 'test': 0}
# DRAW                 7    1     2        {'train': 1, 'val': 0, 'test': 1}
# DAMAGE              11    2     2        {'train': 3, 'val': 0, 'test': 0}
# CAUGHT               3    1     1        {'train': 1, 'val': 0, 'test': 0}
# HUGE                10    2     3        {'train': 1, 'val': 0, 'test': 2}
# THIN                11    2     2        {'train': 2, 'val': 1, 'test': 0}
# CHOSEN               3    1     1        {'train': 1, 'val': 0, 'test': 0}
# CARTOONS             7    1     2        {'train': 2, 'val': 0, 'test': 0}
# EMPLOYMENT          16    4     5        {'train': 3, 'val': 1, 'test': 1}
# MUSICAL             10    2     3        {'train': 2, 'val': 0, 'test': 1}
# LAST                 3    1     1        {'train': 1, 'val': 0, 'test': 0}
# WASTE                7    1     2        {'train': 1, 'val': 0, 'test': 1}
# JUICE               14    3     3        {'train': 4, 'val': 0, 'test': 0}
# JOHN'S               7    1     2        {'train': 2, 'val': 0, 'test': 0}
# THOUGHT              3    1     1        {'train': 0, 'val': 0, 'test': 1}
# PAPER                7    1     2        {'train': 1, 'val': 0, 'test': 1}
# PLEASE              19    3     3        {'train': 3, 'val': 1, 'test': 1}
# SHIP'S               7    1     2        {'train': 1, 'val': 0, 'test': 1}
# LITHOGRAPHS          3    1     1        {'train': 0, 'val': 1, 'test': 0}
# DISCOURAGING         7    1     2        {'train': 1, 'val': 0, 'test': 1}
# SERVICE              3    1     1        {'train': 0, 'val': 1, 'test': 0}
# WATCH               19    3     3        {'train': 4, 'val': 1, 'test': 0}
# CLAY                 7    1     2        {'train': 1, 'val': 0, 'test': 1}
# COSTUME              7    1     2        {'train': 1, 'val': 0, 'test': 1}
# BE                 104   26    25       {'train': 19, 'val': 7, 'test': 5}
# DEADLINE             3    1     1        {'train': 0, 'val': 0, 'test': 1}
# BEANS                7    1     2        {'train': 1, 'val': 1, 'test': 0}
# IF                  28    6     6        {'train': 7, 'val': 1, 'test': 0}
# COUNTY               3    1     1        {'train': 0, 'val': 0, 'test': 1}
# THROUGH             17    4     4        {'train': 4, 'val': 0, 'test': 1}
# WHENEVER            19    3     3        {'train': 3, 'val': 1, 'test': 1}
# SOYBEANS            11    2     2        {'train': 3, 'val': 0, 'test': 0}
# MONEY               10    2     3        {'train': 1, 'val': 1, 'test': 1}
# SHOCKED             11    2     2        {'train': 3, 'val': 0, 'test': 0}
# THINKS              14    3     3        {'train': 3, 'val': 0, 'test': 1}
# PRIORITY             7    1     2        {'train': 2, 'val': 0, 'test': 0}
# GENERALS             7    1     2        {'train': 2, 'val': 0, 'test': 0}
# CLAMS                3    1     1        {'train': 1, 'val': 0, 'test': 0}
# DRUGS               10    2     3        {'train': 2, 'val': 0, 'test': 1}
# STAR                10    2     3        {'train': 2, 'val': 0, 'test': 1}
# GIRAFFES             7    1     2        {'train': 1, 'val': 0, 'test': 1}
# MEETING              3    1     1        {'train': 1, 'val': 0, 'test': 0}
# JEWELS              11    2     2        {'train': 0, 'val': 2, 'test': 1}
# JIM                  3    1     1        {'train': 0, 'val': 1, 'test': 0}
# ANSWERED             7    1     2        {'train': 1, 'val': 0, 'test': 1}
# OUR                 19    3     3        {'train': 3, 'val': 1, 'test': 1}
# UNEXPECTED           7    1     2        {'train': 2, 'val': 0, 'test': 0}
# SPEECH               7    1     2        {'train': 1, 'val': 0, 'test': 1}
# SAVE                10    2     3        {'train': 1, 'val': 1, 'test': 1}
# PARANOID             3    1     1        {'train': 0, 'val': 0, 'test': 1}
# THINNER              3    1     1        {'train': 1, 'val': 0, 'test': 0}
# EQUAL                7    1     2        {'train': 1, 'val': 1, 'test': 0}
# HOURS               21    4     5        {'train': 5, 'val': 1, 'test': 0}
# ABOUT               14    3     3        {'train': 3, 'val': 0, 'test': 1}
# THING                3    1     1        {'train': 1, 'val': 0, 'test': 0}
# DOCUMENTS            7    1     2        {'train': 2, 'val': 0, 'test': 0}
# HAND                19    3     3        {'train': 4, 'val': 1, 'test': 0}
# ORGANIZATIONS        7    1     2        {'train': 1, 'val': 1, 'test': 0}
# TWICE               11    2     2        {'train': 1, 'val': 1, 'test': 1}
# UNTIMELY             3    1     1        {'train': 1, 'val': 0, 'test': 0}
# MORE                14    3     3        {'train': 2, 'val': 1, 'test': 1}
# IT                  36    7     7        {'train': 8, 'val': 0, 'test': 2}
# BRUSH                3    1     1        {'train': 0, 'val': 1, 'test': 0}
# SHIPBUILDING         7    1     2        {'train': 2, 'val': 0, 'test': 0}
# PINE                 3    1     1        {'train': 1, 'val': 0, 'test': 0}
# COURSE               7    1     2        {'train': 1, 'val': 0, 'test': 1}
# HIM                 24    6     5        {'train': 4, 'val': 2, 'test': 1}
# ALONG                3    1     1        {'train': 0, 'val': 1, 'test': 0}
# OIL                 10    2     3        {'train': 2, 'val': 1, 'test': 0}
# JAW                  3    1     1        {'train': 0, 'val': 0, 'test': 1}
# WITH                65   15    15       {'train': 13, 'val': 3, 'test': 3}
# AUTHORS              3    1     1        {'train': 1, 'val': 0, 'test': 0}
# PIE                  7    1     2        {'train': 1, 'val': 1, 'test': 0}
# TAXICAB             14    3     3        {'train': 3, 'val': 0, 'test': 1}
# ACHES               19    3     3        {'train': 4, 'val': 1, 'test': 0}
# DRIVING              3    1     1        {'train': 1, 'val': 0, 'test': 0}
# NATIONAL             3    1     1        {'train': 0, 'val': 1, 'test': 0}
# TOMBOY               3    1     1        {'train': 1, 'val': 0, 'test': 0}
# DOLPHINS            14    3     3        {'train': 3, 'val': 1, 'test': 0}
# DEW                 17    4     4        {'train': 3, 'val': 1, 'test': 1}
# GROUNDHOG            7    1     2        {'train': 0, 'val': 1, 'test': 1}
# OWN                  3    1     1        {'train': 0, 'val': 0, 'test': 1}
# A                  854  183   183    {'train': 170, 'val': 40, 'test': 34}
# FLAG                 3    1     1        {'train': 0, 'val': 0, 'test': 1}
# ILLUMINATING        17    4     4        {'train': 3, 'val': 1, 'test': 1}
# LUNCH                7    1     2        {'train': 1, 'val': 1, 'test': 0}
# VALUES               3    1     1        {'train': 1, 'val': 0, 'test': 0}
# PROCESS              7    1     2        {'train': 2, 'val': 0, 'test': 0}
# IDENTICAL            7    1     2        {'train': 2, 'val': 0, 'test': 0}
# HAS                 28    7     5        {'train': 5, 'val': 2, 'test': 1}
# DECORATE             7    1     2        {'train': 2, 'val': 0, 'test': 0}
# NONPROFIT            3    1     1        {'train': 1, 'val': 0, 'test': 0}
# EATING               3    1     1        {'train': 1, 'val': 0, 'test': 0}
# PLOW                 3    1     1        {'train': 0, 'val': 1, 'test': 0}
# FAMOUS               3    1     1        {'train': 1, 'val': 0, 'test': 0}
# BIRTH                3    1     1        {'train': 0, 'val': 0, 'test': 1}
# GUS                  3    1     1        {'train': 0, 'val': 1, 'test': 0}
# PLAY                 3    1     1        {'train': 0, 'val': 0, 'test': 1}
# ADDITION             7    1     2        {'train': 1, 'val': 0, 'test': 1}
# CLASSROOMS           7    1     2        {'train': 2, 'val': 0, 'test': 0}
# POSSIBLE            10    2     3        {'train': 2, 'val': 1, 'test': 0}
# LIGHT               10    2     3        {'train': 2, 'val': 0, 'test': 1}
# SUN                 28    6     6        {'train': 3, 'val': 3, 'test': 2}
# DROP                14    3     3        {'train': 4, 'val': 0, 'test': 0}
# THURSDAYS            3    1     1        {'train': 1, 'val': 0, 'test': 0}
# FROM                91   22    22       {'train': 18, 'val': 5, 'test': 4}
# CLEARLY              7    1     2        {'train': 2, 'val': 0, 'test': 0}
# TOMORROW             3    1     1        {'train': 0, 'val': 1, 'test': 0}
# ENTERTAINING         7    1     2        {'train': 2, 'val': 0, 'test': 0}
# TRAFFIC             16    4     5        {'train': 3, 'val': 1, 'test': 1}
# DRY                  3    1     1        {'train': 1, 'val': 0, 'test': 0}
# GARDEN              21    4     5        {'train': 5, 'val': 0, 'test': 1}
# CO                   7    1     2        {'train': 2, 'val': 0, 'test': 0}
# BOX                 21    4     5        {'train': 4, 'val': 1, 'test': 1}
# CONSUMING            7    1     2        {'train': 2, 'val': 0, 'test': 0}
# ANOTHER              7    1     2        {'train': 2, 'val': 0, 'test': 0}
# TABLE               14    3     3        {'train': 3, 'val': 0, 'test': 1}
# RECORDS             14    3     3        {'train': 3, 'val': 0, 'test': 1}
# ZOO                  3    1     1        {'train': 0, 'val': 0, 'test': 1}
# GOLD                 3    1     1        {'train': 1, 'val': 0, 'test': 0}
# ANSWER              11    2     2        {'train': 1, 'val': 1, 'test': 1}
# BEGAN                3    1     1        {'train': 0, 'val': 1, 'test': 0}
# MAINTENANCE          7    1     2        {'train': 2, 'val': 0, 'test': 0}
# EVALUATE             3    1     1        {'train': 0, 'val': 1, 'test': 0}
# AROUND               3    1     1        {'train': 1, 'val': 0, 'test': 0}
# SUGGESTION          11    2     2        {'train': 3, 'val': 0, 'test': 0}
# FAWN                 3    1     1        {'train': 1, 'val': 0, 'test': 0}
# INCOME               3    1     1        {'train': 1, 'val': 0, 'test': 0}
# CHOICES              7    1     2        {'train': 1, 'val': 0, 'test': 1}
# EARN                 3    1     1        {'train': 0, 'val': 1, 'test': 0}
# TRADITION            7    1     2        {'train': 2, 'val': 0, 'test': 0}
# CREATE              17    4     4        {'train': 5, 'val': 0, 'test': 0}
# KIDNAPPERS           3    1     1        {'train': 1, 'val': 0, 'test': 0}
# RACCOONS            11    2     2        {'train': 2, 'val': 1, 'test': 0}
# GIFT                25    5     5        {'train': 5, 'val': 1, 'test': 1}
# PERPENDICULAR        7    1     2        {'train': 2, 'val': 0, 'test': 0}
# YOUNGSTERS          10    2     3        {'train': 2, 'val': 0, 'test': 1}
# FAILS                3    1     1        {'train': 0, 'val': 0, 'test': 1}
# WHEN                32    8     5        {'train': 8, 'val': 0, 'test': 1}
# JEFF                 3    1     1        {'train': 0, 'val': 1, 'test': 0}
# GETS                 3    1     1        {'train': 0, 'val': 1, 'test': 0}
# MARINE              14    3     3        {'train': 2, 'val': 1, 'test': 1}
# ALICE'S              3    1     1        {'train': 1, 'val': 0, 'test': 0}
# CHURCH              10    2     3        {'train': 1, 'val': 1, 'test': 1}
# STUDY               14    3     3        {'train': 3, 'val': 1, 'test': 0}
# THEY'RE              3    1     1        {'train': 0, 'val': 1, 'test': 0}
# ROSES               10    2     3        {'train': 1, 'val': 0, 'test': 2}
# LATEST              10    2     3        {'train': 2, 'val': 0, 'test': 1}
# JOURNAL              3    1     1        {'train': 1, 'val': 0, 'test': 0}
# KEEP                17    4     4        {'train': 3, 'val': 0, 'test': 2}
# ALGEBRAIC            3    1     1        {'train': 1, 'val': 0, 'test': 0}
# TODDLER              3    1     1        {'train': 1, 'val': 0, 'test': 0}
# CLIFF                7    1     2        {'train': 2, 'val': 0, 'test': 0}
# FAIL                10    2     3        {'train': 2, 'val': 0, 'test': 1}
# UPDATING             3    1     1        {'train': 1, 'val': 0, 'test': 0}
# MUSKRAT              3    1     1        {'train': 0, 'val': 1, 'test': 0}
# STANDBY              3    1     1        {'train': 0, 'val': 1, 'test': 0}
# PROCESSED           11    2     2        {'train': 2, 'val': 0, 'test': 1}
# EDGE                 3    1     1        {'train': 0, 'val': 1, 'test': 0}
# COMPILE             14    3     3        {'train': 3, 'val': 1, 'test': 0}
# PLANNED              3    1     1        {'train': 1, 'val': 0, 'test': 0}
# MUST                17    4     4        {'train': 3, 'val': 1, 'test': 1}
# CHEATING             3    1     1        {'train': 1, 'val': 0, 'test': 0}
# DISCUSSIONS          3    1     1        {'train': 1, 'val': 0, 'test': 0}
# COFFEE               7    1     2        {'train': 2, 'val': 0, 'test': 0}
# PLEASANTLY           7    1     2        {'train': 2, 'val': 0, 'test': 0}
# SHADOW               7    1     2        {'train': 2, 'val': 0, 'test': 0}
# FOG                 10    2     3        {'train': 2, 'val': 0, 'test': 1}
# ARRIVING            10    2     3        {'train': 2, 'val': 1, 'test': 0}
# SAFARI               7    1     2        {'train': 2, 'val': 0, 'test': 0}
# WELFARE              7    1     2        {'train': 1, 'val': 0, 'test': 1}
# JOYCE                3    1     1        {'train': 1, 'val': 0, 'test': 0}
# FOAM                 7    1     2        {'train': 0, 'val': 1, 'test': 1}
# FREEWAY              3    1     1        {'train': 1, 'val': 0, 'test': 0}
# NEEDS               17    4     4        {'train': 5, 'val': 0, 'test': 0}
# DUTCH                3    1     1        {'train': 0, 'val': 1, 'test': 0}
# EASTERN              7    1     2        {'train': 2, 'val': 0, 'test': 0}
# JIMS                 7    1     2        {'train': 1, 'val': 1, 'test': 0}
# PROMOTE              3    1     1        {'train': 0, 'val': 0, 'test': 1}
# SURVEY               3    1     1        {'train': 1, 'val': 0, 'test': 0}
# MY                  31    7     7        {'train': 6, 'val': 2, 'test': 1}
# MASSAGE              7    1     2        {'train': 1, 'val': 0, 'test': 1}
# NINE                24    6     5        {'train': 4, 'val': 2, 'test': 1}
# GIANT                7    1     2        {'train': 1, 'val': 0, 'test': 1}
# ARTISTS             16    4     5        {'train': 4, 'val': 0, 'test': 1}
# ACCOMPLISHED        11    2     2        {'train': 2, 'val': 1, 'test': 0}
# SURE                 3    1     1        {'train': 0, 'val': 0, 'test': 1}
# NIGHT               11    2     2        {'train': 2, 'val': 0, 'test': 1}
# ACTIVITIES           3    1     1        {'train': 1, 'val': 0, 'test': 0}
# PENGUINS             3    1     1        {'train': 1, 'val': 0, 'test': 0}
# SHEILA              11    2     2        {'train': 2, 'val': 1, 'test': 0}
# SELDOM              11    2     2        {'train': 3, 'val': 0, 'test': 0}
# NEW                 36    9    10        {'train': 6, 'val': 3, 'test': 2}
# LONGER               3    1     1        {'train': 0, 'val': 1, 'test': 0}
# BRACELET             3    1     1        {'train': 0, 'val': 0, 'test': 1}
# SATURDAY             3    1     1        {'train': 0, 'val': 1, 'test': 0}
# BOWL                10    2     3        {'train': 2, 'val': 0, 'test': 1}
# MAKES               14    3     3        {'train': 2, 'val': 2, 'test': 0}
# FUNDRAISERS          3    1     1        {'train': 1, 'val': 0, 'test': 0}
# OF                 140   30    30       {'train': 26, 'val': 6, 'test': 8}
# CHILD               10    2     3        {'train': 1, 'val': 1, 'test': 1}
# DIFFICULT            7    1     2        {'train': 2, 'val': 0, 'test': 0}
# ITEMIZE              3    1     1        {'train': 0, 'val': 1, 'test': 0}
# INTELLIGENT         14    3     3        {'train': 3, 'val': 1, 'test': 0}
# PERSONNEL            3    1     1        {'train': 0, 'val': 1, 'test': 0}
# JUST                19    3     3        {'train': 3, 'val': 1, 'test': 1}
# VEGETABLE            7    1     2        {'train': 2, 'val': 0, 'test': 0}
# CHALLENGED          14    3     3        {'train': 3, 'val': 0, 'test': 1}
# ENTER                7    1     2        {'train': 1, 'val': 1, 'test': 0}
# COMMON               3    1     1        {'train': 1, 'val': 0, 'test': 0}
# SUCCESS              3    1     1        {'train': 1, 'val': 0, 'test': 0}
# RICH                17    4     4        {'train': 3, 'val': 1, 'test': 1}
# PREVIOUS             3    1     1        {'train': 0, 'val': 0, 'test': 1}
# FINGER               3    1     1        {'train': 0, 'val': 0, 'test': 1}
# INTELLIGENCE         7    1     2        {'train': 2, 'val': 0, 'test': 0}
# LOOKING             16    4     5        {'train': 3, 'val': 1, 'test': 1}
# HANDBAG             14    3     3        {'train': 4, 'val': 0, 'test': 0}
# PRECAUTION           3    1     1        {'train': 1, 'val': 0, 'test': 0}
# ALONE                3    1     1        {'train': 1, 'val': 0, 'test': 0}
# GENEROUS             7    1     2        {'train': 1, 'val': 0, 'test': 1}
# THIMBLE              7    1     2        {'train': 1, 'val': 0, 'test': 1}
# WIRE                11    2     2        {'train': 2, 'val': 1, 'test': 0}
# REGULAR              7    1     2        {'train': 1, 'val': 0, 'test': 1}
# WOOL                 3    1     1        {'train': 1, 'val': 0, 'test': 0}
# GENTLY               7    1     2        {'train': 2, 'val': 0, 'test': 0}
# PRESSURE            19    3     3        {'train': 2, 'val': 2, 'test': 1}
# ICES                 3    1     1        {'train': 0, 'val': 0, 'test': 1}
# LAKE                 3    1     1        {'train': 1, 'val': 0, 'test': 0}
# CORN                10    2     3        {'train': 1, 'val': 0, 'test': 2}
# BLUES                7    1     2        {'train': 2, 'val': 0, 'test': 0}
# CIGARETTES           7    1     2        {'train': 2, 'val': 0, 'test': 0}
# WILL                58   11    11       {'train': 11, 'val': 3, 'test': 2}
# BOY                 10    2     3        {'train': 2, 'val': 0, 'test': 1}
# TEASPOONS            3    1     1        {'train': 1, 'val': 0, 'test': 0}
# SYSTEM              11    2     2        {'train': 2, 'val': 0, 'test': 1}
# WEB                 17    4     4        {'train': 4, 'val': 0, 'test': 1}
# HELP                 7    1     2        {'train': 2, 'val': 0, 'test': 0}
# POPULAR              3    1     1        {'train': 1, 'val': 0, 'test': 0}
# BUNGALOW             7    1     2        {'train': 1, 'val': 0, 'test': 1}
# UNDER               11    2     2        {'train': 1, 'val': 1, 'test': 1}
# WORKING              3    1     1        {'train': 1, 'val': 0, 'test': 0}
# MICROORGANISMS       7    1     2        {'train': 2, 'val': 0, 'test': 0}
# SUGAR               10    2     3        {'train': 3, 'val': 0, 'test': 0}
# STEVE                7    1     2        {'train': 1, 'val': 0, 'test': 1}
# ECONOMIC             7    1     2        {'train': 0, 'val': 1, 'test': 1}
# BIBLICAL             3    1     1        {'train': 0, 'val': 0, 'test': 1}
# ABILITY              3    1     1        {'train': 1, 'val': 0, 'test': 0}
# PROJECT             19    3     3        {'train': 4, 'val': 0, 'test': 1}
# GUARD                3    1     1        {'train': 1, 'val': 0, 'test': 0}
# CAROL                3    1     1        {'train': 0, 'val': 0, 'test': 1}
# VIEW                 3    1     1        {'train': 1, 'val': 0, 'test': 0}
# ANY                 14    3     3        {'train': 3, 'val': 0, 'test': 1}
# HOW                573  131   131    {'train': 112, 'val': 29, 'test': 26}
# TROUBLE              7    1     2        {'train': 1, 'val': 0, 'test': 1}
# CARL                 7    1     2        {'train': 0, 'val': 0, 'test': 2}
# ROGER'S             10    2     3        {'train': 2, 'val': 0, 'test': 1}
# TRY                 11    2     2        {'train': 2, 'val': 1, 'test': 0}
# SPRAINED             7    1     2        {'train': 2, 'val': 0, 'test': 0}
# DEVELOPMENT         28    6     6        {'train': 5, 'val': 2, 'test': 1}
# CRITICAL             7    1     2        {'train': 1, 'val': 0, 'test': 1}
# ATE                 14    3     3        {'train': 3, 'val': 0, 'test': 1}
# ABLY                 3    1     1        {'train': 1, 'val': 0, 'test': 0}
# STIMULATING          3    1     1        {'train': 0, 'val': 1, 'test': 0}
# NEVER               31    7     7        {'train': 5, 'val': 2, 'test': 2}
# NEGLECT              7    1     2        {'train': 2, 'val': 0, 'test': 0}
# WAS                108   27    10      {'train': 17, 'val': 10, 'test': 2}
# BUSINESS             7    1     2        {'train': 1, 'val': 1, 'test': 0}
# PRESENT              3    1     1        {'train': 1, 'val': 0, 'test': 0}
# WANDERED             3    1     1        {'train': 1, 'val': 0, 'test': 0}
# WOULD               53   11    11       {'train': 10, 'val': 3, 'test': 2}
# HEATING              3    1     1        {'train': 0, 'val': 1, 'test': 0}
# MUSCLES              3    1     1        {'train': 0, 'val': 0, 'test': 1}
# STOLE               17    4     4        {'train': 4, 'val': 0, 'test': 1}
# CAMEO                7    1     2        {'train': 1, 'val': 1, 'test': 0}
# EXCLUDED             3    1     1        {'train': 0, 'val': 0, 'test': 1}
# SUBWAY              10    2     3        {'train': 2, 'val': 1, 'test': 0}
# THREE               14    3     3        {'train': 3, 'val': 0, 'test': 1}
# SEVERAL             10    2     3        {'train': 1, 'val': 0, 'test': 2}
# ANGRY                7    1     2        {'train': 0, 'val': 0, 'test': 2}
# LET                  7    1     2        {'train': 1, 'val': 0, 'test': 1}
# SEAMSTRESSES         7    1     2        {'train': 2, 'val': 0, 'test': 0}
# THIRTY              11    2     2        {'train': 3, 'val': 0, 'test': 0}
# NUMBER               3    1     1        {'train': 1, 'val': 0, 'test': 0}
# BANDAGED             3    1     1        {'train': 1, 'val': 0, 'test': 0}
# FASHION              7    1     2        {'train': 1, 'val': 1, 'test': 0}
# GLISTENED           17    4     4        {'train': 3, 'val': 0, 'test': 2}
# LOTS                 7    1     2        {'train': 1, 'val': 0, 'test': 1}
# SLOPE                7    1     2        {'train': 2, 'val': 0, 'test': 0}
# SOOTHED              7    1     2        {'train': 1, 'val': 1, 'test': 0}
# CHANGES             19    3     3        {'train': 4, 'val': 0, 'test': 1}
# PATHOLOGICAL        14    3     3        {'train': 3, 'val': 0, 'test': 1}
# CHAIN                3    1     1        {'train': 1, 'val': 0, 'test': 0}
# GALLON               3    1     1        {'train': 1, 'val': 0, 'test': 0}
# CORRECT              3    1     1        {'train': 1, 'val': 0, 'test': 0}
# EXTRA               21    4     5        {'train': 3, 'val': 2, 'test': 1}
# PARENTHOOD           3    1     1        {'train': 1, 'val': 0, 'test': 0}
# GARDENS              7    1     2        {'train': 1, 'val': 0, 'test': 1}
# YOUNG               14    3     3        {'train': 3, 'val': 1, 'test': 0}
# IDLY                 3    1     1        {'train': 1, 'val': 0, 'test': 0}
# PERMANENT           14    3     3        {'train': 3, 'val': 0, 'test': 1}
# BROTHER             34    8     8        {'train': 7, 'val': 3, 'test': 0}
# AWAY                11    2     2        {'train': 2, 'val': 1, 'test': 0}
# LEATHER             14    3     3        {'train': 2, 'val': 0, 'test': 2}
# GOOSE                7    1     2        {'train': 2, 'val': 0, 'test': 0}
# QUESTION            11    2     2        {'train': 3, 'val': 0, 'test': 0}
# ERRORS               7    1     2        {'train': 2, 'val': 0, 'test': 0}
# STRAW                7    1     2        {'train': 2, 'val': 0, 'test': 0}
# SO                   7    1     2        {'train': 1, 'val': 0, 'test': 1}
# CHILDREN             7    1     2        {'train': 1, 'val': 0, 'test': 1}
# INVEST               7    1     2        {'train': 2, 'val': 0, 'test': 0}
# BECAME               3    1     1        {'train': 1, 'val': 0, 'test': 0}
# PATH                 3    1     1        {'train': 1, 'val': 0, 'test': 0}
# ISOTOPES             7    1     2        {'train': 1, 'val': 0, 'test': 1}
# ANCIENT              3    1     1        {'train': 1, 'val': 0, 'test': 0}
# WELL                 3    1     1        {'train': 1, 'val': 0, 'test': 0}
# AL                   3    1     1        {'train': 1, 'val': 0, 'test': 0}
# THICK                7    1     2        {'train': 2, 'val': 0, 'test': 0}
# OVERFLOWED           7    1     2        {'train': 2, 'val': 0, 'test': 0}
# COW                  3    1     1        {'train': 1, 'val': 0, 'test': 0}
# INTELLIGIBLE         3    1     1        {'train': 1, 'val': 0, 'test': 0}
# COOPERATES           7    1     2        {'train': 1, 'val': 1, 'test': 0}
# RECENT               3    1     1        {'train': 1, 'val': 0, 'test': 0}
# HIS                 84   18    18       {'train': 20, 'val': 1, 'test': 3}
# AS                  92   19    19       {'train': 17, 'val': 4, 'test': 5}
# RUN                 16    4     5        {'train': 2, 'val': 2, 'test': 1}
# KINDERGARTEN         7    1     2        {'train': 2, 'val': 0, 'test': 0}
# ZEBRAS               3    1     1        {'train': 1, 'val': 0, 'test': 0}
# PAYS                14    3     3        {'train': 4, 'val': 0, 'test': 0}
# OPERATES             3    1     1        {'train': 1, 'val': 0, 'test': 0}
# WOMAN                3    1     1        {'train': 1, 'val': 0, 'test': 0}
# STREET               7    1     2        {'train': 2, 'val': 0, 'test': 0}
# DRINK               11    2     2        {'train': 3, 'val': 0, 'test': 0}
# OVERLY               7    1     2        {'train': 1, 'val': 0, 'test': 1}
# LIVELY               7    1     2        {'train': 1, 'val': 1, 'test': 0}
# THANKSGIVING        11    2     2        {'train': 2, 'val': 0, 'test': 1}
# RESCUE               3    1     1        {'train': 1, 'val': 0, 'test': 0}
# BARB                 3    1     1        {'train': 1, 'val': 0, 'test': 0}
# PHIL'S               7    1     2        {'train': 1, 'val': 1, 'test': 0}
# OILY                10    2     3        {'train': 0, 'val': 1, 'test': 2}
# AN                  40   10     5        {'train': 9, 'val': 1, 'test': 1}
# BROTHERS             3    1     1        {'train': 0, 'val': 1, 'test': 0}
# TAPESTRY             7    1     2        {'train': 2, 'val': 0, 'test': 0}
# AFTERNOON            7    1     2        {'train': 2, 'val': 0, 'test': 0}
# DANNY               14    3     3        {'train': 2, 'val': 1, 'test': 1}
# THOUGHTLESS          3    1     1        {'train': 1, 'val': 0, 'test': 0}
# BIRTHDAY            16    4     5        {'train': 3, 'val': 1, 'test': 1}
# ME                 552  124   124    {'train': 107, 'val': 26, 'test': 27}
# UNEVENLY             7    1     2        {'train': 2, 'val': 0, 'test': 0}
# CONSISTS             3    1     1        {'train': 0, 'val': 0, 'test': 1}
# BREAK                7    1     2        {'train': 1, 'val': 0, 'test': 1}
# WITHOUT             17    4     4        {'train': 3, 'val': 2, 'test': 0}
# WRAP                 7    1     2        {'train': 0, 'val': 1, 'test': 1}
# BY                  44   11     5       {'train': 10, 'val': 1, 'test': 1}
# HE                  58   11    11       {'train': 11, 'val': 2, 'test': 3}
# RATIONALIZE          7    1     2        {'train': 2, 'val': 0, 'test': 0}
# SOMETIMES            3    1     1        {'train': 1, 'val': 0, 'test': 0}
# STAB                14    3     3        {'train': 3, 'val': 1, 'test': 0}
# GOODBYE            540  120   120    {'train': 108, 'val': 28, 'test': 20}
# SAW                 19    3     3        {'train': 5, 'val': 0, 'test': 0}
# BUY                 24    6     5        {'train': 5, 'val': 1, 'test': 1}
# LINES                7    1     2        {'train': 2, 'val': 0, 'test': 0}
# GLISTENING           7    1     2        {'train': 1, 'val': 1, 'test': 0}
# COINCIDED            3    1     1        {'train': 1, 'val': 0, 'test': 0}
# INTERCHANGEABLY     10    2     3        {'train': 3, 'val': 0, 'test': 0}
# ENOUGH              14    3     3        {'train': 3, 'val': 1, 'test': 0}
# SCALP                3    1     1        {'train': 1, 'val': 0, 'test': 0}
# SWEATERS             3    1     1        {'train': 0, 'val': 1, 'test': 0}
# DISEASE              3    1     1        {'train': 0, 'val': 0, 'test': 1}
# BEFORE              11    2     2        {'train': 3, 'val': 0, 'test': 0}
# GROWS                7    1     2        {'train': 1, 'val': 0, 'test': 1}
# HALLOWEEN            3    1     1        {'train': 0, 'val': 0, 'test': 1}
# BASKETBALL           7    1     2        {'train': 2, 'val': 0, 'test': 0}
# FUNNY                3    1     1        {'train': 0, 'val': 1, 'test': 0}
# HALLWAY             10    2     3        {'train': 2, 'val': 0, 'test': 1}
# HOSTAGES             3    1     1        {'train': 0, 'val': 1, 'test': 0}
# RABBITS             10    2     3        {'train': 1, 'val': 1, 'test': 1}
# FLOWER               3    1     1        {'train': 1, 'val': 0, 'test': 0}
# HOLIDAYS             7    1     2        {'train': 2, 'val': 0, 'test': 0}
# REQUIRES             7    1     2        {'train': 2, 'val': 0, 'test': 0}
# ACADEMIC             3    1     1        {'train': 1, 'val': 0, 'test': 0}
# ORDERS               3    1     1        {'train': 0, 'val': 0, 'test': 1}
# EVENING             24    6     5        {'train': 6, 'val': 0, 'test': 1}
# REVIEW               3    1     1        {'train': 0, 'val': 0, 'test': 1}
# MUSCULAR             3    1     1        {'train': 0, 'val': 0, 'test': 1}
# FAILURE             11    2     2        {'train': 3, 'val': 0, 'test': 0}
# PRESCRIBE           10    2     3        {'train': 1, 'val': 2, 'test': 0}
# ROCK                14    3     3        {'train': 2, 'val': 2, 'test': 0}
# GUNMAN              11    2     2        {'train': 3, 'val': 0, 'test': 0}
# BUTCHER              7    1     2        {'train': 1, 'val': 1, 'test': 0}
# WALL                11    2     2        {'train': 1, 'val': 1, 'test': 1}
# WATER               16    4     5        {'train': 4, 'val': 0, 'test': 1}
# GIVES               14    3     3        {'train': 3, 'val': 0, 'test': 1}
# NOTEWORTHY           3    1     1        {'train': 1, 'val': 0, 'test': 0}
# USING                3    1     1        {'train': 0, 'val': 0, 'test': 1}
# CONTROL              3    1     1        {'train': 0, 'val': 0, 'test': 1}
# BECOME              10    2     3        {'train': 2, 'val': 1, 'test': 0}
# ATTENTION            3    1     1        {'train': 1, 'val': 0, 'test': 0}
# DIAGRAM              7    1     2        {'train': 2, 'val': 0, 'test': 0}
# SOLVES              11    2     2        {'train': 3, 'val': 0, 'test': 0}
# THEM                32    8     5        {'train': 7, 'val': 1, 'test': 1}
# CONTRIBUTIONS        3    1     1        {'train': 0, 'val': 1, 'test': 0}
# ORANGE              14    3     3        {'train': 2, 'val': 1, 'test': 1}
# GUNPOWDER            3    1     1        {'train': 1, 'val': 0, 'test': 0}
# JAGUARS              7    1     2        {'train': 0, 'val': 1, 'test': 1}
# GRADES               3    1     1        {'train': 0, 'val': 1, 'test': 0}
# SKILL                3    1     1        {'train': 0, 'val': 0, 'test': 1}
# STRONGHOLD           3    1     1        {'train': 1, 'val': 0, 'test': 0}
# SHOWERS              7    1     2        {'train': 2, 'val': 0, 'test': 0}
# AGRICULTURAL         7    1     2        {'train': 2, 'val': 0, 'test': 0}
# OUTLAWS              3    1     1        {'train': 1, 'val': 0, 'test': 0}
# CHEMICALS            3    1     1        {'train': 0, 'val': 0, 'test': 1}
# GO                  20    5     5        {'train': 3, 'val': 2, 'test': 1}
# PRACTICAL            3    1     1        {'train': 1, 'val': 0, 'test': 0}
# DOWN                20    5     5        {'train': 4, 'val': 1, 'test': 1}
# SCREWDRIVER          3    1     1        {'train': 1, 'val': 0, 'test': 0}
# BLOUSES              3    1     1        {'train': 1, 'val': 0, 'test': 0}
# FIVE                 3    1     1        {'train': 1, 'val': 0, 'test': 0}
# OFFENSIVE            3    1     1        {'train': 0, 'val': 1, 'test': 0}
# JOINT                3    1     1        {'train': 0, 'val': 0, 'test': 1}
# MILITARY             3    1     1        {'train': 0, 'val': 0, 'test': 1}
# BOTTOM               7    1     2        {'train': 1, 'val': 0, 'test': 1}
# REWARDED            10    2     3        {'train': 2, 'val': 1, 'test': 0}
# BAROMETRIC          19    3     3        {'train': 5, 'val': 0, 'test': 0}
# EXECUTE              3    1     1        {'train': 1, 'val': 0, 'test': 0}
# LOWER                3    1     1        {'train': 0, 'val': 0, 'test': 1}
# FORCES               3    1     1        {'train': 1, 'val': 0, 'test': 0}
# WERE                25    5     5        {'train': 3, 'val': 2, 'test': 2}
# ELEGANT              7    1     2        {'train': 1, 'val': 1, 'test': 0}
# TINA                 7    1     2        {'train': 2, 'val': 0, 'test': 0}
# HORSERADISH         11    2     2        {'train': 3, 'val': 0, 'test': 0}
# FINISH               3    1     1        {'train': 1, 'val': 0, 'test': 0}
# ELSE                19    3     3        {'train': 5, 'val': 0, 'test': 0}
# LOCKED               7    1     2        {'train': 1, 'val': 0, 'test': 1}
# NEARLY               3    1     1        {'train': 1, 'val': 0, 'test': 0}
# TOFU                11    2     2        {'train': 3, 'val': 0, 'test': 0}
# PICKPOCKET           3    1     1        {'train': 0, 'val': 0, 'test': 1}
# LOOK                 7    1     2        {'train': 0, 'val': 1, 'test': 1}
# LEMON                7    1     2        {'train': 1, 'val': 0, 'test': 1}
# SYMBOLS              7    1     2        {'train': 2, 'val': 0, 'test': 0}
# PRICE               14    3     3        {'train': 3, 'val': 0, 'test': 1}
# UNDENIABLY           3    1     1        {'train': 1, 'val': 0, 'test': 0}
# CHOCOLATE           10    2     3        {'train': 2, 'val': 1, 'test': 0}
# MUCH                44   11    10        {'train': 9, 'val': 2, 'test': 2}
# ANNOYING            11    2     2        {'train': 2, 'val': 0, 'test': 1}
# COLORFUL            11    2     2        {'train': 3, 'val': 0, 'test': 0}
# EAT                  7    1     2        {'train': 0, 'val': 1, 'test': 1}
# DIME                17    4     4        {'train': 5, 'val': 0, 'test': 0}
# YELLOW               3    1     1        {'train': 1, 'val': 0, 'test': 0}
# SHOULDER             7    1     2        {'train': 2, 'val': 0, 'test': 0}
# CUTBACKS             7    1     2        {'train': 1, 'val': 0, 'test': 1}
# OVERWHELMED          3    1     1        {'train': 0, 'val': 0, 'test': 1}
# REPAINTED           11    2     2        {'train': 2, 'val': 0, 'test': 1}
# STAG                 3    1     1        {'train': 1, 'val': 0, 'test': 0}
# CHEAP                3    1     1        {'train': 1, 'val': 0, 'test': 0}
# CHAMBER              3    1     1        {'train': 0, 'val': 0, 'test': 1}
# MIGHT                7    1     2        {'train': 1, 'val': 0, 'test': 1}
# HIGHER               3    1     1        {'train': 0, 'val': 0, 'test': 1}
# ITEM                 3    1     1        {'train': 0, 'val': 1, 'test': 0}
# SHAVING              3    1     1        {'train': 0, 'val': 0, 'test': 1}
# EXPECTED             3    1     1        {'train': 1, 'val': 0, 'test': 0}
# UNLIMITED            3    1     1        {'train': 0, 'val': 0, 'test': 1}
# HARD                14    3     3        {'train': 3, 'val': 1, 'test': 0}
# SECURITY             3    1     1        {'train': 1, 'val': 0, 'test': 0}
# IDEAL                3    1     1        {'train': 1, 'val': 0, 'test': 0}
# APPRECIATED         10    2     3        {'train': 2, 'val': 1, 'test': 0}
# ALMOST               3    1     1        {'train': 0, 'val': 0, 'test': 1}
# FASCINATING          7    1     2        {'train': 2, 'val': 0, 'test': 0}
# LESSONS              3    1     1        {'train': 1, 'val': 0, 'test': 0}
# ROLL                20    5     5        {'train': 5, 'val': 0, 'test': 1}
# MUSIC               14    3     3        {'train': 2, 'val': 0, 'test': 2}
# DECEMBER             3    1     1        {'train': 1, 'val': 0, 'test': 0}
# BARELY               3    1     1        {'train': 0, 'val': 1, 'test': 0}
# SHIMMERED            7    1     2        {'train': 2, 'val': 0, 'test': 0}
# SHIMMERS            10    2     3        {'train': 3, 'val': 0, 'test': 0}
# ACCOUNT              3    1     1        {'train': 1, 'val': 0, 'test': 0}
# ROB                  3    1     1        {'train': 0, 'val': 1, 'test': 0}
# VODKA                3    1     1        {'train': 1, 'val': 0, 'test': 0}
# REPAINTING           3    1     1        {'train': 1, 'val': 0, 'test': 0}
# IS                 121   27    27       {'train': 28, 'val': 3, 'test': 4}
# HERBS                3    1     1        {'train': 0, 'val': 0, 'test': 1}
# NO                   7    1     2        {'train': 1, 'val': 0, 'test': 1}
# BOUGHT               7    1     2        {'train': 1, 'val': 1, 'test': 0}
# FLEW                 3    1     1        {'train': 0, 'val': 1, 'test': 0}
# TEMPERATE            3    1     1        {'train': 1, 'val': 0, 'test': 0}
# DOLL                16    4     5        {'train': 3, 'val': 1, 'test': 1}
# WINDOW               3    1     1        {'train': 1, 'val': 0, 'test': 0}
# CYCLICAL            14    3     3        {'train': 3, 'val': 0, 'test': 1}
# SET                  7    1     2        {'train': 2, 'val': 0, 'test': 0}
# SOCKS               24    6     5        {'train': 3, 'val': 3, 'test': 1}
# CRAB                14    3     3        {'train': 2, 'val': 1, 'test': 1}
# SPOTTED              7    1     2        {'train': 2, 'val': 0, 'test': 0}
# OVER                 7    1     2        {'train': 1, 'val': 1, 'test': 0}
# HONOUR               7    1     2        {'train': 2, 'val': 0, 'test': 0}
# EVERY               44    8     8       {'train': 10, 'val': 0, 'test': 2}
# NEAR                27    4     4        {'train': 6, 'val': 0, 'test': 1}
# SMALL               10    2     3        {'train': 2, 'val': 1, 'test': 0}
# BREAKDOWN            3    1     1        {'train': 1, 'val': 0, 'test': 0}
# CAN                 39    8     8        {'train': 9, 'val': 1, 'test': 1}
# DISCLAIMER           3    1     1        {'train': 0, 'val': 1, 'test': 0}
# TURNER               7    1     2        {'train': 2, 'val': 0, 'test': 0}
# SINGER'S             3    1     1        {'train': 0, 'val': 0, 'test': 1}
# REMEMBER             7    1     2        {'train': 1, 'val': 1, 'test': 0}
# DAD                  3    1     1        {'train': 1, 'val': 0, 'test': 0}
# MILES                3    1     1        {'train': 1, 'val': 0, 'test': 0}
# OUTSTANDING         16    4     5        {'train': 4, 'val': 0, 'test': 1}
# PRIORITIES           7    1     2        {'train': 1, 'val': 0, 'test': 1}
# NAMES               10    2     3        {'train': 2, 'val': 0, 'test': 1}
# GRAPH                7    1     2        {'train': 1, 'val': 0, 'test': 1}
# BARB'S               3    1     1        {'train': 1, 'val': 0, 'test': 0}
# MILLIONAIRES         7    1     2        {'train': 2, 'val': 0, 'test': 0}
# TOP                  7    1     2        {'train': 0, 'val': 1, 'test': 1}
# FRANTICALLY          3    1     1        {'train': 1, 'val': 0, 'test': 0}
# OCCASIONALLY        10    2     3        {'train': 3, 'val': 0, 'test': 0}
# DAYTIME              3    1     1        {'train': 1, 'val': 0, 'test': 0}
# SURFACE              3    1     1        {'train': 0, 'val': 0, 'test': 1}
# ELEVEN               3    1     1        {'train': 0, 'val': 0, 'test': 1}
# TAKES               11    2     2        {'train': 3, 'val': 0, 'test': 0}
# AUDIOVISUAL         16    4     5        {'train': 3, 'val': 1, 'test': 1}
# EXPLICITLY           3    1     1        {'train': 0, 'val': 0, 'test': 1}
# SUBTRACTION          7    1     2        {'train': 2, 'val': 0, 'test': 0}
# EIGHT               11    2     2        {'train': 3, 'val': 0, 'test': 0}
# APPLES               3    1     1        {'train': 0, 'val': 0, 'test': 1}
# RUG                  3    1     1        {'train': 1, 'val': 0, 'test': 0}
# OAK                  7    1     2        {'train': 1, 'val': 1, 'test': 0}
# AUDIENCE             3    1     1        {'train': 1, 'val': 0, 'test': 0}
# BEACH                3    1     1        {'train': 0, 'val': 1, 'test': 0}
# OUTDOORS             3    1     1        {'train': 0, 'val': 0, 'test': 1}
# BROKE               14    3     3        {'train': 2, 'val': 1, 'test': 1}
# CATASTROPHIC         7    1     2        {'train': 1, 'val': 0, 'test': 1}
# MONTHS               3    1     1        {'train': 1, 'val': 0, 'test': 0}
# AND                165   40    40       {'train': 36, 'val': 5, 'test': 8}
# TASK                 3    1     1        {'train': 1, 'val': 0, 'test': 0}
# POLICEMAN            3    1     1        {'train': 0, 'val': 0, 'test': 1}
# MOMENT               7    1     2        {'train': 2, 'val': 0, 'test': 0}
# PETROL               3    1     1        {'train': 1, 'val': 0, 'test': 0}
# VIOLENCE            10    2     3        {'train': 2, 'val': 1, 'test': 0}
# WILLOWY              3    1     1        {'train': 0, 'val': 1, 'test': 0}
# STOCKINGS            3    1     1        {'train': 1, 'val': 0, 'test': 0}
# FREELY              16    4     5        {'train': 2, 'val': 2, 'test': 1}
# POOR                16    4     5        {'train': 2, 'val': 2, 'test': 1}
# TRISH                7    1     2        {'train': 2, 'val': 0, 'test': 0}
# ALLOW               52   13    10       {'train': 13, 'val': 0, 'test': 2}
# JUNGLE               3    1     1        {'train': 0, 'val': 1, 'test': 0}
# PUT                  7    1     2        {'train': 1, 'val': 0, 'test': 1}
# CREAM               25    5     5        {'train': 5, 'val': 1, 'test': 1}
# ZIGZAGGED            3    1     1        {'train': 1, 'val': 0, 'test': 0}
# BIG                 50   10    10       {'train': 10, 'val': 3, 'test': 1}
# SHORTEN              3    1     1        {'train': 1, 'val': 0, 'test': 0}
# TWO                 21    4     5        {'train': 3, 'val': 2, 'test': 1}
# WASH                 3    1     1        {'train': 1, 'val': 0, 'test': 0}
# SALAD               10    2     3        {'train': 3, 'val': 0, 'test': 0}
# FILM                 3    1     1        {'train': 1, 'val': 0, 'test': 0}
# CANNOT               3    1     1        {'train': 1, 'val': 0, 'test': 0}
# SLOWLY              11    2     2        {'train': 2, 'val': 1, 'test': 0}
# GEORGE               7    1     2        {'train': 1, 'val': 0, 'test': 1}
# DRESSING            10    2     3        {'train': 2, 'val': 1, 'test': 0}
# FIRST               14    3     3        {'train': 3, 'val': 1, 'test': 0}
# CONFIRM              7    1     2        {'train': 1, 'val': 1, 'test': 0}
# DINNER               7    1     2        {'train': 2, 'val': 0, 'test': 0}
# SPHERICAL            7    1     2        {'train': 1, 'val': 1, 'test': 0}
# GLOVES               7    1     2        {'train': 2, 'val': 0, 'test': 0}
# DIG                  3    1     1        {'train': 0, 'val': 1, 'test': 0}
# THANK              540  120   120    {'train': 103, 'val': 26, 'test': 27}
# FOUND               10    2     3        {'train': 3, 'val': 0, 'test': 0}
# APPROVAL             7    1     2        {'train': 2, 'val': 0, 'test': 0}
# CLOVERLEAF           3    1     1        {'train': 0, 'val': 1, 'test': 0}
# AGGRESSIVE           3    1     1        {'train': 1, 'val': 0, 'test': 0}
# HARMONIZE            3    1     1        {'train': 1, 'val': 0, 'test': 0}
# ...
# FROST                  {'train': 1, 'val': 0, 'test': 0}
# OPEN                   {'train': 3, 'val': 1, 'test': 0}
# COUNT                  {'train': 1, 'val': 0, 'test': 0}
# MIAMI                  {'train': 0, 'val': 0, 'test': 1}
# ELDERLY                {'train': 1, 'val': 0, 'test': 0}
# DARK                   {'train': 0, 'val': 1, 'test': 0}
# JUICY                  {'train': 3, 'val': 0, 'test': 0}
# REFLECTS               {'train': 1, 'val': 0, 'test': 0}
# EXAM                   {'train': 0, 'val': 0, 'test': 1}
# COMBINE                {'train': 1, 'val': 1, 'test': 0}
# INSTRUCTIONS           {'train': 2, 'val': 0, 'test': 0}
# CONTROLLED             {'train': 1, 'val': 2, 'test': 1}
# EXHIBITED              {'train': 0, 'val': 0, 'test': 1}
# WEEK                   {'train': 3, 'val': 0, 'test': 0}
# DIDN'T                 {'train': 3, 'val': 0, 'test': 1}
# ZOOS                   {'train': 2, 'val': 0, 'test': 0}
# STEEP                  {'train': 3, 'val': 0, 'test': 1}
# POPULARITY             {'train': 3, 'val': 0, 'test': 1}
# BONFIRE                {'train': 1, 'val': 0, 'test': 0}
# USED                   {'train': 2, 'val': 0, 'test': 0}
# CLOTHING               {'train': 1, 'val': 2, 'test': 1}
# THURSDAY'S             {'train': 0, 'val': 0, 'test': 1}
# ONTO                   {'train': 2, 'val': 0, 'test': 0}
# SUDDEN                 {'train': 3, 'val': 0, 'test': 0}
# ATTACH                 {'train': 1, 'val': 1, 'test': 0}
# OOZED                  {'train': 0, 'val': 1, 'test': 0}
# EASY                   {'train': 6, 'val': 2, 'test': 1}
# LIFELONG               {'train': 1, 'val': 0, 'test': 0}
# MEN                    {'train': 1, 'val': 1, 'test': 0}
# WHY                    {'train': 5, 'val': 1, 'test': 1}
# LEAVES                 {'train': 1, 'val': 0, 'test': 0}
# EXECUTION              {'train': 0, 'val': 0, 'test': 1}
# CARPET                 {'train': 0, 'val': 0, 'test': 1}
# BOOKS                  {'train': 1, 'val': 1, 'test': 0}
# PRONUNCIATION          {'train': 0, 'val': 0, 'test': 2}
# ORIENTAL               {'train': 1, 'val': 0, 'test': 0}
# LAY                    {'train': 1, 'val': 0, 'test': 1}
# SCREEN                 {'train': 0, 'val': 1, 'test': 0}
# THINK                  {'train': 2, 'val': 0, 'test': 0}
# LAGOON                 {'train': 1, 'val': 0, 'test': 0}
# HERE                   {'train': 0, 'val': 1, 'test': 0}
# APRONS                 {'train': 2, 'val': 0, 'test': 0}
# ATTITUDE               {'train': 1, 'val': 0, 'test': 0}
# SURROUNDED             {'train': 1, 'val': 0, 'test': 0}
# WALK                   {'train': 1, 'val': 0, 'test': 0}
# POSITIVE               {'train': 1, 'val': 0, 'test': 1}
# GEOLOGICAL             {'train': 1, 'val': 0, 'test': 0}
# HOLIDAY                {'train': 2, 'val': 0, 'test': 0}
# EXCLUSIVE              {'train': 2, 'val': 0, 'test': 0}
# SURVIVE                {'train': 1, 'val': 0, 'test': 0}
# GOOD               {'train': 108, 'val': 24, 'test': 27}
# THEME                  {'train': 1, 'val': 0, 'test': 0}
# CAREFULLY              {'train': 2, 'val': 0, 'test': 0}
# GOVERNMENT             {'train': 3, 'val': 0, 'test': 0}
# MADE                   {'train': 2, 'val': 2, 'test': 1}
# OLD                    {'train': 2, 'val': 2, 'test': 1}
# ABDOMEN                {'train': 1, 'val': 0, 'test': 0}
# REQUIRED               {'train': 2, 'val': 0, 'test': 0}
# APPOINTMENT            {'train': 1, 'val': 0, 'test': 0}
# ARGUE                  {'train': 1, 'val': 0, 'test': 0}
# GREASING               {'train': 0, 'val': 0, 'test': 1}
# SURELY                 {'train': 0, 'val': 0, 'test': 1}
# YOU              {'train': 582, 'val': 119, 'test': 127}
# AHEAD                  {'train': 0, 'val': 0, 'test': 1}
# POLICY                 {'train': 1, 'val': 1, 'test': 0}
# FELL                   {'train': 3, 'val': 0, 'test': 0}
# WELCOME            {'train': 113, 'val': 21, 'test': 23}
# HANDED                 {'train': 0, 'val': 0, 'test': 1}
# FINDING                {'train': 1, 'val': 1, 'test': 0}
# GRANDMOTHER            {'train': 2, 'val': 0, 'test': 0}
# COMES                  {'train': 4, 'val': 1, 'test': 1}
# CORNERED               {'train': 1, 'val': 1, 'test': 1}
# BACK                   {'train': 0, 'val': 1, 'test': 0}
# WESTCHESTER            {'train': 1, 'val': 0, 'test': 0}
# SPANISH                {'train': 1, 'val': 0, 'test': 0}
# KNOW                   {'train': 2, 'val': 0, 'test': 0}
# HELLO              {'train': 106, 'val': 27, 'test': 23}
# UP                    {'train': 12, 'val': 2, 'test': 3}
# ATHEISTS               {'train': 2, 'val': 0, 'test': 0}
# PETTICOATS             {'train': 1, 'val': 0, 'test': 1}
# NAN'S                  {'train': 2, 'val': 0, 'test': 0}
# SPRAY                  {'train': 0, 'val': 0, 'test': 2}
# INNOCENCE              {'train': 1, 'val': 0, 'test': 0}
# PREPARED               {'train': 2, 'val': 0, 'test': 0}
# HAUNTED                {'train': 3, 'val': 1, 'test': 1}
# LONE                   {'train': 3, 'val': 0, 'test': 0}
# WARRIOR                {'train': 0, 'val': 0, 'test': 1}
# ROMANTIC               {'train': 3, 'val': 0, 'test': 0}
# POSTPONED              {'train': 3, 'val': 1, 'test': 0}
# GARAGE                 {'train': 4, 'val': 0, 'test': 1}
# LAWYERS                {'train': 1, 'val': 0, 'test': 1}
# OR                     {'train': 1, 'val': 0, 'test': 0}
# CALICO                 {'train': 3, 'val': 0, 'test': 0}
# RARE                   {'train': 1, 'val': 1, 'test': 0}
# WHO                    {'train': 1, 'val': 0, 'test': 1}
# BEGGAR                 {'train': 1, 'val': 0, 'test': 1}
# RHYTHM                 {'train': 3, 'val': 1, 'test': 0}
# SHAWN                  {'train': 1, 'val': 0, 'test': 0}
# THERMOMETER            {'train': 1, 'val': 0, 'test': 0}
# CLIFF'S                {'train': 0, 'val': 0, 'test': 1}
# TO                 {'train': 160, 'val': 30, 'test': 44}
# BEG                    {'train': 0, 'val': 1, 'test': 0}
# READING                {'train': 3, 'val': 0, 'test': 0}
# TREES                  {'train': 0, 'val': 0, 'test': 1}
# REMAINED               {'train': 1, 'val': 0, 'test': 0}
# BIKE                   {'train': 1, 'val': 0, 'test': 1}
# PEACHES                {'train': 2, 'val': 1, 'test': 0}
# CAT                    {'train': 0, 'val': 2, 'test': 1}
# CONTAINS               {'train': 4, 'val': 1, 'test': 0}
# CHALLENGE              {'train': 1, 'val': 0, 'test': 0}
# ALWAYS                 {'train': 7, 'val': 3, 'test': 1}
# MORNING                {'train': 6, 'val': 1, 'test': 2}
# SKIRTS                 {'train': 1, 'val': 0, 'test': 0}
# BLEACHERS              {'train': 3, 'val': 0, 'test': 1}
# SEEKING                {'train': 1, 'val': 1, 'test': 0}
# ADD                    {'train': 0, 'val': 1, 'test': 0}
# FIXED                  {'train': 2, 'val': 0, 'test': 0}
# OFFICIAL               {'train': 0, 'val': 1, 'test': 0}
# PICKED                 {'train': 5, 'val': 1, 'test': 1}
# STOPWATCH              {'train': 4, 'val': 0, 'test': 0}
# RISE                   {'train': 2, 'val': 1, 'test': 0}
# JANE                   {'train': 0, 'val': 0, 'test': 1}
# HOT                    {'train': 3, 'val': 1, 'test': 0}
# RIDE                   {'train': 1, 'val': 0, 'test': 1}
# NOVEL                  {'train': 0, 'val': 1, 'test': 1}
# GEESE                  {'train': 1, 'val': 0, 'test': 0}
# SKY                    {'train': 3, 'val': 0, 'test': 0}
# ARCHEOLOGICAL          {'train': 1, 'val': 0, 'test': 0}
# CHANGE                 {'train': 2, 'val': 0, 'test': 0}
# BROKEN                 {'train': 1, 'val': 1, 'test': 0}
# SKIRT                  {'train': 1, 'val': 0, 'test': 0}
# ELM                    {'train': 2, 'val': 0, 'test': 0}
# CLUB                   {'train': 0, 'val': 0, 'test': 1}
# NOTHING                {'train': 0, 'val': 0, 'test': 1}
# BLACK                  {'train': 4, 'val': 0, 'test': 0}
# SHE                    {'train': 7, 'val': 1, 'test': 1}
# JOB                    {'train': 1, 'val': 1, 'test': 1}
# OTTOS                  {'train': 1, 'val': 0, 'test': 0}
# TOO                    {'train': 8, 'val': 2, 'test': 1}
# RECEIVED               {'train': 0, 'val': 1, 'test': 0}
# DELETE                 {'train': 1, 'val': 0, 'test': 0}
# SHORTAGE               {'train': 2, 'val': 0, 'test': 0}
# FAIRY                  {'train': 3, 'val': 0, 'test': 0}
# CURIOSITY              {'train': 1, 'val': 0, 'test': 1}
# BURNED                 {'train': 0, 'val': 1, 'test': 0}
# EGGS                   {'train': 2, 'val': 2, 'test': 0}
# PRISON                 {'train': 1, 'val': 0, 'test': 0}
# NEED                   {'train': 4, 'val': 0, 'test': 0}
# PROBLEM                {'train': 4, 'val': 0, 'test': 1}
# SLOPES                 {'train': 1, 'val': 0, 'test': 0}
# TODAY'S                {'train': 0, 'val': 0, 'test': 1}
# RESULTS                {'train': 1, 'val': 0, 'test': 0}
# DATE                   {'train': 2, 'val': 0, 'test': 1}
# SQUEEZED               {'train': 0, 'val': 0, 'test': 2}
# DETERMINATION          {'train': 2, 'val': 0, 'test': 0}
# TAG                    {'train': 1, 'val': 0, 'test': 0}
# TRIUMPHANT             {'train': 1, 'val': 0, 'test': 0}
# CHRONOLOGICAL          {'train': 2, 'val': 0, 'test': 1}
# SAT                    {'train': 0, 'val': 1, 'test': 0}
# WHICH                  {'train': 2, 'val': 0, 'test': 0}
# GETTING                {'train': 2, 'val': 0, 'test': 0}
# TIM                    {'train': 2, 'val': 1, 'test': 0}
# SORRY              {'train': 108, 'val': 24, 'test': 24}
# SHOES                  {'train': 3, 'val': 1, 'test': 1}
# NEARER                 {'train': 0, 'val': 1, 'test': 0}
# HOUSE                  {'train': 5, 'val': 0, 'test': 1}
# HOWEVER                {'train': 2, 'val': 0, 'test': 0}
# SIMPLE                 {'train': 1, 'val': 1, 'test': 0}
# EXPERIMENT'S           {'train': 1, 'val': 0, 'test': 1}
# ARM                    {'train': 3, 'val': 0, 'test': 0}
# US                     {'train': 4, 'val': 1, 'test': 1}
# SCIENTIFIC             {'train': 3, 'val': 1, 'test': 1}
# DOOR                   {'train': 2, 'val': 0, 'test': 1}
# BARBED                 {'train': 1, 'val': 0, 'test': 0}
# RAG                    {'train': 2, 'val': 2, 'test': 1}
# ARGUED                 {'train': 1, 'val': 0, 'test': 0}
# FEET                   {'train': 3, 'val': 0, 'test': 0}
# THOSE                  {'train': 6, 'val': 0, 'test': 1}
# OBTAIN                 {'train': 1, 'val': 1, 'test': 1}
# SOYSAUCE               {'train': 0, 'val': 0, 'test': 1}
# GUESS                  {'train': 1, 'val': 1, 'test': 1}
# BEST                   {'train': 1, 'val': 1, 'test': 1}
# THEY                   {'train': 9, 'val': 1, 'test': 1}
# DISTRIBUTED            {'train': 1, 'val': 1, 'test': 0}
# WELLKEPT               {'train': 1, 'val': 0, 'test': 0}
# GREATLY                {'train': 0, 'val': 0, 'test': 1}
# NOW                    {'train': 2, 'val': 0, 'test': 1}
# INTERPRETATION         {'train': 1, 'val': 0, 'test': 1}
# RECALL                 {'train': 1, 'val': 1, 'test': 1}
# STRAIGHTFORWARD        {'train': 1, 'val': 1, 'test': 0}
# SCULPTURE              {'train': 3, 'val': 0, 'test': 0}
# OPENS                  {'train': 1, 'val': 0, 'test': 0}
# FOREST                 {'train': 1, 'val': 0, 'test': 1}
# HERB'S                 {'train': 2, 'val': 0, 'test': 0}
# DEPARTMENTS            {'train': 1, 'val': 0, 'test': 0}
# ONE                    {'train': 1, 'val': 0, 'test': 0}
# GREAT                  {'train': 1, 'val': 1, 'test': 2}
# VANQUISHED             {'train': 4, 'val': 0, 'test': 0}
# PAPAYA                 {'train': 1, 'val': 0, 'test': 0}
# YESTERDAY              {'train': 1, 'val': 0, 'test': 1}
# SWING                  {'train': 3, 'val': 0, 'test': 0}
# ARRANGE                {'train': 0, 'val': 1, 'test': 0}
# LAWYER                 {'train': 1, 'val': 0, 'test': 0}
# PHILS                  {'train': 1, 'val': 0, 'test': 0}
# THREAD                 {'train': 2, 'val': 0, 'test': 0}
# PAM                    {'train': 1, 'val': 0, 'test': 0}
# ATTENDANCE             {'train': 2, 'val': 0, 'test': 0}
# PEELING                {'train': 1, 'val': 1, 'test': 0}
# ACTIVITY               {'train': 1, 'val': 0, 'test': 0}
# WEBBED                 {'train': 2, 'val': 0, 'test': 1}
# GRADUATION             {'train': 0, 'val': 0, 'test': 1}
# TOOK                   {'train': 2, 'val': 0, 'test': 0}
# SYMPOSIUM              {'train': 1, 'val': 0, 'test': 1}
# DOCTOR                 {'train': 1, 'val': 0, 'test': 0}
# MUM                    {'train': 2, 'val': 0, 'test': 0}
# QUICK                  {'train': 3, 'val': 0, 'test': 1}
# EXPENSE                {'train': 0, 'val': 1, 'test': 0}
# JAM                    {'train': 3, 'val': 0, 'test': 1}
# TASTES                 {'train': 1, 'val': 0, 'test': 0}
# READS                  {'train': 0, 'val': 1, 'test': 0}
# NICE               {'train': 105, 'val': 27, 'test': 27}
# FELT                   {'train': 2, 'val': 0, 'test': 0}
# ICE                    {'train': 6, 'val': 1, 'test': 0}
# PARENTAL               {'train': 2, 'val': 0, 'test': 0}
# KEPT                   {'train': 4, 'val': 1, 'test': 1}
# HIRES                  {'train': 1, 'val': 0, 'test': 1}
# ONLY                   {'train': 8, 'val': 1, 'test': 3}
# BEGINS                 {'train': 0, 'val': 0, 'test': 1}
# STAYED                 {'train': 0, 'val': 0, 'test': 2}
# VICTIM                 {'train': 1, 'val': 1, 'test': 1}
# THOROUGHLY             {'train': 0, 'val': 1, 'test': 0}
# SHAMPOOED              {'train': 1, 'val': 0, 'test': 0}
# PROCEEDING             {'train': 2, 'val': 0, 'test': 1}
# TODD                   {'train': 1, 'val': 0, 'test': 1}
# SLIPPED                {'train': 4, 'val': 0, 'test': 1}
# SHOULD                 {'train': 5, 'val': 0, 'test': 2}
# PRODUCTS               {'train': 2, 'val': 0, 'test': 0}
# ACROPOLIS              {'train': 1, 'val': 0, 'test': 0}
# VOCABULARY             {'train': 2, 'val': 0, 'test': 0}
# HAVEN'T                {'train': 1, 'val': 0, 'test': 1}
# SEQUOIA                {'train': 1, 'val': 0, 'test': 0}
# HIGHWAY                {'train': 0, 'val': 0, 'test': 1}
# WORD                   {'train': 1, 'val': 0, 'test': 1}
# HER                   {'train': 16, 'val': 2, 'test': 2}
# NEEDLE                 {'train': 2, 'val': 0, 'test': 0}
# ON                    {'train': 25, 'val': 4, 'test': 6}
# SEISMIC                {'train': 1, 'val': 0, 'test': 0}
# COAST                  {'train': 1, 'val': 0, 'test': 1}
# COINS                  {'train': 1, 'val': 0, 'test': 1}
# ACTS                   {'train': 2, 'val': 1, 'test': 0}
# THIEVES                {'train': 1, 'val': 1, 'test': 1}
# SUITABLE               {'train': 3, 'val': 1, 'test': 0}
# NOTICES                {'train': 2, 'val': 0, 'test': 1}
# INTO                   {'train': 5, 'val': 0, 'test': 1}
# MOTHER                 {'train': 0, 'val': 1, 'test': 0}
# ANKLE                  {'train': 2, 'val': 0, 'test': 0}
# PAIRS                  {'train': 3, 'val': 3, 'test': 1}
# PRESTIGE               {'train': 0, 'val': 1, 'test': 0}
# DESPERATELY            {'train': 0, 'val': 0, 'test': 1}
# IN                  {'train': 46, 'val': 15, 'test': 10}
# NEVADA                 {'train': 1, 'val': 0, 'test': 0}
# THOMAS                 {'train': 2, 'val': 0, 'test': 1}
# PAYMENTS               {'train': 2, 'val': 0, 'test': 1}
# AM                 {'train': 112, 'val': 16, 'test': 29}
# ENJOY                  {'train': 3, 'val': 0, 'test': 0}
# TOOTH                  {'train': 4, 'val': 1, 'test': 1}
# EARLY                  {'train': 7, 'val': 0, 'test': 1}
# BRIGHT                 {'train': 3, 'val': 0, 'test': 0}
# SPRING                 {'train': 2, 'val': 1, 'test': 0}
# THIS                  {'train': 10, 'val': 1, 'test': 3}
# BALLS                  {'train': 0, 'val': 0, 'test': 1}

# %%
total_rows = len(v4_df)
print(f"Total rows in v4_df: {total_rows}")
# Out:
# Total rows in v4_df: 1203
