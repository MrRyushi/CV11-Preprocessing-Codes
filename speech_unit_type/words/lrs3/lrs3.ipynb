# %%
import os
import shutil
import random
import pandas as pd
from collections import defaultdict
from sklearn.model_selection import train_test_split

'''
original_dir = "../../../models/DC-TCN/datasets/lrs3_words_may"
dir = "../../../models/DC-TCN/datasets/lrs3_words_may"
'''
original_dir = "../lrs3_may/preprocessed_videos_all"
dir = original_dir

# %%
# Duplicate folder for checkpoint
source_folder = "../../../models/DC-TCN/datasets/lrs3_words_original"
destination_folder = "../../../models/DC-TCN/datasets/lrs3_words_v2_retry"

if not os.path.exists(destination_folder):
    shutil.copytree(source_folder, destination_folder)
    print(f"Copied {source_folder} to {destination_folder}")
else:
    print(f"Destination folder '{destination_folder}' already exists!")
# Out:
# Destination folder '../../../models/DC-TCN/datasets/lrs3_words_v2_retry' already exists!

# %%
def create_df(dir):
    word_data_counts = defaultdict(lambda: defaultdict(lambda: defaultdict(int)))
    
    for word in os.listdir(dir):
        word_path = os.path.join(dir, word)
    
        if not os.path.isdir(word_path):
            print(f"Skipping {word}: not a directory.")
            continue
    
        for split in ['train', 'val', 'test']:
            split_path = os.path.join(word_path, split)
            
            if not os.path.isdir(split_path):
                continue
        
            file_count = sum(1 for file in os.listdir(split_path) if file.endswith(".mp4"))
            word_data_counts[word][split]["total"] = file_count

    df = pd.DataFrame(columns=["train", "val", "test"])
    
    for word, splits in word_data_counts.items():
        row = {}
        row["train"] = splits["train"]["total"]
        row["val"] = splits["val"]["total"]
        row["test"] = splits["test"]["total"]
        df.loc[word] = row
    
    df['total'] = df[['train', 'val', 'test']].sum(axis=1)
    return df

# %%
df = create_df(original_dir)

# %%
sorted_df = df.sort_index()
sorted_df['total'] = sorted_df[['train', 'val', 'test']].sum(axis=1)
sorted_df = sorted_df.sort_values(by='total', ascending=False)
print(sorted_df[['train', 'val', 'test', 'total']])
# Out:
#             train   val  test  total
# THE         11261  2816   318  14395
# TO           9084  2272   332  11688
# AND          8692  2173   273  11138
# THAT         6824  1706   243   8773
# I            6745  1687   283   8715
# ...           ...   ...   ...    ...
# MAXIMIZING      1     0     0      1
# MAX'S           1     0     0      1
# MAVERICK        1     0     0      1
# MAVEN           1     0     0      1
# KEITH           1     0     0      1
#
# [15267 rows x 4 columns]

# %%
min = print(sorted_df['total'].min())
max = print(sorted_df['total'].max())
# Out:
# 1
# 14395

# %%
max_value = sorted_df['total'].max()  # Get the max value from the 'total' column
for i in range(0, max_value + 1):  # Use max_value instead of max
    total = (sorted_df['total'] == i).sum()
    if total != 0:
        print(f"{i} files - {total}")
# Out:
# 1 files - 6646
# 2 files - 2364
# 3 files - 1148
# 4 files - 799
# 5 files - 532
# 6 files - 422
# 7 files - 313
# 8 files - 245
# 9 files - 225
# 10 files - 185
# 11 files - 164
# 12 files - 124
# 13 files - 98
# 14 files - 101
# 15 files - 83
# 16 files - 95
# 17 files - 86
# 18 files - 77
# 19 files - 56
# 20 files - 60
# 21 files - 53
# 22 files - 41
# 23 files - 47
# 24 files - 48
# 25 files - 41
# 26 files - 44
# 27 files - 29
# 28 files - 28
# 29 files - 25
# 30 files - 21
# 31 files - 29
# 32 files - 20
# 33 files - 16
# 34 files - 26
# 35 files - 29
# 36 files - 13
# 37 files - 15
# 38 files - 22
# 39 files - 21
# 40 files - 29
# 41 files - 5
# 42 files - 19
# 43 files - 15
# 44 files - 15
# 45 files - 11
# 46 files - 20
# 47 files - 14
# 48 files - 12
# 49 files - 11
# 50 files - 8
# 51 files - 14
# 52 files - 13
# 53 files - 12
# 54 files - 11
# 55 files - 13
# 56 files - 11
# 57 files - 5
# 58 files - 10
# 59 files - 10
# 60 files - 8
# 61 files - 9
# 62 files - 6
# 63 files - 7
# 64 files - 7
# 65 files - 12
# 66 files - 10
# 67 files - 8
# 68 files - 6
# 69 files - 6
# 70 files - 2
# 71 files - 6
# 72 files - 4
# 73 files - 5
# 74 files - 8
# 75 files - 3
# 76 files - 5
# 77 files - 5
# 78 files - 5
# 79 files - 3
# 80 files - 7
# 81 files - 7
# 82 files - 4
# 83 files - 2
# 84 files - 2
# 85 files - 5
# 86 files - 2
# 87 files - 7
# 88 files - 7
# 89 files - 4
# 90 files - 1
# 91 files - 7
# 92 files - 3
# 93 files - 6
# 94 files - 4
# 95 files - 5
# 96 files - 2
# 97 files - 2
# 98 files - 4
# 99 files - 2
# 101 files - 2
# 102 files - 4
# 103 files - 3
# 104 files - 5
# 105 files - 5
# 106 files - 4
# 107 files - 2
# 108 files - 7
# 110 files - 2
# 111 files - 4
# 112 files - 7
# 113 files - 4
# 114 files - 5
# 115 files - 4
# 116 files - 2
# 117 files - 3
# 118 files - 2
# 119 files - 1
# 120 files - 2
# 121 files - 4
# 122 files - 1
# 123 files - 4
# 124 files - 3
# 125 files - 3
# 126 files - 5
# 127 files - 4
# 128 files - 2
# 129 files - 3
# 130 files - 1
# 131 files - 3
# 132 files - 1
# 133 files - 1
# 134 files - 1
# 135 files - 2
# 136 files - 5
# 137 files - 1
# 138 files - 2
# 139 files - 2
# 140 files - 1
# 141 files - 3
# 142 files - 1
# 143 files - 5
# 144 files - 2
# 145 files - 1
# 146 files - 1
# 147 files - 1
# 148 files - 3
# 149 files - 2
# 151 files - 1
# 153 files - 1
# 154 files - 1
# 157 files - 1
# 158 files - 1
# 160 files - 2
# 162 files - 2
# 163 files - 2
# 164 files - 1
# 165 files - 2
# 166 files - 3
# 167 files - 1
# 168 files - 1
# 171 files - 1
# 172 files - 3
# 173 files - 1
# 176 files - 3
# 178 files - 2
# 180 files - 2
# 181 files - 1
# 184 files - 3
# 185 files - 2
# 186 files - 1
# 187 files - 2
# 188 files - 1
# 189 files - 1
# 190 files - 1
# 191 files - 2
# 192 files - 2
# 193 files - 1
# 194 files - 3
# 196 files - 2
# 197 files - 1
# 198 files - 3
# 200 files - 2
# 202 files - 1
# 205 files - 1
# 207 files - 1
# 208 files - 1
# 209 files - 2
# 210 files - 2
# 211 files - 1
# 212 files - 2
# 216 files - 2
# 219 files - 1
# 224 files - 1
# 228 files - 1
# 229 files - 2
# 230 files - 1
# 234 files - 1
# 235 files - 2
# 238 files - 1
# 244 files - 1
# 248 files - 1
# 252 files - 1
# 254 files - 1
# 255 files - 2
# 256 files - 1
# 257 files - 1
# 261 files - 1
# 262 files - 1
# 265 files - 1
# 270 files - 2
# 272 files - 2
# 274 files - 2
# 278 files - 2
# 279 files - 1
# 281 files - 2
# 282 files - 1
# 283 files - 1
# 284 files - 3
# 293 files - 1
# 294 files - 2
# 295 files - 1
# 296 files - 1
# 299 files - 1
# 300 files - 1
# 301 files - 1
# 302 files - 1
# 304 files - 1
# 305 files - 1
# 306 files - 1
# 308 files - 1
# 310 files - 1
# 311 files - 2
# 312 files - 1
# 313 files - 1
# 326 files - 1
# 339 files - 2
# 355 files - 1
# 358 files - 1
# 359 files - 1
# 368 files - 1
# 370 files - 1
# 376 files - 2
# 385 files - 1
# 387 files - 1
# 394 files - 1
# 400 files - 1
# 402 files - 1
# 404 files - 1
# 407 files - 1
# 408 files - 2
# 410 files - 1
# 414 files - 1
# 415 files - 1
# 422 files - 1
# 424 files - 1
# 435 files - 1
# 436 files - 1
# 444 files - 1
# 452 files - 1
# 454 files - 2
# 459 files - 1
# 462 files - 1
# 476 files - 1
# 486 files - 1
# 487 files - 1
# 489 files - 1
# 492 files - 1
# 493 files - 1
# 495 files - 1
# 497 files - 1
# 501 files - 1
# 503 files - 1
# 522 files - 1
# 526 files - 1
# 542 files - 2
# 544 files - 1
# 545 files - 1
# 574 files - 1
# 583 files - 1
# 585 files - 1
# 588 files - 1
# 590 files - 1
# 594 files - 1
# 610 files - 1
# 615 files - 1
# 619 files - 1
# 620 files - 1
# 622 files - 1
# 640 files - 1
# 657 files - 1
# 663 files - 1
# 677 files - 1
# 679 files - 1
# 688 files - 1
# 690 files - 1
# 720 files - 2
# 734 files - 1
# 746 files - 1
# 760 files - 1
# 762 files - 1
# 773 files - 1
# 794 files - 1
# 851 files - 1
# 852 files - 1
# 868 files - 1
# 896 files - 1
# 898 files - 1
# 940 files - 1
# 947 files - 1
# 953 files - 1
# 955 files - 1
# 963 files - 1
# 976 files - 1
# 977 files - 1
# 981 files - 1
# 1001 files - 1
# 1063 files - 1
# 1064 files - 2
# 1068 files - 1
# 1080 files - 1
# 1084 files - 1
# 1088 files - 1
# 1092 files - 1
# 1095 files - 1
# 1102 files - 1
# 1103 files - 1
# 1109 files - 1
# 1121 files - 1
# 1195 files - 1
# 1198 files - 1
# 1215 files - 1
# 1249 files - 1
# 1262 files - 1
# 1344 files - 1
# 1348 files - 1
# 1358 files - 1
# 1423 files - 1
# 1435 files - 1
# 1460 files - 1
# 1496 files - 1
# 1563 files - 1
# 1591 files - 1
# 1647 files - 1
# 1676 files - 1
# 1749 files - 1
# 1941 files - 1
# 2049 files - 1
# 2083 files - 1
# 2129 files - 1
# 2204 files - 1
# 2252 files - 1
# 2359 files - 1
# 2428 files - 1
# 2499 files - 1
# 2701 files - 1
# 2716 files - 1
# 2750 files - 1
# 2842 files - 1
# 2887 files - 1
# 3363 files - 1
# 3368 files - 1
# 3458 files - 1
# 4997 files - 1
# 5066 files - 1
# 5380 files - 1
# 5655 files - 1
# 6171 files - 1
# 8124 files - 1
# 8630 files - 1
# 8715 files - 1
# 8773 files - 1
# 11138 files - 1
# 11688 files - 1
# 14395 files - 1

# %%
print(f"Total of words with 0 or 1 or 2 files: {(sorted_df['total'] == 0).sum() + (sorted_df['total'] == 1).sum() +  (sorted_df['total'] == 2).sum()}")
# Out:
# Total of words with 0 or 1 or 2 files: 9010

# %%
# drop/delete the word folders that only contain 1 or 2 files
source_dir = "../lrs3_may/preprocessed_videos_all"
target_dir = "../lrs3_may/preprocessed_videos_dropped"

os.makedirs(target_dir, exist_ok=True)

words_to_delete = sorted_df[sorted_df['total'].isin([0, 1, 2])].index
print(words_to_delete)
moved = 0

for word in words_to_delete:
    folder_path = os.path.join(source_dir, word)

    if os.path.exists(folder_path):
        target_folder_path = os.path.join(target_dir, word)
        shutil.move(folder_path, target_folder_path)
        print(f"Moved {word} to {target_folder_path}")
        moved += 1
print(f"total moved: {moved}")
# Out:
# Index(['BIOMIMICRY', 'NEOCORTEX', 'AMANATULLAH', 'IPODS', 'SOFA', 'SLICK',
#        'OBSERVATIONAL', 'IPCC', 'ROBOTOSPHERE', 'LOYALTY',
#        ...
#        'MAZATL', 'BODILY', 'BOGGLING', 'BOGUS', 'BOHR', 'MAXIMIZING', 'MAX'S',
#        'MAVERICK', 'MAVEN', 'KEITH'],
#       dtype='object', length=9010)
# Moved BIOMIMICRY to ../lrs3_may/preprocessed_videos_dropped/BIOMIMICRY
# Moved NEOCORTEX to ../lrs3_may/preprocessed_videos_dropped/NEOCORTEX
# Moved AMANATULLAH to ../lrs3_may/preprocessed_videos_dropped/AMANATULLAH
# Moved IPODS to ../lrs3_may/preprocessed_videos_dropped/IPODS
# Moved SOFA to ../lrs3_may/preprocessed_videos_dropped/SOFA
# Moved SLICK to ../lrs3_may/preprocessed_videos_dropped/SLICK
# Moved OBSERVATIONAL to ../lrs3_may/preprocessed_videos_dropped/OBSERVATIONAL
# Moved IPCC to ../lrs3_may/preprocessed_videos_dropped/IPCC
# Moved ROBOTOSPHERE to ../lrs3_may/preprocessed_videos_dropped/ROBOTOSPHERE
# Moved LOYALTY to ../lrs3_may/preprocessed_videos_dropped/LOYALTY
# Moved MUTUALLY to ../lrs3_may/preprocessed_videos_dropped/MUTUALLY
# Moved STYROFOAM to ../lrs3_may/preprocessed_videos_dropped/STYROFOAM
# Moved NERVOUSLY to ../lrs3_may/preprocessed_videos_dropped/NERVOUSLY
# Moved SLIPPER to ../lrs3_may/preprocessed_videos_dropped/SLIPPER
# Moved IPRONIAZID to ../lrs3_may/preprocessed_videos_dropped/IPRONIAZID
# Moved LUCAS to ../lrs3_may/preprocessed_videos_dropped/LUCAS
# Moved BIOMASS to ../lrs3_may/preprocessed_videos_dropped/BIOMASS
# Moved SUPERHERO to ../lrs3_may/preprocessed_videos_dropped/SUPERHERO
# Moved SOCIOLOGIST to ../lrs3_may/preprocessed_videos_dropped/SOCIOLOGIST
# Moved SIXTEEN to ../lrs3_may/preprocessed_videos_dropped/SIXTEEN
# Moved PARTICIPATED to ../lrs3_may/preprocessed_videos_dropped/PARTICIPATED
# Moved INVESTIGATIVE to ../lrs3_may/preprocessed_videos_dropped/INVESTIGATIVE
# Moved INGENUITY to ../lrs3_may/preprocessed_videos_dropped/INGENUITY
# Moved INHALE to ../lrs3_may/preprocessed_videos_dropped/INHALE
# Moved MAYANS to ../lrs3_may/preprocessed_videos_dropped/MAYANS
# Moved BOMBINGS to ../lrs3_may/preprocessed_videos_dropped/BOMBINGS
# Moved MARGINALIZE to ../lrs3_may/preprocessed_videos_dropped/MARGINALIZE
# Moved ROCA to ../lrs3_may/preprocessed_videos_dropped/ROCA
# Moved INFUSION to ../lrs3_may/preprocessed_videos_dropped/INFUSION
# Moved BUN to ../lrs3_may/preprocessed_videos_dropped/BUN
# Moved INTRUSION to ../lrs3_may/preprocessed_videos_dropped/INTRUSION
# Moved ROBE to ../lrs3_may/preprocessed_videos_dropped/ROBE
# Moved PALETTE to ../lrs3_may/preprocessed_videos_dropped/PALETTE
# Moved SIREN to ../lrs3_may/preprocessed_videos_dropped/SIREN
# Moved OBJECTIVITY to ../lrs3_may/preprocessed_videos_dropped/OBJECTIVITY
# Moved AMPLIFY to ../lrs3_may/preprocessed_videos_dropped/AMPLIFY
# Moved INJECTABLE to ../lrs3_may/preprocessed_videos_dropped/INJECTABLE
# Moved INTRICATE to ../lrs3_may/preprocessed_videos_dropped/INTRICATE
# Moved NEEDLE to ../lrs3_may/preprocessed_videos_dropped/NEEDLE
# Moved LOVER to ../lrs3_may/preprocessed_videos_dropped/LOVER
# Moved BOBBY to ../lrs3_may/preprocessed_videos_dropped/BOBBY
# Moved ONSET to ../lrs3_may/preprocessed_videos_dropped/ONSET
# Moved SOBBING to ../lrs3_may/preprocessed_videos_dropped/SOBBING
# Moved SEASICK to ../lrs3_may/preprocessed_videos_dropped/SEASICK
# Moved NEIGHBORING to ../lrs3_may/preprocessed_videos_dropped/NEIGHBORING
# Moved SAFEWAY to ../lrs3_may/preprocessed_videos_dropped/SAFEWAY
# Moved NEGATIVELY to ../lrs3_may/preprocessed_videos_dropped/NEGATIVELY
# Moved BOMBER to ../lrs3_may/preprocessed_videos_dropped/BOMBER
# Moved APOSTLE to ../lrs3_may/preprocessed_videos_dropped/APOSTLE
# Moved SOFTBALL to ../lrs3_may/preprocessed_videos_dropped/SOFTBALL
# Moved BASS to ../lrs3_may/preprocessed_videos_dropped/BASS
# Moved SELECTING to ../lrs3_may/preprocessed_videos_dropped/SELECTING
# Moved SCROLL to ../lrs3_may/preprocessed_videos_dropped/SCROLL
# Moved SLOPE to ../lrs3_may/preprocessed_videos_dropped/SLOPE
# Moved INGENIOUS to ../lrs3_may/preprocessed_videos_dropped/INGENIOUS
# Moved MARITAL to ../lrs3_may/preprocessed_videos_dropped/MARITAL
# Moved NEGOTIATE to ../lrs3_may/preprocessed_videos_dropped/NEGOTIATE
# Moved BILINGUAL to ../lrs3_may/preprocessed_videos_dropped/BILINGUAL
# Moved NIGERIAN to ../lrs3_may/preprocessed_videos_dropped/NIGERIAN
# Moved NEPAL to ../lrs3_may/preprocessed_videos_dropped/NEPAL
# Moved INVOICE to ../lrs3_may/preprocessed_videos_dropped/INVOICE
# Moved MYSTERIOUSLY to ../lrs3_may/preprocessed_videos_dropped/MYSTERIOUSLY
# Moved MANKIND to ../lrs3_may/preprocessed_videos_dropped/MANKIND
# Moved STUNNING to ../lrs3_may/preprocessed_videos_dropped/STUNNING
# Moved LUCKILY to ../lrs3_may/preprocessed_videos_dropped/LUCKILY
# Moved BULK to ../lrs3_may/preprocessed_videos_dropped/BULK
# Moved AFRICA'S to ../lrs3_may/preprocessed_videos_dropped/AFRICA'S
# Moved RISD to ../lrs3_may/preprocessed_videos_dropped/RISD
# Moved OBSERVER to ../lrs3_may/preprocessed_videos_dropped/OBSERVER
# Moved SCREW to ../lrs3_may/preprocessed_videos_dropped/SCREW
# Moved MANUSCRIPT to ../lrs3_may/preprocessed_videos_dropped/MANUSCRIPT
# Moved INHERENTLY to ../lrs3_may/preprocessed_videos_dropped/INHERENTLY
# Moved SALSA to ../lrs3_may/preprocessed_videos_dropped/SALSA
# Moved SALTY to ../lrs3_may/preprocessed_videos_dropped/SALTY
# Moved SUPERBUGS to ../lrs3_may/preprocessed_videos_dropped/SUPERBUGS
# Moved AMINO to ../lrs3_may/preprocessed_videos_dropped/AMINO
# Moved NIECE to ../lrs3_may/preprocessed_videos_dropped/NIECE
# Moved INVERTEBRATE to ../lrs3_may/preprocessed_videos_dropped/INVERTEBRATE
# Moved MBA to ../lrs3_may/preprocessed_videos_dropped/MBA
# Moved INHERENT to ../lrs3_may/preprocessed_videos_dropped/INHERENT
# Moved PALMPILOTS to ../lrs3_may/preprocessed_videos_dropped/PALMPILOTS
# Moved SAP to ../lrs3_may/preprocessed_videos_dropped/SAP
# Moved AMNIOTIC to ../lrs3_may/preprocessed_videos_dropped/AMNIOTIC
# Moved MYSTERIOUS to ../lrs3_may/preprocessed_videos_dropped/MYSTERIOUS
# Moved INHALER to ../lrs3_may/preprocessed_videos_dropped/INHALER
# Moved AQUAPONICS to ../lrs3_may/preprocessed_videos_dropped/AQUAPONICS
# Moved SUNNY to ../lrs3_may/preprocessed_videos_dropped/SUNNY
# Moved RIPPING to ../lrs3_may/preprocessed_videos_dropped/RIPPING
# Moved SAHARA to ../lrs3_may/preprocessed_videos_dropped/SAHARA
# Moved SUPERFICIAL to ../lrs3_may/preprocessed_videos_dropped/SUPERFICIAL
# Moved PALEO to ../lrs3_may/preprocessed_videos_dropped/PALEO
# Moved BON to ../lrs3_may/preprocessed_videos_dropped/BON
# Moved STUFFED to ../lrs3_may/preprocessed_videos_dropped/STUFFED
# Moved SOCIALIZATION to ../lrs3_may/preprocessed_videos_dropped/SOCIALIZATION
# Moved MARBURG to ../lrs3_may/preprocessed_videos_dropped/MARBURG
# Moved MCGOWAN to ../lrs3_may/preprocessed_videos_dropped/MCGOWAN
# Moved BENEFITING to ../lrs3_may/preprocessed_videos_dropped/BENEFITING
# Moved SOCIOECONOMIC to ../lrs3_may/preprocessed_videos_dropped/SOCIOECONOMIC
# Moved SELINGER to ../lrs3_may/preprocessed_videos_dropped/SELINGER
# Moved MARDER to ../lrs3_may/preprocessed_videos_dropped/MARDER
# Moved SOCIO to ../lrs3_may/preprocessed_videos_dropped/SOCIO
# Moved INHIBITIONS to ../lrs3_may/preprocessed_videos_dropped/INHIBITIONS
# Moved NEGRO to ../lrs3_may/preprocessed_videos_dropped/NEGRO
# Moved OPENLY to ../lrs3_may/preprocessed_videos_dropped/OPENLY
# Moved INVOLVEMENT to ../lrs3_may/preprocessed_videos_dropped/INVOLVEMENT
# Moved SLOT to ../lrs3_may/preprocessed_videos_dropped/SLOT
# Moved BULB to ../lrs3_may/preprocessed_videos_dropped/BULB
# Moved BEIRUT to ../lrs3_may/preprocessed_videos_dropped/BEIRUT
# Moved SALTING to ../lrs3_may/preprocessed_videos_dropped/SALTING
# Moved LT to ../lrs3_may/preprocessed_videos_dropped/LT
# Moved INVADE to ../lrs3_may/preprocessed_videos_dropped/INVADE
# Moved ANTELOPE to ../lrs3_may/preprocessed_videos_dropped/ANTELOPE
# Moved MARGINALIZED to ../lrs3_may/preprocessed_videos_dropped/MARGINALIZED
# Moved AQUARIUM to ../lrs3_may/preprocessed_videos_dropped/AQUARIUM
# Moved MANJU to ../lrs3_may/preprocessed_videos_dropped/MANJU
# Moved SUNFLOWER to ../lrs3_may/preprocessed_videos_dropped/SUNFLOWER
# Moved INGRAINED to ../lrs3_may/preprocessed_videos_dropped/INGRAINED
# Moved BULLY to ../lrs3_may/preprocessed_videos_dropped/BULLY
# Moved INTUIT to ../lrs3_may/preprocessed_videos_dropped/INTUIT
# Moved SUBMISSION to ../lrs3_may/preprocessed_videos_dropped/SUBMISSION
# Moved ROBBINS to ../lrs3_may/preprocessed_videos_dropped/ROBBINS
# Moved NATURE'S to ../lrs3_may/preprocessed_videos_dropped/NATURE'S
# Moved OCTOPUS to ../lrs3_may/preprocessed_videos_dropped/OCTOPUS
# Moved MAMMOGRAPHY to ../lrs3_may/preprocessed_videos_dropped/MAMMOGRAPHY
# Moved INSERT to ../lrs3_may/preprocessed_videos_dropped/INSERT
# Moved MAMMOGRAM to ../lrs3_may/preprocessed_videos_dropped/MAMMOGRAM
# Moved ADVISEDLY to ../lrs3_may/preprocessed_videos_dropped/ADVISEDLY
# Moved SALAD to ../lrs3_may/preprocessed_videos_dropped/SALAD
# Moved SCOTLAND to ../lrs3_may/preprocessed_videos_dropped/SCOTLAND
# Moved INSIGHTFUL to ../lrs3_may/preprocessed_videos_dropped/INSIGHTFUL
# Moved INSIST to ../lrs3_may/preprocessed_videos_dropped/INSIST
# Moved MAILING to ../lrs3_may/preprocessed_videos_dropped/MAILING
# Moved PARALYZING to ../lrs3_may/preprocessed_videos_dropped/PARALYZING
# Moved SECRECY to ../lrs3_may/preprocessed_videos_dropped/SECRECY
# Moved BUSTED to ../lrs3_may/preprocessed_videos_dropped/BUSTED
# Moved BORE to ../lrs3_may/preprocessed_videos_dropped/BORE
# Moved BIODEGRADABLE to ../lrs3_may/preprocessed_videos_dropped/BIODEGRADABLE
# Moved BURIAL to ../lrs3_may/preprocessed_videos_dropped/BURIAL
# Moved PARAMEDICS to ../lrs3_may/preprocessed_videos_dropped/PARAMEDICS
# Moved SKIPPED to ../lrs3_may/preprocessed_videos_dropped/SKIPPED
# Moved INTENDED to ../lrs3_may/preprocessed_videos_dropped/INTENDED
# Moved BID to ../lrs3_may/preprocessed_videos_dropped/BID
# Moved NEVERTHELESS to ../lrs3_may/preprocessed_videos_dropped/NEVERTHELESS
# Moved BURGER to ../lrs3_may/preprocessed_videos_dropped/BURGER
# Moved INSECURE to ../lrs3_may/preprocessed_videos_dropped/INSECURE
# Moved INSECTICIDE to ../lrs3_may/preprocessed_videos_dropped/INSECTICIDE
# Moved SNAPCHAT to ../lrs3_may/preprocessed_videos_dropped/SNAPCHAT
# Moved SNAPPER to ../lrs3_may/preprocessed_videos_dropped/SNAPPER
# Moved INTERCOURSE to ../lrs3_may/preprocessed_videos_dropped/INTERCOURSE
# Moved NANOTECHNOLOGY to ../lrs3_may/preprocessed_videos_dropped/NANOTECHNOLOGY
# Moved ANTIOXIDANT to ../lrs3_may/preprocessed_videos_dropped/ANTIOXIDANT
# Moved SANDY to ../lrs3_may/preprocessed_videos_dropped/SANDY
# Moved ARABLE to ../lrs3_may/preprocessed_videos_dropped/ARABLE
# Moved BENT to ../lrs3_may/preprocessed_videos_dropped/BENT
# Moved SCRAMJET to ../lrs3_may/preprocessed_videos_dropped/SCRAMJET
# Moved INTERCONNECTEDNESS to ../lrs3_may/preprocessed_videos_dropped/INTERCONNECTEDNESS
# Moved SUITED to ../lrs3_may/preprocessed_videos_dropped/SUITED
# Moved ROADSIDE to ../lrs3_may/preprocessed_videos_dropped/ROADSIDE
# Moved SUBURBIA to ../lrs3_may/preprocessed_videos_dropped/SUBURBIA
# Moved PARAGRAPH to ../lrs3_may/preprocessed_videos_dropped/PARAGRAPH
# Moved SNAP to ../lrs3_may/preprocessed_videos_dropped/SNAP
# Moved PARALLEL to ../lrs3_may/preprocessed_videos_dropped/PARALLEL
# Moved SKINNER to ../lrs3_may/preprocessed_videos_dropped/SKINNER
# Moved SKINNY to ../lrs3_may/preprocessed_videos_dropped/SKINNY
# Moved SNAKE to ../lrs3_may/preprocessed_videos_dropped/SNAKE
# Moved AFFIRMED to ../lrs3_may/preprocessed_videos_dropped/AFFIRMED
# Moved SUCCEEDED to ../lrs3_may/preprocessed_videos_dropped/SUCCEEDED
# Moved NARCISSUS to ../lrs3_may/preprocessed_videos_dropped/NARCISSUS
# Moved PARAPHRASE to ../lrs3_may/preprocessed_videos_dropped/PARAPHRASE
# Moved SEEKERS to ../lrs3_may/preprocessed_videos_dropped/SEEKERS
# Moved INTELLECTUALLY to ../lrs3_may/preprocessed_videos_dropped/INTELLECTUALLY
# Moved SALARY to ../lrs3_may/preprocessed_videos_dropped/SALARY
# Moved NARROWING to ../lrs3_may/preprocessed_videos_dropped/NARROWING
# Moved BURYING to ../lrs3_may/preprocessed_videos_dropped/BURYING
# Moved INSULA to ../lrs3_may/preprocessed_videos_dropped/INSULA
# Moved AMEND to ../lrs3_may/preprocessed_videos_dropped/AMEND
# Moved SMIRK to ../lrs3_may/preprocessed_videos_dropped/SMIRK
# Moved OCCUPY to ../lrs3_may/preprocessed_videos_dropped/OCCUPY
# Moved SUFFERERS to ../lrs3_may/preprocessed_videos_dropped/SUFFERERS
# Moved NASA'S to ../lrs3_may/preprocessed_videos_dropped/NASA'S
# Moved PARENTAL to ../lrs3_may/preprocessed_videos_dropped/PARENTAL
# Moved SECULARIZED to ../lrs3_may/preprocessed_videos_dropped/SECULARIZED
# Moved ANTICIPATION to ../lrs3_may/preprocessed_videos_dropped/ANTICIPATION
# Moved INSTRUMENTAL to ../lrs3_may/preprocessed_videos_dropped/INSTRUMENTAL
# Moved BOLT to ../lrs3_may/preprocessed_videos_dropped/BOLT
# Moved AESTHETIC to ../lrs3_may/preprocessed_videos_dropped/AESTHETIC
# Moved SCOUTED to ../lrs3_may/preprocessed_videos_dropped/SCOUTED
# Moved BIOGRAPHY to ../lrs3_may/preprocessed_videos_dropped/BIOGRAPHY
# Moved SAMSUNG to ../lrs3_may/preprocessed_videos_dropped/SAMSUNG
# Moved NEWLY to ../lrs3_may/preprocessed_videos_dropped/NEWLY
# Moved APPEALING to ../lrs3_may/preprocessed_videos_dropped/APPEALING
# Moved OCEANIC to ../lrs3_may/preprocessed_videos_dropped/OCEANIC
# Moved SUFFICIENTLY to ../lrs3_may/preprocessed_videos_dropped/SUFFICIENTLY
# Moved AFFECTIONATE to ../lrs3_may/preprocessed_videos_dropped/AFFECTIONATE
# Moved INSURER to ../lrs3_may/preprocessed_videos_dropped/INSURER
# Moved NATIONALLY to ../lrs3_may/preprocessed_videos_dropped/NATIONALLY
# Moved MARTYR to ../lrs3_may/preprocessed_videos_dropped/MARTYR
# Moved SLAUGHTER to ../lrs3_may/preprocessed_videos_dropped/SLAUGHTER
# Moved BURNING to ../lrs3_may/preprocessed_videos_dropped/BURNING
# Moved INTELLECT to ../lrs3_may/preprocessed_videos_dropped/INTELLECT
# Moved PARASITE to ../lrs3_may/preprocessed_videos_dropped/PARASITE
# Moved NEWSROOMS to ../lrs3_may/preprocessed_videos_dropped/NEWSROOMS
# Moved INTEGRATION to ../lrs3_may/preprocessed_videos_dropped/INTEGRATION
# Moved MAST to ../lrs3_may/preprocessed_videos_dropped/MAST
# Moved OCR to ../lrs3_may/preprocessed_videos_dropped/OCR
# Moved SALARIES to ../lrs3_may/preprocessed_videos_dropped/SALARIES
# Moved INSTILL to ../lrs3_may/preprocessed_videos_dropped/INSTILL
# Moved BIOLOGICALLY to ../lrs3_may/preprocessed_videos_dropped/BIOLOGICALLY
# Moved BOOMING to ../lrs3_may/preprocessed_videos_dropped/BOOMING
# Moved INTEGRAL to ../lrs3_may/preprocessed_videos_dropped/INTEGRAL
# Moved SMOKER to ../lrs3_may/preprocessed_videos_dropped/SMOKER
# Moved PARASITIC to ../lrs3_may/preprocessed_videos_dropped/PARASITIC
# Moved MAMA'S to ../lrs3_may/preprocessed_videos_dropped/MAMA'S
# Moved SALESPEOPLE to ../lrs3_may/preprocessed_videos_dropped/SALESPEOPLE
# Moved SMOKED to ../lrs3_may/preprocessed_videos_dropped/SMOKED
# Moved AMENDMENT to ../lrs3_may/preprocessed_videos_dropped/AMENDMENT
# Moved SLAVERY to ../lrs3_may/preprocessed_videos_dropped/SLAVERY
# Moved MATERNAL to ../lrs3_may/preprocessed_videos_dropped/MATERNAL
# Moved MA to ../lrs3_may/preprocessed_videos_dropped/MA
# Moved BUTT to ../lrs3_may/preprocessed_videos_dropped/BUTT
# Moved SNOWY to ../lrs3_may/preprocessed_videos_dropped/SNOWY
# Moved NICEST to ../lrs3_may/preprocessed_videos_dropped/NICEST
# Moved OBSOLETE to ../lrs3_may/preprocessed_videos_dropped/OBSOLETE
# Moved INTERTWINED to ../lrs3_may/preprocessed_videos_dropped/INTERTWINED
# Moved ROBBED to ../lrs3_may/preprocessed_videos_dropped/ROBBED
# Moved INTERSECTION to ../lrs3_may/preprocessed_videos_dropped/INTERSECTION
# Moved BOOM to ../lrs3_may/preprocessed_videos_dropped/BOOM
# Moved BIOMARKER to ../lrs3_may/preprocessed_videos_dropped/BIOMARKER
# Moved SNOWMOBILE to ../lrs3_may/preprocessed_videos_dropped/SNOWMOBILE
# Moved MACRO to ../lrs3_may/preprocessed_videos_dropped/MACRO
# Moved SEAWATER to ../lrs3_may/preprocessed_videos_dropped/SEAWATER
# Moved AMBITION to ../lrs3_may/preprocessed_videos_dropped/AMBITION
# Moved MARKING to ../lrs3_may/preprocessed_videos_dropped/MARKING
# Moved SALMON to ../lrs3_may/preprocessed_videos_dropped/SALMON
# Moved SUMMIT to ../lrs3_may/preprocessed_videos_dropped/SUMMIT
# Moved PARSLEY to ../lrs3_may/preprocessed_videos_dropped/PARSLEY
# Moved INTERRUPTED to ../lrs3_may/preprocessed_videos_dropped/INTERRUPTED
# Moved ADVIL to ../lrs3_may/preprocessed_videos_dropped/ADVIL
# Moved BIOLOGIST to ../lrs3_may/preprocessed_videos_dropped/BIOLOGIST
# Moved INNOVATING to ../lrs3_may/preprocessed_videos_dropped/INNOVATING
# Moved SEGREGATED to ../lrs3_may/preprocessed_videos_dropped/SEGREGATED
# Moved MACHINERY to ../lrs3_may/preprocessed_videos_dropped/MACHINERY
# Moved BINGE to ../lrs3_may/preprocessed_videos_dropped/BINGE
# Moved SKEPTICAL to ../lrs3_may/preprocessed_videos_dropped/SKEPTICAL
# Moved ROBBERY to ../lrs3_may/preprocessed_videos_dropped/ROBBERY
# Moved SUBCONTRACTING to ../lrs3_may/preprocessed_videos_dropped/SUBCONTRACTING
# Moved MA'AM to ../lrs3_may/preprocessed_videos_dropped/MA'AM
# Moved BIND to ../lrs3_may/preprocessed_videos_dropped/BIND
# Moved INTRACTABLE to ../lrs3_may/preprocessed_videos_dropped/INTRACTABLE
# Moved BELINDA to ../lrs3_may/preprocessed_videos_dropped/BELINDA
# Moved NAILED to ../lrs3_may/preprocessed_videos_dropped/NAILED
# Moved INJECTION to ../lrs3_may/preprocessed_videos_dropped/INJECTION
# Moved SUMMONED to ../lrs3_may/preprocessed_videos_dropped/SUMMONED
# Moved SANTA to ../lrs3_may/preprocessed_videos_dropped/SANTA
# Moved MAC to ../lrs3_may/preprocessed_videos_dropped/MAC
# Moved SEISMIC to ../lrs3_may/preprocessed_videos_dropped/SEISMIC
# Moved NICKNAME to ../lrs3_may/preprocessed_videos_dropped/NICKNAME
# Moved MARKETPLACE to ../lrs3_may/preprocessed_videos_dropped/MARKETPLACE
# Moved SLOWING to ../lrs3_may/preprocessed_videos_dropped/SLOWING
# Moved INTIMATE to ../lrs3_may/preprocessed_videos_dropped/INTIMATE
# Moved INTIMACY to ../lrs3_may/preprocessed_videos_dropped/INTIMACY
# Moved SOAKED to ../lrs3_may/preprocessed_videos_dropped/SOAKED
# Moved INJURED to ../lrs3_may/preprocessed_videos_dropped/INJURED
# Moved SCRAPED to ../lrs3_may/preprocessed_videos_dropped/SCRAPED
# Moved BATTERIES to ../lrs3_may/preprocessed_videos_dropped/BATTERIES
# Moved ANXIETIES to ../lrs3_may/preprocessed_videos_dropped/ANXIETIES
# Moved SCRAPBOOK to ../lrs3_may/preprocessed_videos_dropped/SCRAPBOOK
# Moved SNAPPING to ../lrs3_may/preprocessed_videos_dropped/SNAPPING
# Moved SUBMITTED to ../lrs3_may/preprocessed_videos_dropped/SUBMITTED
# Moved SCORING to ../lrs3_may/preprocessed_videos_dropped/SCORING
# Moved INTERMINABLE to ../lrs3_may/preprocessed_videos_dropped/INTERMINABLE
# Moved NANNY to ../lrs3_may/preprocessed_videos_dropped/NANNY
# Moved SAILOR to ../lrs3_may/preprocessed_videos_dropped/SAILOR
# Moved SUBSIDIZED to ../lrs3_may/preprocessed_videos_dropped/SUBSIDIZED
# Moved SUBSISTENCE to ../lrs3_may/preprocessed_videos_dropped/SUBSISTENCE
# Moved SCRAP to ../lrs3_may/preprocessed_videos_dropped/SCRAP
# Moved BATIK to ../lrs3_may/preprocessed_videos_dropped/BATIK
# Moved ADVISE to ../lrs3_may/preprocessed_videos_dropped/ADVISE
# Moved NANOMATERIALS to ../lrs3_may/preprocessed_videos_dropped/NANOMATERIALS
# Moved INTERFERENCE to ../lrs3_may/preprocessed_videos_dropped/INTERFERENCE
# Moved AMBIGUOUS to ../lrs3_may/preprocessed_videos_dropped/AMBIGUOUS
# Moved BONOBOS to ../lrs3_may/preprocessed_videos_dropped/BONOBOS
# Moved AMBIGUITY to ../lrs3_may/preprocessed_videos_dropped/AMBIGUITY
# Moved MAFIA to ../lrs3_may/preprocessed_videos_dropped/MAFIA
# Moved MAGELLANIC to ../lrs3_may/preprocessed_videos_dropped/MAGELLANIC
# Moved PARLIAMENTARY to ../lrs3_may/preprocessed_videos_dropped/PARLIAMENTARY
# Moved SUBSTANTIALLY to ../lrs3_may/preprocessed_videos_dropped/SUBSTANTIALLY
# Moved AMID to ../lrs3_may/preprocessed_videos_dropped/AMID
# Moved SNEAK to ../lrs3_may/preprocessed_videos_dropped/SNEAK
# Moved NANOSCALE to ../lrs3_may/preprocessed_videos_dropped/NANOSCALE
# Moved NANCY to ../lrs3_may/preprocessed_videos_dropped/NANCY
# Moved OESTROGEN to ../lrs3_may/preprocessed_videos_dropped/OESTROGEN
# Moved INORGANIC to ../lrs3_may/preprocessed_videos_dropped/INORGANIC
# Moved SEGMENT to ../lrs3_may/preprocessed_videos_dropped/SEGMENT
# Moved PAROXETINE to ../lrs3_may/preprocessed_videos_dropped/PAROXETINE
# Moved ROBARDS to ../lrs3_may/preprocessed_videos_dropped/ROBARDS
# Moved MADDIE'S to ../lrs3_may/preprocessed_videos_dropped/MADDIE'S
# Moved INTERRELATED to ../lrs3_may/preprocessed_videos_dropped/INTERRELATED
# Moved MANDELA to ../lrs3_may/preprocessed_videos_dropped/MANDELA
# Moved INTERPRETING to ../lrs3_may/preprocessed_videos_dropped/INTERPRETING
# Moved MANDATE to ../lrs3_may/preprocessed_videos_dropped/MANDATE
# Moved BUTCH to ../lrs3_may/preprocessed_videos_dropped/BUTCH
# Moved SUBSCRIBE to ../lrs3_may/preprocessed_videos_dropped/SUBSCRIBE
# Moved INTERNIST to ../lrs3_may/preprocessed_videos_dropped/INTERNIST
# Moved PAPYRUS to ../lrs3_may/preprocessed_videos_dropped/PAPYRUS
# Moved SALIENT to ../lrs3_may/preprocessed_videos_dropped/SALIENT
# Moved BIOCHEMICAL to ../lrs3_may/preprocessed_videos_dropped/BIOCHEMICAL
# Moved SLEDGE to ../lrs3_may/preprocessed_videos_dropped/SLEDGE
# Moved PAPERWORK to ../lrs3_may/preprocessed_videos_dropped/PAPERWORK
# Moved MADISON to ../lrs3_may/preprocessed_videos_dropped/MADISON
# Moved SUMMARY to ../lrs3_may/preprocessed_videos_dropped/SUMMARY
# Moved PAPUA to ../lrs3_may/preprocessed_videos_dropped/PAPUA
# Moved INTERN to ../lrs3_may/preprocessed_videos_dropped/INTERN
# Moved NICELY to ../lrs3_may/preprocessed_videos_dropped/NICELY
# Moved SPIT to ../lrs3_may/preprocessed_videos_dropped/SPIT
# Moved MELTING to ../lrs3_may/preprocessed_videos_dropped/MELTING
# Moved IRAQI to ../lrs3_may/preprocessed_videos_dropped/IRAQI
# Moved KILOWATT to ../lrs3_may/preprocessed_videos_dropped/KILOWATT
# Moved SHARP to ../lrs3_may/preprocessed_videos_dropped/SHARP
# Moved NUMBING to ../lrs3_may/preprocessed_videos_dropped/NUMBING
# Moved OUTWEIGHED to ../lrs3_may/preprocessed_videos_dropped/OUTWEIGHED
# Moved NORTHWEST to ../lrs3_may/preprocessed_videos_dropped/NORTHWEST
# Moved MOBILITY to ../lrs3_may/preprocessed_videos_dropped/MOBILITY
# Moved ANEW to ../lrs3_may/preprocessed_videos_dropped/ANEW
# Moved BROADENED to ../lrs3_may/preprocessed_videos_dropped/BROADENED
# Moved BROADLY to ../lrs3_may/preprocessed_videos_dropped/BROADLY
# Moved MOCK to ../lrs3_may/preprocessed_videos_dropped/MOCK
# Moved OVARIAN to ../lrs3_may/preprocessed_videos_dropped/OVARIAN
# Moved BREADTH to ../lrs3_may/preprocessed_videos_dropped/BREADTH
# Moved APOLOGIZE to ../lrs3_may/preprocessed_videos_dropped/APOLOGIZE
# Moved SPECIALITY to ../lrs3_may/preprocessed_videos_dropped/SPECIALITY
# Moved APPRECIATING to ../lrs3_may/preprocessed_videos_dropped/APPRECIATING
# Moved RUNWAY to ../lrs3_may/preprocessed_videos_dropped/RUNWAY
# Moved MEYERHOFF to ../lrs3_may/preprocessed_videos_dropped/MEYERHOFF
# Moved MEVLANA to ../lrs3_may/preprocessed_videos_dropped/MEVLANA
# Moved LEGITIMATE to ../lrs3_may/preprocessed_videos_dropped/LEGITIMATE
# Moved KHAN to ../lrs3_may/preprocessed_videos_dropped/KHAN
# Moved ALASKA to ../lrs3_may/preprocessed_videos_dropped/ALASKA
# Moved STARTUP to ../lrs3_may/preprocessed_videos_dropped/STARTUP
# Moved MODIFICATION to ../lrs3_may/preprocessed_videos_dropped/MODIFICATION
# Moved KEYBOARD to ../lrs3_may/preprocessed_videos_dropped/KEYBOARD
# Moved STARVING to ../lrs3_may/preprocessed_videos_dropped/STARVING
# Moved MODULES to ../lrs3_may/preprocessed_videos_dropped/MODULES
# Moved LEISURE to ../lrs3_may/preprocessed_videos_dropped/LEISURE
# Moved OVERCAME to ../lrs3_may/preprocessed_videos_dropped/OVERCAME
# Moved ROUNDED to ../lrs3_may/preprocessed_videos_dropped/ROUNDED
# Moved LEEWAY to ../lrs3_may/preprocessed_videos_dropped/LEEWAY
# Moved STATED to ../lrs3_may/preprocessed_videos_dropped/STATED
# Moved RUNG to ../lrs3_may/preprocessed_videos_dropped/RUNG
# Moved NUGGETS to ../lrs3_may/preprocessed_videos_dropped/NUGGETS
# Moved BLANK to ../lrs3_may/preprocessed_videos_dropped/BLANK
# Moved SPECIFIED to ../lrs3_may/preprocessed_videos_dropped/SPECIFIED
# Moved MITCHELL to ../lrs3_may/preprocessed_videos_dropped/MITCHELL
# Moved ORGANIZER to ../lrs3_may/preprocessed_videos_dropped/ORGANIZER
# Moved BETRAY to ../lrs3_may/preprocessed_videos_dropped/BETRAY
# Moved OUTSIDER to ../lrs3_may/preprocessed_videos_dropped/OUTSIDER
# Moved MITOCHONDRIAL to ../lrs3_may/preprocessed_videos_dropped/MITOCHONDRIAL
# Moved OUTSOURCING to ../lrs3_may/preprocessed_videos_dropped/OUTSOURCING
# Moved MITROVICA to ../lrs3_may/preprocessed_videos_dropped/MITROVICA
# Moved RUNAWAY to ../lrs3_may/preprocessed_videos_dropped/RUNAWAY
# Moved BETRAYAL to ../lrs3_may/preprocessed_videos_dropped/BETRAYAL
# Moved STAMPED to ../lrs3_may/preprocessed_videos_dropped/STAMPED
# Moved MICHELIN to ../lrs3_may/preprocessed_videos_dropped/MICHELIN
# Moved STANCE to ../lrs3_may/preprocessed_videos_dropped/STANCE
# Moved KINGDOM to ../lrs3_may/preprocessed_videos_dropped/KINGDOM
# Moved KINETIC to ../lrs3_may/preprocessed_videos_dropped/KINETIC
# Moved ALCHEMIST to ../lrs3_may/preprocessed_videos_dropped/ALCHEMIST
# Moved KINDNESS to ../lrs3_may/preprocessed_videos_dropped/KINDNESS
# Moved KINDLY to ../lrs3_may/preprocessed_videos_dropped/KINDLY
# Moved SHARPEN to ../lrs3_may/preprocessed_videos_dropped/SHARPEN
# Moved MOB to ../lrs3_may/preprocessed_videos_dropped/MOB
# Moved MICAH to ../lrs3_may/preprocessed_videos_dropped/MICAH
# Moved STANDARDISED to ../lrs3_may/preprocessed_videos_dropped/STANDARDISED
# Moved OUTSTANDING to ../lrs3_may/preprocessed_videos_dropped/OUTSTANDING
# Moved SPECIALTY to ../lrs3_may/preprocessed_videos_dropped/SPECIALTY
# Moved BROADBAND to ../lrs3_may/preprocessed_videos_dropped/BROADBAND
# Moved ALARMING to ../lrs3_may/preprocessed_videos_dropped/ALARMING
# Moved ORDERLY to ../lrs3_may/preprocessed_videos_dropped/ORDERLY
# Moved OVERSIGHT to ../lrs3_may/preprocessed_videos_dropped/OVERSIGHT
# Moved STDS to ../lrs3_may/preprocessed_videos_dropped/STDS
# Moved OVERLAPPING to ../lrs3_may/preprocessed_videos_dropped/OVERLAPPING
# Moved LEVER to ../lrs3_may/preprocessed_videos_dropped/LEVER
# Moved STEALING to ../lrs3_may/preprocessed_videos_dropped/STEALING
# Moved STEAM to ../lrs3_may/preprocessed_videos_dropped/STEAM
# Moved RUSS to ../lrs3_may/preprocessed_videos_dropped/RUSS
# Moved ALLERGIES to ../lrs3_may/preprocessed_videos_dropped/ALLERGIES
# Moved ALLEY to ../lrs3_may/preprocessed_videos_dropped/ALLEY
# Moved STEEL to ../lrs3_may/preprocessed_videos_dropped/STEEL
# Moved STEEPED to ../lrs3_may/preprocessed_videos_dropped/STEEPED
# Moved OVERLOAD to ../lrs3_may/preprocessed_videos_dropped/OVERLOAD
# Moved STEERING to ../lrs3_may/preprocessed_videos_dropped/STEERING
# Moved NORMALITY to ../lrs3_may/preprocessed_videos_dropped/NORMALITY
# Moved SIDED to ../lrs3_may/preprocessed_videos_dropped/SIDED
# Moved BETTING to ../lrs3_may/preprocessed_videos_dropped/BETTING
# Moved STELLAR to ../lrs3_may/preprocessed_videos_dropped/STELLAR
# Moved BLOCKCHAIN to ../lrs3_may/preprocessed_videos_dropped/BLOCKCHAIN
# Moved ANGIOGRAM to ../lrs3_may/preprocessed_videos_dropped/ANGIOGRAM
# Moved LGBTQ to ../lrs3_may/preprocessed_videos_dropped/LGBTQ
# Moved MONITORED to ../lrs3_may/preprocessed_videos_dropped/MONITORED
# Moved METALLIC to ../lrs3_may/preprocessed_videos_dropped/METALLIC
# Moved BRONNIE to ../lrs3_may/preprocessed_videos_dropped/BRONNIE
# Moved LIABLE to ../lrs3_may/preprocessed_videos_dropped/LIABLE
# Moved STEPPING to ../lrs3_may/preprocessed_videos_dropped/STEPPING
# Moved LIBERATE to ../lrs3_may/preprocessed_videos_dropped/LIBERATE
# Moved OVERREACTION to ../lrs3_may/preprocessed_videos_dropped/OVERREACTION
# Moved SPACEX to ../lrs3_may/preprocessed_videos_dropped/SPACEX
# Moved OVERSEAS to ../lrs3_may/preprocessed_videos_dropped/OVERSEAS
# Moved MONARCH to ../lrs3_may/preprocessed_videos_dropped/MONARCH
# Moved OVERLAP to ../lrs3_may/preprocessed_videos_dropped/OVERLAP
# Moved SHAPING to ../lrs3_may/preprocessed_videos_dropped/SHAPING
# Moved ROTE to ../lrs3_may/preprocessed_videos_dropped/ROTE
# Moved MOINES to ../lrs3_may/preprocessed_videos_dropped/MOINES
# Moved ROTTERDAM to ../lrs3_may/preprocessed_videos_dropped/ROTTERDAM
# Moved LEND to ../lrs3_may/preprocessed_videos_dropped/LEND
# Moved SPATIAL to ../lrs3_may/preprocessed_videos_dropped/SPATIAL
# Moved LEONARDO to ../lrs3_may/preprocessed_videos_dropped/LEONARDO
# Moved MOLD to ../lrs3_may/preprocessed_videos_dropped/MOLD
# Moved LEONE to ../lrs3_may/preprocessed_videos_dropped/LEONE
# Moved MOLE to ../lrs3_may/preprocessed_videos_dropped/MOLE
# Moved METRIC to ../lrs3_may/preprocessed_videos_dropped/METRIC
# Moved OVERFISHING to ../lrs3_may/preprocessed_videos_dropped/OVERFISHING
# Moved BLAKE to ../lrs3_may/preprocessed_videos_dropped/BLAKE
# Moved SHAOLIN to ../lrs3_may/preprocessed_videos_dropped/SHAOLIN
# Moved SHANGHAI to ../lrs3_may/preprocessed_videos_dropped/SHANGHAI
# Moved BETTERMENT to ../lrs3_may/preprocessed_videos_dropped/BETTERMENT
# Moved BRODERICK to ../lrs3_may/preprocessed_videos_dropped/BRODERICK
# Moved ALAN to ../lrs3_may/preprocessed_videos_dropped/ALAN
# Moved SHAMING to ../lrs3_may/preprocessed_videos_dropped/SHAMING
# Moved METHODOLOGY to ../lrs3_may/preprocessed_videos_dropped/METHODOLOGY
# Moved LESION to ../lrs3_may/preprocessed_videos_dropped/LESION
# Moved METH to ../lrs3_may/preprocessed_videos_dropped/METH
# Moved BLOCKBUSTER to ../lrs3_may/preprocessed_videos_dropped/BLOCKBUSTER
# Moved KAY to ../lrs3_may/preprocessed_videos_dropped/KAY
# Moved STAVE to ../lrs3_may/preprocessed_videos_dropped/STAVE
# Moved LETHAL to ../lrs3_may/preprocessed_videos_dropped/LETHAL
# Moved KATE to ../lrs3_may/preprocessed_videos_dropped/KATE
# Moved OVERHEARD to ../lrs3_may/preprocessed_videos_dropped/OVERHEARD
# Moved LETTUCE to ../lrs3_may/preprocessed_videos_dropped/LETTUCE
# Moved OUTREACH to ../lrs3_may/preprocessed_videos_dropped/OUTREACH
# Moved SHATTER to ../lrs3_may/preprocessed_videos_dropped/SHATTER
# Moved SHAUNA to ../lrs3_may/preprocessed_videos_dropped/SHAUNA
# Moved ANCHORED to ../lrs3_may/preprocessed_videos_dropped/ANCHORED
# Moved ORPHAN to ../lrs3_may/preprocessed_videos_dropped/ORPHAN
# Moved LATRINE to ../lrs3_may/preprocessed_videos_dropped/LATRINE
# Moved OTHERING to ../lrs3_may/preprocessed_videos_dropped/OTHERING
# Moved LATTER to ../lrs3_may/preprocessed_videos_dropped/LATTER
# Moved LATVIAN to ../lrs3_may/preprocessed_videos_dropped/LATVIAN
# Moved SPIKE to ../lrs3_may/preprocessed_videos_dropped/SPIKE
# Moved SHOUT to ../lrs3_may/preprocessed_videos_dropped/SHOUT
# Moved SPIETH to ../lrs3_may/preprocessed_videos_dropped/SPIETH
# Moved MIGHT'VE to ../lrs3_may/preprocessed_videos_dropped/MIGHT'VE
# Moved SHOUTED to ../lrs3_may/preprocessed_videos_dropped/SHOUTED
# Moved SPOTTED to ../lrs3_may/preprocessed_videos_dropped/SPOTTED
# Moved OTTOMAN to ../lrs3_may/preprocessed_videos_dropped/OTTOMAN
# Moved SPOTTY to ../lrs3_may/preprocessed_videos_dropped/SPOTTY
# Moved RUBBER to ../lrs3_may/preprocessed_videos_dropped/RUBBER
# Moved BREXIT to ../lrs3_may/preprocessed_videos_dropped/BREXIT
# Moved MIDWEST to ../lrs3_may/preprocessed_videos_dropped/MIDWEST
# Moved BECK to ../lrs3_may/preprocessed_videos_dropped/BECK
# Moved SCALED to ../lrs3_may/preprocessed_videos_dropped/SCALED
# Moved LACKED to ../lrs3_may/preprocessed_videos_dropped/LACKED
# Moved ALERT to ../lrs3_may/preprocessed_videos_dropped/ALERT
# Moved SPREADSHEET to ../lrs3_may/preprocessed_videos_dropped/SPREADSHEET
# Moved NOZZLE to ../lrs3_may/preprocessed_videos_dropped/NOZZLE
# Moved BEAUVOIR to ../lrs3_may/preprocessed_videos_dropped/BEAUVOIR
# Moved NP to ../lrs3_may/preprocessed_videos_dropped/NP
# Moved SHOCKINGLY to ../lrs3_may/preprocessed_videos_dropped/SHOCKINGLY
# Moved LABORERS to ../lrs3_may/preprocessed_videos_dropped/LABORERS
# Moved SPRINKLE to ../lrs3_may/preprocessed_videos_dropped/SPRINKLE
# Moved MINDED to ../lrs3_may/preprocessed_videos_dropped/MINDED
# Moved OSUN to ../lrs3_may/preprocessed_videos_dropped/OSUN
# Moved OUTRAGEOUS to ../lrs3_may/preprocessed_videos_dropped/OUTRAGEOUS
# Moved SPONSOR to ../lrs3_may/preprocessed_videos_dropped/SPONSOR
# Moved LAS to ../lrs3_may/preprocessed_videos_dropped/LAS
# Moved SPITTING to ../lrs3_may/preprocessed_videos_dropped/SPITTING
# Moved SAVVY to ../lrs3_may/preprocessed_videos_dropped/SAVVY
# Moved ANDERSON to ../lrs3_may/preprocessed_videos_dropped/ANDERSON
# Moved RUINED to ../lrs3_may/preprocessed_videos_dropped/RUINED
# Moved ANDERS to ../lrs3_may/preprocessed_videos_dropped/ANDERS
# Moved SHORTER to ../lrs3_may/preprocessed_videos_dropped/SHORTER
# Moved ORTHODOX to ../lrs3_may/preprocessed_videos_dropped/ORTHODOX
# Moved SHORTEN to ../lrs3_may/preprocessed_videos_dropped/SHORTEN
# Moved LATCH to ../lrs3_may/preprocessed_videos_dropped/LATCH
# Moved SPINAL to ../lrs3_may/preprocessed_videos_dropped/SPINAL
# Moved SPOCK to ../lrs3_may/preprocessed_videos_dropped/SPOCK
# Moved LANDING to ../lrs3_may/preprocessed_videos_dropped/LANDING
# Moved LATELY to ../lrs3_may/preprocessed_videos_dropped/LATELY
# Moved SPINACH to ../lrs3_may/preprocessed_videos_dropped/SPINACH
# Moved SPOIL to ../lrs3_may/preprocessed_videos_dropped/SPOIL
# Moved RUG to ../lrs3_may/preprocessed_videos_dropped/RUG
# Moved ORPHANAGE to ../lrs3_may/preprocessed_videos_dropped/ORPHANAGE
# Moved BRIAN'S to ../lrs3_may/preprocessed_videos_dropped/BRIAN'S
# Moved ANCHORING to ../lrs3_may/preprocessed_videos_dropped/ANCHORING
# Moved ALEXIS to ../lrs3_may/preprocessed_videos_dropped/ALEXIS
# Moved MILLENNIA to ../lrs3_may/preprocessed_videos_dropped/MILLENNIA
# Moved SHORE to ../lrs3_may/preprocessed_videos_dropped/SHORE
# Moved SAWYER to ../lrs3_may/preprocessed_videos_dropped/SAWYER
# Moved MIME to ../lrs3_may/preprocessed_videos_dropped/MIME
# Moved LAMP to ../lrs3_may/preprocessed_videos_dropped/LAMP
# Moved BERT to ../lrs3_may/preprocessed_videos_dropped/BERT
# Moved SPICE to ../lrs3_may/preprocessed_videos_dropped/SPICE
# Moved LAUNCHES to ../lrs3_may/preprocessed_videos_dropped/LAUNCHES
# Moved ANARCHY to ../lrs3_may/preprocessed_videos_dropped/ANARCHY
# Moved LABELLED to ../lrs3_may/preprocessed_videos_dropped/LABELLED
# Moved NUANCED to ../lrs3_may/preprocessed_videos_dropped/NUANCED
# Moved MISINFORMATION to ../lrs3_may/preprocessed_videos_dropped/MISINFORMATION
# Moved SHRINK to ../lrs3_may/preprocessed_videos_dropped/SHRINK
# Moved KPI to ../lrs3_may/preprocessed_videos_dropped/KPI
# Moved BREEZE to ../lrs3_may/preprocessed_videos_dropped/BREEZE
# Moved SAVORY to ../lrs3_may/preprocessed_videos_dropped/SAVORY
# Moved SHELL to ../lrs3_may/preprocessed_videos_dropped/SHELL
# Moved MISLEADING to ../lrs3_may/preprocessed_videos_dropped/MISLEADING
# Moved NUDGE to ../lrs3_may/preprocessed_videos_dropped/NUDGE
# Moved BEDTIME to ../lrs3_may/preprocessed_videos_dropped/BEDTIME
# Moved KONG to ../lrs3_may/preprocessed_videos_dropped/KONG
# Moved KONA to ../lrs3_may/preprocessed_videos_dropped/KONA
# Moved ALCOHOLISM to ../lrs3_may/preprocessed_videos_dropped/ALCOHOLISM
# Moved NOSTALGIA to ../lrs3_may/preprocessed_videos_dropped/NOSTALGIA
# Moved MARCUS to ../lrs3_may/preprocessed_videos_dropped/MARCUS
# Moved LEAF to ../lrs3_may/preprocessed_videos_dropped/LEAF
# Moved SPECULATE to ../lrs3_may/preprocessed_videos_dropped/SPECULATE
# Moved OUTPUT to ../lrs3_may/preprocessed_videos_dropped/OUTPUT
# Moved ALCOHOLIC to ../lrs3_may/preprocessed_videos_dropped/ALCOHOLIC
# Moved MISSILE to ../lrs3_may/preprocessed_videos_dropped/MISSILE
# Moved ORIENTATION to ../lrs3_may/preprocessed_videos_dropped/ORIENTATION
# Moved SHED to ../lrs3_may/preprocessed_videos_dropped/SHED
# Moved MISSOURI to ../lrs3_may/preprocessed_videos_dropped/MISSOURI
# Moved KNOCKING to ../lrs3_may/preprocessed_videos_dropped/KNOCKING
# Moved ANESTHESIA to ../lrs3_may/preprocessed_videos_dropped/ANESTHESIA
# Moved KNOCKED to ../lrs3_may/preprocessed_videos_dropped/KNOCKED
# Moved SPECTACULAR to ../lrs3_may/preprocessed_videos_dropped/SPECTACULAR
# Moved ROWE to ../lrs3_may/preprocessed_videos_dropped/ROWE
# Moved ROWERS to ../lrs3_may/preprocessed_videos_dropped/ROWERS
# Moved OUTLINED to ../lrs3_may/preprocessed_videos_dropped/OUTLINED
# Moved LAWRENCE to ../lrs3_may/preprocessed_videos_dropped/LAWRENCE
# Moved LAURAN to ../lrs3_may/preprocessed_videos_dropped/LAURAN
# Moved MIDDAY to ../lrs3_may/preprocessed_videos_dropped/MIDDAY
# Moved RS to ../lrs3_may/preprocessed_videos_dropped/RS
# Moved BLINDLY to ../lrs3_may/preprocessed_videos_dropped/BLINDLY
# Moved SHIT to ../lrs3_may/preprocessed_videos_dropped/SHIT
# Moved BESTOWED to ../lrs3_may/preprocessed_videos_dropped/BESTOWED
# Moved L1 to ../lrs3_may/preprocessed_videos_dropped/L1
# Moved OUTER to ../lrs3_may/preprocessed_videos_dropped/OUTER
# Moved LAVAVOLO to ../lrs3_may/preprocessed_videos_dropped/LAVAVOLO
# Moved RUMOR to ../lrs3_may/preprocessed_videos_dropped/RUMOR
# Moved ORIGINATE to ../lrs3_may/preprocessed_videos_dropped/ORIGINATE
# Moved SQUADRON to ../lrs3_may/preprocessed_videos_dropped/SQUADRON
# Moved LAWSUIT to ../lrs3_may/preprocessed_videos_dropped/LAWSUIT
# Moved SQUEEZING to ../lrs3_may/preprocessed_videos_dropped/SQUEEZING
# Moved SQUANDER to ../lrs3_may/preprocessed_videos_dropped/SQUANDER
# Moved MICROSCOPIC to ../lrs3_may/preprocessed_videos_dropped/MICROSCOPIC
# Moved KUSH to ../lrs3_may/preprocessed_videos_dropped/KUSH
# Moved ALIGNED to ../lrs3_may/preprocessed_videos_dropped/ALIGNED
# Moved NOTHINGNESS to ../lrs3_may/preprocessed_videos_dropped/NOTHINGNESS
# Moved SPENCER'S to ../lrs3_may/preprocessed_videos_dropped/SPENCER'S
# Moved SPELLING to ../lrs3_may/preprocessed_videos_dropped/SPELLING
# Moved NOTHING'S to ../lrs3_may/preprocessed_videos_dropped/NOTHING'S
# Moved SPEEDING to ../lrs3_may/preprocessed_videos_dropped/SPEEDING
# Moved SHIFTED to ../lrs3_may/preprocessed_videos_dropped/SHIFTED
# Moved SCANNED to ../lrs3_may/preprocessed_videos_dropped/SCANNED
# Moved MICROORGANISMS to ../lrs3_may/preprocessed_videos_dropped/MICROORGANISMS
# Moved BLACKOUT to ../lrs3_may/preprocessed_videos_dropped/BLACKOUT
# Moved JUSTIN to ../lrs3_may/preprocessed_videos_dropped/JUSTIN
# Moved SINKING to ../lrs3_may/preprocessed_videos_dropped/SINKING
# Moved MT to ../lrs3_may/preprocessed_videos_dropped/MT
# Moved BHUTAN to ../lrs3_may/preprocessed_videos_dropped/BHUTAN
# Moved STRAP to ../lrs3_may/preprocessed_videos_dropped/STRAP
# Moved APOLOGIZED to ../lrs3_may/preprocessed_videos_dropped/APOLOGIZED
# Moved ALTERING to ../lrs3_may/preprocessed_videos_dropped/ALTERING
# Moved ALTERNATE to ../lrs3_may/preprocessed_videos_dropped/ALTERNATE
# Moved OBESE to ../lrs3_may/preprocessed_videos_dropped/OBESE
# Moved SOMALILAND to ../lrs3_may/preprocessed_videos_dropped/SOMALILAND
# Moved AGLOE to ../lrs3_may/preprocessed_videos_dropped/AGLOE
# Moved SEQUENCING to ../lrs3_may/preprocessed_videos_dropped/SEQUENCING
# Moved MELATONIN to ../lrs3_may/preprocessed_videos_dropped/MELATONIN
# Moved AMUSEMENT to ../lrs3_may/preprocessed_videos_dropped/AMUSEMENT
# Moved BUDDHA to ../lrs3_may/preprocessed_videos_dropped/BUDDHA
# Moved JAFFA to ../lrs3_may/preprocessed_videos_dropped/JAFFA
# Moved ANNOUNCING to ../lrs3_may/preprocessed_videos_dropped/ANNOUNCING
# Moved MUD to ../lrs3_may/preprocessed_videos_dropped/MUD
# Moved MUFFIN to ../lrs3_may/preprocessed_videos_dropped/MUFFIN
# Moved SADNESS to ../lrs3_may/preprocessed_videos_dropped/SADNESS
# Moved MULTICULTURAL to ../lrs3_may/preprocessed_videos_dropped/MULTICULTURAL
# Moved JACKIE to ../lrs3_may/preprocessed_videos_dropped/JACKIE
# Moved STREAMING to ../lrs3_may/preprocessed_videos_dropped/STREAMING
# Moved SIMPLEST to ../lrs3_may/preprocessed_videos_dropped/SIMPLEST
# Moved SEPARATELY to ../lrs3_may/preprocessed_videos_dropped/SEPARATELY
# Moved IYA to ../lrs3_may/preprocessed_videos_dropped/IYA
# Moved IV to ../lrs3_may/preprocessed_videos_dropped/IV
# Moved BEHAVING to ../lrs3_may/preprocessed_videos_dropped/BEHAVING
# Moved AGGRESSION to ../lrs3_may/preprocessed_videos_dropped/AGGRESSION
# Moved SOLUBLE to ../lrs3_may/preprocessed_videos_dropped/SOLUBLE
# Moved LOCKER to ../lrs3_may/preprocessed_videos_dropped/LOCKER
# Moved BOWLES to ../lrs3_may/preprocessed_videos_dropped/BOWLES
# Moved STRESSES to ../lrs3_may/preprocessed_videos_dropped/STRESSES
# Moved SCHMIDT to ../lrs3_may/preprocessed_videos_dropped/SCHMIDT
# Moved ALPHA to ../lrs3_may/preprocessed_videos_dropped/ALPHA
# Moved MOTTO to ../lrs3_may/preprocessed_videos_dropped/MOTTO
# Moved LOBBY to ../lrs3_may/preprocessed_videos_dropped/LOBBY
# Moved ROMANTICIZE to ../lrs3_may/preprocessed_videos_dropped/ROMANTICIZE
# Moved JENN to ../lrs3_may/preprocessed_videos_dropped/JENN
# Moved MOUND to ../lrs3_may/preprocessed_videos_dropped/MOUND
# Moved STRAIN to ../lrs3_may/preprocessed_videos_dropped/STRAIN
# Moved OATH to ../lrs3_may/preprocessed_videos_dropped/OATH
# Moved LOBE to ../lrs3_may/preprocessed_videos_dropped/LOBE
# Moved MOUNTING to ../lrs3_may/preprocessed_videos_dropped/MOUNTING
# Moved JELLY to ../lrs3_may/preprocessed_videos_dropped/JELLY
# Moved MOURN to ../lrs3_may/preprocessed_videos_dropped/MOURN
# Moved SEROTONIN to ../lrs3_may/preprocessed_videos_dropped/SEROTONIN
# Moved LOBSTER to ../lrs3_may/preprocessed_videos_dropped/LOBSTER
# Moved SERMON to ../lrs3_may/preprocessed_videos_dropped/SERMON
# Moved MEMO to ../lrs3_may/preprocessed_videos_dropped/MEMO
# Moved MEME to ../lrs3_may/preprocessed_videos_dropped/MEME
# Moved MEMBERSHIP to ../lrs3_may/preprocessed_videos_dropped/MEMBERSHIP
# Moved ANNOUNCEMENT to ../lrs3_may/preprocessed_videos_dropped/ANNOUNCEMENT
# Moved LOCALIZE to ../lrs3_may/preprocessed_videos_dropped/LOCALIZE
# Moved JAUNDICE to ../lrs3_may/preprocessed_videos_dropped/JAUNDICE
# Moved LOCATE to ../lrs3_may/preprocessed_videos_dropped/LOCATE
# Moved LOCATED to ../lrs3_may/preprocessed_videos_dropped/LOCATED
# Moved MPH to ../lrs3_may/preprocessed_videos_dropped/MPH
# Moved SIMON to ../lrs3_may/preprocessed_videos_dropped/SIMON
# Moved OSCAR to ../lrs3_may/preprocessed_videos_dropped/OSCAR
# Moved JARGON to ../lrs3_may/preprocessed_videos_dropped/JARGON
# Moved BUDDHIST to ../lrs3_may/preprocessed_videos_dropped/BUDDHIST
# Moved ITERATION to ../lrs3_may/preprocessed_videos_dropped/ITERATION
# Moved METABOLICALLY to ../lrs3_may/preprocessed_videos_dropped/METABOLICALLY
# Moved BLUNT to ../lrs3_may/preprocessed_videos_dropped/BLUNT
# Moved BOUNCING to ../lrs3_may/preprocessed_videos_dropped/BOUNCING
# Moved BLUR to ../lrs3_may/preprocessed_videos_dropped/BLUR
# Moved LOTUS to ../lrs3_may/preprocessed_videos_dropped/LOTUS
# Moved MEDIAN to ../lrs3_may/preprocessed_videos_dropped/MEDIAN
# Moved STRIVING to ../lrs3_may/preprocessed_videos_dropped/STRIVING
# Moved OBJECTIFICATION to ../lrs3_may/preprocessed_videos_dropped/OBJECTIFICATION
# Moved PAIRED to ../lrs3_may/preprocessed_videos_dropped/PAIRED
# Moved IRS to ../lrs3_may/preprocessed_videos_dropped/IRS
# Moved AGEN to ../lrs3_may/preprocessed_videos_dropped/AGEN
# Moved BLURRY to ../lrs3_may/preprocessed_videos_dropped/BLURRY
# Moved OPERATED to ../lrs3_may/preprocessed_videos_dropped/OPERATED
# Moved LOUIS to ../lrs3_may/preprocessed_videos_dropped/LOUIS
# Moved LOUISIANA to ../lrs3_may/preprocessed_videos_dropped/LOUISIANA
# Moved PAJAMA to ../lrs3_may/preprocessed_videos_dropped/PAJAMA
# Moved INFLUENZA to ../lrs3_may/preprocessed_videos_dropped/INFLUENZA
# Moved SAFEST to ../lrs3_may/preprocessed_videos_dropped/SAFEST
# Moved MEATLESS to ../lrs3_may/preprocessed_videos_dropped/MEATLESS
# Moved SENSING to ../lrs3_may/preprocessed_videos_dropped/SENSING
# Moved IRONY to ../lrs3_may/preprocessed_videos_dropped/IRONY
# Moved MURPHY to ../lrs3_may/preprocessed_videos_dropped/MURPHY
# Moved IRONICALLY to ../lrs3_may/preprocessed_videos_dropped/IRONICALLY
# Moved SENSATION to ../lrs3_may/preprocessed_videos_dropped/SENSATION
# Moved ANYBODY'S to ../lrs3_may/preprocessed_videos_dropped/ANYBODY'S
# Moved BMP2 to ../lrs3_may/preprocessed_videos_dropped/BMP2
# Moved BOULEVARD to ../lrs3_may/preprocessed_videos_dropped/BOULEVARD
# Moved SINGING to ../lrs3_may/preprocessed_videos_dropped/SINGING
# Moved SARCOMA to ../lrs3_may/preprocessed_videos_dropped/SARCOMA
# Moved ALTRIA'S to ../lrs3_may/preprocessed_videos_dropped/ALTRIA'S
# Moved MUNICIPALITIES to ../lrs3_may/preprocessed_videos_dropped/MUNICIPALITIES
# Moved PAINFULLY to ../lrs3_may/preprocessed_videos_dropped/PAINFULLY
# Moved MEDICINAL to ../lrs3_may/preprocessed_videos_dropped/MEDICINAL
# Moved ITCHY to ../lrs3_may/preprocessed_videos_dropped/ITCHY
# Moved MULTIPLIER to ../lrs3_may/preprocessed_videos_dropped/MULTIPLIER
# Moved ITALIAN to ../lrs3_may/preprocessed_videos_dropped/ITALIAN
# Moved BUDDY to ../lrs3_may/preprocessed_videos_dropped/BUDDY
# Moved OPERATOR to ../lrs3_may/preprocessed_videos_dropped/OPERATOR
# Moved MULTIPLIES to ../lrs3_may/preprocessed_videos_dropped/MULTIPLIES
# Moved PAINKILLER to ../lrs3_may/preprocessed_videos_dropped/PAINKILLER
# Moved AGER to ../lrs3_may/preprocessed_videos_dropped/AGER
# Moved MEDITATIVE to ../lrs3_may/preprocessed_videos_dropped/MEDITATIVE
# Moved LOOSE to ../lrs3_may/preprocessed_videos_dropped/LOOSE
# Moved BLUEPRINT to ../lrs3_may/preprocessed_videos_dropped/BLUEPRINT
# Moved MEDITATE to ../lrs3_may/preprocessed_videos_dropped/MEDITATE
# Moved LORD to ../lrs3_may/preprocessed_videos_dropped/LORD
# Moved NINETEEN to ../lrs3_may/preprocessed_videos_dropped/NINETEEN
# Moved ISSUING to ../lrs3_may/preprocessed_videos_dropped/ISSUING
# Moved SENTIMENT to ../lrs3_may/preprocessed_videos_dropped/SENTIMENT
# Moved STRETCHING to ../lrs3_may/preprocessed_videos_dropped/STRETCHING
# Moved SOLE to ../lrs3_may/preprocessed_videos_dropped/SOLE
# Moved APOPHIS to ../lrs3_may/preprocessed_videos_dropped/APOPHIS
# Moved MULTITASKING to ../lrs3_may/preprocessed_videos_dropped/MULTITASKING
# Moved OBEYING to ../lrs3_may/preprocessed_videos_dropped/OBEYING
# Moved ISOTOPES to ../lrs3_may/preprocessed_videos_dropped/ISOTOPES
# Moved OPERATIONAL to ../lrs3_may/preprocessed_videos_dropped/OPERATIONAL
# Moved SCHREYER to ../lrs3_may/preprocessed_videos_dropped/SCHREYER
# Moved STRIIV to ../lrs3_may/preprocessed_videos_dropped/STRIIV
# Moved MUMCHKIN to ../lrs3_may/preprocessed_videos_dropped/MUMCHKIN
# Moved MEDIEVAL to ../lrs3_may/preprocessed_videos_dropped/MEDIEVAL
# Moved BOXES to ../lrs3_may/preprocessed_videos_dropped/BOXES
# Moved SERVER to ../lrs3_may/preprocessed_videos_dropped/SERVER
# Moved MOTORCYCLIST to ../lrs3_may/preprocessed_videos_dropped/MOTORCYCLIST
# Moved JULY to ../lrs3_may/preprocessed_videos_dropped/JULY
# Moved ROSA to ../lrs3_may/preprocessed_videos_dropped/ROSA
# Moved BEARING to ../lrs3_may/preprocessed_videos_dropped/BEARING
# Moved NUTRITIONAL to ../lrs3_may/preprocessed_videos_dropped/NUTRITIONAL
# Moved AIRFARE to ../lrs3_may/preprocessed_videos_dropped/AIRFARE
# Moved MONUMENTALLY to ../lrs3_may/preprocessed_videos_dropped/MONUMENTALLY
# Moved LIGAMENTS to ../lrs3_may/preprocessed_videos_dropped/LIGAMENTS
# Moved BRAINWASHED to ../lrs3_may/preprocessed_videos_dropped/BRAINWASHED
# Moved SIGNATURE to ../lrs3_may/preprocessed_videos_dropped/SIGNATURE
# Moved MERIT to ../lrs3_may/preprocessed_videos_dropped/MERIT
# Moved JUICER to ../lrs3_may/preprocessed_videos_dropped/JUICER
# Moved BEARD to ../lrs3_may/preprocessed_videos_dropped/BEARD
# Moved LIGHTER to ../lrs3_may/preprocessed_videos_dropped/LIGHTER
# Moved RUSTY to ../lrs3_may/preprocessed_videos_dropped/RUSTY
# Moved BROW to ../lrs3_may/preprocessed_videos_dropped/BROW
# Moved NONVIOLENCE to ../lrs3_may/preprocessed_videos_dropped/NONVIOLENCE
# Moved LIGHTLY to ../lrs3_may/preprocessed_videos_dropped/LIGHTLY
# Moved OPTIONAL to ../lrs3_may/preprocessed_videos_dropped/OPTIONAL
# Moved SATURATED to ../lrs3_may/preprocessed_videos_dropped/SATURATED
# Moved BLOGGING to ../lrs3_may/preprocessed_videos_dropped/BLOGGING
# Moved SIGNIFIERS to ../lrs3_may/preprocessed_videos_dropped/SIGNIFIERS
# Moved STIMULATION to ../lrs3_may/preprocessed_videos_dropped/STIMULATION
# Moved OWENS to ../lrs3_may/preprocessed_videos_dropped/OWENS
# Moved JUAN to ../lrs3_may/preprocessed_videos_dropped/JUAN
# Moved STIMULUS to ../lrs3_may/preprocessed_videos_dropped/STIMULUS
# Moved STING to ../lrs3_may/preprocessed_videos_dropped/STING
# Moved STINK to ../lrs3_may/preprocessed_videos_dropped/STINK
# Moved NYC to ../lrs3_may/preprocessed_videos_dropped/NYC
# Moved BRAINWAVE to ../lrs3_may/preprocessed_videos_dropped/BRAINWAVE
# Moved SIFTING to ../lrs3_may/preprocessed_videos_dropped/SIFTING
# Moved AGRIBUSINESS to ../lrs3_may/preprocessed_videos_dropped/AGRIBUSINESS
# Moved NURTURING to ../lrs3_may/preprocessed_videos_dropped/NURTURING
# Moved JUSTIFY to ../lrs3_may/preprocessed_videos_dropped/JUSTIFY
# Moved STEROIDS to ../lrs3_may/preprocessed_videos_dropped/STEROIDS
# Moved ROSS to ../lrs3_may/preprocessed_videos_dropped/ROSS
# Moved ORBITAL to ../lrs3_may/preprocessed_videos_dropped/ORBITAL
# Moved SHACKLED to ../lrs3_may/preprocessed_videos_dropped/SHACKLED
# ...
# Moved MANDARIN to ../lrs3_may/preprocessed_videos_dropped/MANDARIN
# Moved MANCHESTER to ../lrs3_may/preprocessed_videos_dropped/MANCHESTER
# Moved MANAGUA to ../lrs3_may/preprocessed_videos_dropped/MANAGUA
# Moved BONNIE to ../lrs3_may/preprocessed_videos_dropped/BONNIE
# Moved BONSAI to ../lrs3_may/preprocessed_videos_dropped/BONSAI
# Moved MANAGEABLE to ../lrs3_may/preprocessed_videos_dropped/MANAGEABLE
# Moved BONY to ../lrs3_may/preprocessed_videos_dropped/BONY
# Moved BOOKCASE to ../lrs3_may/preprocessed_videos_dropped/BOOKCASE
# Moved MARGINALLY to ../lrs3_may/preprocessed_videos_dropped/MARGINALLY
# Moved MARIANA'S to ../lrs3_may/preprocessed_videos_dropped/MARIANA'S
# Moved MARIANE to ../lrs3_may/preprocessed_videos_dropped/MARIANE
# Moved MARIE to ../lrs3_may/preprocessed_videos_dropped/MARIE
# Moved BOLSTER to ../lrs3_may/preprocessed_videos_dropped/BOLSTER
# Moved MARYANNE to ../lrs3_may/preprocessed_videos_dropped/MARYANNE
# Moved MARYAM to ../lrs3_may/preprocessed_videos_dropped/MARYAM
# Moved MARVIN to ../lrs3_may/preprocessed_videos_dropped/MARVIN
# Moved MARVELOUS to ../lrs3_may/preprocessed_videos_dropped/MARVELOUS
# Moved MARVELING to ../lrs3_may/preprocessed_videos_dropped/MARVELING
# Moved MARTINI to ../lrs3_may/preprocessed_videos_dropped/MARTINI
# Moved MARTIN'S to ../lrs3_may/preprocessed_videos_dropped/MARTIN'S
# Moved MARTIANS to ../lrs3_may/preprocessed_videos_dropped/MARTIANS
# Moved MARTHA to ../lrs3_may/preprocessed_videos_dropped/MARTHA
# Moved MARSUPIAL to ../lrs3_may/preprocessed_videos_dropped/MARSUPIAL
# Moved MARSHMALLOWS to ../lrs3_may/preprocessed_videos_dropped/MARSHMALLOWS
# Moved BOLTED to ../lrs3_may/preprocessed_videos_dropped/BOLTED
# Moved MARRYING to ../lrs3_may/preprocessed_videos_dropped/MARRYING
# Moved BOLTZMANN'S to ../lrs3_may/preprocessed_videos_dropped/BOLTZMANN'S
# Moved BOMBARDING to ../lrs3_may/preprocessed_videos_dropped/BOMBARDING
# Moved MARMITE to ../lrs3_may/preprocessed_videos_dropped/MARMITE
# Moved MARLOWE to ../lrs3_may/preprocessed_videos_dropped/MARLOWE
# Moved BOMBAY to ../lrs3_may/preprocessed_videos_dropped/BOMBAY
# Moved MARKETER'S to ../lrs3_may/preprocessed_videos_dropped/MARKETER'S
# Moved MARKETEERS to ../lrs3_may/preprocessed_videos_dropped/MARKETEERS
# Moved MARKETED to ../lrs3_may/preprocessed_videos_dropped/MARKETED
# Moved BOMBED to ../lrs3_may/preprocessed_videos_dropped/BOMBED
# Moved MARITIME to ../lrs3_may/preprocessed_videos_dropped/MARITIME
# Moved MARION to ../lrs3_may/preprocessed_videos_dropped/MARION
# Moved MARINA to ../lrs3_may/preprocessed_videos_dropped/MARINA
# Moved MARILYN to ../lrs3_may/preprocessed_videos_dropped/MARILYN
# Moved MARILEE to ../lrs3_may/preprocessed_videos_dropped/MARILEE
# Moved MARIJUANA'S to ../lrs3_may/preprocessed_videos_dropped/MARIJUANA'S
# Moved BOOKED to ../lrs3_may/preprocessed_videos_dropped/BOOKED
# Moved MAMMA to ../lrs3_may/preprocessed_videos_dropped/MAMMA
# Moved MAMIE to ../lrs3_may/preprocessed_videos_dropped/MAMIE
# Moved MAGNA to ../lrs3_may/preprocessed_videos_dropped/MAGNA
# Moved MAGI to ../lrs3_may/preprocessed_videos_dropped/MAGI
# Moved MAGGIE to ../lrs3_may/preprocessed_videos_dropped/MAGGIE
# Moved MADURO to ../lrs3_may/preprocessed_videos_dropped/MADURO
# Moved MADRID to ../lrs3_may/preprocessed_videos_dropped/MADRID
# Moved MADONNA to ../lrs3_may/preprocessed_videos_dropped/MADONNA
# Moved MADIBA to ../lrs3_may/preprocessed_videos_dropped/MADIBA
# Moved MADELEINE to ../lrs3_may/preprocessed_videos_dropped/MADELEINE
# Moved BORROWER to ../lrs3_may/preprocessed_videos_dropped/BORROWER
# Moved MADDIE to ../lrs3_may/preprocessed_videos_dropped/MADDIE
# Moved MADAME to ../lrs3_may/preprocessed_videos_dropped/MADAME
# Moved BORROWING to ../lrs3_may/preprocessed_videos_dropped/BORROWING
# Moved MACLACHLAN to ../lrs3_may/preprocessed_videos_dropped/MACLACHLAN
# Moved MACKEY to ../lrs3_may/preprocessed_videos_dropped/MACKEY
# Moved MACHO to ../lrs3_may/preprocessed_videos_dropped/MACHO
# Moved MACHE to ../lrs3_may/preprocessed_videos_dropped/MACHE
# Moved MACEDA to ../lrs3_may/preprocessed_videos_dropped/MACEDA
# Moved MACARTHUR to ../lrs3_may/preprocessed_videos_dropped/MACARTHUR
# Moved MAATHAI to ../lrs3_may/preprocessed_videos_dropped/MAATHAI
# Moved MAASAI to ../lrs3_may/preprocessed_videos_dropped/MAASAI
# Moved BOSNIAN to ../lrs3_may/preprocessed_videos_dropped/BOSNIAN
# Moved LZ to ../lrs3_may/preprocessed_videos_dropped/LZ
# Moved LYSOZYME to ../lrs3_may/preprocessed_videos_dropped/LYSOZYME
# Moved LYNX to ../lrs3_may/preprocessed_videos_dropped/LYNX
# Moved LYNCHING to ../lrs3_may/preprocessed_videos_dropped/LYNCHING
# Moved LUXURIOUS to ../lrs3_may/preprocessed_videos_dropped/LUXURIOUS
# Moved LUXURIATE to ../lrs3_may/preprocessed_videos_dropped/LUXURIATE
# Moved LURE to ../lrs3_may/preprocessed_videos_dropped/LURE
# Moved LUPITA to ../lrs3_may/preprocessed_videos_dropped/LUPITA
# Moved LUNCHTIME to ../lrs3_may/preprocessed_videos_dropped/LUNCHTIME
# Moved BORLAUG to ../lrs3_may/preprocessed_videos_dropped/BORLAUG
# Moved MAGNETAR to ../lrs3_may/preprocessed_videos_dropped/MAGNETAR
# Moved BOOKSHELVES to ../lrs3_may/preprocessed_videos_dropped/BOOKSHELVES
# Moved BORIS to ../lrs3_may/preprocessed_videos_dropped/BORIS
# Moved MALWARE to ../lrs3_may/preprocessed_videos_dropped/MALWARE
# Moved MALNUTRITION to ../lrs3_may/preprocessed_videos_dropped/MALNUTRITION
# Moved MALLORY to ../lrs3_may/preprocessed_videos_dropped/MALLORY
# Moved BOOKSTORE to ../lrs3_may/preprocessed_videos_dropped/BOOKSTORE
# Moved MALI to ../lrs3_may/preprocessed_videos_dropped/MALI
# Moved MALFUNCTION to ../lrs3_may/preprocessed_videos_dropped/MALFUNCTION
# Moved MALAYSIA to ../lrs3_may/preprocessed_videos_dropped/MALAYSIA
# Moved MALAWI to ../lrs3_may/preprocessed_videos_dropped/MALAWI
# Moved MALAKWANG to ../lrs3_may/preprocessed_videos_dropped/MALAKWANG
# Moved MALA to ../lrs3_may/preprocessed_videos_dropped/MALA
# Moved BOOMERANG to ../lrs3_may/preprocessed_videos_dropped/BOOMERANG
# Moved MAKHERS to ../lrs3_may/preprocessed_videos_dropped/MAKHERS
# Moved MAKESHIFT to ../lrs3_may/preprocessed_videos_dropped/MAKESHIFT
# Moved BOOMERS to ../lrs3_may/preprocessed_videos_dropped/BOOMERS
# Moved MAKEOVER to ../lrs3_may/preprocessed_videos_dropped/MAKEOVER
# Moved MAJORITIES to ../lrs3_may/preprocessed_videos_dropped/MAJORITIES
# Moved MAJORING to ../lrs3_may/preprocessed_videos_dropped/MAJORING
# Moved MAINTAINED to ../lrs3_may/preprocessed_videos_dropped/MAINTAINED
# Moved BORDEN to ../lrs3_may/preprocessed_videos_dropped/BORDEN
# Moved MAINLAND to ../lrs3_may/preprocessed_videos_dropped/MAINLAND
# Moved MAILERS to ../lrs3_may/preprocessed_videos_dropped/MAILERS
# Moved MAIDEN to ../lrs3_may/preprocessed_videos_dropped/MAIDEN
# Moved MAGNUSSEN to ../lrs3_may/preprocessed_videos_dropped/MAGNUSSEN
# Moved MAGNUM to ../lrs3_may/preprocessed_videos_dropped/MAGNUM
# Moved BOREDOM to ../lrs3_may/preprocessed_videos_dropped/BOREDOM
# Moved MAGNIFYING to ../lrs3_may/preprocessed_videos_dropped/MAGNIFYING
# Moved MAGNIFY to ../lrs3_may/preprocessed_videos_dropped/MAGNIFY
# Moved MAGNIFICENT to ../lrs3_may/preprocessed_videos_dropped/MAGNIFICENT
# Moved MAGNETISMS to ../lrs3_may/preprocessed_videos_dropped/MAGNETISMS
# Moved MASAI to ../lrs3_may/preprocessed_videos_dropped/MASAI
# Moved MASCULINIZING to ../lrs3_may/preprocessed_videos_dropped/MASCULINIZING
# Moved BLOCKAGES to ../lrs3_may/preprocessed_videos_dropped/BLOCKAGES
# Moved MELLODY to ../lrs3_may/preprocessed_videos_dropped/MELLODY
# Moved BLOODSHOT to ../lrs3_may/preprocessed_videos_dropped/BLOODSHOT
# Moved MENINGITIS to ../lrs3_may/preprocessed_videos_dropped/MENINGITIS
# Moved MENDEL to ../lrs3_may/preprocessed_videos_dropped/MENDEL
# Moved MENDED to ../lrs3_may/preprocessed_videos_dropped/MENDED
# Moved MEND to ../lrs3_may/preprocessed_videos_dropped/MEND
# Moved MENA to ../lrs3_may/preprocessed_videos_dropped/MENA
# Moved BLOODSTREAM to ../lrs3_may/preprocessed_videos_dropped/BLOODSTREAM
# Moved MEMORY'S to ../lrs3_may/preprocessed_videos_dropped/MEMORY'S
# Moved BLOOMBERG to ../lrs3_may/preprocessed_videos_dropped/BLOOMBERG
# Moved BLOSSOMED to ../lrs3_may/preprocessed_videos_dropped/BLOSSOMED
# Moved MEMORIALIZED to ../lrs3_may/preprocessed_videos_dropped/MEMORIALIZED
# Moved MEMORABILIA to ../lrs3_may/preprocessed_videos_dropped/MEMORABILIA
# Moved MEMOIR to ../lrs3_may/preprocessed_videos_dropped/MEMOIR
# Moved BLOSSOMING to ../lrs3_may/preprocessed_videos_dropped/BLOSSOMING
# Moved MELISSA'S to ../lrs3_may/preprocessed_videos_dropped/MELISSA'S
# Moved MASHED to ../lrs3_may/preprocessed_videos_dropped/MASHED
# Moved MELANOMAS to ../lrs3_may/preprocessed_videos_dropped/MELANOMAS
# Moved MEL to ../lrs3_may/preprocessed_videos_dropped/MEL
# Moved MEIJI to ../lrs3_may/preprocessed_videos_dropped/MEIJI
# Moved MEGAFAUNAS to ../lrs3_may/preprocessed_videos_dropped/MEGAFAUNAS
# Moved MEEGEREN to ../lrs3_may/preprocessed_videos_dropped/MEEGEREN
# Moved MEDS to ../lrs3_may/preprocessed_videos_dropped/MEDS
# Moved BLUEBERRY to ../lrs3_may/preprocessed_videos_dropped/BLUEBERRY
# Moved MEDIOCRITY'S to ../lrs3_may/preprocessed_videos_dropped/MEDIOCRITY'S
# Moved MEDIOCRITY to ../lrs3_may/preprocessed_videos_dropped/MEDIOCRITY
# Moved BLUER to ../lrs3_may/preprocessed_videos_dropped/BLUER
# Moved MEDICATE to ../lrs3_may/preprocessed_videos_dropped/MEDICATE
# Moved MEDICALLY to ../lrs3_may/preprocessed_videos_dropped/MEDICALLY
# Moved MEDIATE to ../lrs3_may/preprocessed_videos_dropped/MEDIATE
# Moved MEDIA'S to ../lrs3_may/preprocessed_videos_dropped/MEDIA'S
# Moved BLOODLETTING to ../lrs3_may/preprocessed_videos_dropped/BLOODLETTING
# Moved BLOOD'S to ../lrs3_may/preprocessed_videos_dropped/BLOOD'S
# Moved MENTIONING to ../lrs3_may/preprocessed_videos_dropped/MENTIONING
# Moved MENTORSHIP to ../lrs3_may/preprocessed_videos_dropped/MENTORSHIP
# Moved METHAMPHETAMINE to ../lrs3_may/preprocessed_videos_dropped/METHAMPHETAMINE
# Moved METASTATIC to ../lrs3_may/preprocessed_videos_dropped/METASTATIC
# Moved METAPHYSICS to ../lrs3_may/preprocessed_videos_dropped/METAPHYSICS
# Moved METAPHYSICAL to ../lrs3_may/preprocessed_videos_dropped/METAPHYSICAL
# Moved METAPHORICAL to ../lrs3_may/preprocessed_videos_dropped/METAPHORICAL
# Moved BLOCKER to ../lrs3_may/preprocessed_videos_dropped/BLOCKER
# Moved METABOLOMICS to ../lrs3_may/preprocessed_videos_dropped/METABOLOMICS
# Moved METABOLISM to ../lrs3_may/preprocessed_videos_dropped/METABOLISM
# Moved METAANALYSIS to ../lrs3_may/preprocessed_videos_dropped/METAANALYSIS
# Moved META to ../lrs3_may/preprocessed_videos_dropped/META
# Moved MESSIER to ../lrs3_may/preprocessed_videos_dropped/MESSIER
# Moved MESSI to ../lrs3_may/preprocessed_videos_dropped/MESSI
# Moved MESSED to ../lrs3_may/preprocessed_videos_dropped/MESSED
# Moved MESQUITE to ../lrs3_may/preprocessed_videos_dropped/MESQUITE
# Moved MESOTHELIN to ../lrs3_may/preprocessed_videos_dropped/MESOTHELIN
# Moved MESOPOTAMIA to ../lrs3_may/preprocessed_videos_dropped/MESOPOTAMIA
# Moved MESHING to ../lrs3_may/preprocessed_videos_dropped/MESHING
# Moved MESH to ../lrs3_may/preprocessed_videos_dropped/MESH
# Moved MESASGE to ../lrs3_may/preprocessed_videos_dropped/MESASGE
# Moved MERMAID to ../lrs3_may/preprocessed_videos_dropped/MERMAID
# Moved MERITOCRACY to ../lrs3_may/preprocessed_videos_dropped/MERITOCRACY
# Moved MERITED to ../lrs3_may/preprocessed_videos_dropped/MERITED
# Moved MERGING to ../lrs3_may/preprocessed_videos_dropped/MERGING
# Moved MERGERS to ../lrs3_may/preprocessed_videos_dropped/MERGERS
# Moved MERGED to ../lrs3_may/preprocessed_videos_dropped/MERGED
# Moved MERGE to ../lrs3_may/preprocessed_videos_dropped/MERGE
# Moved MERE to ../lrs3_may/preprocessed_videos_dropped/MERE
# Moved MERCEDES to ../lrs3_may/preprocessed_videos_dropped/MERCEDES
# Moved MERCANTILIST to ../lrs3_may/preprocessed_videos_dropped/MERCANTILIST
# Moved BLURRED to ../lrs3_may/preprocessed_videos_dropped/BLURRED
# Moved MECHANICALLY to ../lrs3_may/preprocessed_videos_dropped/MECHANICALLY
# Moved BLV to ../lrs3_may/preprocessed_videos_dropped/BLV
# Moved MATURITY to ../lrs3_may/preprocessed_videos_dropped/MATURITY
# Moved MATTHIEU'S to ../lrs3_may/preprocessed_videos_dropped/MATTHIEU'S
# Moved MATRIX to ../lrs3_may/preprocessed_videos_dropped/MATRIX
# Moved MATRILINEAL to ../lrs3_may/preprocessed_videos_dropped/MATRILINEAL
# Moved MATING to ../lrs3_may/preprocessed_videos_dropped/MATING
# Moved BOILED to ../lrs3_may/preprocessed_videos_dropped/BOILED
# Moved MATHEMATICALLY to ../lrs3_may/preprocessed_videos_dropped/MATHEMATICALLY
# Moved BOILERS to ../lrs3_may/preprocessed_videos_dropped/BOILERS
# Moved BOILING to ../lrs3_may/preprocessed_videos_dropped/BOILING
# Moved MATERNITY to ../lrs3_may/preprocessed_videos_dropped/MATERNITY
# Moved MATERIALIZES to ../lrs3_may/preprocessed_videos_dropped/MATERIALIZES
# Moved MATERIALITY to ../lrs3_may/preprocessed_videos_dropped/MATERIALITY
# Moved MATERIALISTIC to ../lrs3_may/preprocessed_videos_dropped/MATERIALISTIC
# Moved BOISE to ../lrs3_may/preprocessed_videos_dropped/BOISE
# Moved MATER to ../lrs3_may/preprocessed_videos_dropped/MATER
# Moved MATCHING to ../lrs3_may/preprocessed_videos_dropped/MATCHING
# Moved MASTURDATING to ../lrs3_may/preprocessed_videos_dropped/MASTURDATING
# Moved MASTURBATED to ../lrs3_may/preprocessed_videos_dropped/MASTURBATED
# Moved MASTERWORK to ../lrs3_may/preprocessed_videos_dropped/MASTERWORK
# Moved MASTERPIECE to ../lrs3_may/preprocessed_videos_dropped/MASTERPIECE
# Moved MASTERING to ../lrs3_may/preprocessed_videos_dropped/MASTERING
# Moved BOLDER to ../lrs3_may/preprocessed_videos_dropped/BOLDER
# Moved BOLEYN to ../lrs3_may/preprocessed_videos_dropped/BOLEYN
# Moved MASSES to ../lrs3_may/preprocessed_videos_dropped/MASSES
# Moved MASSAGE to ../lrs3_may/preprocessed_videos_dropped/MASSAGE
# Moved MASSACHUSETTS to ../lrs3_may/preprocessed_videos_dropped/MASSACHUSETTS
# Moved MASON to ../lrs3_may/preprocessed_videos_dropped/MASON
# Moved MASLIN to ../lrs3_may/preprocessed_videos_dropped/MASLIN
# Moved BOLLYWOOD to ../lrs3_may/preprocessed_videos_dropped/BOLLYWOOD
# Moved MASHING to ../lrs3_may/preprocessed_videos_dropped/MASHING
# Moved MATTRESSES to ../lrs3_may/preprocessed_videos_dropped/MATTRESSES
# Moved MAUI to ../lrs3_may/preprocessed_videos_dropped/MAUI
# Moved BMI to ../lrs3_may/preprocessed_videos_dropped/BMI
# Moved MAUREEN to ../lrs3_may/preprocessed_videos_dropped/MAUREEN
# Moved BMP to ../lrs3_may/preprocessed_videos_dropped/BMP
# Moved MEASLES to ../lrs3_may/preprocessed_videos_dropped/MEASLES
# Moved BOARDING to ../lrs3_may/preprocessed_videos_dropped/BOARDING
# Moved BOASTED to ../lrs3_may/preprocessed_videos_dropped/BOASTED
# Moved MEANINGLESS to ../lrs3_may/preprocessed_videos_dropped/MEANINGLESS
# Moved BOATING to ../lrs3_may/preprocessed_videos_dropped/BOATING
# Moved BOATMAN to ../lrs3_may/preprocessed_videos_dropped/BOATMAN
# Moved BOBBING to ../lrs3_may/preprocessed_videos_dropped/BOBBING
# Moved MEAD to ../lrs3_may/preprocessed_videos_dropped/MEAD
# Moved ME'ONE to ../lrs3_may/preprocessed_videos_dropped/ME'ONE
# Moved ME'I to ../lrs3_may/preprocessed_videos_dropped/ME'I
# Moved BODIED to ../lrs3_may/preprocessed_videos_dropped/BODIED
# Moved MCMAFIA to ../lrs3_may/preprocessed_videos_dropped/MCMAFIA
# Moved MCLAGLEN to ../lrs3_may/preprocessed_videos_dropped/MCLAGLEN
# Moved MCING to ../lrs3_may/preprocessed_videos_dropped/MCING
# Moved MCCALLUM to ../lrs3_may/preprocessed_videos_dropped/MCCALLUM
# Moved MCAVOY to ../lrs3_may/preprocessed_videos_dropped/MCAVOY
# Moved MCAT to ../lrs3_may/preprocessed_videos_dropped/MCAT
# Moved MC2 to ../lrs3_may/preprocessed_videos_dropped/MC2
# Moved MC to ../lrs3_may/preprocessed_videos_dropped/MC
# Moved MAZATL to ../lrs3_may/preprocessed_videos_dropped/MAZATL
# Moved BODILY to ../lrs3_may/preprocessed_videos_dropped/BODILY
# Moved BOGGLING to ../lrs3_may/preprocessed_videos_dropped/BOGGLING
# Moved BOGUS to ../lrs3_may/preprocessed_videos_dropped/BOGUS
# Moved BOHR to ../lrs3_may/preprocessed_videos_dropped/BOHR
# Moved MAXIMIZING to ../lrs3_may/preprocessed_videos_dropped/MAXIMIZING
# Moved MAX'S to ../lrs3_may/preprocessed_videos_dropped/MAX'S
# Moved MAVERICK to ../lrs3_may/preprocessed_videos_dropped/MAVERICK
# Moved MAVEN to ../lrs3_may/preprocessed_videos_dropped/MAVEN
# Moved KEITH to ../lrs3_may/preprocessed_videos_dropped/KEITH
# total moved: 9010

# %%
new_dir = "../lrs3_may/preprocessed_videos_all"
v2_df = create_df(new_dir)

# %%
# Compare original vs v2

# %%
# Train Val Test Counts for Original Dataset
print("\nOriginal Word and File Counts per Subfolder:")
print(sorted_df[['train', 'val', 'test', 'total']])
# Out:
# Original Word and File Counts per Subfolder:
#             train   val  test  total
# THE         11261  2816   318  14395
# TO           9084  2272   332  11688
# AND          8692  2173   273  11138
# THAT         6824  1706   243   8773
# I            6745  1687   283   8715
# ...           ...   ...   ...    ...
# MAXIMIZING      1     0     0      1
# MAX'S           1     0     0      1
# MAVERICK        1     0     0      1
# MAVEN           1     0     0      1
# KEITH           1     0     0      1
#
# [15267 rows x 4 columns]

# %%
# Train Val Test Counts for V2 Dataset
print("\nV2 Word and File Counts per Subfolder:")
v2_sorted_df = v2_df.sort_index()
v2_sorted_df['total'] = v2_sorted_df[['train', 'val', 'test']].sum(axis=1)
v2_sorted_df = v2_sorted_df.sort_values(by='total', ascending=False)
print(v2_sorted_df[['train', 'val', 'test', 'total']])
# Out:
# V2 Word and File Counts per Subfolder:
#            train   val  test  total
# THE        11261  2816   318  14395
# TO          9084  2272   332  11688
# AND         8692  2173   273  11138
# THAT        6824  1706   243   8773
# I           6745  1687   283   8715
# ...          ...   ...   ...    ...
# CRUSHING       1     1     1      3
# FORMATION      2     1     0      3
# FORREST        2     1     0      3
# SHATTERED      2     1     0      3
# COLDEST        1     1     1      3
#
# [6257 rows x 4 columns]

# %%
# Total of each set
total_train = sorted_df['train'].sum()
total_val = sorted_df['val'].sum()
total_test = sorted_df['test'].sum()

print(f"Total OG train: {total_train}")
print(f"Total OG val: {total_val}")
print(f"Total OG test: {total_test}")

v2_total_train = v2_sorted_df['train'].sum()
v2_total_val = v2_sorted_df['val'].sum()
v2_total_test = v2_sorted_df['test'].sum()

print(f"\nTotal V2 train: {v2_total_train}")
print(f"Total V2 val: {v2_total_val}")
print(f"Total V2 test: {v2_total_test}")
# Out:
# Total OG train: 283034
# Total OG val: 73735
# Total OG test: 9890
#
# Total V2 train: 274112
# Total V2 val: 71452
# Total V2 test: 9721

# %%
# The number of words that are empty in a set
total_train_zeros = (sorted_df['train'] == 0).sum()
total_val_zeros = (sorted_df['val'] == 0).sum()
total_test_zeros = (sorted_df['test'] == 0).sum()

print(f"Total OG train = 0: {total_train_zeros}")
print(f"Total OG val = 0: {total_val_zeros}")
print(f"Total OG test = 0: {total_test_zeros}")

v2_total_train_zeros = (v2_sorted_df['train'] == 0).sum()
v2_total_val_zeros = (v2_sorted_df['val'] == 0).sum()
v2_total_test_zeros = (v2_sorted_df['test'] == 0).sum()

print(f"\nTotal V2 train = 0: {v2_total_train_zeros}")
print(f"Total V2 val = 0: {v2_total_val_zeros}")
print(f"Total V2 test = 0: {v2_total_test_zeros}")
# Out:
# Total OG train = 0: 89
# Total OG val = 0: 6730
# Total OG test = 0: 13397
#
# Total V2 train = 0: 1
# Total V2 val = 0: 3
# Total V2 test = 0: 4553

# %%
# The number of words that have only 1 or 2 files
print(f"Total of words in OG with 1 or 2 files: {(sorted_df['total'] == 1).sum() +  (sorted_df['total'] == 2).sum()}")
print(f"Total of words in v2 with 1 or 2 files: {(v2_sorted_df['total'] == 1).sum() +  (v2_sorted_df['total'] == 2).sum()}")
# Out:
# Total of words in OG with 1 or 2 files: 9010
# Total of words in v2 with 1 or 2 files: 0

# %%
# Number of words
print(f"Number of words in OG: {sorted_df.shape[0]}")
print(f"Number of words in V2: {v2_sorted_df.shape[0]}")
# Out:
# Number of words in OG: 15267
# Number of words in V2: 6257

# %%
# Combine trainval again
moved = 0

# Loop through each word
for word in os.listdir(dir):
    # Define folder paths for train and val
    train_folder_path = os.path.join(dir, word, 'train')
    val_folder_path = os.path.join(dir, word, 'val')

    # Check if val folder exists and has files to move
    if os.path.exists(val_folder_path):
        # Check if train folder exists, if not create it
        if not os.path.exists(train_folder_path):
            os.makedirs(train_folder_path)

        # Move all files from val folder to train folder
        for item in os.listdir(val_folder_path):
            val_item_path = os.path.join(val_folder_path, item)
            train_item_path = os.path.join(train_folder_path, item)

            # Move the file
            if os.path.isdir(val_item_path):
                shutil.move(val_item_path, train_item_path)
            else:
                shutil.move(val_item_path, train_item_path)

        print(f"Moved all files from {word}/val to {word}/train")
        moved += 1

print(f"Total words processed: {moved}")
# Out:
# Moved all files from VIEWED/val to VIEWED/train
# Moved all files from RECENTLY/val to RECENTLY/train
# Moved all files from ARRIVE/val to ARRIVE/train
# Moved all files from THEIR/val to THEIR/train
# Moved all files from ARABIC/val to ARABIC/train
# Moved all files from CHEMOTHERAPY/val to CHEMOTHERAPY/train
# Moved all files from BOLD/val to BOLD/train
# Moved all files from PASSING/val to PASSING/train
# Moved all files from PARTICULAR/val to PARTICULAR/train
# Moved all files from BASKET/val to BASKET/train
# Moved all files from INFORMED/val to INFORMED/train
# Moved all files from ANTHROPOLOGY/val to ANTHROPOLOGY/train
# Moved all files from KILL/val to KILL/train
# Moved all files from GLAND/val to GLAND/train
# Moved all files from SHAKING/val to SHAKING/train
# Moved all files from SUM/val to SUM/train
# Moved all files from SYRIA/val to SYRIA/train
# Moved all files from RESEARCHING/val to RESEARCHING/train
# Moved all files from INNOVATOR/val to INNOVATOR/train
# Moved all files from SHOCK/val to SHOCK/train
# Moved all files from SYMPHONY/val to SYMPHONY/train
# Moved all files from FUNERAL/val to FUNERAL/train
# Moved all files from CHOSE/val to CHOSE/train
# Moved all files from DEEPER/val to DEEPER/train
# Moved all files from FUNDAMENTALLY/val to FUNDAMENTALLY/train
# Moved all files from DECEPTION/val to DECEPTION/train
# Moved all files from UNTIL/val to UNTIL/train
# Moved all files from PLACED/val to PLACED/train
# Moved all files from ANSWERING/val to ANSWERING/train
# Moved all files from FEARLESS/val to FEARLESS/train
# Moved all files from CHEESE/val to CHEESE/train
# Moved all files from MARGIN/val to MARGIN/train
# Moved all files from BRIDE/val to BRIDE/train
# Moved all files from LIVED/val to LIVED/train
# Moved all files from FLU/val to FLU/train
# Moved all files from INDIAN/val to INDIAN/train
# Moved all files from SHE'S/val to SHE'S/train
# Moved all files from ACCORDING/val to ACCORDING/train
# Moved all files from MASSIVELY/val to MASSIVELY/train
# Moved all files from CANCER/val to CANCER/train
# Moved all files from CHIP/val to CHIP/train
# Moved all files from INFECTED/val to INFECTED/train
# Moved all files from FIRSTLY/val to FIRSTLY/train
# Moved all files from CROSSES/val to CROSSES/train
# Moved all files from INVESTMENT/val to INVESTMENT/train
# Moved all files from DISCUSS/val to DISCUSS/train
# Moved all files from ERROR/val to ERROR/train
# Moved all files from FACILITIES/val to FACILITIES/train
# Moved all files from VILLAGE/val to VILLAGE/train
# Moved all files from CLAPPING/val to CLAPPING/train
# Moved all files from SOLO/val to SOLO/train
# Moved all files from PREVIOUSLY/val to PREVIOUSLY/train
# Moved all files from SURPRISINGLY/val to SURPRISINGLY/train
# Moved all files from JOKE/val to JOKE/train
# Moved all files from RITUAL/val to RITUAL/train
# Moved all files from ACTIVATED/val to ACTIVATED/train
# Moved all files from DIRECT/val to DIRECT/train
# Moved all files from PHYSICAL/val to PHYSICAL/train
# Moved all files from APPRENTICESHIP/val to APPRENTICESHIP/train
# Moved all files from EXISTING/val to EXISTING/train
# Moved all files from ENTERPRISE/val to ENTERPRISE/train
# Moved all files from CUBA/val to CUBA/train
# Moved all files from CYBER/val to CYBER/train
# Moved all files from FREQUENTLY/val to FREQUENTLY/train
# Moved all files from WANDER/val to WANDER/train
# Moved all files from LAZY/val to LAZY/train
# Moved all files from JOURNALIST/val to JOURNALIST/train
# Moved all files from TOLERANT/val to TOLERANT/train
# Moved all files from THAT/val to THAT/train
# Moved all files from AIM/val to AIM/train
# Moved all files from PERFORMED/val to PERFORMED/train
# Moved all files from GREECE/val to GREECE/train
# Moved all files from ELECTRONS/val to ELECTRONS/train
# Moved all files from EXILE/val to EXILE/train
# Moved all files from TURKEY/val to TURKEY/train
# Moved all files from EITHER/val to EITHER/train
# Moved all files from PRIORITIZE/val to PRIORITIZE/train
# Moved all files from SHEET/val to SHEET/train
# Moved all files from MCDONALD'S/val to MCDONALD'S/train
# Moved all files from PINK/val to PINK/train
# Moved all files from OWL/val to OWL/train
# Moved all files from CLEAR/val to CLEAR/train
# Moved all files from DIAPHRAGM/val to DIAPHRAGM/train
# Moved all files from MOISTURE/val to MOISTURE/train
# Moved all files from IOWA/val to IOWA/train
# Moved all files from PERSIST/val to PERSIST/train
# Moved all files from OUTCOME/val to OUTCOME/train
# Moved all files from EVEN/val to EVEN/train
# Moved all files from MALL/val to MALL/train
# Moved all files from IGNORANCE/val to IGNORANCE/train
# Moved all files from STRAY/val to STRAY/train
# Moved all files from SOMEPLACE/val to SOMEPLACE/train
# Moved all files from BLOCK/val to BLOCK/train
# Moved all files from READER/val to READER/train
# Moved all files from FORGIVE/val to FORGIVE/train
# Moved all files from STAGGERING/val to STAGGERING/train
# Moved all files from COMPETING/val to COMPETING/train
# Moved all files from INVESTING/val to INVESTING/train
# Moved all files from DIVORCE/val to DIVORCE/train
# Moved all files from SAUCE/val to SAUCE/train
# Moved all files from FEW/val to FEW/train
# Moved all files from NOR/val to NOR/train
# Moved all files from GREEK/val to GREEK/train
# Moved all files from ASSUME/val to ASSUME/train
# Moved all files from YOUR/val to YOUR/train
# Moved all files from OUTLET/val to OUTLET/train
# Moved all files from BEGIN/val to BEGIN/train
# Moved all files from ROUGHLY/val to ROUGHLY/train
# Moved all files from POCKET/val to POCKET/train
# Moved all files from COVER/val to COVER/train
# Moved all files from DENYING/val to DENYING/train
# Moved all files from BUNK/val to BUNK/train
# Moved all files from ALCOHOL/val to ALCOHOL/train
# Moved all files from PROGRESSION/val to PROGRESSION/train
# Moved all files from ENSURE/val to ENSURE/train
# Moved all files from ENGLISH/val to ENGLISH/train
# Moved all files from HUMANITARIAN/val to HUMANITARIAN/train
# Moved all files from EXPECTING/val to EXPECTING/train
# Moved all files from ESCAPED/val to ESCAPED/train
# Moved all files from TRANSFORMATIVE/val to TRANSFORMATIVE/train
# Moved all files from EXPRESSION/val to EXPRESSION/train
# Moved all files from PRAIRIE/val to PRAIRIE/train
# Moved all files from INCREDIBLY/val to INCREDIBLY/train
# Moved all files from PROTECTION/val to PROTECTION/train
# Moved all files from SWIMMING/val to SWIMMING/train
# Moved all files from CAMP/val to CAMP/train
# Moved all files from UGLY/val to UGLY/train
# Moved all files from WASTING/val to WASTING/train
# Moved all files from CHEAPER/val to CHEAPER/train
# Moved all files from PUNCH/val to PUNCH/train
# Moved all files from TUBE/val to TUBE/train
# Moved all files from ATTEMPT/val to ATTEMPT/train
# Moved all files from COUPLE/val to COUPLE/train
# Moved all files from HOME/val to HOME/train
# Moved all files from INTERESTING/val to INTERESTING/train
# Moved all files from FORCE/val to FORCE/train
# Moved all files from INVESTED/val to INVESTED/train
# Moved all files from EXPERIMENT/val to EXPERIMENT/train
# Moved all files from CHUTZPAH/val to CHUTZPAH/train
# Moved all files from CLOTH/val to CLOTH/train
# Moved all files from DISTRIBUTION/val to DISTRIBUTION/train
# Moved all files from EXTRACT/val to EXTRACT/train
# Moved all files from STRESS/val to STRESS/train
# Moved all files from TEXTING/val to TEXTING/train
# Moved all files from GRAFFITI/val to GRAFFITI/train
# Moved all files from HI/val to HI/train
# Moved all files from LUTHER/val to LUTHER/train
# Moved all files from PROMISED/val to PROMISED/train
# Moved all files from WASTED/val to WASTED/train
# Moved all files from SPIDER/val to SPIDER/train
# Moved all files from YOUTH/val to YOUTH/train
# Moved all files from ADMISSION/val to ADMISSION/train
# Moved all files from SPHERE/val to SPHERE/train
# Moved all files from RELEASED/val to RELEASED/train
# Moved all files from RUBBISH/val to RUBBISH/train
# Moved all files from LOAF/val to LOAF/train
# Moved all files from ACCEPTING/val to ACCEPTING/train
# Moved all files from DEPENDING/val to DEPENDING/train
# Moved all files from FAIR/val to FAIR/train
# Moved all files from EVOLUTIONARY/val to EVOLUTIONARY/train
# Moved all files from EXECUTIVE/val to EXECUTIVE/train
# Moved all files from LASTED/val to LASTED/train
# Moved all files from EFFECTIVE/val to EFFECTIVE/train
# Moved all files from PROTECT/val to PROTECT/train
# Moved all files from LOAD/val to LOAD/train
# Moved all files from TOXIC/val to TOXIC/train
# Moved all files from ROLE/val to ROLE/train
# Moved all files from PALLIATIVE/val to PALLIATIVE/train
# Moved all files from MUNCHKIN/val to MUNCHKIN/train
# Moved all files from PURE/val to PURE/train
# Moved all files from PERSONALITY/val to PERSONALITY/train
# Moved all files from POLL/val to POLL/train
# Moved all files from PREVENTED/val to PREVENTED/train
# Moved all files from LISTEN/val to LISTEN/train
# Moved all files from WILLIAM/val to WILLIAM/train
# Moved all files from HERO/val to HERO/train
# Moved all files from GET/val to GET/train
# Moved all files from EVIDENT/val to EVIDENT/train
# Moved all files from PEACE/val to PEACE/train
# Moved all files from CLAIM/val to CLAIM/train
# Moved all files from GOAL/val to GOAL/train
# Moved all files from INTERESTINGLY/val to INTERESTINGLY/train
# Moved all files from DIFFICULTIES/val to DIFFICULTIES/train
# Moved all files from LARGER/val to LARGER/train
# Moved all files from DISCIPLINE/val to DISCIPLINE/train
# Moved all files from NERVOUS/val to NERVOUS/train
# Moved all files from DRAW/val to DRAW/train
# Moved all files from SAFELY/val to SAFELY/train
# Moved all files from RYAN/val to RYAN/train
# Moved all files from BOOT/val to BOOT/train
# Moved all files from DAMAGE/val to DAMAGE/train
# Moved all files from INTERNET/val to INTERNET/train
# Moved all files from DANCER/val to DANCER/train
# Moved all files from MATERIAL/val to MATERIAL/train
# Moved all files from UNABLE/val to UNABLE/train
# Moved all files from COURT/val to COURT/train
# Moved all files from CHASE/val to CHASE/train
# Moved all files from CAUGHT/val to CAUGHT/train
# Moved all files from MOTOR/val to MOTOR/train
# Moved all files from DAILY/val to DAILY/train
# Moved all files from HUGE/val to HUGE/train
# Moved all files from PERFECTIONIST/val to PERFECTIONIST/train
# Moved all files from GEIGER/val to GEIGER/train
# Moved all files from THIN/val to THIN/train
# Moved all files from CHOSEN/val to CHOSEN/train
# Moved all files from CAGE/val to CAGE/train
# Moved all files from GUY/val to GUY/train
# Moved all files from PORT/val to PORT/train
# Moved all files from CRASHED/val to CRASHED/train
# Moved all files from GIVE/val to GIVE/train
# Moved all files from GIVEN/val to GIVEN/train
# Moved all files from DEMANDING/val to DEMANDING/train
# Moved all files from CALCULUS/val to CALCULUS/train
# Moved all files from EMPLOYMENT/val to EMPLOYMENT/train
# Moved all files from ESPECIALLY/val to ESPECIALLY/train
# Moved all files from CRY/val to CRY/train
# Moved all files from ECONOMIES/val to ECONOMIES/train
# Moved all files from OUTSIDE/val to OUTSIDE/train
# Moved all files from DISAPPOINTMENT/val to DISAPPOINTMENT/train
# Moved all files from MICROBIAL/val to MICROBIAL/train
# Moved all files from SERVING/val to SERVING/train
# Moved all files from MORTALITY/val to MORTALITY/train
# Moved all files from CRUSHING/val to CRUSHING/train
# Moved all files from ABUNDANCE/val to ABUNDANCE/train
# Moved all files from MUSICAL/val to MUSICAL/train
# Moved all files from FLOSS/val to FLOSS/train
# Moved all files from PODCAST/val to PODCAST/train
# Moved all files from TULSA/val to TULSA/train
# Moved all files from GAINED/val to GAINED/train
# Moved all files from LAST/val to LAST/train
# Moved all files from WASTE/val to WASTE/train
# Moved all files from JUICE/val to JUICE/train
# Moved all files from DEFINING/val to DEFINING/train
# Moved all files from FOUNDATION/val to FOUNDATION/train
# Moved all files from TABOO/val to TABOO/train
# Moved all files from CEREMONY/val to CEREMONY/train
# Moved all files from SHORTCUT/val to SHORTCUT/train
# Moved all files from PROMOTION/val to PROMOTION/train
# Moved all files from THOUGHT/val to THOUGHT/train
# Moved all files from MAN'S/val to MAN'S/train
# Moved all files from COLD/val to COLD/train
# Moved all files from QUIETLY/val to QUIETLY/train
# Moved all files from FIGHTERS/val to FIGHTERS/train
# Moved all files from MASTERY/val to MASTERY/train
# Moved all files from MINDFUL/val to MINDFUL/train
# Moved all files from POINTED/val to POINTED/train
# Moved all files from MONOGAMY/val to MONOGAMY/train
# Moved all files from PHOTOGRAPH/val to PHOTOGRAPH/train
# Moved all files from PAPER/val to PAPER/train
# Moved all files from INTRODUCE/val to INTRODUCE/train
# Moved all files from BREAKUP/val to BREAKUP/train
# Moved all files from EXPERT/val to EXPERT/train
# Moved all files from CRACKING/val to CRACKING/train
# Moved all files from DAMN/val to DAMN/train
# Moved all files from INTENTION/val to INTENTION/train
# Moved all files from SELECT/val to SELECT/train
# Moved all files from TEENAGER/val to TEENAGER/train
# Moved all files from SOPHISTICATED/val to SOPHISTICATED/train
# Moved all files from PLEASE/val to PLEASE/train
# Moved all files from SOLELY/val to SOLELY/train
# Moved all files from STRIPE/val to STRIPE/train
# Moved all files from LIKED/val to LIKED/train
# Moved all files from SOLDIER/val to SOLDIER/train
# Moved all files from GDP/val to GDP/train
# Moved all files from METROPOLITAN/val to METROPOLITAN/train
# Moved all files from VALUED/val to VALUED/train
# Moved all files from DESIGNED/val to DESIGNED/train
# Moved all files from INGEST/val to INGEST/train
# Moved all files from NEGATIVE/val to NEGATIVE/train
# Moved all files from ELSEWHERE/val to ELSEWHERE/train
# Moved all files from INVASIVE/val to INVASIVE/train
# Moved all files from APPROPRIATE/val to APPROPRIATE/train
# Moved all files from PAN/val to PAN/train
# Moved all files from REPUBLICAN/val to REPUBLICAN/train
# Moved all files from POSED/val to POSED/train
# Moved all files from BOWLING/val to BOWLING/train
# Moved all files from RACE/val to RACE/train
# Moved all files from NORMAL/val to NORMAL/train
# Moved all files from COPYRIGHT/val to COPYRIGHT/train
# Moved all files from BERLIN/val to BERLIN/train
# Moved all files from SELECTED/val to SELECTED/train
# Moved all files from NATION/val to NATION/train
# Moved all files from ENGAGED/val to ENGAGED/train
# Moved all files from EM/val to EM/train
# Moved all files from SHOE/val to SHOE/train
# Moved all files from SOFT/val to SOFT/train
# Moved all files from INTERDEPENDENT/val to INTERDEPENDENT/train
# Moved all files from FIBER/val to FIBER/train
# Moved all files from FORGOTTEN/val to FORGOTTEN/train
# Moved all files from POWERFUL/val to POWERFUL/train
# Moved all files from PSYCHIATRIST/val to PSYCHIATRIST/train
# Moved all files from POTENTIALLY/val to POTENTIALLY/train
# Moved all files from SERVICE/val to SERVICE/train
# Moved all files from WATCH/val to WATCH/train
# Moved all files from WILLENDORF/val to WILLENDORF/train
# Moved all files from METHANE/val to METHANE/train
# Moved all files from COSTUME/val to COSTUME/train
# Moved all files from MOORE'S/val to MOORE'S/train
# Moved all files from EL/val to EL/train
# Moved all files from SLEEVE/val to SLEEVE/train
# Moved all files from COMMITTED/val to COMMITTED/train
# Moved all files from BE/val to BE/train
# Moved all files from SOMEDAY/val to SOMEDAY/train
# Moved all files from IMPORTANCE/val to IMPORTANCE/train
# Moved all files from P/val to P/train
# Moved all files from DOWNTOWN/val to DOWNTOWN/train
# Moved all files from DEADLINE/val to DEADLINE/train
# Moved all files from ESTEEM/val to ESTEEM/train
# Moved all files from BEAUTY/val to BEAUTY/train
# Moved all files from LIST/val to LIST/train
# Moved all files from LIFESTYLE/val to LIFESTYLE/train
# Moved all files from IF/val to IF/train
# Moved all files from POINTING/val to POINTING/train
# Moved all files from CLIMBED/val to CLIMBED/train
# Moved all files from LITERALLY/val to LITERALLY/train
# Moved all files from COMPARISON/val to COMPARISON/train
# Moved all files from STOLEN/val to STOLEN/train
# Moved all files from SECULAR/val to SECULAR/train
# Moved all files from SHE'D/val to SHE'D/train
# Moved all files from SOUP/val to SOUP/train
# Moved all files from PASSAGE/val to PASSAGE/train
# Moved all files from IMMIGRATION/val to IMMIGRATION/train
# Moved all files from SELVES/val to SELVES/train
# Moved all files from WEALTHY/val to WEALTHY/train
# Moved all files from FACING/val to FACING/train
# Moved all files from COUNTY/val to COUNTY/train
# Moved all files from PIECE/val to PIECE/train
# Moved all files from SICKNESS/val to SICKNESS/train
# Moved all files from DAVID/val to DAVID/train
# Moved all files from EPIGENETIC/val to EPIGENETIC/train
# Moved all files from REPLACE/val to REPLACE/train
# Moved all files from DISRUPTIVE/val to DISRUPTIVE/train
# Moved all files from THROUGH/val to THROUGH/train
# Moved all files from WITHDREW/val to WITHDREW/train
# Moved all files from WHENEVER/val to WHENEVER/train
# Moved all files from CASKET/val to CASKET/train
# Moved all files from PROMOTED/val to PROMOTED/train
# Moved all files from IRAN/val to IRAN/train
# Moved all files from MINIMUM/val to MINIMUM/train
# Moved all files from PORNOGRAPHY/val to PORNOGRAPHY/train
# Moved all files from X/val to X/train
# Moved all files from WALMART/val to WALMART/train
# Moved all files from RAPE/val to RAPE/train
# Moved all files from THRUST/val to THRUST/train
# Moved all files from INTERVENTION/val to INTERVENTION/train
# Moved all files from WAKE/val to WAKE/train
# Moved all files from BETWEEN/val to BETWEEN/train
# Moved all files from ASPIRE/val to ASPIRE/train
# Moved all files from MONEY/val to MONEY/train
# Moved all files from CARING/val to CARING/train
# Moved all files from HABIT/val to HABIT/train
# Moved all files from SHOCKED/val to SHOCKED/train
# Moved all files from REALIZING/val to REALIZING/train
# Moved all files from ROSE/val to ROSE/train
# Moved all files from PRIVACY/val to PRIVACY/train
# Moved all files from ENTIRELY/val to ENTIRELY/train
# Moved all files from RAISED/val to RAISED/train
# Moved all files from SCHOLARSHIP/val to SCHOLARSHIP/train
# Moved all files from CREATED/val to CREATED/train
# Moved all files from DERVISH/val to DERVISH/train
# Moved all files from PERFORMANCE/val to PERFORMANCE/train
# Moved all files from EXPLICIT/val to EXPLICIT/train
# Moved all files from PAIR/val to PAIR/train
# Moved all files from SPACE/val to SPACE/train
# Moved all files from UPGRADE/val to UPGRADE/train
# Moved all files from AGED/val to AGED/train
# Moved all files from STRUGGLE/val to STRUGGLE/train
# Moved all files from UNCONDITIONAL/val to UNCONDITIONAL/train
# Moved all files from PRIORITY/val to PRIORITY/train
# Moved all files from TENET/val to TENET/train
# Moved all files from MOLECULE/val to MOLECULE/train
# Moved all files from BREATHING/val to BREATHING/train
# Moved all files from STRESSFUL/val to STRESSFUL/train
# Moved all files from REWARDING/val to REWARDING/train
# Moved all files from DEMOCRAT/val to DEMOCRAT/train
# Moved all files from ILLNESS/val to ILLNESS/train
# Moved all files from CRUCIALLY/val to CRUCIALLY/train
# Moved all files from PERSPECTIVE/val to PERSPECTIVE/train
# Moved all files from SYMBOLIC/val to SYMBOLIC/train
# Moved all files from STARK/val to STARK/train
# Moved all files from IMPROVED/val to IMPROVED/train
# Moved all files from STAR/val to STAR/train
# Moved all files from UNDERSTOOD/val to UNDERSTOOD/train
# Moved all files from GOES/val to GOES/train
# Moved all files from EMBARRASSED/val to EMBARRASSED/train
# Moved all files from CLOSET/val to CLOSET/train
# Moved all files from HIRE/val to HIRE/train
# Moved all files from MEETING/val to MEETING/train
# Moved all files from TRANSITION/val to TRANSITION/train
# Moved all files from COMMONALITIES/val to COMMONALITIES/train
# Moved all files from RELATIVE/val to RELATIVE/train
# Moved all files from CHRONIC/val to CHRONIC/train
# Moved all files from END/val to END/train
# Moved all files from SOCIALLY/val to SOCIALLY/train
# Moved all files from FORT/val to FORT/train
# Moved all files from OUTFIT/val to OUTFIT/train
# Moved all files from TRANSLATE/val to TRANSLATE/train
# Moved all files from EXPONENTIALLY/val to EXPONENTIALLY/train
# Moved all files from DIEGO/val to DIEGO/train
# Moved all files from TWELVE/val to TWELVE/train
# Moved all files from INSPIRATION/val to INSPIRATION/train
# Moved all files from OFFICER/val to OFFICER/train
# Moved all files from CARED/val to CARED/train
# Moved all files from NETHERLANDS/val to NETHERLANDS/train
# Moved all files from COMPETITION/val to COMPETITION/train
# Moved all files from HOPEFUL/val to HOPEFUL/train
# Moved all files from AVENUE/val to AVENUE/train
# Moved all files from INCIDENT/val to INCIDENT/train
# Moved all files from CARDBOARD/val to CARDBOARD/train
# Moved all files from RATHER/val to RATHER/train
# Moved all files from JIM/val to JIM/train
# Moved all files from ADS/val to ADS/train
# Moved all files from WARMING/val to WARMING/train
# Moved all files from HOMO/val to HOMO/train
# Moved all files from CARPENTRY/val to CARPENTRY/train
# Moved all files from LEAD/val to LEAD/train
# Moved all files from SWIRLING/val to SWIRLING/train
# Moved all files from REACHING/val to REACHING/train
# Moved all files from DISCOVERY/val to DISCOVERY/train
# Moved all files from VOLCANO/val to VOLCANO/train
# Moved all files from ANYONE/val to ANYONE/train
# Moved all files from LEMONADE/val to LEMONADE/train
# Moved all files from THERE'RE/val to THERE'RE/train
# Moved all files from REASON/val to REASON/train
# Moved all files from BATH/val to BATH/train
# Moved all files from O/val to O/train
# Moved all files from UNEMPLOYMENT/val to UNEMPLOYMENT/train
# Moved all files from ANSWERED/val to ANSWERED/train
# Moved all files from OUR/val to OUR/train
# Moved all files from SEEING/val to SEEING/train
# Moved all files from UNEXPECTED/val to UNEXPECTED/train
# Moved all files from PHOTOGRAPHED/val to PHOTOGRAPHED/train
# Moved all files from SPEECH/val to SPEECH/train
# Moved all files from GENERATE/val to GENERATE/train
# Moved all files from LAPTOP/val to LAPTOP/train
# Moved all files from DIVERSE/val to DIVERSE/train
# Moved all files from UPSET/val to UPSET/train
# Moved all files from MONK/val to MONK/train
# Moved all files from BLINDNESS/val to BLINDNESS/train
# Moved all files from SAVE/val to SAVE/train
# Moved all files from INCREASED/val to INCREASED/train
# Moved all files from JEWELRY/val to JEWELRY/train
# Moved all files from TERRORIST/val to TERRORIST/train
# Moved all files from THIRDLY/val to THIRDLY/train
# Moved all files from EXCITED/val to EXCITED/train
# Moved all files from COGNITIVE/val to COGNITIVE/train
# Moved all files from BASE/val to BASE/train
# Moved all files from WOKEN/val to WOKEN/train
# Moved all files from EQUAL/val to EQUAL/train
# Moved all files from GUESSING/val to GUESSING/train
# Moved all files from PUBLICATION/val to PUBLICATION/train
# Moved all files from HARNESS/val to HARNESS/train
# Moved all files from COLLAPSE/val to COLLAPSE/train
# Moved all files from HEADING/val to HEADING/train
# Moved all files from PLATFORM/val to PLATFORM/train
# Moved all files from SUPER/val to SUPER/train
# Moved all files from PLANTING/val to PLANTING/train
# Moved all files from BLA/val to BLA/train
# Moved all files from MENTORING/val to MENTORING/train
# Moved all files from NOTICED/val to NOTICED/train
# Moved all files from AUDITION/val to AUDITION/train
# Moved all files from KOREAN/val to KOREAN/train
# Moved all files from BEING/val to BEING/train
# Moved all files from REVOLUTION/val to REVOLUTION/train
# Moved all files from COX/val to COX/train
# Moved all files from METAL/val to METAL/train
# Moved all files from GRAVE/val to GRAVE/train
# Moved all files from EFFORT/val to EFFORT/train
# Moved all files from CHARITY/val to CHARITY/train
# Moved all files from ABOUT/val to ABOUT/train
# Moved all files from ETHICS/val to ETHICS/train
# Moved all files from STATEMENT/val to STATEMENT/train
# Moved all files from SPORTING/val to SPORTING/train
# Moved all files from ISLAND/val to ISLAND/train
# Moved all files from CAKE/val to CAKE/train
# Moved all files from IRELAND/val to IRELAND/train
# Moved all files from FUELED/val to FUELED/train
# Moved all files from EXPLORATION/val to EXPLORATION/train
# Moved all files from PROPOSED/val to PROPOSED/train
# Moved all files from REDUCED/val to REDUCED/train
# Moved all files from THING/val to THING/train
# Moved all files from ELLEN/val to ELLEN/train
# Moved all files from THRILL/val to THRILL/train
# Moved all files from HAND/val to HAND/train
# Moved all files from OKAY/val to OKAY/train
# Moved all files from COMPROMISE/val to COMPROMISE/train
# Moved all files from NEIGHBOR/val to NEIGHBOR/train
# Moved all files from LHC/val to LHC/train
# Moved all files from MATTHEW/val to MATTHEW/train
# Moved all files from DIFFERENCE/val to DIFFERENCE/train
# Moved all files from DOCUMENTARY/val to DOCUMENTARY/train
# Moved all files from WIKIPEDIA/val to WIKIPEDIA/train
# Moved all files from LOG/val to LOG/train
# Moved all files from DOING/val to DOING/train
# Moved all files from TECHNOLOGY/val to TECHNOLOGY/train
# Moved all files from POSSIBLY/val to POSSIBLY/train
# Moved all files from RESEARCH/val to RESEARCH/train
# Moved all files from VACATION/val to VACATION/train
# Moved all files from BRUSHED/val to BRUSHED/train
# Moved all files from COLLABORATION/val to COLLABORATION/train
# Moved all files from APPLICATION/val to APPLICATION/train
# Moved all files from ASK/val to ASK/train
# Moved all files from WIDER/val to WIDER/train
# Moved all files from BRAIN/val to BRAIN/train
# Moved all files from TWICE/val to TWICE/train
# Moved all files from COMPANIES/val to COMPANIES/train
# Moved all files from ASKED/val to ASKED/train
# Moved all files from DENIAL/val to DENIAL/train
# Moved all files from ISN/val to ISN/train
# Moved all files from CAUSE/val to CAUSE/train
# Moved all files from PERSON/val to PERSON/train
# Moved all files from EVENT/val to EVENT/train
# Moved all files from FUNCTIONING/val to FUNCTIONING/train
# Moved all files from PAINTER/val to PAINTER/train
# Moved all files from COMPLEX/val to COMPLEX/train
# Moved all files from JURY/val to JURY/train
# Moved all files from SECONDARY/val to SECONDARY/train
# Moved all files from ASSUMED/val to ASSUMED/train
# Moved all files from PHYSICALLY/val to PHYSICALLY/train
# Moved all files from EVENTUALLY/val to EVENTUALLY/train
# Moved all files from RISK/val to RISK/train
# Moved all files from QUALIFIED/val to QUALIFIED/train
# Moved all files from ERA/val to ERA/train
# Moved all files from MORE/val to MORE/train
# Moved all files from FICTIONAL/val to FICTIONAL/train
# Moved all files from ORGANIC/val to ORGANIC/train
# Moved all files from ORG/val to ORG/train
# Moved all files from SUICIDAL/val to SUICIDAL/train
# Moved all files from OBJECTIVE/val to OBJECTIVE/train
# Moved all files from IT/val to IT/train
# Moved all files from TOGETHER/val to TOGETHER/train
# Moved all files from APPALLING/val to APPALLING/train
# Moved all files from CAPABLE/val to CAPABLE/train
# Moved all files from DIVIDED/val to DIVIDED/train
# Moved all files from INSECURITY/val to INSECURITY/train
# Moved all files from LAPILLI/val to LAPILLI/train
# Moved all files from REGULATE/val to REGULATE/train
# Moved all files from DE/val to DE/train
# Moved all files from BRUSH/val to BRUSH/train
# Moved all files from EVOLVE/val to EVOLVE/train
# Moved all files from PHASE/val to PHASE/train
# Moved all files from ERIC/val to ERIC/train
# Moved all files from BASEMENT/val to BASEMENT/train
# Moved all files from REFRIGERATOR/val to REFRIGERATOR/train
# Moved all files from JUNE/val to JUNE/train
# Moved all files from MOSQUE/val to MOSQUE/train
# Moved all files from CURRENCY/val to CURRENCY/train
# Moved all files from MEASUREMENT/val to MEASUREMENT/train
# Moved all files from RELATIONSHIP/val to RELATIONSHIP/train
# Moved all files from RELEASE/val to RELEASE/train
# Moved all files from TYPE/val to TYPE/train
# Moved all files from GRIMMS/val to GRIMMS/train
# Moved all files from DECIDE/val to DECIDE/train
# Moved all files from IMAGE/val to IMAGE/train
# Moved all files from SLAM/val to SLAM/train
# Moved all files from DEAF/val to DEAF/train
# Moved all files from GRANDSON/val to GRANDSON/train
# Moved all files from REPORTER/val to REPORTER/train
# Moved all files from NUMB/val to NUMB/train
# Moved all files from DEAN/val to DEAN/train
# Moved all files from MOZART/val to MOZART/train
# Moved all files from MENOPAUSE/val to MENOPAUSE/train
# Moved all files from BROWN/val to BROWN/train
# Moved all files from COURSE/val to COURSE/train
# Moved all files from BIRMINGHAM/val to BIRMINGHAM/train
# Moved all files from FEE/val to FEE/train
# Moved all files from BETA/val to BETA/train
# Moved all files from VULNERABLE/val to VULNERABLE/train
# Moved all files from RISING/val to RISING/train
# Moved all files from POLITICS/val to POLITICS/train
# Moved all files from BOTHER/val to BOTHER/train
# Moved all files from WAITING/val to WAITING/train
# Moved all files from HAPPEN/val to HAPPEN/train
# Moved all files from STABLE/val to STABLE/train
# Moved all files from COLORED/val to COLORED/train
# Moved all files from SIMPLIFY/val to SIMPLIFY/train
# Moved all files from DIGIT/val to DIGIT/train
# Moved all files from HIM/val to HIM/train
# Moved all files from REACTIVE/val to REACTIVE/train
# Moved all files from VALUABLE/val to VALUABLE/train
# Moved all files from ANIMATOR/val to ANIMATOR/train
# Moved all files from UPTAKE/val to UPTAKE/train
# Moved all files from ADVANCED/val to ADVANCED/train
# Moved all files from CEO/val to CEO/train
# Moved all files from FLUORESCENT/val to FLUORESCENT/train
# Moved all files from REALIZATION/val to REALIZATION/train
# Moved all files from ALONG/val to ALONG/train
# Moved all files from MAIL/val to MAIL/train
# Moved all files from PRAYER/val to PRAYER/train
# Moved all files from INTROVERTS/val to INTROVERTS/train
# Moved all files from OIL/val to OIL/train
# Moved all files from JAW/val to JAW/train
# Moved all files from STANDARDIZED/val to STANDARDIZED/train
# Moved all files from F/val to F/train
# Moved all files from BRUSHING/val to BRUSHING/train
# Moved all files from MILLION/val to MILLION/train
# Moved all files from MANUFACTURER/val to MANUFACTURER/train
# Moved all files from MECHANICAL/val to MECHANICAL/train
# Moved all files from ABUSE/val to ABUSE/train
# Moved all files from DRILL/val to DRILL/train
# Moved all files from GENERIC/val to GENERIC/train
# Moved all files from OBESITY/val to OBESITY/train
# Moved all files from VENUE/val to VENUE/train
# Moved all files from WITH/val to WITH/train
# Moved all files from TRIAL/val to TRIAL/train
# Moved all files from COMMUNICATION/val to COMMUNICATION/train
# Moved all files from HOLLYWOOD/val to HOLLYWOOD/train
# Moved all files from BAGHDAD/val to BAGHDAD/train
# Moved all files from ROD/val to ROD/train
# Moved all files from TAXES/val to TAXES/train
# Moved all files from INFECTIOUS/val to INFECTIOUS/train
# Moved all files from MARATHON/val to MARATHON/train
# Moved all files from MINORITY/val to MINORITY/train
# Moved all files from YOGA/val to YOGA/train
# Moved all files from DEFINITIVE/val to DEFINITIVE/train
# Moved all files from NEIL/val to NEIL/train
# Moved all files from GENERATOR/val to GENERATOR/train
# Moved all files from RUNNING/val to RUNNING/train
# Moved all files from SISTER/val to SISTER/train
# Moved all files from PORN/val to PORN/train
# Moved all files from COOPERATE/val to COOPERATE/train
# Moved all files from APPETITE/val to APPETITE/train
# Moved all files from PIE/val to PIE/train
# Moved all files from BUREAUCRAT/val to BUREAUCRAT/train
# Moved all files from SURPRISING/val to SURPRISING/train
# Moved all files from RURAL/val to RURAL/train
# Moved all files from SKYPE/val to SKYPE/train
# Moved all files from EVIL/val to EVIL/train
# Moved all files from BOW/val to BOW/train
# Moved all files from SYMMETRY/val to SYMMETRY/train
# Moved all files from ATHLETE/val to ATHLETE/train
# Moved all files from HUNTER/val to HUNTER/train
# Moved all files from B/val to B/train
# Moved all files from HONEY/val to HONEY/train
# Moved all files from DRIVING/val to DRIVING/train
# Moved all files from SAKE/val to SAKE/train
# Moved all files from FREAKED/val to FREAKED/train
# Moved all files from CELEBRATION/val to CELEBRATION/train
# Moved all files from RECOVER/val to RECOVER/train
# Moved all files from MARTIAL/val to MARTIAL/train
# Moved all files from DESERT/val to DESERT/train
# Moved all files from SEXISM/val to SEXISM/train
# Moved all files from SUGGESTING/val to SUGGESTING/train
# Moved all files from BLOW/val to BLOW/train
# Moved all files from IMPLEMENTED/val to IMPLEMENTED/train
# Moved all files from DATING/val to DATING/train
# Moved all files from NATIONAL/val to NATIONAL/train
# Moved all files from LION/val to LION/train
# Moved all files from LINGUISTIC/val to LINGUISTIC/train
# Moved all files from TOMBOY/val to TOMBOY/train
# Moved all files from BLUE/val to BLUE/train
# Moved all files from STRUCTURE/val to STRUCTURE/train
# Moved all files from RECOVERY/val to RECOVERY/train
# Moved all files from MATTER/val to MATTER/train
# Moved all files from VIA/val to VIA/train
# Moved all files from JAIL/val to JAIL/train
# Moved all files from INTERVIEWING/val to INTERVIEWING/train
# Moved all files from SIBLING/val to SIBLING/train
# Moved all files from SIGN/val to SIGN/train
# Moved all files from CONSENSUS/val to CONSENSUS/train
# Moved all files from ONLINE/val to ONLINE/train
# Moved all files from SITUATION/val to SITUATION/train
# Moved all files from YORUBA/val to YORUBA/train
# Moved all files from OWN/val to OWN/train
# Moved all files from HACKER/val to HACKER/train
# Moved all files from TARAHUMARA/val to TARAHUMARA/train
# Moved all files from MOSES/val to MOSES/train
# Moved all files from EAR/val to EAR/train
# Moved all files from FRONT/val to FRONT/train
# Moved all files from LIGHTING/val to LIGHTING/train
# Moved all files from OVERALL/val to OVERALL/train
# Moved all files from PERSONALLY/val to PERSONALLY/train
# Moved all files from PARTY/val to PARTY/train
# Moved all files from BUTTER/val to BUTTER/train
# Moved all files from LINED/val to LINED/train
# Moved all files from WHOLE/val to WHOLE/train
# Moved all files from EDUCATION/val to EDUCATION/train
# Moved all files from PLANTATION/val to PLANTATION/train
# Moved all files from STUDIED/val to STUDIED/train
# Moved all files from A/val to A/train
# Moved all files from FLAG/val to FLAG/train
# Moved all files from RHYME/val to RHYME/train
# Moved all files from FRUSTRATED/val to FRUSTRATED/train
# Moved all files from ACCOUNTING/val to ACCOUNTING/train
# Moved all files from LUNCH/val to LUNCH/train
# Moved all files from PROCESS/val to PROCESS/train
# Moved all files from IDENTICAL/val to IDENTICAL/train
# Moved all files from EVIDENCE/val to EVIDENCE/train
# Moved all files from PANAMA/val to PANAMA/train
# Moved all files from MOTEL/val to MOTEL/train
# Moved all files from HAS/val to HAS/train
# Moved all files from SHOWN/val to SHOWN/train
# Moved all files from DIOXIDE/val to DIOXIDE/train
# Moved all files from TRACKER/val to TRACKER/train
# Moved all files from AID/val to AID/train
# Moved all files from KIDDING/val to KIDDING/train
# Moved all files from NONPROFIT/val to NONPROFIT/train
# Moved all files from EATING/val to EATING/train
# Moved all files from RID/val to RID/train
# Moved all files from BEETLE/val to BEETLE/train
# Moved all files from RELIABLE/val to RELIABLE/train
# Moved all files from TRUSTED/val to TRUSTED/train
# Moved all files from CAR/val to CAR/train
# Moved all files from FAMOUS/val to FAMOUS/train
# Moved all files from ESSENTIAL/val to ESSENTIAL/train
# Moved all files from ORGASM/val to ORGASM/train
# Moved all files from ABRAHAM'S/val to ABRAHAM'S/train
# Moved all files from BIRTH/val to BIRTH/train
# Moved all files from LINEAR/val to LINEAR/train
# Moved all files from CADAVER/val to CADAVER/train
# Moved all files from NETWORKING/val to NETWORKING/train
# Moved all files from PLANT/val to PLANT/train
# Moved all files from ADOLESCENT/val to ADOLESCENT/train
# Moved all files from REJECTED/val to REJECTED/train
# Moved all files from POSITION/val to POSITION/train
# Moved all files from INVESTIGATE/val to INVESTIGATE/train
# Moved all files from NEURAL/val to NEURAL/train
# Moved all files from GENETIC/val to GENETIC/train
# Moved all files from PROPOSITION/val to PROPOSITION/train
# Moved all files from EVERYBODY/val to EVERYBODY/train
# Moved all files from DEAL/val to DEAL/train
# Moved all files from PLAY/val to PLAY/train
# Moved all files from ADDITION/val to ADDITION/train
# Moved all files from POSSIBLE/val to POSSIBLE/train
# Moved all files from LIGHT/val to LIGHT/train
# Moved all files from FIGURING/val to FIGURING/train
# Moved all files from SPOKE/val to SPOKE/train
# Moved all files from SUN/val to SUN/train
# Moved all files from INCENTIVE/val to INCENTIVE/train
# Moved all files from ANNOUNCE/val to ANNOUNCE/train
# Moved all files from ENGAGING/val to ENGAGING/train
# Moved all files from TRANSGENDER/val to TRANSGENDER/train
# Moved all files from BUTTON/val to BUTTON/train
# Moved all files from WELLNESS/val to WELLNESS/train
# Moved all files from VIABLE/val to VIABLE/train
# Moved all files from DROP/val to DROP/train
# Moved all files from CENTURY/val to CENTURY/train
# Moved all files from MAHATMA/val to MAHATMA/train
# Moved all files from FISHERIES/val to FISHERIES/train
# Moved all files from SUSTAINABLE/val to SUSTAINABLE/train
# Moved all files from THUS/val to THUS/train
# Moved all files from OFFER/val to OFFER/train
# Moved all files from ACCENT/val to ACCENT/train
# Moved all files from REVEAL/val to REVEAL/train
# Moved all files from LANE/val to LANE/train
# Moved all files from WORKED/val to WORKED/train
# Moved all files from ACTIVIST/val to ACTIVIST/train
# Moved all files from FROM/val to FROM/train
# Moved all files from UNIT/val to UNIT/train
# Moved all files from HEAVILY/val to HEAVILY/train
# Moved all files from NATURALLY/val to NATURALLY/train
# Moved all files from SCREENING/val to SCREENING/train
# Moved all files from SPEED/val to SPEED/train
# Moved all files from FOOTPRINT/val to FOOTPRINT/train
# Moved all files from CLEARLY/val to CLEARLY/train
# Moved all files from EARTHQUAKE/val to EARTHQUAKE/train
# Moved all files from TOMORROW/val to TOMORROW/train
# Moved all files from WILDLIFE/val to WILDLIFE/train
# Moved all files from SMOKE/val to SMOKE/train
# Moved all files from SAINT/val to SAINT/train
# Moved all files from PHRASE/val to PHRASE/train
# Moved all files from SHELF/val to SHELF/train
# Moved all files from TRAFFIC/val to TRAFFIC/train
# Moved all files from STAGE/val to STAGE/train
# Moved all files from PASSED/val to PASSED/train
# Moved all files from FRENCH/val to FRENCH/train
# Moved all files from DRY/val to DRY/train
# Moved all files from NASA/val to NASA/train
# Moved all files from MAYOR/val to MAYOR/train
# Moved all files from R/val to R/train
# Moved all files from ALGORITHM/val to ALGORITHM/train
# Moved all files from MINI/val to MINI/train
# Moved all files from TRAINING/val to TRAINING/train
# Moved all files from GARDEN/val to GARDEN/train
# Moved all files from SUPERSTAR/val to SUPERSTAR/train
# Moved all files from PRECISELY/val to PRECISELY/train
# Moved all files from CAPTAIN/val to CAPTAIN/train
# Moved all files from CUSTOM/val to CUSTOM/train
# Moved all files from UNLEASHED/val to UNLEASHED/train
# Moved all files from WEAK/val to WEAK/train
# Moved all files from CO/val to CO/train
# Moved all files from GROUP/val to GROUP/train
# Moved all files from BOX/val to BOX/train
# Moved all files from CONSUMING/val to CONSUMING/train
# Moved all files from WALKED/val to WALKED/train
# Moved all files from APPLIES/val to APPLIES/train
# Moved all files from WHAT'S/val to WHAT'S/train
# Moved all files from MEDITATION/val to MEDITATION/train
# Moved all files from ANOTHER/val to ANOTHER/train
# Moved all files from LADIES/val to LADIES/train
# Moved all files from ASSEMBLY/val to ASSEMBLY/train
# Moved all files from MASTER/val to MASTER/train
# Moved all files from TABLE/val to TABLE/train
# Moved all files from REBEL/val to REBEL/train
# Moved all files from APPLYING/val to APPLYING/train
# Moved all files from ZOO/val to ZOO/train
# Moved all files from FOLK/val to FOLK/train
# Moved all files from SPLIT/val to SPLIT/train
# Moved all files from DEALT/val to DEALT/train
# Moved all files from SHOULDN'T/val to SHOULDN'T/train
# Moved all files from GOLD/val to GOLD/train
# Moved all files from ANSWER/val to ANSWER/train
# Moved all files from ENDING/val to ENDING/train
# Moved all files from NEUROSCIENCE/val to NEUROSCIENCE/train
# Moved all files from SCHOLAR/val to SCHOLAR/train
# Moved all files from SEXUAL/val to SEXUAL/train
# Moved all files from REPLACED/val to REPLACED/train
# Moved all files from IRAQ/val to IRAQ/train
# Moved all files from PRETEND/val to PRETEND/train
# Moved all files from UNAWARE/val to UNAWARE/train
# Moved all files from VEHICLE/val to VEHICLE/train
# Moved all files from TOILET/val to TOILET/train
# Moved all files from MIX/val to MIX/train
# Moved all files from BRAND/val to BRAND/train
# Moved all files from BOUND/val to BOUND/train
# Moved all files from RESILIENCE/val to RESILIENCE/train
# Moved all files from RESENTED/val to RESENTED/train
# Moved all files from INTEGRATED/val to INTEGRATED/train
# Moved all files from SHOULD'VE/val to SHOULD'VE/train
# Moved all files from WINTER/val to WINTER/train
# Moved all files from WIDOW/val to WIDOW/train
# Moved all files from LEBANON/val to LEBANON/train
# Moved all files from RUGBY/val to RUGBY/train
# Moved all files from BEGAN/val to BEGAN/train
# Moved all files from SECRETARY/val to SECRETARY/train
# Moved all files from LAUNCHED/val to LAUNCHED/train
# Moved all files from MARIJUANA/val to MARIJUANA/train
# Moved all files from NOVELTY/val to NOVELTY/train
# Moved all files from FAMILY'S/val to FAMILY'S/train
# Moved all files from NEXT/val to NEXT/train
# Moved all files from MAINTENANCE/val to MAINTENANCE/train
# Moved all files from PULLED/val to PULLED/train
# Moved all files from SLOW/val to SLOW/train
# Moved all files from FLASHLIGHT/val to FLASHLIGHT/train
# Moved all files from EVALUATE/val to EVALUATE/train
# Moved all files from AROUND/val to AROUND/train
# Moved all files from SECTOR/val to SECTOR/train
# Moved all files from SUGGESTION/val to SUGGESTION/train
# Moved all files from HAPPINESS/val to HAPPINESS/train
# Moved all files from EMBRACED/val to EMBRACED/train
# Moved all files from SMITH/val to SMITH/train
# Moved all files from EARTH/val to EARTH/train
# Moved all files from DRIFT/val to DRIFT/train
# Moved all files from Y/val to Y/train
# Moved all files from FLAT/val to FLAT/train
# Moved all files from COUNSEL/val to COUNSEL/train
# Moved all files from GLOBALIZATION/val to GLOBALIZATION/train
# Moved all files from VOICE/val to VOICE/train
# Moved all files from VALUE/val to VALUE/train
# Moved all files from STEPHEN/val to STEPHEN/train
# Moved all files from LOUSY/val to LOUSY/train
# Moved all files from WORLDVIEW/val to WORLDVIEW/train
# Moved all files from ROVER/val to ROVER/train
# Moved all files from SECOND/val to SECOND/train
# Moved all files from VITAL/val to VITAL/train
# Moved all files from FEDERAL/val to FEDERAL/train
# Moved all files from HELPING/val to HELPING/train
# Moved all files from SEND/val to SEND/train
# Moved all files from ENTHUSIASTIC/val to ENTHUSIASTIC/train
# Moved all files from INCOME/val to INCOME/train
# Moved all files from HABITAT/val to HABITAT/train
# Moved all files from CONCEPT/val to CONCEPT/train
# Moved all files from WRAPPED/val to WRAPPED/train
# Moved all files from POLLUTION/val to POLLUTION/train
# Moved all files from THEORETICAL/val to THEORETICAL/train
# Moved all files from VITAMIN/val to VITAMIN/train
# Moved all files from WANNA/val to WANNA/train
# Moved all files from GRIEF/val to GRIEF/train
# Moved all files from COWARD/val to COWARD/train
# Moved all files from ACCOUNTANT/val to ACCOUNTANT/train
# Moved all files from ROW/val to ROW/train
# Moved all files from WAGE/val to WAGE/train
# Moved all files from DROWNING/val to DROWNING/train
# Moved all files from STRANGER/val to STRANGER/train
# Moved all files from GROWER/val to GROWER/train
# Moved all files from CLASSMATE/val to CLASSMATE/train
# Moved all files from EARN/val to EARN/train
# Moved all files from INVOLVED/val to INVOLVED/train
# Moved all files from CHOLESTEROL/val to CHOLESTEROL/train
# Moved all files from TRADITION/val to TRADITION/train
# Moved all files from OPENNESS/val to OPENNESS/train
# Moved all files from CAPABILITIES/val to CAPABILITIES/train
# Moved all files from INEFFICIENT/val to INEFFICIENT/train
# Moved all files from TRIUMPH/val to TRIUMPH/train
# Moved all files from METAPHOR/val to METAPHOR/train
# Moved all files from STIMULATE/val to STIMULATE/train
# Moved all files from CREATE/val to CREATE/train
# Moved all files from OCCURRED/val to OCCURRED/train
# Moved all files from ACTING/val to ACTING/train
# Moved all files from IDENTITY/val to IDENTITY/train
# Moved all files from BANK/val to BANK/train
# Moved all files from LESS/val to LESS/train
# Moved all files from FOXES/val to FOXES/train
# Moved all files from WORLD/val to WORLD/train
# Moved all files from MYSTERIES/val to MYSTERIES/train
# Moved all files from PLUS/val to PLUS/train
# Moved all files from GIFT/val to GIFT/train
# Moved all files from STORYTELLING/val to STORYTELLING/train
# Moved all files from SHORT/val to SHORT/train
# Moved all files from REEF/val to REEF/train
# Moved all files from SOVIET/val to SOVIET/train
# Moved all files from REPRESENT/val to REPRESENT/train
# Moved all files from ISOLATED/val to ISOLATED/train
# Moved all files from TRIP/val to TRIP/train
# Moved all files from TREMENDOUSLY/val to TREMENDOUSLY/train
# Moved all files from SOME/val to SOME/train
# Moved all files from THOUGH/val to THOUGH/train
# Moved all files from HALL/val to HALL/train
# Moved all files from DEAD/val to DEAD/train
# Moved all files from JEWISH/val to JEWISH/train
# Moved all files from MILK/val to MILK/train
# Moved all files from WHEN/val to WHEN/train
# Moved all files from INTERACT/val to INTERACT/train
# Moved all files from JEFF/val to JEFF/train
# Moved all files from RETAIL/val to RETAIL/train
# Moved all files from FOOL/val to FOOL/train
# Moved all files from EXPERIMENTAL/val to EXPERIMENTAL/train
# Moved all files from FUND/val to FUND/train
# Moved all files from FRANKLY/val to FRANKLY/train
# Moved all files from LICENSED/val to LICENSED/train
# Moved all files from MARINE/val to MARINE/train
# Moved all files from ABSURD/val to ABSURD/train
# Moved all files from ANTIBODIES/val to ANTIBODIES/train
# Moved all files from DISAPPEAR/val to DISAPPEAR/train
# Moved all files from FRIENDLY/val to FRIENDLY/train
# Moved all files from FORWARD/val to FORWARD/train
# Moved all files from PENNY/val to PENNY/train
# Moved all files from PATTERN/val to PATTERN/train
# Moved all files from SIZED/val to SIZED/train
# Moved all files from COMMITMENT/val to COMMITMENT/train
# Moved all files from USA/val to USA/train
# Moved all files from NOUN/val to NOUN/train
# Moved all files from LIFESPAN/val to LIFESPAN/train
# Moved all files from PLUG/val to PLUG/train
# Moved all files from CHURCH/val to CHURCH/train
# Moved all files from BACKYARD/val to BACKYARD/train
# Moved all files from SERVANT/val to SERVANT/train
# Moved all files from STUDY/val to STUDY/train
# Moved all files from THEY'RE/val to THEY'RE/train
# Moved all files from DROPPING/val to DROPPING/train
# Moved all files from GLAD/val to GLAD/train
# Moved all files from STEPPED/val to STEPPED/train
# Moved all files from PROGRESSIVE/val to PROGRESSIVE/train
# Moved all files from TWITTER/val to TWITTER/train
# Moved all files from HISTORICAL/val to HISTORICAL/train
# Moved all files from LATEST/val to LATEST/train
# Moved all files from JOURNAL/val to JOURNAL/train
# Moved all files from KEEP/val to KEEP/train
# Moved all files from TIE/val to TIE/train
# Moved all files from TRANSPARENT/val to TRANSPARENT/train
# Moved all files from CHANGER/val to CHANGER/train
# Moved all files from TOUCHING/val to TOUCHING/train
# Moved all files from DIVINE/val to DIVINE/train
# Moved all files from ALLEN/val to ALLEN/train
# Moved all files from CHEMISTRY/val to CHEMISTRY/train
# Moved all files from THREAT/val to THREAT/train
# Moved all files from EXCHANGE/val to EXCHANGE/train
# Moved all files from FRAGMENTS/val to FRAGMENTS/train
# Moved all files from DIVE/val to DIVE/train
# Moved all files from TALK/val to TALK/train
# Moved all files from VACCINATION/val to VACCINATION/train
# Moved all files from SUPREME/val to SUPREME/train
# Moved all files from STRANGE/val to STRANGE/train
# Moved all files from RITE/val to RITE/train
# Moved all files from FADE/val to FADE/train
# Moved all files from AFFECTING/val to AFFECTING/train
# Moved all files from BLOWING/val to BLOWING/train
# Moved all files from RELEVANT/val to RELEVANT/train
# ...
# Moved all files from DISPOSAL/val to DISPOSAL/train
# Moved all files from BORROW/val to BORROW/train
# Moved all files from HOLY/val to HOLY/train
# Moved all files from STRETCH/val to STRETCH/train
# Moved all files from WEBSITE/val to WEBSITE/train
# Moved all files from NASTY/val to NASTY/train
# Moved all files from YESTERDAY/val to YESTERDAY/train
# Moved all files from NORM/val to NORM/train
# Moved all files from USEFUL/val to USEFUL/train
# Moved all files from LASER/val to LASER/train
# Moved all files from SE/val to SE/train
# Moved all files from EXAGGERATION/val to EXAGGERATION/train
# Moved all files from LEGEND/val to LEGEND/train
# Moved all files from ABUSED/val to ABUSED/train
# Moved all files from SENT/val to SENT/train
# Moved all files from UNLUCKY/val to UNLUCKY/train
# Moved all files from SMILING/val to SMILING/train
# Moved all files from SQUARE/val to SQUARE/train
# Moved all files from NEEDING/val to NEEDING/train
# Moved all files from LAWYER/val to LAWYER/train
# Moved all files from HEAVY/val to HEAVY/train
# Moved all files from EMPOWERED/val to EMPOWERED/train
# Moved all files from DEFINE/val to DEFINE/train
# Moved all files from BLIND/val to BLIND/train
# Moved all files from LIP/val to LIP/train
# Moved all files from ADULT/val to ADULT/train
# Moved all files from AMBULANCE/val to AMBULANCE/train
# Moved all files from CHASING/val to CHASING/train
# Moved all files from DISCOVERED/val to DISCOVERED/train
# Moved all files from FLORIDA/val to FLORIDA/train
# Moved all files from REGRET/val to REGRET/train
# Moved all files from THREAD/val to THREAD/train
# Moved all files from GAME/val to GAME/train
# Moved all files from REUNITE/val to REUNITE/train
# Moved all files from UNBELIEVABLE/val to UNBELIEVABLE/train
# Moved all files from AUGMENTED/val to AUGMENTED/train
# Moved all files from RENAISSANCE/val to RENAISSANCE/train
# Moved all files from REDUCE/val to REDUCE/train
# Moved all files from COMMAND/val to COMMAND/train
# Moved all files from FIFTY/val to FIFTY/train
# Moved all files from BLAST/val to BLAST/train
# Moved all files from TREE/val to TREE/train
# Moved all files from ROTTEN/val to ROTTEN/train
# Moved all files from CONSULTANT/val to CONSULTANT/train
# Moved all files from BEAR/val to BEAR/train
# Moved all files from PROMISE/val to PROMISE/train
# Moved all files from ENGINEER/val to ENGINEER/train
# Moved all files from FUN/val to FUN/train
# Moved all files from ACTIVITY/val to ACTIVITY/train
# Moved all files from SNOWDEN/val to SNOWDEN/train
# Moved all files from BOAT/val to BOAT/train
# Moved all files from OMEGA/val to OMEGA/train
# Moved all files from FLOWING/val to FLOWING/train
# Moved all files from SLIP/val to SLIP/train
# Moved all files from ADDICTED/val to ADDICTED/train
# Moved all files from CONSENT/val to CONSENT/train
# Moved all files from PERCEIVE/val to PERCEIVE/train
# Moved all files from EQUIVALENT/val to EQUIVALENT/train
# Moved all files from PARADIGM/val to PARADIGM/train
# Moved all files from LAVA/val to LAVA/train
# Moved all files from GRADUATION/val to GRADUATION/train
# Moved all files from DOUBLED/val to DOUBLED/train
# Moved all files from COHEN/val to COHEN/train
# Moved all files from EMPIRICAL/val to EMPIRICAL/train
# Moved all files from CONGESTION/val to CONGESTION/train
# Moved all files from CAROLINA/val to CAROLINA/train
# Moved all files from TOOK/val to TOOK/train
# Moved all files from GOLF/val to GOLF/train
# Moved all files from PHILOSOPHY/val to PHILOSOPHY/train
# Moved all files from MANUFACTURE/val to MANUFACTURE/train
# Moved all files from PLANTED/val to PLANTED/train
# Moved all files from ISLAMIST/val to ISLAMIST/train
# Moved all files from VS/val to VS/train
# Moved all files from STRICT/val to STRICT/train
# Moved all files from DOCTOR/val to DOCTOR/train
# Moved all files from MUM/val to MUM/train
# Moved all files from NORMAN/val to NORMAN/train
# Moved all files from CABLE/val to CABLE/train
# Moved all files from QUICK/val to QUICK/train
# Moved all files from GONE/val to GONE/train
# Moved all files from NAKED/val to NAKED/train
# Moved all files from EXPENSE/val to EXPENSE/train
# Moved all files from DANCE/val to DANCE/train
# Moved all files from HANGING/val to HANGING/train
# Moved all files from LOSING/val to LOSING/train
# Moved all files from FULFILLING/val to FULFILLING/train
# Moved all files from POSE/val to POSE/train
# Moved all files from COMMITTEE/val to COMMITTEE/train
# Moved all files from TOWARD/val to TOWARD/train
# Moved all files from DECENT/val to DECENT/train
# Moved all files from WASHINGTON/val to WASHINGTON/train
# Moved all files from PRE/val to PRE/train
# Moved all files from HORMONE/val to HORMONE/train
# Moved all files from WEAPON/val to WEAPON/train
# Moved all files from ABLE/val to ABLE/train
# Moved all files from CRYSTALS/val to CRYSTALS/train
# Moved all files from MARK/val to MARK/train
# Moved all files from COOPERATIVE/val to COOPERATIVE/train
# Moved all files from ASTONISHED/val to ASTONISHED/train
# Moved all files from STRATEGIC/val to STRATEGIC/train
# Moved all files from BONUS/val to BONUS/train
# Moved all files from DEPEND/val to DEPEND/train
# Moved all files from MINISTER/val to MINISTER/train
# Moved all files from SERGIO/val to SERGIO/train
# Moved all files from EXPLAIN/val to EXPLAIN/train
# Moved all files from RELYING/val to RELYING/train
# Moved all files from WORKPLACE/val to WORKPLACE/train
# Moved all files from NICE/val to NICE/train
# Moved all files from UNLIKELY/val to UNLIKELY/train
# Moved all files from PULSE/val to PULSE/train
# Moved all files from UCLA/val to UCLA/train
# Moved all files from READ/val to READ/train
# Moved all files from FELT/val to FELT/train
# Moved all files from ICE/val to ICE/train
# Moved all files from FORTY/val to FORTY/train
# Moved all files from PRINCIPAL/val to PRINCIPAL/train
# Moved all files from MODEL/val to MODEL/train
# Moved all files from HERE'S/val to HERE'S/train
# Moved all files from DOES/val to DOES/train
# Moved all files from SELFISH/val to SELFISH/train
# Moved all files from SYNAPSES/val to SYNAPSES/train
# Moved all files from HORRIFYING/val to HORRIFYING/train
# Moved all files from UPRIGHT/val to UPRIGHT/train
# Moved all files from VOTING/val to VOTING/train
# Moved all files from BROUGHT/val to BROUGHT/train
# Moved all files from CONSUMED/val to CONSUMED/train
# Moved all files from KEPT/val to KEPT/train
# Moved all files from PHOTO/val to PHOTO/train
# Moved all files from RANCHER/val to RANCHER/train
# Moved all files from UNKNOWN/val to UNKNOWN/train
# Moved all files from ONLY/val to ONLY/train
# Moved all files from MIGRATION/val to MIGRATION/train
# Moved all files from PRODUCER/val to PRODUCER/train
# Moved all files from STAYED/val to STAYED/train
# Moved all files from EMPOWERMENT/val to EMPOWERMENT/train
# Moved all files from VICTIM/val to VICTIM/train
# Moved all files from FULLY/val to FULLY/train
# Moved all files from INSPIRED/val to INSPIRED/train
# Moved all files from FILMING/val to FILMING/train
# Moved all files from CORE/val to CORE/train
# Moved all files from SYNDROME/val to SYNDROME/train
# Moved all files from MARKET/val to MARKET/train
# Moved all files from ADDICTIVE/val to ADDICTIVE/train
# Moved all files from CONTRADICTION/val to CONTRADICTION/train
# Moved all files from PUSH/val to PUSH/train
# Moved all files from MOBILE/val to MOBILE/train
# Moved all files from ITSELF/val to ITSELF/train
# Moved all files from OVERDOSE/val to OVERDOSE/train
# Moved all files from PRESCRIPTION/val to PRESCRIPTION/train
# Moved all files from NELSON/val to NELSON/train
# Moved all files from ROYAL/val to ROYAL/train
# Moved all files from NUDGING/val to NUDGING/train
# Moved all files from TACKLE/val to TACKLE/train
# Moved all files from JUDGEMENT/val to JUDGEMENT/train
# Moved all files from APPLIED/val to APPLIED/train
# Moved all files from RATIONALE/val to RATIONALE/train
# Moved all files from WEIRD/val to WEIRD/train
# Moved all files from COLLECTIVELY/val to COLLECTIVELY/train
# Moved all files from SLIPPED/val to SLIPPED/train
# Moved all files from TRANSFERRED/val to TRANSFERRED/train
# Moved all files from PINT/val to PINT/train
# Moved all files from INDEED/val to INDEED/train
# Moved all files from STANFORD/val to STANFORD/train
# Moved all files from COOPERATION/val to COOPERATION/train
# Moved all files from IMPLANT/val to IMPLANT/train
# Moved all files from DIVERSITY/val to DIVERSITY/train
# Moved all files from ARAB/val to ARAB/train
# Moved all files from SHOULD/val to SHOULD/train
# Moved all files from TRUSTING/val to TRUSTING/train
# Moved all files from VOTE/val to VOTE/train
# Moved all files from BREEDING/val to BREEDING/train
# Moved all files from LEWIS/val to LEWIS/train
# Moved all files from PERIOD/val to PERIOD/train
# Moved all files from ENCOUNTER/val to ENCOUNTER/train
# Moved all files from WORRIES/val to WORRIES/train
# Moved all files from VOCABULARY/val to VOCABULARY/train
# Moved all files from JACK/val to JACK/train
# Moved all files from YEAH/val to YEAH/train
# Moved all files from CORPORATION/val to CORPORATION/train
# Moved all files from FAILED/val to FAILED/train
# Moved all files from MET/val to MET/train
# Moved all files from MALE/val to MALE/train
# Moved all files from DETECT/val to DETECT/train
# Moved all files from HAVEN'T/val to HAVEN'T/train
# Moved all files from ROCKET/val to ROCKET/train
# Moved all files from ALREADY/val to ALREADY/train
# Moved all files from LINE/val to LINE/train
# Moved all files from OXYGEN/val to OXYGEN/train
# Moved all files from GHOST/val to GHOST/train
# Moved all files from IMPORTANT/val to IMPORTANT/train
# Moved all files from HIGHWAY/val to HIGHWAY/train
# Moved all files from SICK/val to SICK/train
# Moved all files from WORD/val to WORD/train
# Moved all files from IMAGINATION/val to IMAGINATION/train
# Moved all files from SPARK/val to SPARK/train
# Moved all files from OWNED/val to OWNED/train
# Moved all files from TUNNEL/val to TUNNEL/train
# Moved all files from ASTRONAUT/val to ASTRONAUT/train
# Moved all files from HER/val to HER/train
# Moved all files from UNTRUE/val to UNTRUE/train
# Moved all files from WIRED/val to WIRED/train
# Moved all files from LETTER/val to LETTER/train
# Moved all files from APPROACHED/val to APPROACHED/train
# Moved all files from CONNECTED/val to CONNECTED/train
# Moved all files from ON/val to ON/train
# Moved all files from FARM/val to FARM/train
# Moved all files from INTERVENE/val to INTERVENE/train
# Moved all files from YES/val to YES/train
# Moved all files from COAST/val to COAST/train
# Moved all files from MIDST/val to MIDST/train
# Moved all files from TRACKING/val to TRACKING/train
# Moved all files from SEARCHING/val to SEARCHING/train
# Moved all files from FORBIDDEN/val to FORBIDDEN/train
# Moved all files from OK/val to OK/train
# Moved all files from KOSOVO/val to KOSOVO/train
# Moved all files from AWARD/val to AWARD/train
# Moved all files from PEACH/val to PEACH/train
# Moved all files from ACCUMULATION/val to ACCUMULATION/train
# Moved all files from SAM/val to SAM/train
# Moved all files from COVERED/val to COVERED/train
# Moved all files from CRYING/val to CRYING/train
# Moved all files from MONASTERY/val to MONASTERY/train
# Moved all files from HAMILTON/val to HAMILTON/train
# Moved all files from VIOLENT/val to VIOLENT/train
# Moved all files from CONTEST/val to CONTEST/train
# Moved all files from WILLINGNESS/val to WILLINGNESS/train
# Moved all files from VOLUME/val to VOLUME/train
# Moved all files from M/val to M/train
# Moved all files from NEWSPAPER/val to NEWSPAPER/train
# Moved all files from TRADITIONAL/val to TRADITIONAL/train
# Moved all files from DYNAMIC/val to DYNAMIC/train
# Moved all files from LIMIT/val to LIMIT/train
# Moved all files from TERM/val to TERM/train
# Moved all files from CORPSE/val to CORPSE/train
# Moved all files from INTO/val to INTO/train
# Moved all files from RATE/val to RATE/train
# Moved all files from UNDERSTAND/val to UNDERSTAND/train
# Moved all files from MANHOOD/val to MANHOOD/train
# Moved all files from INNOVATE/val to INNOVATE/train
# Moved all files from CAPITAL/val to CAPITAL/train
# Moved all files from ALGEBRA/val to ALGEBRA/train
# Moved all files from MILD/val to MILD/train
# Moved all files from COMMENT/val to COMMENT/train
# Moved all files from OAKLAND/val to OAKLAND/train
# Moved all files from INSULT/val to INSULT/train
# Moved all files from LIMITED/val to LIMITED/train
# Moved all files from MOOD/val to MOOD/train
# Moved all files from DIAGNOSE/val to DIAGNOSE/train
# Moved all files from SAVED/val to SAVED/train
# Moved all files from EMBODIMENT/val to EMBODIMENT/train
# Moved all files from DEVELOPER/val to DEVELOPER/train
# Moved all files from TRANSLATING/val to TRANSLATING/train
# Moved all files from MOTHER/val to MOTHER/train
# Moved all files from THRILLED/val to THRILLED/train
# Moved all files from HITTING/val to HITTING/train
# Moved all files from ENVIRONMENTAL/val to ENVIRONMENTAL/train
# Moved all files from SPIRITUALITY/val to SPIRITUALITY/train
# Moved all files from MINOR/val to MINOR/train
# Moved all files from INVENTOR/val to INVENTOR/train
# Moved all files from GERMAN/val to GERMAN/train
# Moved all files from MIRACLE/val to MIRACLE/train
# Moved all files from ASSET/val to ASSET/train
# Moved all files from BRIEFLY/val to BRIEFLY/train
# Moved all files from PAIN/val to PAIN/train
# Moved all files from DULL/val to DULL/train
# Moved all files from AD/val to AD/train
# Moved all files from SHIP/val to SHIP/train
# Moved all files from AGREEMENT/val to AGREEMENT/train
# Moved all files from ACQUIRE/val to ACQUIRE/train
# Moved all files from DESPERATELY/val to DESPERATELY/train
# Moved all files from SOFTWARE/val to SOFTWARE/train
# Moved all files from EXPLODING/val to EXPLODING/train
# Moved all files from SOCIETIES/val to SOCIETIES/train
# Moved all files from SEARCHES/val to SEARCHES/train
# Moved all files from STORYTELLER/val to STORYTELLER/train
# Moved all files from ABDOMINAL/val to ABDOMINAL/train
# Moved all files from DIGGING/val to DIGGING/train
# Moved all files from BULLET/val to BULLET/train
# Moved all files from IN/val to IN/train
# Moved all files from CLUE/val to CLUE/train
# Moved all files from POEM/val to POEM/train
# Moved all files from ATTRACTED/val to ATTRACTED/train
# Moved all files from REPAIR/val to REPAIR/train
# Moved all files from COPE/val to COPE/train
# Moved all files from CONFUSING/val to CONFUSING/train
# Moved all files from LESSON/val to LESSON/train
# Moved all files from RESOLUTION/val to RESOLUTION/train
# Moved all files from CONTRAST/val to CONTRAST/train
# Moved all files from KING/val to KING/train
# Moved all files from LGBT/val to LGBT/train
# Moved all files from REMOVING/val to REMOVING/train
# Moved all files from FROG/val to FROG/train
# Moved all files from CONSUME/val to CONSUME/train
# Moved all files from SECRET/val to SECRET/train
# Moved all files from BREAKING/val to BREAKING/train
# Moved all files from THOMAS/val to THOMAS/train
# Moved all files from FOLD/val to FOLD/train
# Moved all files from ADVERTISEMENT/val to ADVERTISEMENT/train
# Moved all files from MUSTER/val to MUSTER/train
# Moved all files from GRANT/val to GRANT/train
# Moved all files from CLIMB/val to CLIMB/train
# Moved all files from AM/val to AM/train
# Moved all files from TESTING/val to TESTING/train
# Moved all files from HEARTBREAKING/val to HEARTBREAKING/train
# Moved all files from BOIL/val to BOIL/train
# Moved all files from ENJOY/val to ENJOY/train
# Moved all files from ANALYZED/val to ANALYZED/train
# Moved all files from PURELY/val to PURELY/train
# Moved all files from EXACT/val to EXACT/train
# Moved all files from HETEROSEXUAL/val to HETEROSEXUAL/train
# Moved all files from GERMANY/val to GERMANY/train
# Moved all files from EARLY/val to EARLY/train
# Moved all files from CUTTING/val to CUTTING/train
# Moved all files from STILL/val to STILL/train
# Moved all files from BLAMED/val to BLAMED/train
# Moved all files from BRIGHT/val to BRIGHT/train
# Moved all files from CHROMOSOME/val to CHROMOSOME/train
# Moved all files from DISRUPT/val to DISRUPT/train
# Moved all files from SPRING/val to SPRING/train
# Moved all files from HUMOR/val to HUMOR/train
# Moved all files from THIS/val to THIS/train
# Moved all files from MEAT/val to MEAT/train
# Moved all files from PROVIDER/val to PROVIDER/train
# Moved all files from ACTIVE/val to ACTIVE/train
# Total words processed: 6124

# %%
updated_df = create_df(dir)

# %%
# Get the words that have total = 3
# Put all in train
words_with_3 = updated_df[(updated_df['total'] == 3)]
print(len(words_with_3))
# Out:
# 1121

# %%
import os
import shutil

moved = 0

for word in words_with_3.index:
    train_folder_path = os.path.join(dir, word, 'train')
    val_folder_path = os.path.join(dir, word, 'val')
    test_folder_path = os.path.join(dir, word, 'test')

    os.makedirs(train_folder_path, exist_ok=True)
    os.makedirs(val_folder_path, exist_ok=True)
    os.makedirs(test_folder_path, exist_ok=True)

    total_files = 0
    if os.path.exists(train_folder_path):
        total_files += len([f for f in os.listdir(train_folder_path) if f.endswith('.mp4') and os.path.isfile(os.path.join(train_folder_path, f))])

    if os.path.exists(val_folder_path):
        total_files += len([f for f in os.listdir(val_folder_path) if f.endswith('.mp4') and os.path.isfile(os.path.join(val_folder_path, f))])

    if os.path.exists(test_folder_path):
        total_files += len([f for f in os.listdir(test_folder_path) if f.endswith('.mp4') and os.path.isfile(os.path.join(test_folder_path, f))])

    # If the total number of .npz files across all sets is exactly 3, move everything to the train folder
    if total_files == 3:

        # Move .npz files from val folder to train folder
        if os.path.exists(val_folder_path):
            for item in os.listdir(val_folder_path):
                val_item_path = os.path.join(val_folder_path, item)
                train_item_path = os.path.join(train_folder_path, item)

                if os.path.isfile(val_item_path):
                    shutil.move(val_item_path, train_item_path)
                    print(f"Moved {item} from {word}/val to {word}/train")

        # Move .npz files from test folder to train folder (if any)
        if os.path.exists(test_folder_path):
            for item in os.listdir(test_folder_path):
                test_item_path = os.path.join(test_folder_path, item)
                train_item_path = os.path.join(train_folder_path, item)

                if os.path.isfile(test_item_path):
                    shutil.move(test_item_path, train_item_path)
                    print(f"Moved {item} from {word}/test to {word}/train")

        moved += 1
        print(f"Moved all 3 .npz files from {word}/train, {word}/val, and {word}/test to {word}/train")

print(f"Total words processed: {moved}")
# Out:
# Moved all 3 .npz files from ARABIC/train, ARABIC/val, and ARABIC/test to ARABIC/train
# Moved all 3 .npz files from ANTHROPOLOGY/train, ANTHROPOLOGY/val, and ANTHROPOLOGY/test to ANTHROPOLOGY/train
# Moved all 3 .npz files from GLAND/train, GLAND/val, and GLAND/test to GLAND/train
# Moved all 3 .npz files from SHAKING/train, SHAKING/val, and SHAKING/test to SHAKING/train
# Moved all 3 .npz files from SYMPHONY/train, SYMPHONY/val, and SYMPHONY/test to SYMPHONY/train
# Moved all 3 .npz files from DECEPTION/train, DECEPTION/val, and DECEPTION/test to DECEPTION/train
# Moved all 3 .npz files from ANSWERING/train, ANSWERING/val, and ANSWERING/test to ANSWERING/train
# Moved all 3 .npz files from BRIDE/train, BRIDE/val, and BRIDE/test to BRIDE/train
# Moved all 3 .npz files from CLAPPING/train, CLAPPING/val, and CLAPPING/test to CLAPPING/train
# Moved all 3 .npz files from APPRENTICESHIP/train, APPRENTICESHIP/val, and APPRENTICESHIP/test to APPRENTICESHIP/train
# Moved all 3 .npz files from FREQUENTLY/train, FREQUENTLY/val, and FREQUENTLY/test to FREQUENTLY/train
# Moved all 3 .npz files from WANDER/train, WANDER/val, and WANDER/test to WANDER/train
# Moved all 3 .npz files from TOLERANT/train, TOLERANT/val, and TOLERANT/test to TOLERANT/train
# Moved all 3 .npz files from EXILE/train, EXILE/val, and EXILE/test to EXILE/train
# Moved all 3 .npz files from MCDONALD'S/train, MCDONALD'S/val, and MCDONALD'S/test to MCDONALD'S/train
# Moved all 3 .npz files from MOISTURE/train, MOISTURE/val, and MOISTURE/test to MOISTURE/train
# Moved all 3 .npz files from PERSIST/train, PERSIST/val, and PERSIST/test to PERSIST/train
# Moved all 3 .npz files from STRAY/train, STRAY/val, and STRAY/test to STRAY/train
# Moved all 3 .npz files from SOMEPLACE/train, SOMEPLACE/val, and SOMEPLACE/test to SOMEPLACE/train
# Moved all 3 .npz files from COMPETING/train, COMPETING/val, and COMPETING/test to COMPETING/train
# Moved all 3 .npz files from SAUCE/train, SAUCE/val, and SAUCE/test to SAUCE/train
# Moved all 3 .npz files from OUTLET/train, OUTLET/val, and OUTLET/test to OUTLET/train
# Moved all 3 .npz files from DENYING/train, DENYING/val, and DENYING/test to DENYING/train
# Moved all 3 .npz files from BUNK/train, BUNK/val, and BUNK/test to BUNK/train
# Moved all 3 .npz files from PROGRESSION/train, PROGRESSION/val, and PROGRESSION/test to PROGRESSION/train
# Moved all 3 .npz files from ESCAPED/train, ESCAPED/val, and ESCAPED/test to ESCAPED/train
# Moved all 3 .npz files from PRAIRIE/train, PRAIRIE/val, and PRAIRIE/test to PRAIRIE/train
# Moved all 3 .npz files from CLOTH/train, CLOTH/val, and CLOTH/test to CLOTH/train
# Moved all 3 .npz files from GRAFFITI/train, GRAFFITI/val, and GRAFFITI/test to GRAFFITI/train
# Moved all 3 .npz files from ADMISSION/train, ADMISSION/val, and ADMISSION/test to ADMISSION/train
# Moved all 3 .npz files from LOAF/train, LOAF/val, and LOAF/test to LOAF/train
# Moved all 3 .npz files from MUNCHKIN/train, MUNCHKIN/val, and MUNCHKIN/test to MUNCHKIN/train
# Moved all 3 .npz files from INTERESTINGLY/train, INTERESTINGLY/val, and INTERESTINGLY/test to INTERESTINGLY/train
# Moved all 3 .npz files from DANCER/train, DANCER/val, and DANCER/test to DANCER/train
# Moved all 3 .npz files from PORT/train, PORT/val, and PORT/test to PORT/train
# Moved all 3 .npz files from CALCULUS/train, CALCULUS/val, and CALCULUS/test to CALCULUS/train
# Moved all 3 .npz files from ECONOMIES/train, ECONOMIES/val, and ECONOMIES/test to ECONOMIES/train
# Moved all 3 .npz files from CRUSHING/train, CRUSHING/val, and CRUSHING/test to CRUSHING/train
# Moved all 3 .npz files from ABUNDANCE/train, ABUNDANCE/val, and ABUNDANCE/test to ABUNDANCE/train
# Moved all 3 .npz files from FLOSS/train, FLOSS/val, and FLOSS/test to FLOSS/train
# Moved all 3 .npz files from TABOO/train, TABOO/val, and TABOO/test to TABOO/train
# Moved all 3 .npz files from CEREMONY/train, CEREMONY/val, and CEREMONY/test to CEREMONY/train
# Moved all 3 .npz files from QUIETLY/train, QUIETLY/val, and QUIETLY/test to QUIETLY/train
# Moved all 3 .npz files from MASTERY/train, MASTERY/val, and MASTERY/test to MASTERY/train
# Moved all 3 .npz files from MONOGAMY/train, MONOGAMY/val, and MONOGAMY/test to MONOGAMY/train
# Moved all 3 .npz files from CRACKING/train, CRACKING/val, and CRACKING/test to CRACKING/train
# Moved all 3 .npz files from SOLELY/train, SOLELY/val, and SOLELY/test to SOLELY/train
# Moved all 3 .npz files from STRIPE/train, STRIPE/val, and STRIPE/test to STRIPE/train
# Moved all 3 .npz files from VALUED/train, VALUED/val, and VALUED/test to VALUED/train
# Moved all 3 .npz files from INGEST/train, INGEST/val, and INGEST/test to INGEST/train
# Moved all 3 .npz files from INVASIVE/train, INVASIVE/val, and INVASIVE/test to INVASIVE/train
# Moved all 3 .npz files from POSED/train, POSED/val, and POSED/test to POSED/train
# Moved all 3 .npz files from BERLIN/train, BERLIN/val, and BERLIN/test to BERLIN/train
# Moved all 3 .npz files from EM/train, EM/val, and EM/test to EM/train
# Moved all 3 .npz files from WILLENDORF/train, WILLENDORF/val, and WILLENDORF/test to WILLENDORF/train
# Moved all 3 .npz files from COSTUME/train, COSTUME/val, and COSTUME/test to COSTUME/train
# Moved all 3 .npz files from SLEEVE/train, SLEEVE/val, and SLEEVE/test to SLEEVE/train
# Moved all 3 .npz files from POINTING/train, POINTING/val, and POINTING/test to POINTING/train
# Moved all 3 .npz files from WITHDREW/train, WITHDREW/val, and WITHDREW/test to WITHDREW/train
# Moved all 3 .npz files from CASKET/train, CASKET/val, and CASKET/test to CASKET/train
# Moved all 3 .npz files from WALMART/train, WALMART/val, and WALMART/test to WALMART/train
# Moved all 3 .npz files from THRUST/train, THRUST/val, and THRUST/test to THRUST/train
# Moved all 3 .npz files from DERVISH/train, DERVISH/val, and DERVISH/test to DERVISH/train
# Moved all 3 .npz files from TENET/train, TENET/val, and TENET/test to TENET/train
# Moved all 3 .npz files from CRUCIALLY/train, CRUCIALLY/val, and CRUCIALLY/test to CRUCIALLY/train
# Moved all 3 .npz files from COMMONALITIES/train, COMMONALITIES/val, and COMMONALITIES/test to COMMONALITIES/train
# Moved all 3 .npz files from FORT/train, FORT/val, and FORT/test to FORT/train
# Moved all 3 .npz files from EXPONENTIALLY/train, EXPONENTIALLY/val, and EXPONENTIALLY/test to EXPONENTIALLY/train
# Moved all 3 .npz files from HOMO/train, HOMO/val, and HOMO/test to HOMO/train
# Moved all 3 .npz files from CARPENTRY/train, CARPENTRY/val, and CARPENTRY/test to CARPENTRY/train
# Moved all 3 .npz files from SWIRLING/train, SWIRLING/val, and SWIRLING/test to SWIRLING/train
# Moved all 3 .npz files from LEMONADE/train, LEMONADE/val, and LEMONADE/test to LEMONADE/train
# Moved all 3 .npz files from BATH/train, BATH/val, and BATH/test to BATH/train
# Moved all 3 .npz files from PHOTOGRAPHED/train, PHOTOGRAPHED/val, and PHOTOGRAPHED/test to PHOTOGRAPHED/train
# Moved all 3 .npz files from WOKEN/train, WOKEN/val, and WOKEN/test to WOKEN/train
# Moved all 3 .npz files from GUESSING/train, GUESSING/val, and GUESSING/test to GUESSING/train
# Moved all 3 .npz files from BLA/train, BLA/val, and BLA/test to BLA/train
# Moved all 3 .npz files from MENTORING/train, MENTORING/val, and MENTORING/test to MENTORING/train
# Moved all 3 .npz files from AUDITION/train, AUDITION/val, and AUDITION/test to AUDITION/train
# Moved all 3 .npz files from COX/train, COX/val, and COX/test to COX/train
# Moved all 3 .npz files from ETHICS/train, ETHICS/val, and ETHICS/test to ETHICS/train
# Moved all 3 .npz files from SPORTING/train, SPORTING/val, and SPORTING/test to SPORTING/train
# Moved all 3 .npz files from FUELED/train, FUELED/val, and FUELED/test to FUELED/train
# Moved all 3 .npz files from ELLEN/train, ELLEN/val, and ELLEN/test to ELLEN/train
# Moved all 3 .npz files from THRILL/train, THRILL/val, and THRILL/test to THRILL/train
# Moved all 3 .npz files from COMPROMISE/train, COMPROMISE/val, and COMPROMISE/test to COMPROMISE/train
# Moved all 3 .npz files from MATTHEW/train, MATTHEW/val, and MATTHEW/test to MATTHEW/train
# Moved all 3 .npz files from BRUSHED/train, BRUSHED/val, and BRUSHED/test to BRUSHED/train
# Moved all 3 .npz files from ISN/train, ISN/val, and ISN/test to ISN/train
# Moved all 3 .npz files from PAINTER/train, PAINTER/val, and PAINTER/test to PAINTER/train
# Moved all 3 .npz files from JURY/train, JURY/val, and JURY/test to JURY/train
# Moved all 3 .npz files from QUALIFIED/train, QUALIFIED/val, and QUALIFIED/test to QUALIFIED/train
# Moved all 3 .npz files from FICTIONAL/train, FICTIONAL/val, and FICTIONAL/test to FICTIONAL/train
# Moved all 3 .npz files from APPALLING/train, APPALLING/val, and APPALLING/test to APPALLING/train
# Moved all 3 .npz files from LAPILLI/train, LAPILLI/val, and LAPILLI/test to LAPILLI/train
# Moved all 3 .npz files from MOSQUE/train, MOSQUE/val, and MOSQUE/test to MOSQUE/train
# Moved all 3 .npz files from DEAN/train, DEAN/val, and DEAN/test to DEAN/train
# Moved all 3 .npz files from BETA/train, BETA/val, and BETA/test to BETA/train
# Moved all 3 .npz files from COLORED/train, COLORED/val, and COLORED/test to COLORED/train
# Moved all 3 .npz files from REACTIVE/train, REACTIVE/val, and REACTIVE/test to REACTIVE/train
# Moved all 3 .npz files from UPTAKE/train, UPTAKE/val, and UPTAKE/test to UPTAKE/train
# Moved all 3 .npz files from FLUORESCENT/train, FLUORESCENT/val, and FLUORESCENT/test to FLUORESCENT/train
# Moved all 3 .npz files from VENUE/train, VENUE/val, and VENUE/test to VENUE/train
# Moved all 3 .npz files from HOLLYWOOD/train, HOLLYWOOD/val, and HOLLYWOOD/test to HOLLYWOOD/train
# Moved all 3 .npz files from BAGHDAD/train, BAGHDAD/val, and BAGHDAD/test to BAGHDAD/train
# Moved all 3 .npz files from ROD/train, ROD/val, and ROD/test to ROD/train
# Moved all 3 .npz files from DEFINITIVE/train, DEFINITIVE/val, and DEFINITIVE/test to DEFINITIVE/train
# Moved all 3 .npz files from NEIL/train, NEIL/val, and NEIL/test to NEIL/train
# Moved all 3 .npz files from APPETITE/train, APPETITE/val, and APPETITE/test to APPETITE/train
# Moved all 3 .npz files from PIE/train, PIE/val, and PIE/test to PIE/train
# Moved all 3 .npz files from BUREAUCRAT/train, BUREAUCRAT/val, and BUREAUCRAT/test to BUREAUCRAT/train
# Moved all 3 .npz files from BOW/train, BOW/val, and BOW/test to BOW/train
# Moved all 3 .npz files from CELEBRATION/train, CELEBRATION/val, and CELEBRATION/test to CELEBRATION/train
# Moved all 3 .npz files from MARTIAL/train, MARTIAL/val, and MARTIAL/test to MARTIAL/train
# Moved all 3 .npz files from YORUBA/train, YORUBA/val, and YORUBA/test to YORUBA/train
# Moved all 3 .npz files from MOSES/train, MOSES/val, and MOSES/test to MOSES/train
# Moved all 3 .npz files from LINED/train, LINED/val, and LINED/test to LINED/train
# Moved all 3 .npz files from PLANTATION/train, PLANTATION/val, and PLANTATION/test to PLANTATION/train
# Moved all 3 .npz files from PANAMA/train, PANAMA/val, and PANAMA/test to PANAMA/train
# Moved all 3 .npz files from DIOXIDE/train, DIOXIDE/val, and DIOXIDE/test to DIOXIDE/train
# Moved all 3 .npz files from TRACKER/train, TRACKER/val, and TRACKER/test to TRACKER/train
# Moved all 3 .npz files from BEETLE/train, BEETLE/val, and BEETLE/test to BEETLE/train
# Moved all 3 .npz files from TRUSTED/train, TRUSTED/val, and TRUSTED/test to TRUSTED/train
# Moved all 3 .npz files from ABRAHAM'S/train, ABRAHAM'S/val, and ABRAHAM'S/test to ABRAHAM'S/train
# Moved all 3 .npz files from CADAVER/train, CADAVER/val, and CADAVER/test to CADAVER/train
# Moved all 3 .npz files from MAHATMA/train, MAHATMA/val, and MAHATMA/test to MAHATMA/train
# Moved all 3 .npz files from PRECISELY/train, PRECISELY/val, and PRECISELY/test to PRECISELY/train
# Moved all 3 .npz files from CAPTAIN/train, CAPTAIN/val, and CAPTAIN/test to CAPTAIN/train
# Moved all 3 .npz files from UNLEASHED/train, UNLEASHED/val, and UNLEASHED/test to UNLEASHED/train
# Moved all 3 .npz files from REBEL/train, REBEL/val, and REBEL/test to REBEL/train
# Moved all 3 .npz files from APPLYING/train, APPLYING/val, and APPLYING/test to APPLYING/train
# Moved all 3 .npz files from ZOO/train, ZOO/val, and ZOO/test to ZOO/train
# Moved all 3 .npz files from RESENTED/train, RESENTED/val, and RESENTED/test to RESENTED/train
# Moved all 3 .npz files from SHOULD'VE/train, SHOULD'VE/val, and SHOULD'VE/test to SHOULD'VE/train
# Moved all 3 .npz files from LEBANON/train, LEBANON/val, and LEBANON/test to LEBANON/train
# Moved all 3 .npz files from NOVELTY/train, NOVELTY/val, and NOVELTY/test to NOVELTY/train
# Moved all 3 .npz files from FLASHLIGHT/train, FLASHLIGHT/val, and FLASHLIGHT/test to FLASHLIGHT/train
# Moved all 3 .npz files from DRIFT/train, DRIFT/val, and DRIFT/test to DRIFT/train
# Moved all 3 .npz files from Y/train, Y/val, and Y/test to Y/train
# Moved all 3 .npz files from COUNSEL/train, COUNSEL/val, and COUNSEL/test to COUNSEL/train
# Moved all 3 .npz files from ENTHUSIASTIC/train, ENTHUSIASTIC/val, and ENTHUSIASTIC/test to ENTHUSIASTIC/train
# Moved all 3 .npz files from COWARD/train, COWARD/val, and COWARD/test to COWARD/train
# Moved all 3 .npz files from DROWNING/train, DROWNING/val, and DROWNING/test to DROWNING/train
# Moved all 3 .npz files from INEFFICIENT/train, INEFFICIENT/val, and INEFFICIENT/test to INEFFICIENT/train
# Moved all 3 .npz files from TRIUMPH/train, TRIUMPH/val, and TRIUMPH/test to TRIUMPH/train
# Moved all 3 .npz files from FOXES/train, FOXES/val, and FOXES/test to FOXES/train
# Moved all 3 .npz files from MILK/train, MILK/val, and MILK/test to MILK/train
# Moved all 3 .npz files from RETAIL/train, RETAIL/val, and RETAIL/test to RETAIL/train
# Moved all 3 .npz files from EXPERIMENTAL/train, EXPERIMENTAL/val, and EXPERIMENTAL/test to EXPERIMENTAL/train
# Moved all 3 .npz files from PENNY/train, PENNY/val, and PENNY/test to PENNY/train
# Moved all 3 .npz files from USA/train, USA/val, and USA/test to USA/train
# Moved all 3 .npz files from PLUG/train, PLUG/val, and PLUG/test to PLUG/train
# Moved all 3 .npz files from SERVANT/train, SERVANT/val, and SERVANT/test to SERVANT/train
# Moved all 3 .npz files from DIVINE/train, DIVINE/val, and DIVINE/test to DIVINE/train
# Moved all 3 .npz files from ALLEN/train, ALLEN/val, and ALLEN/test to ALLEN/train
# Moved all 3 .npz files from RITE/train, RITE/val, and RITE/test to RITE/train
# Moved all 3 .npz files from FADE/train, FADE/val, and FADE/test to FADE/train
# Moved all 3 .npz files from BLOWING/train, BLOWING/val, and BLOWING/test to BLOWING/train
# Moved all 3 .npz files from QUEUE/train, QUEUE/val, and QUEUE/test to QUEUE/train
# Moved all 3 .npz files from STRUCTURED/train, STRUCTURED/val, and STRUCTURED/test to STRUCTURED/train
# Moved all 3 .npz files from RESTRICTION/train, RESTRICTION/val, and RESTRICTION/test to RESTRICTION/train
# Moved all 3 .npz files from STRANGELY/train, STRANGELY/val, and STRANGELY/test to STRANGELY/train
# Moved all 3 .npz files from RWANDA/train, RWANDA/val, and RWANDA/test to RWANDA/train
# Moved all 3 .npz files from CROCHET/train, CROCHET/val, and CROCHET/test to CROCHET/train
# Moved all 3 .npz files from ESTATE/train, ESTATE/val, and ESTATE/test to ESTATE/train
# Moved all 3 .npz files from WALKABLE/train, WALKABLE/val, and WALKABLE/test to WALKABLE/train
# Moved all 3 .npz files from FORMATION/train, FORMATION/val, and FORMATION/test to FORMATION/train
# Moved all 3 .npz files from EXPANDING/train, EXPANDING/val, and EXPANDING/test to EXPANDING/train
# Moved all 3 .npz files from VALIDATION/train, VALIDATION/val, and VALIDATION/test to VALIDATION/train
# Moved all 3 .npz files from FILED/train, FILED/val, and FILED/test to FILED/train
# Moved all 3 .npz files from STRAND/train, STRAND/val, and STRAND/test to STRAND/train
# Moved all 3 .npz files from RACING/train, RACING/val, and RACING/test to RACING/train
# Moved all 3 .npz files from BLESS/train, BLESS/val, and BLESS/test to BLESS/train
# Moved all 3 .npz files from KATRINA/train, KATRINA/val, and KATRINA/test to KATRINA/train
# Moved all 3 .npz files from SCREAM/train, SCREAM/val, and SCREAM/test to SCREAM/train
# Moved all 3 .npz files from PROJECTING/train, PROJECTING/val, and PROJECTING/test to PROJECTING/train
# Moved all 3 .npz files from MONOPOLY/train, MONOPOLY/val, and MONOPOLY/test to MONOPOLY/train
# Moved all 3 .npz files from ASSESSMENT/train, ASSESSMENT/val, and ASSESSMENT/test to ASSESSMENT/train
# Moved all 3 .npz files from SHINE/train, SHINE/val, and SHINE/test to SHINE/train
# Moved all 3 .npz files from FOG/train, FOG/val, and FOG/test to FOG/train
# Moved all 3 .npz files from REVOLVE/train, REVOLVE/val, and REVOLVE/test to REVOLVE/train
# Moved all 3 .npz files from SPARKED/train, SPARKED/val, and SPARKED/test to SPARKED/train
# Moved all 3 .npz files from MARROW/train, MARROW/val, and MARROW/test to MARROW/train
# Moved all 3 .npz files from POT/train, POT/val, and POT/test to POT/train
# Moved all 3 .npz files from DISAPPEARED/train, DISAPPEARED/val, and DISAPPEARED/test to DISAPPEARED/train
# Moved all 3 .npz files from MISERY/train, MISERY/val, and MISERY/test to MISERY/train
# Moved all 3 .npz files from HAROLD/train, HAROLD/val, and HAROLD/test to HAROLD/train
# Moved all 3 .npz files from APPROXIMATION/train, APPROXIMATION/val, and APPROXIMATION/test to APPROXIMATION/train
# Moved all 3 .npz files from PESSIMIST/train, PESSIMIST/val, and PESSIMIST/test to PESSIMIST/train
# Moved all 3 .npz files from ACRONYM/train, ACRONYM/val, and ACRONYM/test to ACRONYM/train
# Moved all 3 .npz files from IDAHO/train, IDAHO/val, and IDAHO/test to IDAHO/train
# Moved all 3 .npz files from INFANT/train, INFANT/val, and INFANT/test to INFANT/train
# Moved all 3 .npz files from SEBASTIAN/train, SEBASTIAN/val, and SEBASTIAN/test to SEBASTIAN/train
# Moved all 3 .npz files from RUPEES/train, RUPEES/val, and RUPEES/test to RUPEES/train
# Moved all 3 .npz files from SELECTIVELY/train, SELECTIVELY/val, and SELECTIVELY/test to SELECTIVELY/train
# Moved all 3 .npz files from ETCHED/train, ETCHED/val, and ETCHED/test to ETCHED/train
# Moved all 3 .npz files from ALTOGETHER/train, ALTOGETHER/val, and ALTOGETHER/test to ALTOGETHER/train
# Moved all 3 .npz files from ULTRASOUND/train, ULTRASOUND/val, and ULTRASOUND/test to ULTRASOUND/train
# Moved all 3 .npz files from BATMAN/train, BATMAN/val, and BATMAN/test to BATMAN/train
# Moved all 3 .npz files from NEGOTIATING/train, NEGOTIATING/val, and NEGOTIATING/test to NEGOTIATING/train
# Moved all 3 .npz files from LADDER/train, LADDER/val, and LADDER/test to LADDER/train
# Moved all 3 .npz files from DISAPPOINTED/train, DISAPPOINTED/val, and DISAPPOINTED/test to DISAPPOINTED/train
# Moved all 3 .npz files from GIGANTIC/train, GIGANTIC/val, and GIGANTIC/test to GIGANTIC/train
# Moved all 3 .npz files from BANANA/train, BANANA/val, and BANANA/test to BANANA/train
# Moved all 3 .npz files from REPEATED/train, REPEATED/val, and REPEATED/test to REPEATED/train
# Moved all 3 .npz files from URANIUM/train, URANIUM/val, and URANIUM/test to URANIUM/train
# Moved all 3 .npz files from TIDY/train, TIDY/val, and TIDY/test to TIDY/train
# Moved all 3 .npz files from HOW'S/train, HOW'S/val, and HOW'S/test to HOW'S/train
# Moved all 3 .npz files from SEPARATING/train, SEPARATING/val, and SEPARATING/test to SEPARATING/train
# Moved all 3 .npz files from GUESSED/train, GUESSED/val, and GUESSED/test to GUESSED/train
# Moved all 3 .npz files from BANNING/train, BANNING/val, and BANNING/test to BANNING/train
# Moved all 3 .npz files from RECLAIM/train, RECLAIM/val, and RECLAIM/test to RECLAIM/train
# Moved all 3 .npz files from SIMPLICITY/train, SIMPLICITY/val, and SIMPLICITY/test to SIMPLICITY/train
# Moved all 3 .npz files from KICK/train, KICK/val, and KICK/test to KICK/train
# Moved all 3 .npz files from DISCUSSED/train, DISCUSSED/val, and DISCUSSED/test to DISCUSSED/train
# Moved all 3 .npz files from PROSTHETIC/train, PROSTHETIC/val, and PROSTHETIC/test to PROSTHETIC/train
# Moved all 3 .npz files from LAUNDRY/train, LAUNDRY/val, and LAUNDRY/test to LAUNDRY/train
# Moved all 3 .npz files from PENSION/train, PENSION/val, and PENSION/test to PENSION/train
# Moved all 3 .npz files from EMIT/train, EMIT/val, and EMIT/test to EMIT/train
# Moved all 3 .npz files from MATHEMATICIAN/train, MATHEMATICIAN/val, and MATHEMATICIAN/test to MATHEMATICIAN/train
# Moved all 3 .npz files from ARIZONA/train, ARIZONA/val, and ARIZONA/test to ARIZONA/train
# Moved all 3 .npz files from ILLNESSES/train, ILLNESSES/val, and ILLNESSES/test to ILLNESSES/train
# Moved all 3 .npz files from INSTRUCTOR/train, INSTRUCTOR/val, and INSTRUCTOR/test to INSTRUCTOR/train
# Moved all 3 .npz files from INTERNALIZED/train, INTERNALIZED/val, and INTERNALIZED/test to INTERNALIZED/train
# Moved all 3 .npz files from DISPARATE/train, DISPARATE/val, and DISPARATE/test to DISPARATE/train
# Moved all 3 .npz files from CRICKET/train, CRICKET/val, and CRICKET/test to CRICKET/train
# Moved all 3 .npz files from DEREGULATION/train, DEREGULATION/val, and DEREGULATION/test to DEREGULATION/train
# Moved all 3 .npz files from RIDDLE/train, RIDDLE/val, and RIDDLE/test to RIDDLE/train
# Moved all 3 .npz files from PAROLE/train, PAROLE/val, and PAROLE/test to PAROLE/train
# Moved all 3 .npz files from SEPARATED/train, SEPARATED/val, and SEPARATED/test to SEPARATED/train
# Moved all 3 .npz files from WHISPERING/train, WHISPERING/val, and WHISPERING/test to WHISPERING/train
# Moved all 3 .npz files from INTERRUPTING/train, INTERRUPTING/val, and INTERRUPTING/test to INTERRUPTING/train
# Moved all 3 .npz files from POLARIZED/train, POLARIZED/val, and POLARIZED/test to POLARIZED/train
# Moved all 3 .npz files from TEARING/train, TEARING/val, and TEARING/test to TEARING/train
# Moved all 3 .npz files from PROTOTYPING/train, PROTOTYPING/val, and PROTOTYPING/test to PROTOTYPING/train
# Moved all 3 .npz files from BOOTH/train, BOOTH/val, and BOOTH/test to BOOTH/train
# Moved all 3 .npz files from ULTRA/train, ULTRA/val, and ULTRA/test to ULTRA/train
# Moved all 3 .npz files from SUPPLEMENT/train, SUPPLEMENT/val, and SUPPLEMENT/test to SUPPLEMENT/train
# Moved all 3 .npz files from RAPISTS/train, RAPISTS/val, and RAPISTS/test to RAPISTS/train
# Moved all 3 .npz files from EQUATE/train, EQUATE/val, and EQUATE/test to EQUATE/train
# Moved all 3 .npz files from CONVERSATIONAL/train, CONVERSATIONAL/val, and CONVERSATIONAL/test to CONVERSATIONAL/train
# Moved all 3 .npz files from VIRTUALLY/train, VIRTUALLY/val, and VIRTUALLY/test to VIRTUALLY/train
# Moved all 3 .npz files from SEXIST/train, SEXIST/val, and SEXIST/test to SEXIST/train
# Moved all 3 .npz files from BIN/train, BIN/val, and BIN/test to BIN/train
# Moved all 3 .npz files from OBSERVING/train, OBSERVING/val, and OBSERVING/test to OBSERVING/train
# Moved all 3 .npz files from DRUNKEN/train, DRUNKEN/val, and DRUNKEN/test to DRUNKEN/train
# Moved all 3 .npz files from CALCULATED/train, CALCULATED/val, and CALCULATED/test to CALCULATED/train
# Moved all 3 .npz files from CYCLISTS/train, CYCLISTS/val, and CYCLISTS/test to CYCLISTS/train
# Moved all 3 .npz files from PREVAILING/train, PREVAILING/val, and PREVAILING/test to PREVAILING/train
# Moved all 3 .npz files from FLOATING/train, FLOATING/val, and FLOATING/test to FLOATING/train
# Moved all 3 .npz files from AUTISTIC/train, AUTISTIC/val, and AUTISTIC/test to AUTISTIC/train
# Moved all 3 .npz files from URGENCY/train, URGENCY/val, and URGENCY/test to URGENCY/train
# Moved all 3 .npz files from ARCHAEOLOGIST/train, ARCHAEOLOGIST/val, and ARCHAEOLOGIST/test to ARCHAEOLOGIST/train
# Moved all 3 .npz files from CALENDAR/train, CALENDAR/val, and CALENDAR/test to CALENDAR/train
# Moved all 3 .npz files from MARCHING/train, MARCHING/val, and MARCHING/test to MARCHING/train
# Moved all 3 .npz files from TEA/train, TEA/val, and TEA/test to TEA/train
# Moved all 3 .npz files from HOCKEY/train, HOCKEY/val, and HOCKEY/test to HOCKEY/train
# Moved all 3 .npz files from ASTRONOMICAL/train, ASTRONOMICAL/val, and ASTRONOMICAL/test to ASTRONOMICAL/train
# Moved all 3 .npz files from SHIPPED/train, SHIPPED/val, and SHIPPED/test to SHIPPED/train
# Moved all 3 .npz files from UNIFORM/train, UNIFORM/val, and UNIFORM/test to UNIFORM/train
# Moved all 3 .npz files from SWEEPING/train, SWEEPING/val, and SWEEPING/test to SWEEPING/train
# Moved all 3 .npz files from STIMULATING/train, STIMULATING/val, and STIMULATING/test to STIMULATING/train
# Moved all 3 .npz files from SPECIALIZE/train, SPECIALIZE/val, and SPECIALIZE/test to SPECIALIZE/train
# Moved all 3 .npz files from RUIN/train, RUIN/val, and RUIN/test to RUIN/train
# Moved all 3 .npz files from GINGER/train, GINGER/val, and GINGER/test to GINGER/train
# Moved all 3 .npz files from MCDOW/train, MCDOW/val, and MCDOW/test to MCDOW/train
# Moved all 3 .npz files from SCRATCHED/train, SCRATCHED/val, and SCRATCHED/test to SCRATCHED/train
# Moved all 3 .npz files from SENATOR/train, SENATOR/val, and SENATOR/test to SENATOR/train
# Moved all 3 .npz files from BRIAN/train, BRIAN/val, and BRIAN/test to BRIAN/train
# Moved all 3 .npz files from ANTHROPOLOGIST/train, ANTHROPOLOGIST/val, and ANTHROPOLOGIST/test to ANTHROPOLOGIST/train
# Moved all 3 .npz files from VISA/train, VISA/val, and VISA/test to VISA/train
# Moved all 3 .npz files from COD/train, COD/val, and COD/test to COD/train
# Moved all 3 .npz files from FOOTSTEPS/train, FOOTSTEPS/val, and FOOTSTEPS/test to FOOTSTEPS/train
# Moved all 3 .npz files from CHASED/train, CHASED/val, and CHASED/test to CHASED/train
# Moved all 3 .npz files from CONTROVERSIAL/train, CONTROVERSIAL/val, and CONTROVERSIAL/test to CONTROVERSIAL/train
# Moved all 3 .npz files from EXPONENTIAL/train, EXPONENTIAL/val, and EXPONENTIAL/test to EXPONENTIAL/train
# Moved all 3 .npz files from GROUNDED/train, GROUNDED/val, and GROUNDED/test to GROUNDED/train
# Moved all 3 .npz files from GREY/train, GREY/val, and GREY/test to GREY/train
# Moved all 3 .npz files from IMAGINATIVE/train, IMAGINATIVE/val, and IMAGINATIVE/test to IMAGINATIVE/train
# Moved all 3 .npz files from HOSPITALIZED/train, HOSPITALIZED/val, and HOSPITALIZED/test to HOSPITALIZED/train
# Moved all 3 .npz files from DAMAGING/train, DAMAGING/val, and DAMAGING/test to DAMAGING/train
# Moved all 3 .npz files from FACIAL/train, FACIAL/val, and FACIAL/test to FACIAL/train
# Moved all 3 .npz files from DREAMER/train, DREAMER/val, and DREAMER/test to DREAMER/train
# Moved all 3 .npz files from VIAGRA/train, VIAGRA/val, and VIAGRA/test to VIAGRA/train
# Moved all 3 .npz files from BARACK/train, BARACK/val, and BARACK/test to BARACK/train
# Moved all 3 .npz files from EXTREMIST/train, EXTREMIST/val, and EXTREMIST/test to EXTREMIST/train
# Moved all 3 .npz files from VISITED/train, VISITED/val, and VISITED/test to VISITED/train
# Moved all 3 .npz files from BUYER/train, BUYER/val, and BUYER/test to BUYER/train
# Moved all 3 .npz files from CONTAMINATE/train, CONTAMINATE/val, and CONTAMINATE/test to CONTAMINATE/train
# Moved all 3 .npz files from INTACT/train, INTACT/val, and INTACT/test to INTACT/train
# Moved all 3 .npz files from LANDLORD/train, LANDLORD/val, and LANDLORD/test to LANDLORD/train
# Moved all 3 .npz files from DISTINGUISHING/train, DISTINGUISHING/val, and DISTINGUISHING/test to DISTINGUISHING/train
# Moved all 3 .npz files from NAP/train, NAP/val, and NAP/test to NAP/train
# Moved all 3 .npz files from ALIKE/train, ALIKE/val, and ALIKE/test to ALIKE/train
# Moved all 3 .npz files from ALTITUDE/train, ALTITUDE/val, and ALTITUDE/test to ALTITUDE/train
# Moved all 3 .npz files from SETUP/train, SETUP/val, and SETUP/test to SETUP/train
# Moved all 3 .npz files from HUMBLE/train, HUMBLE/val, and HUMBLE/test to HUMBLE/train
# Moved all 3 .npz files from DETECTION/train, DETECTION/val, and DETECTION/test to DETECTION/train
# Moved all 3 .npz files from HERD/train, HERD/val, and HERD/test to HERD/train
# Moved all 3 .npz files from AW/train, AW/val, and AW/test to AW/train
# Moved all 3 .npz files from FORD/train, FORD/val, and FORD/test to FORD/train
# Moved all 3 .npz files from EVE/train, EVE/val, and EVE/test to EVE/train
# Moved all 3 .npz files from PREDICTING/train, PREDICTING/val, and PREDICTING/test to PREDICTING/train
# Moved all 3 .npz files from VACUUMING/train, VACUUMING/val, and VACUUMING/test to VACUUMING/train
# Moved all 3 .npz files from FEASIBLE/train, FEASIBLE/val, and FEASIBLE/test to FEASIBLE/train
# Moved all 3 .npz files from ISRAELI/train, ISRAELI/val, and ISRAELI/test to ISRAELI/train
# Moved all 3 .npz files from COMMANDER/train, COMMANDER/val, and COMMANDER/test to COMMANDER/train
# Moved all 3 .npz files from DIMENSIONAL/train, DIMENSIONAL/val, and DIMENSIONAL/test to DIMENSIONAL/train
# Moved all 3 .npz files from LEATHER/train, LEATHER/val, and LEATHER/test to LEATHER/train
# Moved all 3 .npz files from RECYCLING/train, RECYCLING/val, and RECYCLING/test to RECYCLING/train
# Moved all 3 .npz files from STRAW/train, STRAW/val, and STRAW/test to STRAW/train
# Moved all 3 .npz files from MARIA/train, MARIA/val, and MARIA/test to MARIA/train
# Moved all 3 .npz files from AVATAR/train, AVATAR/val, and AVATAR/test to AVATAR/train
# Moved all 3 .npz files from BOMBSIGHT/train, BOMBSIGHT/val, and BOMBSIGHT/test to BOMBSIGHT/train
# Moved all 3 .npz files from MASTERED/train, MASTERED/val, and MASTERED/test to MASTERED/train
# Moved all 3 .npz files from EROTIC/train, EROTIC/val, and EROTIC/test to EROTIC/train
# Moved all 3 .npz files from PARALYZED/train, PARALYZED/val, and PARALYZED/test to PARALYZED/train
# Moved all 3 .npz files from DORM/train, DORM/val, and DORM/test to DORM/train
# Moved all 3 .npz files from BASIN/train, BASIN/val, and BASIN/test to BASIN/train
# Moved all 3 .npz files from BROADWAY/train, BROADWAY/val, and BROADWAY/test to BROADWAY/train
# Moved all 3 .npz files from GROSS/train, GROSS/val, and GROSS/test to GROSS/train
# Moved all 3 .npz files from ALEX/train, ALEX/val, and ALEX/test to ALEX/train
# Moved all 3 .npz files from BEGGING/train, BEGGING/val, and BEGGING/test to BEGGING/train
# Moved all 3 .npz files from PAKISTANI/train, PAKISTANI/val, and PAKISTANI/test to PAKISTANI/train
# Moved all 3 .npz files from THINKERS/train, THINKERS/val, and THINKERS/test to THINKERS/train
# Moved all 3 .npz files from ESCAPING/train, ESCAPING/val, and ESCAPING/test to ESCAPING/train
# Moved all 3 .npz files from UNCOMMON/train, UNCOMMON/val, and UNCOMMON/test to UNCOMMON/train
# Moved all 3 .npz files from CROWDSOURCING/train, CROWDSOURCING/val, and CROWDSOURCING/test to CROWDSOURCING/train
# Moved all 3 .npz files from KINDERGARTEN/train, KINDERGARTEN/val, and KINDERGARTEN/test to KINDERGARTEN/train
# Moved all 3 .npz files from DIAPER/train, DIAPER/val, and DIAPER/test to DIAPER/train
# Moved all 3 .npz files from HATCHED/train, HATCHED/val, and HATCHED/test to HATCHED/train
# Moved all 3 .npz files from BULGARIAN/train, BULGARIAN/val, and BULGARIAN/test to BULGARIAN/train
# Moved all 3 .npz files from ATYPICAL/train, ATYPICAL/val, and ATYPICAL/test to ATYPICAL/train
# Moved all 3 .npz files from CHARLIE/train, CHARLIE/val, and CHARLIE/test to CHARLIE/train
# Moved all 3 .npz files from ATTRIBUTE/train, ATTRIBUTE/val, and ATTRIBUTE/test to ATTRIBUTE/train
# Moved all 3 .npz files from EMBEDDED/train, EMBEDDED/val, and EMBEDDED/test to EMBEDDED/train
# Moved all 3 .npz files from DIVERGENT/train, DIVERGENT/val, and DIVERGENT/test to DIVERGENT/train
# Moved all 3 .npz files from SLEPT/train, SLEPT/val, and SLEPT/test to SLEPT/train
# Moved all 3 .npz files from CANAL/train, CANAL/val, and CANAL/test to CANAL/train
# Moved all 3 .npz files from IMPRESSED/train, IMPRESSED/val, and IMPRESSED/test to IMPRESSED/train
# Moved all 3 .npz files from LISTENED/train, LISTENED/val, and LISTENED/test to LISTENED/train
# Moved all 3 .npz files from BRIEF/train, BRIEF/val, and BRIEF/test to BRIEF/train
# Moved all 3 .npz files from MESSING/train, MESSING/val, and MESSING/test to MESSING/train
# Moved all 3 .npz files from ARCHITECTURAL/train, ARCHITECTURAL/val, and ARCHITECTURAL/test to ARCHITECTURAL/train
# Moved all 3 .npz files from BOUNCED/train, BOUNCED/val, and BOUNCED/test to BOUNCED/train
# Moved all 3 .npz files from FAKING/train, FAKING/val, and FAKING/test to FAKING/train
# Moved all 3 .npz files from HOMOPHOBIC/train, HOMOPHOBIC/val, and HOMOPHOBIC/test to HOMOPHOBIC/train
# Moved all 3 .npz files from CONSISTS/train, CONSISTS/val, and CONSISTS/test to CONSISTS/train
# Moved all 3 .npz files from VENEZUELA/train, VENEZUELA/val, and VENEZUELA/test to VENEZUELA/train
# Moved all 3 .npz files from FASHIONED/train, FASHIONED/val, and FASHIONED/test to FASHIONED/train
# Moved all 3 .npz files from RORY/train, RORY/val, and RORY/test to RORY/train
# Moved all 3 .npz files from COMPLIANCE/train, COMPLIANCE/val, and COMPLIANCE/test to COMPLIANCE/train
# Moved all 3 .npz files from HALLWAYS/train, HALLWAYS/val, and HALLWAYS/test to HALLWAYS/train
# Moved all 3 .npz files from BRANCHES/train, BRANCHES/val, and BRANCHES/test to BRANCHES/train
# Moved all 3 .npz files from BEND/train, BEND/val, and BEND/test to BEND/train
# Moved all 3 .npz files from EARLIEST/train, EARLIEST/val, and EARLIEST/test to EARLIEST/train
# Moved all 3 .npz files from CA/train, CA/val, and CA/test to CA/train
# Moved all 3 .npz files from ATTACHED/train, ATTACHED/val, and ATTACHED/test to ATTACHED/train
# Moved all 3 .npz files from COACHES/train, COACHES/val, and COACHES/test to COACHES/train
# Moved all 3 .npz files from GPA/train, GPA/val, and GPA/test to GPA/train
# Moved all 3 .npz files from THURSDAY/train, THURSDAY/val, and THURSDAY/test to THURSDAY/train
# Moved all 3 .npz files from IMAGINED/train, IMAGINED/val, and IMAGINED/test to IMAGINED/train
# Moved all 3 .npz files from SUPREMELY/train, SUPREMELY/val, and SUPREMELY/test to SUPREMELY/train
# Moved all 3 .npz files from REFUEL/train, REFUEL/val, and REFUEL/test to REFUEL/train
# Moved all 3 .npz files from BOUNDARY/train, BOUNDARY/val, and BOUNDARY/test to BOUNDARY/train
# Moved all 3 .npz files from COHERENT/train, COHERENT/val, and COHERENT/test to COHERENT/train
# Moved all 3 .npz files from CONSULTING/train, CONSULTING/val, and CONSULTING/test to CONSULTING/train
# Moved all 3 .npz files from SEDUCTIVE/train, SEDUCTIVE/val, and SEDUCTIVE/test to SEDUCTIVE/train
# Moved all 3 .npz files from HUGGED/train, HUGGED/val, and HUGGED/test to HUGGED/train
# Moved all 3 .npz files from METAPHORICALLY/train, METAPHORICALLY/val, and METAPHORICALLY/test to METAPHORICALLY/train
# Moved all 3 .npz files from BACKUP/train, BACKUP/val, and BACKUP/test to BACKUP/train
# Moved all 3 .npz files from UNPRECEDENTED/train, UNPRECEDENTED/val, and UNPRECEDENTED/test to UNPRECEDENTED/train
# Moved all 3 .npz files from MANNER/train, MANNER/val, and MANNER/test to MANNER/train
# Moved all 3 .npz files from SANK/train, SANK/val, and SANK/test to SANK/train
# Moved all 3 .npz files from FAME/train, FAME/val, and FAME/test to FAME/train
# Moved all 3 .npz files from ROSETTA/train, ROSETTA/val, and ROSETTA/test to ROSETTA/train
# Moved all 3 .npz files from JASPER/train, JASPER/val, and JASPER/test to JASPER/train
# Moved all 3 .npz files from DECLARED/train, DECLARED/val, and DECLARED/test to DECLARED/train
# Moved all 3 .npz files from CANADIAN/train, CANADIAN/val, and CANADIAN/test to CANADIAN/train
# Moved all 3 .npz files from CONFINED/train, CONFINED/val, and CONFINED/test to CONFINED/train
# Moved all 3 .npz files from MARGARET/train, MARGARET/val, and MARGARET/test to MARGARET/train
# Moved all 3 .npz files from SKIING/train, SKIING/val, and SKIING/test to SKIING/train
# Moved all 3 .npz files from INDIGENOUS/train, INDIGENOUS/val, and INDIGENOUS/test to INDIGENOUS/train
# Moved all 3 .npz files from CONVENIENCE/train, CONVENIENCE/val, and CONVENIENCE/test to CONVENIENCE/train
# Moved all 3 .npz files from BOOGIE/train, BOOGIE/val, and BOOGIE/test to BOOGIE/train
# Moved all 3 .npz files from LAWN/train, LAWN/val, and LAWN/test to LAWN/train
# Moved all 3 .npz files from SPINE/train, SPINE/val, and SPINE/test to SPINE/train
# Moved all 3 .npz files from MEERKAT/train, MEERKAT/val, and MEERKAT/test to MEERKAT/train
# Moved all 3 .npz files from CONVERT/train, CONVERT/val, and CONVERT/test to CONVERT/train
# Moved all 3 .npz files from RESISTED/train, RESISTED/val, and RESISTED/test to RESISTED/train
# Moved all 3 .npz files from REPRESENTATIVE/train, REPRESENTATIVE/val, and REPRESENTATIVE/test to REPRESENTATIVE/train
# Moved all 3 .npz files from DIAGRAM/train, DIAGRAM/val, and DIAGRAM/test to DIAGRAM/train
# Moved all 3 .npz files from FOUNDING/train, FOUNDING/val, and FOUNDING/test to FOUNDING/train
# Moved all 3 .npz files from SCANNING/train, SCANNING/val, and SCANNING/test to SCANNING/train
# Moved all 3 .npz files from MAT/train, MAT/val, and MAT/test to MAT/train
# Moved all 3 .npz files from DOORWAY/train, DOORWAY/val, and DOORWAY/test to DOORWAY/train
# Moved all 3 .npz files from DEFAULT/train, DEFAULT/val, and DEFAULT/test to DEFAULT/train
# Moved all 3 .npz files from AMATEUR/train, AMATEUR/val, and AMATEUR/test to AMATEUR/train
# Moved all 3 .npz files from GRANDIN/train, GRANDIN/val, and GRANDIN/test to GRANDIN/train
# Moved all 3 .npz files from BEEF/train, BEEF/val, and BEEF/test to BEEF/train
# Moved all 3 .npz files from RESORT/train, RESORT/val, and RESORT/test to RESORT/train
# Moved all 3 .npz files from PUBLICLY/train, PUBLICLY/val, and PUBLICLY/test to PUBLICLY/train
# Moved all 3 .npz files from RELEASING/train, RELEASING/val, and RELEASING/test to RELEASING/train
# Moved all 3 .npz files from AGRICULTURAL/train, AGRICULTURAL/val, and AGRICULTURAL/test to AGRICULTURAL/train
# Moved all 3 .npz files from CAYMAN/train, CAYMAN/val, and CAYMAN/test to CAYMAN/train
# Moved all 3 .npz files from BRANCH/train, BRANCH/val, and BRANCH/test to BRANCH/train
# Moved all 3 .npz files from SARS/train, SARS/val, and SARS/test to SARS/train
# Moved all 3 .npz files from EFFICIENCY/train, EFFICIENCY/val, and EFFICIENCY/test to EFFICIENCY/train
# Moved all 3 .npz files from HUT/train, HUT/val, and HUT/test to HUT/train
# Moved all 3 .npz files from EXTRAORDINARILY/train, EXTRAORDINARILY/val, and EXTRAORDINARILY/test to EXTRAORDINARILY/train
# Moved all 3 .npz files from NEUTRON/train, NEUTRON/val, and NEUTRON/test to NEUTRON/train
# Moved all 3 .npz files from COP/train, COP/val, and COP/test to COP/train
# Moved all 3 .npz files from JULIA/train, JULIA/val, and JULIA/test to JULIA/train
# Moved all 3 .npz files from PACIFIC/train, PACIFIC/val, and PACIFIC/test to PACIFIC/train
# Moved all 3 .npz files from CONTEMPORARY/train, CONTEMPORARY/val, and CONTEMPORARY/test to CONTEMPORARY/train
# Moved all 3 .npz files from AWAIT/train, AWAIT/val, and AWAIT/test to AWAIT/train
# Moved all 3 .npz files from SUPERMAN/train, SUPERMAN/val, and SUPERMAN/test to SUPERMAN/train
# Moved all 3 .npz files from FAMED/train, FAMED/val, and FAMED/test to FAMED/train
# Moved all 3 .npz files from PLEASED/train, PLEASED/val, and PLEASED/test to PLEASED/train
# Moved all 3 .npz files from THERAPEUTIC/train, THERAPEUTIC/val, and THERAPEUTIC/test to THERAPEUTIC/train
# Moved all 3 .npz files from RILEY/train, RILEY/val, and RILEY/test to RILEY/train
# Moved all 3 .npz files from GREETING/train, GREETING/val, and GREETING/test to GREETING/train
# Moved all 3 .npz files from EXECUTE/train, EXECUTE/val, and EXECUTE/test to EXECUTE/train
# Moved all 3 .npz files from WONDERFULLY/train, WONDERFULLY/val, and WONDERFULLY/test to WONDERFULLY/train
# Moved all 3 .npz files from ALARMED/train, ALARMED/val, and ALARMED/test to ALARMED/train
# Moved all 3 .npz files from WIDELY/train, WIDELY/val, and WIDELY/test to WIDELY/train
# Moved all 3 .npz files from POSTCARD/train, POSTCARD/val, and POSTCARD/test to POSTCARD/train
# Moved all 3 .npz files from ELEGANT/train, ELEGANT/val, and ELEGANT/test to ELEGANT/train
# Moved all 3 .npz files from OBLIGATION/train, OBLIGATION/val, and OBLIGATION/test to OBLIGATION/train
# Moved all 3 .npz files from PORTRAY/train, PORTRAY/val, and PORTRAY/test to PORTRAY/train
# Moved all 3 .npz files from HARMONY/train, HARMONY/val, and HARMONY/test to HARMONY/train
# Moved all 3 .npz files from MICROALGAE/train, MICROALGAE/val, and MICROALGAE/test to MICROALGAE/train
# Moved all 3 .npz files from PROGRAMMER/train, PROGRAMMER/val, and PROGRAMMER/test to PROGRAMMER/train
# Moved all 3 .npz files from MINNEAPOLIS/train, MINNEAPOLIS/val, and MINNEAPOLIS/test to MINNEAPOLIS/train
# Moved all 3 .npz files from RESIDENTIAL/train, RESIDENTIAL/val, and RESIDENTIAL/test to RESIDENTIAL/train
# Moved all 3 .npz files from DOLPHIN/train, DOLPHIN/val, and DOLPHIN/test to DOLPHIN/train
# Moved all 3 .npz files from SOMALI/train, SOMALI/val, and SOMALI/test to SOMALI/train
# Moved all 3 .npz files from COOLER/train, COOLER/val, and COOLER/test to COOLER/train
# Moved all 3 .npz files from STRIVE/train, STRIVE/val, and STRIVE/test to STRIVE/train
# Moved all 3 .npz files from X27/train, X27/val, and X27/test to X27/train
# Moved all 3 .npz files from COLOUR/train, COLOUR/val, and COLOUR/test to COLOUR/train
# Moved all 3 .npz files from CHURCHES/train, CHURCHES/val, and CHURCHES/test to CHURCHES/train
# Moved all 3 .npz files from IMPACTED/train, IMPACTED/val, and IMPACTED/test to IMPACTED/train
# Moved all 3 .npz files from CLOSING/train, CLOSING/val, and CLOSING/test to CLOSING/train
# Moved all 3 .npz files from CONFIRMATION/train, CONFIRMATION/val, and CONFIRMATION/test to CONFIRMATION/train
# Moved all 3 .npz files from UNDERSTANDABLE/train, UNDERSTANDABLE/val, and UNDERSTANDABLE/test to UNDERSTANDABLE/train
# Moved all 3 .npz files from VANISHED/train, VANISHED/val, and VANISHED/test to VANISHED/train
# Moved all 3 .npz files from BEFRIEND/train, BEFRIEND/val, and BEFRIEND/test to BEFRIEND/train
# Moved all 3 .npz files from CARLO/train, CARLO/val, and CARLO/test to CARLO/train
# Moved all 3 .npz files from CONTRIBUTED/train, CONTRIBUTED/val, and CONTRIBUTED/test to CONTRIBUTED/train
# Moved all 3 .npz files from RESERVE/train, RESERVE/val, and RESERVE/test to RESERVE/train
# Moved all 3 .npz files from CORRIDOR/train, CORRIDOR/val, and CORRIDOR/test to CORRIDOR/train
# Moved all 3 .npz files from LIBYA/train, LIBYA/val, and LIBYA/test to LIBYA/train
# Moved all 3 .npz files from HACKING/train, HACKING/val, and HACKING/test to HACKING/train
# Moved all 3 .npz files from RECEPTION/train, RECEPTION/val, and RECEPTION/test to RECEPTION/train
# Moved all 3 .npz files from DECEMBER/train, DECEMBER/val, and DECEMBER/test to DECEMBER/train
# Moved all 3 .npz files from MADAGASCAR/train, MADAGASCAR/val, and MADAGASCAR/test to MADAGASCAR/train
# Moved all 3 .npz files from EURO/train, EURO/val, and EURO/test to EURO/train
# Moved all 3 .npz files from PROMISING/train, PROMISING/val, and PROMISING/test to PROMISING/train
# Moved all 3 .npz files from GEORGIA/train, GEORGIA/val, and GEORGIA/test to GEORGIA/train
# Moved all 3 .npz files from BITCH/train, BITCH/val, and BITCH/test to BITCH/train
# Moved all 3 .npz files from NOTED/train, NOTED/val, and NOTED/test to NOTED/train
# Moved all 3 .npz files from FLAWED/train, FLAWED/val, and FLAWED/test to FLAWED/train
# Moved all 3 .npz files from DISMAY/train, DISMAY/val, and DISMAY/test to DISMAY/train
# Moved all 3 .npz files from ISSUED/train, ISSUED/val, and ISSUED/test to ISSUED/train
# Moved all 3 .npz files from MIXTURE/train, MIXTURE/val, and MIXTURE/test to MIXTURE/train
# Moved all 3 .npz files from GRAPPLE/train, GRAPPLE/val, and GRAPPLE/test to GRAPPLE/train
# Moved all 3 .npz files from REPEATEDLY/train, REPEATEDLY/val, and REPEATEDLY/test to REPEATEDLY/train
# Moved all 3 .npz files from WALKER/train, WALKER/val, and WALKER/test to WALKER/train
# Moved all 3 .npz files from DENMARK/train, DENMARK/val, and DENMARK/test to DENMARK/train
# Moved all 3 .npz files from LENDING/train, LENDING/val, and LENDING/test to LENDING/train
# Moved all 3 .npz files from RESTART/train, RESTART/val, and RESTART/test to RESTART/train
# Moved all 3 .npz files from BIOTECHNOLOGY/train, BIOTECHNOLOGY/val, and BIOTECHNOLOGY/test to BIOTECHNOLOGY/train
# Moved all 3 .npz files from SUBSTANTIAL/train, SUBSTANTIAL/val, and SUBSTANTIAL/test to SUBSTANTIAL/train
# Moved all 3 .npz files from BERKELEY/train, BERKELEY/val, and BERKELEY/test to BERKELEY/train
# Moved all 3 .npz files from PAVE/train, PAVE/val, and PAVE/test to PAVE/train
# Moved all 3 .npz files from CHEAPEST/train, CHEAPEST/val, and CHEAPEST/test to CHEAPEST/train
# Moved all 3 .npz files from QUANTITATIVE/train, QUANTITATIVE/val, and QUANTITATIVE/test to QUANTITATIVE/train
# Moved all 3 .npz files from WIVES/train, WIVES/val, and WIVES/test to WIVES/train
# Moved all 3 .npz files from BOUNCE/train, BOUNCE/val, and BOUNCE/test to BOUNCE/train
# Moved all 3 .npz files from GUIDED/train, GUIDED/val, and GUIDED/test to GUIDED/train
# Moved all 3 .npz files from JUDGED/train, JUDGED/val, and JUDGED/test to JUDGED/train
# Moved all 3 .npz files from COMPLEMENT/train, COMPLEMENT/val, and COMPLEMENT/test to COMPLEMENT/train
# Moved all 3 .npz files from PUPIL/train, PUPIL/val, and PUPIL/test to PUPIL/train
# Moved all 3 .npz files from VISITORS/train, VISITORS/val, and VISITORS/test to VISITORS/train
# Moved all 3 .npz files from NFL/train, NFL/val, and NFL/test to NFL/train
# Moved all 3 .npz files from SHRUNK/train, SHRUNK/val, and SHRUNK/test to SHRUNK/train
# Moved all 3 .npz files from WASHER/train, WASHER/val, and WASHER/test to WASHER/train
# Moved all 3 .npz files from DRAMATIC/train, DRAMATIC/val, and DRAMATIC/test to DRAMATIC/train
# Moved all 3 .npz files from ORCHARD/train, ORCHARD/val, and ORCHARD/test to ORCHARD/train
# Moved all 3 .npz files from JUSTIFIED/train, JUSTIFIED/val, and JUSTIFIED/test to JUSTIFIED/train
# Moved all 3 .npz files from MAX/train, MAX/val, and MAX/test to MAX/train
# Moved all 3 .npz files from GUARANTEED/train, GUARANTEED/val, and GUARANTEED/test to GUARANTEED/train
# Moved all 3 .npz files from BURDENED/train, BURDENED/val, and BURDENED/test to BURDENED/train
# Moved all 3 .npz files from BABY'S/train, BABY'S/val, and BABY'S/test to BABY'S/train
# Moved all 3 .npz files from STUNNED/train, STUNNED/val, and STUNNED/test to STUNNED/train
# Moved all 3 .npz files from BREAKDOWN/train, BREAKDOWN/val, and BREAKDOWN/test to BREAKDOWN/train
# Moved all 3 .npz files from DURBAN/train, DURBAN/val, and DURBAN/test to DURBAN/train
# Moved all 3 .npz files from ARRAY/train, ARRAY/val, and ARRAY/test to ARRAY/train
# Moved all 3 .npz files from COMPUTATION/train, COMPUTATION/val, and COMPUTATION/test to COMPUTATION/train
# Moved all 3 .npz files from REFINED/train, REFINED/val, and REFINED/test to REFINED/train
# Moved all 3 .npz files from HARMFUL/train, HARMFUL/val, and HARMFUL/test to HARMFUL/train
# Moved all 3 .npz files from LEMUR/train, LEMUR/val, and LEMUR/test to LEMUR/train
# Moved all 3 .npz files from DEATHBED/train, DEATHBED/val, and DEATHBED/test to DEATHBED/train
# Moved all 3 .npz files from HEALING/train, HEALING/val, and HEALING/test to HEALING/train
# Moved all 3 .npz files from DUPLICATE/train, DUPLICATE/val, and DUPLICATE/test to DUPLICATE/train
# Moved all 3 .npz files from REGARDED/train, REGARDED/val, and REGARDED/test to REGARDED/train
# Moved all 3 .npz files from THREATENED/train, THREATENED/val, and THREATENED/test to THREATENED/train
# Moved all 3 .npz files from AIRPORT/train, AIRPORT/val, and AIRPORT/test to AIRPORT/train
# Moved all 3 .npz files from WASHING/train, WASHING/val, and WASHING/test to WASHING/train
# Moved all 3 .npz files from POMPEII/train, POMPEII/val, and POMPEII/test to POMPEII/train
# Moved all 3 .npz files from JESUS/train, JESUS/val, and JESUS/test to JESUS/train
# Moved all 3 .npz files from RUSSELL/train, RUSSELL/val, and RUSSELL/test to RUSSELL/train
# Moved all 3 .npz files from PROPORTION/train, PROPORTION/val, and PROPORTION/test to PROPORTION/train
# Moved all 3 .npz files from KEN/train, KEN/val, and KEN/test to KEN/train
# Moved all 3 .npz files from APPROXIMATE/train, APPROXIMATE/val, and APPROXIMATE/test to APPROXIMATE/train
# Moved all 3 .npz files from CATTLE/train, CATTLE/val, and CATTLE/test to CATTLE/train
# Moved all 3 .npz files from SPORES/train, SPORES/val, and SPORES/test to SPORES/train
# Moved all 3 .npz files from RIDER/train, RIDER/val, and RIDER/test to RIDER/train
# Moved all 3 .npz files from BIASED/train, BIASED/val, and BIASED/test to BIASED/train
# Moved all 3 .npz files from TRANSPLANT/train, TRANSPLANT/val, and TRANSPLANT/test to TRANSPLANT/train
# Moved all 3 .npz files from JEWS/train, JEWS/val, and JEWS/test to JEWS/train
# Moved all 3 .npz files from VISCERAL/train, VISCERAL/val, and VISCERAL/test to VISCERAL/train
# Moved all 3 .npz files from SWAM/train, SWAM/val, and SWAM/test to SWAM/train
# ...
# Moved all 3 .npz files from RIPPED/train, RIPPED/val, and RIPPED/test to RIPPED/train
# Moved all 3 .npz files from ADVOCATING/train, ADVOCATING/val, and ADVOCATING/test to ADVOCATING/train
# Moved all 3 .npz files from IMPROVISATION/train, IMPROVISATION/val, and IMPROVISATION/test to IMPROVISATION/train
# Moved all 3 .npz files from SIMPLER/train, SIMPLER/val, and SIMPLER/test to SIMPLER/train
# Moved all 3 .npz files from INCONSISTENT/train, INCONSISTENT/val, and INCONSISTENT/test to INCONSISTENT/train
# Moved all 3 .npz files from CEMETERY/train, CEMETERY/val, and CEMETERY/test to CEMETERY/train
# Moved all 3 .npz files from PENETRATION/train, PENETRATION/val, and PENETRATION/test to PENETRATION/train
# Moved all 3 .npz files from O'MALLEY/train, O'MALLEY/val, and O'MALLEY/test to O'MALLEY/train
# Moved all 3 .npz files from WOULD'VE/train, WOULD'VE/val, and WOULD'VE/test to WOULD'VE/train
# Moved all 3 .npz files from WENDY/train, WENDY/val, and WENDY/test to WENDY/train
# Moved all 3 .npz files from CHEER/train, CHEER/val, and CHEER/test to CHEER/train
# Moved all 3 .npz files from GLOW/train, GLOW/val, and GLOW/test to GLOW/train
# Moved all 3 .npz files from MANDATORY/train, MANDATORY/val, and MANDATORY/test to MANDATORY/train
# Moved all 3 .npz files from UNDERDOG/train, UNDERDOG/val, and UNDERDOG/test to UNDERDOG/train
# Moved all 3 .npz files from STEVENSON/train, STEVENSON/val, and STEVENSON/test to STEVENSON/train
# Moved all 3 .npz files from BUCKET/train, BUCKET/val, and BUCKET/test to BUCKET/train
# Moved all 3 .npz files from INFORM/train, INFORM/val, and INFORM/test to INFORM/train
# Moved all 3 .npz files from DARPA/train, DARPA/val, and DARPA/test to DARPA/train
# Moved all 3 .npz files from UNSTABLE/train, UNSTABLE/val, and UNSTABLE/test to UNSTABLE/train
# Moved all 3 .npz files from COMMISSION/train, COMMISSION/val, and COMMISSION/test to COMMISSION/train
# Moved all 3 .npz files from WHORE/train, WHORE/val, and WHORE/test to WHORE/train
# Moved all 3 .npz files from TRICKY/train, TRICKY/val, and TRICKY/test to TRICKY/train
# Moved CONTACTED_IS4IK8CiLg8_00002.mp4 from CONTACTED/test to CONTACTED/train
# Moved all 3 .npz files from CONTACTED/train, CONTACTED/val, and CONTACTED/test to CONTACTED/train
# Moved all 3 .npz files from PROACTIVE/train, PROACTIVE/val, and PROACTIVE/test to PROACTIVE/train
# Moved all 3 .npz files from HANDED/train, HANDED/val, and HANDED/test to HANDED/train
# Moved all 3 .npz files from THYROID/train, THYROID/val, and THYROID/test to THYROID/train
# Moved all 3 .npz files from WORM/train, WORM/val, and WORM/test to WORM/train
# Moved all 3 .npz files from SENSITIVITY/train, SENSITIVITY/val, and SENSITIVITY/test to SENSITIVITY/train
# Moved all 3 .npz files from RESIGNED/train, RESIGNED/val, and RESIGNED/test to RESIGNED/train
# Moved all 3 .npz files from VETERINARIAN/train, VETERINARIAN/val, and VETERINARIAN/test to VETERINARIAN/train
# Moved all 3 .npz files from CHILDBIRTH/train, CHILDBIRTH/val, and CHILDBIRTH/test to CHILDBIRTH/train
# Moved all 3 .npz files from GRAPHENE/train, GRAPHENE/val, and GRAPHENE/test to GRAPHENE/train
# Moved all 3 .npz files from FINANCIALLY/train, FINANCIALLY/val, and FINANCIALLY/test to FINANCIALLY/train
# Moved all 3 .npz files from SIGNING/train, SIGNING/val, and SIGNING/test to SIGNING/train
# Moved all 3 .npz files from BADGE/train, BADGE/val, and BADGE/test to BADGE/train
# Moved all 3 .npz files from FLOAT/train, FLOAT/val, and FLOAT/test to FLOAT/train
# Moved all 3 .npz files from POMPOUS/train, POMPOUS/val, and POMPOUS/test to POMPOUS/train
# Moved all 3 .npz files from MICROPHONE/train, MICROPHONE/val, and MICROPHONE/test to MICROPHONE/train
# Moved all 3 .npz files from WRESTLING/train, WRESTLING/val, and WRESTLING/test to WRESTLING/train
# Moved all 3 .npz files from COOLIDGE/train, COOLIDGE/val, and COOLIDGE/test to COOLIDGE/train
# Moved all 3 .npz files from SWISS/train, SWISS/val, and SWISS/test to SWISS/train
# Moved all 3 .npz files from OVERCOMING/train, OVERCOMING/val, and OVERCOMING/test to OVERCOMING/train
# Moved all 3 .npz files from SOFTLY/train, SOFTLY/val, and SOFTLY/test to SOFTLY/train
# Moved all 3 .npz files from VENUS/train, VENUS/val, and VENUS/test to VENUS/train
# Moved all 3 .npz files from SACRED/train, SACRED/val, and SACRED/test to SACRED/train
# Moved all 3 .npz files from COLOMBIA/train, COLOMBIA/val, and COLOMBIA/test to COLOMBIA/train
# Moved all 3 .npz files from SENATE/train, SENATE/val, and SENATE/test to SENATE/train
# Moved all 3 .npz files from TVS/train, TVS/val, and TVS/test to TVS/train
# Moved all 3 .npz files from TIGER/train, TIGER/val, and TIGER/test to TIGER/train
# Moved all 3 .npz files from CRAVE/train, CRAVE/val, and CRAVE/test to CRAVE/train
# Moved all 3 .npz files from BRO/train, BRO/val, and BRO/test to BRO/train
# Moved POLLINATION_hiIcwt88o94_00023.mp4 from POLLINATION/test to POLLINATION/train
# Moved all 3 .npz files from POLLINATION/train, POLLINATION/val, and POLLINATION/test to POLLINATION/train
# Moved all 3 .npz files from AIRLINE/train, AIRLINE/val, and AIRLINE/test to AIRLINE/train
# Moved all 3 .npz files from BENEATH/train, BENEATH/val, and BENEATH/test to BENEATH/train
# Moved all 3 .npz files from QUITTING/train, QUITTING/val, and QUITTING/test to QUITTING/train
# Moved all 3 .npz files from SHATTERED/train, SHATTERED/val, and SHATTERED/test to SHATTERED/train
# Moved all 3 .npz files from ARISTOTLE/train, ARISTOTLE/val, and ARISTOTLE/test to ARISTOTLE/train
# Moved all 3 .npz files from GATHERER/train, GATHERER/val, and GATHERER/test to GATHERER/train
# Moved all 3 .npz files from STARVE/train, STARVE/val, and STARVE/test to STARVE/train
# Moved all 3 .npz files from ISLAMIC/train, ISLAMIC/val, and ISLAMIC/test to ISLAMIC/train
# Moved all 3 .npz files from SHORTAGE/train, SHORTAGE/val, and SHORTAGE/test to SHORTAGE/train
# Moved all 3 .npz files from FRAGILE/train, FRAGILE/val, and FRAGILE/test to FRAGILE/train
# Moved all 3 .npz files from OFFENDED/train, OFFENDED/val, and OFFENDED/test to OFFENDED/train
# Moved all 3 .npz files from ENCOURAGEMENT/train, ENCOURAGEMENT/val, and ENCOURAGEMENT/test to ENCOURAGEMENT/train
# Moved all 3 .npz files from BUFFER/train, BUFFER/val, and BUFFER/test to BUFFER/train
# Moved all 3 .npz files from METRO/train, METRO/val, and METRO/test to METRO/train
# Moved all 3 .npz files from HANNAH/train, HANNAH/val, and HANNAH/test to HANNAH/train
# Moved all 3 .npz files from RHETORIC/train, RHETORIC/val, and RHETORIC/test to RHETORIC/train
# Moved all 3 .npz files from CRITICIZED/train, CRITICIZED/val, and CRITICIZED/test to CRITICIZED/train
# Moved HOP_mjDjbJJlqZ0_00001.mp4 from HOP/test to HOP/train
# Moved all 3 .npz files from HOP/train, HOP/val, and HOP/test to HOP/train
# Moved all 3 .npz files from REPEATING/train, REPEATING/val, and REPEATING/test to REPEATING/train
# Moved all 3 .npz files from CLEOPATRA/train, CLEOPATRA/val, and CLEOPATRA/test to CLEOPATRA/train
# Moved all 3 .npz files from UNCANNY/train, UNCANNY/val, and UNCANNY/test to UNCANNY/train
# Moved all 3 .npz files from TAG/train, TAG/val, and TAG/test to TAG/train
# Moved all 3 .npz files from SILVER/train, SILVER/val, and SILVER/test to SILVER/train
# Moved all 3 .npz files from COCAINE/train, COCAINE/val, and COCAINE/test to COCAINE/train
# Moved all 3 .npz files from INDIRECT/train, INDIRECT/val, and INDIRECT/test to INDIRECT/train
# Moved all 3 .npz files from GENEROSITY/train, GENEROSITY/val, and GENEROSITY/test to GENEROSITY/train
# Moved all 3 .npz files from ELIMINATING/train, ELIMINATING/val, and ELIMINATING/test to ELIMINATING/train
# Moved SWEAT_Mt0PiXLvYlU_00003.mp4 from SWEAT/test to SWEAT/train
# Moved all 3 .npz files from SWEAT/train, SWEAT/val, and SWEAT/test to SWEAT/train
# Moved all 3 .npz files from ORAL/train, ORAL/val, and ORAL/test to ORAL/train
# Moved all 3 .npz files from MORALLY/train, MORALLY/val, and MORALLY/test to MORALLY/train
# Moved all 3 .npz files from RUSHING/train, RUSHING/val, and RUSHING/test to RUSHING/train
# Moved all 3 .npz files from JENNIFER/train, JENNIFER/val, and JENNIFER/test to JENNIFER/train
# Moved GLOVE_V1yW5IsnSjo_00005.mp4 from GLOVE/test to GLOVE/train
# Moved all 3 .npz files from GLOVE/train, GLOVE/val, and GLOVE/test to GLOVE/train
# Moved all 3 .npz files from EXTINGUISHER/train, EXTINGUISHER/val, and EXTINGUISHER/test to EXTINGUISHER/train
# Moved all 3 .npz files from ANONYMOUS/train, ANONYMOUS/val, and ANONYMOUS/test to ANONYMOUS/train
# Moved all 3 .npz files from INVOLVING/train, INVOLVING/val, and INVOLVING/test to INVOLVING/train
# Moved GREATLY_ZJNESMhIxQ0_00016.mp4 from GREATLY/test to GREATLY/train
# Moved all 3 .npz files from GREATLY/train, GREATLY/val, and GREATLY/test to GREATLY/train
# Moved all 3 .npz files from FORREST/train, FORREST/val, and FORREST/test to FORREST/train
# Moved all 3 .npz files from SOCK/train, SOCK/val, and SOCK/test to SOCK/train
# Moved all 3 .npz files from HAUL/train, HAUL/val, and HAUL/test to HAUL/train
# Moved all 3 .npz files from INTENTIONALLY/train, INTENTIONALLY/val, and INTENTIONALLY/test to INTENTIONALLY/train
# Moved all 3 .npz files from INTERPRETATION/train, INTERPRETATION/val, and INTERPRETATION/test to INTERPRETATION/train
# Moved all 3 .npz files from HOSTAGE/train, HOSTAGE/val, and HOSTAGE/test to HOSTAGE/train
# Moved all 3 .npz files from JURISDICTION/train, JURISDICTION/val, and JURISDICTION/test to JURISDICTION/train
# Moved all 3 .npz files from SUBJECTIVE/train, SUBJECTIVE/val, and SUBJECTIVE/test to SUBJECTIVE/train
# Moved all 3 .npz files from CLICHE/train, CLICHE/val, and CLICHE/test to CLICHE/train
# Moved all 3 .npz files from ELEVATE/train, ELEVATE/val, and ELEVATE/test to ELEVATE/train
# Moved all 3 .npz files from SE/train, SE/val, and SE/test to SE/train
# Moved all 3 .npz files from EXAGGERATION/train, EXAGGERATION/val, and EXAGGERATION/test to EXAGGERATION/train
# Moved UNLUCKY_UMhLBPPtlrY_00002.mp4 from UNLUCKY/test to UNLUCKY/train
# Moved all 3 .npz files from UNLUCKY/train, UNLUCKY/val, and UNLUCKY/test to UNLUCKY/train
# Moved all 3 .npz files from NEEDING/train, NEEDING/val, and NEEDING/test to NEEDING/train
# Moved all 3 .npz files from LIP/train, LIP/val, and LIP/test to LIP/train
# Moved all 3 .npz files from REUNITE/train, REUNITE/val, and REUNITE/test to REUNITE/train
# Moved all 3 .npz files from UNBELIEVABLE/train, UNBELIEVABLE/val, and UNBELIEVABLE/test to UNBELIEVABLE/train
# Moved all 3 .npz files from AUGMENTED/train, AUGMENTED/val, and AUGMENTED/test to AUGMENTED/train
# Moved all 3 .npz files from BLAST/train, BLAST/val, and BLAST/test to BLAST/train
# Moved all 3 .npz files from ROTTEN/train, ROTTEN/val, and ROTTEN/test to ROTTEN/train
# Moved all 3 .npz files from FLOWING/train, FLOWING/val, and FLOWING/test to FLOWING/train
# Moved all 3 .npz files from LAVA/train, LAVA/val, and LAVA/test to LAVA/train
# Moved all 3 .npz files from GRADUATION/train, GRADUATION/val, and GRADUATION/test to GRADUATION/train
# Moved all 3 .npz files from COHEN/train, COHEN/val, and COHEN/test to COHEN/train
# Moved all 3 .npz files from EMPIRICAL/train, EMPIRICAL/val, and EMPIRICAL/test to EMPIRICAL/train
# Moved all 3 .npz files from CONGESTION/train, CONGESTION/val, and CONGESTION/test to CONGESTION/train
# Moved all 3 .npz files from ISLAMIST/train, ISLAMIST/val, and ISLAMIST/test to ISLAMIST/train
# Moved all 3 .npz files from STRICT/train, STRICT/val, and STRICT/test to STRICT/train
# Moved all 3 .npz files from NORMAN/train, NORMAN/val, and NORMAN/test to NORMAN/train
# Moved all 3 .npz files from NAKED/train, NAKED/val, and NAKED/test to NAKED/train
# Moved all 3 .npz files from DECENT/train, DECENT/val, and DECENT/test to DECENT/train
# Moved all 3 .npz files from CRYSTALS/train, CRYSTALS/val, and CRYSTALS/test to CRYSTALS/train
# Moved all 3 .npz files from ASTONISHED/train, ASTONISHED/val, and ASTONISHED/test to ASTONISHED/train
# Moved STRATEGIC_jcp5vvxtEaU_00009.mp4 from STRATEGIC/test to STRATEGIC/train
# Moved all 3 .npz files from STRATEGIC/train, STRATEGIC/val, and STRATEGIC/test to STRATEGIC/train
# Moved all 3 .npz files from BONUS/train, BONUS/val, and BONUS/test to BONUS/train
# Moved all 3 .npz files from SERGIO/train, SERGIO/val, and SERGIO/test to SERGIO/train
# Moved all 3 .npz files from RELYING/train, RELYING/val, and RELYING/test to RELYING/train
# Moved all 3 .npz files from PULSE/train, PULSE/val, and PULSE/test to PULSE/train
# Moved all 3 .npz files from SYNAPSES/train, SYNAPSES/val, and SYNAPSES/test to SYNAPSES/train
# Moved HORRIFYING_OwgWkUIm9Gc_00009.mp4 from HORRIFYING/test to HORRIFYING/train
# Moved all 3 .npz files from HORRIFYING/train, HORRIFYING/val, and HORRIFYING/test to HORRIFYING/train
# Moved all 3 .npz files from UPRIGHT/train, UPRIGHT/val, and UPRIGHT/test to UPRIGHT/train
# Moved all 3 .npz files from RANCHER/train, RANCHER/val, and RANCHER/test to RANCHER/train
# Moved all 3 .npz files from EMPOWERMENT/train, EMPOWERMENT/val, and EMPOWERMENT/test to EMPOWERMENT/train
# Moved all 3 .npz files from ROYAL/train, ROYAL/val, and ROYAL/test to ROYAL/train
# Moved all 3 .npz files from NUDGING/train, NUDGING/val, and NUDGING/test to NUDGING/train
# Moved all 3 .npz files from RATIONALE/train, RATIONALE/val, and RATIONALE/test to RATIONALE/train
# Moved all 3 .npz files from PINT/train, PINT/val, and PINT/test to PINT/train
# Moved COOPERATION_dYNc3P4jSt4_00006.mp4 from COOPERATION/test to COOPERATION/train
# Moved all 3 .npz files from COOPERATION/train, COOPERATION/val, and COOPERATION/test to COOPERATION/train
# Moved all 3 .npz files from TRUSTING/train, TRUSTING/val, and TRUSTING/test to TRUSTING/train
# Moved all 3 .npz files from LEWIS/train, LEWIS/val, and LEWIS/test to LEWIS/train
# Moved all 3 .npz files from GHOST/train, GHOST/val, and GHOST/test to GHOST/train
# Moved all 3 .npz files from SPARK/train, SPARK/val, and SPARK/test to SPARK/train
# Moved all 3 .npz files from UNTRUE/train, UNTRUE/val, and UNTRUE/test to UNTRUE/train
# Moved TRACKING_Sa27SUR0Mlo_00013.mp4 from TRACKING/test to TRACKING/train
# Moved all 3 .npz files from TRACKING/train, TRACKING/val, and TRACKING/test to TRACKING/train
# Moved all 3 .npz files from FORBIDDEN/train, FORBIDDEN/val, and FORBIDDEN/test to FORBIDDEN/train
# Moved all 3 .npz files from KOSOVO/train, KOSOVO/val, and KOSOVO/test to KOSOVO/train
# Moved all 3 .npz files from PEACH/train, PEACH/val, and PEACH/test to PEACH/train
# Moved all 3 .npz files from ACCUMULATION/train, ACCUMULATION/val, and ACCUMULATION/test to ACCUMULATION/train
# Moved all 3 .npz files from MONASTERY/train, MONASTERY/val, and MONASTERY/test to MONASTERY/train
# Moved all 3 .npz files from CONTEST/train, CONTEST/val, and CONTEST/test to CONTEST/train
# Moved all 3 .npz files from MANHOOD/train, MANHOOD/val, and MANHOOD/test to MANHOOD/train
# Moved OAKLAND_ZJNESMhIxQ0_00012.mp4 from OAKLAND/test to OAKLAND/train
# Moved all 3 .npz files from OAKLAND/train, OAKLAND/val, and OAKLAND/test to OAKLAND/train
# Moved all 3 .npz files from INSULT/train, INSULT/val, and INSULT/test to INSULT/train
# Moved all 3 .npz files from EMBODIMENT/train, EMBODIMENT/val, and EMBODIMENT/test to EMBODIMENT/train
# Moved all 3 .npz files from THRILLED/train, THRILLED/val, and THRILLED/test to THRILLED/train
# Moved all 3 .npz files from DULL/train, DULL/val, and DULL/test to DULL/train
# Moved all 3 .npz files from EXPLODING/train, EXPLODING/val, and EXPLODING/test to EXPLODING/train
# Moved all 3 .npz files from ABDOMINAL/train, ABDOMINAL/val, and ABDOMINAL/test to ABDOMINAL/train
# Moved all 3 .npz files from DIGGING/train, DIGGING/val, and DIGGING/test to DIGGING/train
# Moved all 3 .npz files from REMOVING/train, REMOVING/val, and REMOVING/test to REMOVING/train
# Moved all 3 .npz files from MUSTER/train, MUSTER/val, and MUSTER/test to MUSTER/train
# Moved all 3 .npz files from HEARTBREAKING/train, HEARTBREAKING/val, and HEARTBREAKING/test to HEARTBREAKING/train
# Moved all 3 .npz files from BOIL/train, BOIL/val, and BOIL/test to BOIL/train
# Moved all 3 .npz files from ANALYZED/train, ANALYZED/val, and ANALYZED/test to ANALYZED/train
# Moved all 3 .npz files from BLAMED/train, BLAMED/val, and BLAMED/test to BLAMED/train
# Total words processed: 1121

# %%
updated_df = create_df(dir)

# %%
# The words that have an empty set (either train, val, or test)
words_with_zeros = updated_df[(updated_df['train'] == 0) | (updated_df['val'] == 0) | (updated_df['test'] == 0)]
pd.set_option('display.max_rows', None)
print(words_with_zeros)
# Out:
#                   train  val  test  total
# VIEWED                5    0     0      5
# RECENTLY             31    0     0     31
# ARRIVE                8    0     0      8
# THEIR               838    0    14    852
# ARABIC                3    0     0      3
# CHEMOTHERAPY          5    0     1      6
# BOLD                  4    0     0      4
# PASSING              11    0     0     11
# PARTICULAR           34    0     1     35
# BASKET                7    0     0      7
# INFORMED              9    0     1     10
# ANTHROPOLOGY          3    0     0      3
# KILL                 32    0     2     34
# GLAND                 3    0     0      3
# SHAKING               3    0     0      3
# SUM                  22    0     0     22
# SYRIA                 5    0     0      5
# RESEARCHING          10    0     0     10
# INNOVATOR             7    0     1      8
# SHOCK                 6    0     0      6
# SYMPHONY              3    0     0      3
# FUNERAL               9    0     0      9
# CHOSE                16    0     0     16
# DEEPER               14    0     1     15
# FUNDAMENTALLY         8    0     0      8
# DECEPTION             3    0     0      3
# UNTIL                90    0     1     91
# PLACED                8    0     0      8
# ANSWERING             3    0     0      3
# FEARLESS              4    0     0      4
# CHEESE                6    0     0      6
# MARGIN                4    0     0      4
# BRIDE                 3    0     0      3
# LIVED                38    0     0     38
# FLU                   5    0     0      5
# INDIAN               23    0     0     23
# SHE'S                57    0     1     58
# ACCORDING            21    0     1     22
# MASSIVELY             4    0     0      4
# CANCER              108    0     3    111
# CHIP                  8    0     0      8
# INFECTED              4    0     0      4
# FIRSTLY               4    0     0      4
# CROSSES               5    0     0      5
# INVESTMENT           13    0     1     14
# DISCUSS               7    0     0      7
# ERROR                11    0     0     11
# FACILITIES            4    0     0      4
# VILLAGE              23    0     2     25
# CLAPPING              3    0     0      3
# SOLO                  6    0     0      6
# PREVIOUSLY            5    0     0      5
# SURPRISINGLY          6    0     0      6
# JOKE                 18    0     1     19
# RITUAL                7    0     3     10
# ACTIVATED             4    0     0      4
# DIRECT               17    0     0     17
# PHYSICAL             40    0     0     40
# APPRENTICESHIP        3    0     0      3
# EXISTING              7    0     0      7
# ENTERPRISE           10    0     0     10
# CUBA                  4    0     0      4
# CYBER                 4    0     0      4
# FREQUENTLY            3    0     0      3
# WANDER                3    0     0      3
# LAZY                  6    0     0      6
# JOURNALIST           17    0     0     17
# TOLERANT              3    0     0      3
# THAT               8530    0   243   8773
# AIM                  12    0     2     14
# PERFORMED             4    0     0      4
# GREECE                5    0     0      5
# ELECTRONS             4    0     0      4
# EXILE                 3    0     0      3
# TURKEY                8    0     0      8
# EITHER               53    0     1     54
# PRIORITIZE            4    0     0      4
# SHEET                 8    0     0      8
# MCDONALD'S            3    0     0      3
# PINK                  6    0     0      6
# OWL                   7    0     0      7
# CLEAR                21    0     1     22
# DIAPHRAGM             5    0     0      5
# MOISTURE              3    0     0      3
# IOWA                  5    0     0      5
# PERSIST               3    0     0      3
# OUTCOME              30    0     1     31
# EVEN                441    0    13    454
# MALL                 12    0     1     13
# IGNORANCE             4    0     0      4
# STRAY                 3    0     0      3
# SOMEPLACE             3    0     0      3
# BLOCK                12    0     1     13
# READER                9    0     0      9
# FORGIVE               6    0     1      7
# STAGGERING            4    0     1      5
# COMPETING             3    0     0      3
# INVESTING             4    0     0      4
# DIVORCE               6    0     0      6
# SAUCE                 3    0     0      3
# FEW                 165    0     0    165
# NOR                   9    0     1     10
# GREEK                 9    0     0      9
# ASSUME               11    0     0     11
# YOUR               1183    0    32   1215
# OUTLET                3    0     0      3
# BEGIN                62    0     1     63
# ROUGHLY              12    0     2     14
# POCKET               16    0     0     16
# COVER                23    0     1     24
# DENYING               3    0     0      3
# BUNK                  3    0     0      3
# ALCOHOL               6    0     0      6
# PROGRESSION           3    0     0      3
# ENSURE               10    0     0     10
# ENGLISH              30    0     0     30
# HUMANITARIAN          4    0     1      5
# EXPECTING             4    0     0      4
# ESCAPED               3    0     0      3
# TRANSFORMATIVE        4    0     0      4
# EXPRESSION           19    0     1     20
# PRAIRIE               3    0     0      3
# INCREDIBLY           43    0     2     45
# PROTECTION           12    0     1     13
# SWIMMING             10    0     0     10
# CAMP                 23    0     0     23
# UGLY                  8    0     0      8
# WASTING               5    0     0      5
# CHEAPER               4    0     0      4
# PUNCH                 5    0     0      5
# TUBE                  4    0     0      4
# ATTEMPT              10    0     0     10
# COUPLE               94    0     2     96
# HOME                177    0     8    185
# INTERESTING         108    0     0    108
# FORCE                51    0     1     52
# INVESTED             10    0     0     10
# EXPERIMENT           55    0     1     56
# CHUTZPAH              5    0     0      5
# CLOTH                 3    0     0      3
# DISTRIBUTION          5    0     0      5
# EXTRACT               4    0     0      4
# STRESS               51    0     1     52
# TEXTING               3    0     3      6
# GRAFFITI              3    0     0      3
# HI                   13    0     0     13
# LUTHER                3    0     1      4
# PROMISED              6    0     0      6
# WASTED                9    0     0      9
# SPIDER                5    0     0      5
# YOUTH                23    0     1     24
# ADMISSION             3    0     0      3
# SPHERE                6    0     0      6
# RELEASED             13    0     0     13
# RUBBISH               9    0     0      9
# LOAF                  3    0     0      3
# ACCEPTING             5    0     0      5
# DEPENDING             5    0     0      5
# FAIR                 17    0     0     17
# EVOLUTIONARY          4    0     0      4
# EXECUTIVE            16    0     0     16
# LASTED                4    0     0      4
# EFFECTIVE            31    0     3     34
# PROTECT              43    0     0     43
# LOAD                  6    0     0      6
# TOXIC                10    0     0     10
# ROLE                 59    0     0     59
# PALLIATIVE            4    0     0      4
# MUNCHKIN              3    0     0      3
# PURE                 10    0     0     10
# PERSONALITY          16    0     0     16
# POLL                  4    0     2      6
# PREVENTED             5    0     0      5
# LISTEN               32    0     2     34
# WILLIAM               9    0     0      9
# HERO                 12    0     0     12
# GET                 936    0    41    977
# EVIDENT               4    0     0      4
# PEACE                20    0     0     20
# CLAIM                18    0     0     18
# GOAL                 80    0     1     81
# INTERESTINGLY         3    0     0      3
# DIFFICULTIES          4    0     0      4
# LARGER               15    0     0     15
# DISCIPLINE            5    0     0      5
# NERVOUS               9    0     0      9
# DRAW                 23    0     1     24
# SAFELY                7    0     0      7
# RYAN                  4    0     0      4
# BOOT                  5    0     0      5
# DAMAGE               17    0     0     17
# INTERNET             81    0     7     88
# DANCER                3    0     0      3
# MATERIAL             38    0     0     38
# UNABLE                9    0     0      9
# COURT                22    0     2     24
# CHASE                 8    0     0      8
# CAUGHT               19    0     1     20
# MOTOR                 5    0     0      5
# DAILY                25    0     1     26
# HUGE                 72    0     2     74
# PERFECTIONIST         6    0     0      6
# GEIGER                3    0     1      4
# THIN                  5    0     0      5
# CHOSEN               12    0     0     12
# CAGE                  5    0     0      5
# GUY                 141    0     7    148
# PORT                  3    0     0      3
# CRASHED               4    0     0      4
# GIVE                302    0     6    308
# GIVEN                57    0     2     59
# DEMANDING             4    0     1      5
# CALCULUS              3    0     0      3
# EMPLOYMENT            5    0     0      5
# ESPECIALLY           23    0     2     25
# CRY                   9    0     1     10
# ECONOMIES             3    0     0      3
# OUTSIDE              70    0     1     71
# DISAPPOINTMENT        5    0     0      5
# MICROBIAL             5    0     0      5
# SERVING               6    0     0      6
# MORTALITY             6    0     1      7
# CRUSHING              3    0     0      3
# ABUNDANCE             3    0     0      3
# MUSICAL               6    0     0      6
# FLOSS                 3    0     0      3
# PODCAST               4    0     0      4
# TULSA                 5    0     0      5
# GAINED               10    0     0     10
# LAST                188    0     4    192
# WASTE                38    0     1     39
# JUICE                 8    0     0      8
# DEFINING              8    0     0      8
# FOUNDATION           22    0     1     23
# TABOO                 3    0     0      3
# CEREMONY              3    0     0      3
# SHORTCUT              4    0     0      4
# PROMOTION             4    0     0      4
# THOUGHT             302    0    10    312
# MAN'S                 4    0     0      4
# COLD                 23    0     1     24
# QUIETLY               3    0     0      3
# FIGHTERS              4    0     0      4
# MASTERY               3    0     0      3
# MINDFUL               4    0     0      4
# POINTED               5    0     0      5
# MONOGAMY              3    0     0      3
# PHOTOGRAPH           13    0     1     14
# PAPER                57    0     1     58
# INTRODUCE             5    0     0      5
# BREAKUP               4    0     0      4
# EXPERT               28    0     0     28
# CRACKING              3    0     0      3
# DAMN                  5    0     0      5
# INTENTION             9    0     1     10
# SELECT                4    0     0      4
# TEENAGER             24    0     0     24
# SOPHISTICATED        10    0     0     10
# PLEASE               41    0     2     43
# SOLELY                3    0     0      3
# STRIPE                3    0     0      3
# LIKED                10    0     0     10
# SOLDIER              21    0     2     23
# GDP                   8    0     0      8
# METROPOLITAN          6    0     0      6
# VALUED                3    0     0      3
# DESIGNED             28    0     0     28
# INGEST                3    0     0      3
# NEGATIVE             35    0     0     35
# ELSEWHERE             4    0     0      4
# INVASIVE              3    0     0      3
# APPROPRIATE          11    0     0     11
# PAN                   5    0     0      5
# REPUBLICAN            8    0     0      8
# POSED                 3    0     0      3
# BOWLING               5    0     0      5
# RACE                 35    0     2     37
# NORMAL               37    0     1     38
# COPYRIGHT             5    0     0      5
# BERLIN                3    0     0      3
# SELECTED              6    0     0      6
# NATION               39    0     1     40
# ENGAGED              21    0     0     21
# EM                    3    0     0      3
# SHOE                 12    0     0     12
# SOFT                  9    0     0      9
# INTERDEPENDENT        5    0     0      5
# FIBER                 8    0     0      8
# FORGOTTEN            16    0     1     17
# POWERFUL             83    0     4     87
# PSYCHIATRIST          5    0     0      5
# POTENTIALLY          21    0     0     21
# SERVICE              71    0     2     73
# WATCH                56    0     1     57
# WILLENDORF            3    0     0      3
# METHANE               3    0     1      4
# COSTUME               3    0     0      3
# MOORE'S               4    0     1      5
# EL                    4    0     0      4
# SLEEVE                3    0     0      3
# COMMITTED            17    0     0     17
# BE                 1998    0    51   2049
# SOMEDAY              10    0     0     10
# IMPORTANCE           13    0     1     14
# P                     8    0     0      8
# DOWNTOWN              6    0     0      6
# DEADLINE              6    0     0      6
# ESTEEM                9    0     0      9
# BEAUTY               13    0     0     13
# LIST                 30    0     1     31
# LIFESTYLE            16    0     0     16
# IF                 1415    0    20   1435
# POINTING              3    0     0      3
# CLIMBED               4    0     0      4
# LITERALLY            26    0     1     27
# COMPARISON            4    0     1      5
# STOLEN                4    0     0      4
# SECULAR               4    0     0      4
# SHE'D                11    0     0     11
# SOUP                  5    0     0      5
# PASSAGE               6    0     0      6
# IMMIGRATION           8    0     0      8
# SELVES                8    0     0      8
# WEALTHY               3    0     1      4
# FACING               18    0     0     18
# COUNTY               10    0     0     10
# PIECE                64    0     2     66
# SICKNESS              3    0     1      4
# DAVID                17    0     0     17
# EPIGENETIC            6    0     0      6
# REPLACE              14    0     0     14
# DISRUPTIVE            5    0     0      5
# THROUGH             295    0     9    304
# WITHDREW              3    0     0      3
# WHENEVER             14    0     0     14
# CASKET                3    0     0      3
# PROMOTED              4    0     0      4
# IRAN                 12    0     0     12
# MINIMUM               4    0     0      4
# PORNOGRAPHY           5    0     0      5
# X                    14    0     0     14
# WALMART               3    0     0      3
# RAPE                 21    0     0     21
# THRUST                3    0     0      3
# INTERVENTION         15    0     0     15
# WAKE                 37    0     0     37
# BETWEEN             121    0     3    124
# ASPIRE                2    0     2      4
# MONEY               182    0     7    189
# CARING                7    0     1      8
# HABIT                14    0     0     14
# SHOCKED               4    0     0      4
# REALIZING             5    0     0      5
# ROSE                  8    0     0      8
# PRIVACY              17    0     0     17
# ENTIRELY             19    0     0     19
# RAISED               22    0     0     22
# SCHOLARSHIP           5    0     0      5
# CREATED              69    0     2     71
# DERVISH               3    0     0      3
# PERFORMANCE          31    0     1     32
# EXPLICIT              4    0     0      4
# PAIR                  8    0     0      8
# SPACE               125    0     2    127
# UPGRADE               2    0     2      4
# AGED                  6    0     1      7
# STRUGGLE             24    0     0     24
# UNCONDITIONAL         3    0     1      4
# PRIORITY              6    0     0      6
# TENET                 3    0     0      3
# MOLECULE             15    0     1     16
# BREATHING             4    0     0      4
# STRESSFUL            10    0     0     10
# REWARDING             4    0     0      4
# DEMOCRAT              5    0     0      5
# ILLNESS              20    0     0     20
# CRUCIALLY             3    0     0      3
# PERSPECTIVE          53    0     0     53
# SYMBOLIC              4    0     0      4
# STARK                 5    0     0      5
# IMPROVED              5    0     0      5
# STAR                 45    0     1     46
# UNDERSTOOD           23    0     0     23
# GOES                128    0     3    131
# EMBARRASSED           8    0     0      8
# CLOSET                8    0     1      9
# HIRE                  7    0     0      7
# MEETING              41    0     1     42
# TRANSITION            8    0     0      8
# COMMONALITIES         3    0     0      3
# RELATIVE             14    0     0     14
# CHRONIC              12    0     0     12
# END                 182    0     3    185
# SOCIALLY              5    0     0      5
# FORT                  3    0     0      3
# OUTFIT                5    0     0      5
# TRANSLATE             7    0     0      7
# EXPONENTIALLY         3    0     0      3
# DIEGO                 4    0     0      4
# TWELVE                5    0     0      5
# INSPIRATION          14    0     1     15
# OFFICER              11    0     0     11
# CARED                 5    0     0      5
# NETHERLANDS           7    0     1      8
# COMPETITION          23    0     0     23
# HOPEFUL               4    0     0      4
# AVENUE                7    0     0      7
# INCIDENT              5    0     0      5
# CARDBOARD             6    0     1      7
# RATHER               64    0     1     65
# JIM                   4    0     0      4
# ADS                   6    0     0      6
# WARMING               9    0     0      9
# HOMO                  3    0     0      3
# CARPENTRY             3    0     0      3
# LEAD                 44    0     2     46
# SWIRLING              3    0     0      3
# REACHING             10    0     1     11
# DISCOVERY            21    0     0     21
# VOLCANO               4    0     0      4
# ANYONE               82    0     4     86
# LEMONADE              3    0     0      3
# THERE'RE              5    0     0      5
# REASON              164    0     2    166
# BATH                  3    0     0      3
# O                     4    0     0      4
# UNEMPLOYMENT          8    0     0      8
# ANSWERED              5    0     0      5
# OUR                1319    0    25   1344
# SEEING               66    0     2     68
# UNEXPECTED            3    0     1      4
# PHOTOGRAPHED          3    0     0      3
# SPEECH               33    0     1     34
# GENERATE             20    0     0     20
# LAPTOP                8    0     0      8
# DIVERSE              10    0     0     10
# UPSET                15    0     0     15
# MONK                  4    0     0      4
# BLINDNESS             5    0     0      5
# SAVE                 28    0     0     28
# INCREASED            10    0     0     10
# JEWELRY               4    0     0      4
# TERRORIST             9    0     1     10
# THIRDLY               4    0     0      4
# EXCITED              39    0     1     40
# COGNITIVE            16    0     0     16
# BASE                 15    0     0     15
# WOKEN                 3    0     0      3
# EQUAL                25    0     0     25
# GUESSING              3    0     0      3
# PUBLICATION           4    0     0      4
# HARNESS               4    0     1      5
# COLLAPSE             11    0     0     11
# HEADING               4    0     0      4
# PLATFORM             21    0     2     23
# SUPER                22    0     1     23
# PLANTING              5    0     0      5
# BLA                   3    0     0      3
# MENTORING             3    0     0      3
# NOTICED              22    0     0     22
# AUDITION              3    0     0      3
# KOREAN                5    0     0      5
# BEING               409    0     5    414
# REVOLUTION           19    0     0     19
# COX                   3    0     0      3
# METAL                11    0     0     11
# GRAVE                11    0     0     11
# EFFORT               27    0     0     27
# CHARITY               9    0     0      9
# ABOUT              2182    0    70   2252
# ETHICS                3    0     0      3
# STATEMENT            22    0     1     23
# SPORTING              3    0     0      3
# ISLAND               35    0     0     35
# CAKE                  9    0     0      9
# IRELAND               4    0     0      4
# FUELED                3    0     0      3
# EXPLORATION           6    0     0      6
# PROPOSED              4    0     0      4
# REDUCED               8    0     0      8
# THING              1036    0    28   1064
# ELLEN                 3    0     0      3
# THRILL                3    0     0      3
# HAND                187    0     7    194
# OKAY                 59    0     3     62
# COMPROMISE            3    0     0      3
# NEIGHBOR             17    0     1     18
# LHC                   4    0     0      4
# MATTHEW               3    0     0      3
# DIFFERENCE           70    0     4     74
# DOCUMENTARY           4    0     0      4
# WIKIPEDIA             6    0     1      7
# LOG                   7    0     0      7
# DOING               346    0     9    355
# TECHNOLOGY          121    0     5    126
# POSSIBLY             30    0     2     32
# RESEARCH            140    0     3    143
# VACATION             10    0     0     10
# BRUSHED               3    0     0      3
# COLLABORATION        14    0     0     14
# APPLICATION          26    0     0     26
# ASK                 216    0     3    219
# WIDER                 4    0     0      4
# BRAIN               268    0     4    272
# TWICE                18    0     0     18
# COMPANIES            66    0     1     67
# ASKED               133    0     5    138
# DENIAL                6    0     0      6
# ISN                   3    0     0      3
# CAUSE                65    0     1     66
# PERSON              207    0     9    216
# EVENT                50    0     1     51
# FUNCTIONING           6    0     0      6
# PAINTER               3    0     0      3
# COMPLEX              47    0     1     48
# JURY                  3    0     0      3
# SECONDARY             5    0     0      5
# ASSUMED               5    0     0      5
# PHYSICALLY           10    0     0     10
# EVENTUALLY           58    0     1     59
# RISK                 73    0     1     74
# QUALIFIED             3    0     0      3
# ERA                  15    0     0     15
# MORE                948    0    33    981
# FICTIONAL             3    0     0      3
# ORGANIC              17    0     0     17
# ORG                   6    0     0      6
# SUICIDAL              6    0     0      6
# OBJECTIVE            16    0     0     16
# IT                 4837    0   160   4997
# TOGETHER            174    0    10    184
# APPALLING             3    0     0      3
# CAPABLE              17    0     1     18
# DIVIDED               7    0     0      7
# INSECURITY            5    0     0      5
# LAPILLI               3    0     0      3
# REGULATE              4    0     0      4
# DE                    7    0     0      7
# BRUSH                 6    0     0      6
# EVOLVE               10    0     0     10
# PHASE                10    0     0     10
# ERIC                  6    0     0      6
# BASEMENT              6    0     1      7
# REFRIGERATOR          4    0     0      4
# JUNE                  4    0     0      4
# MOSQUE                3    0     0      3
# CURRENCY              6    0     0      6
# MEASUREMENT           9    0     0      9
# RELATIONSHIP         84    0     5     89
# RELEASE              16    0     0     16
# TYPE                 65    0     0     65
# GRIMMS                4    0     0      4
# DECIDE               54    0     2     56
# IMAGE                54    0     2     56
# SLAM                  4    0     0      4
# DEAF                  5    0     0      5
# GRANDSON              4    0     0      4
# REPORTER              9    0     0      9
# NUMB                  4    0     0      4
# DEAN                  3    0     0      3
# MOZART                8    0     0      8
# MENOPAUSE             5    0     0      5
# BROWN                13    0     0     13
# COURSE              204    0     5    209
# BIRMINGHAM            4    0     0      4
# FEE                   5    0     0      5
# BETA                  3    0     0      3
# VULNERABLE           17    0     0     17
# RISING                5    0     0      5
# POLITICS             32    0     0     32
# BOTHER                7    0     0      7
# WAITING              38    0     1     39
# HAPPEN              276    0    19    295
# STABLE               10    0     0     10
# COLORED               3    0     0      3
# SIMPLIFY              4    0     0      4
# DIGIT                 6    0     0      6
# HIM                 246    0     2    248
# REACTIVE              3    0     0      3
# VALUABLE             14    0     2     16
# ANIMATOR              5    0     0      5
# UPTAKE                3    0     0      3
# ADVANCED              8    0     0      8
# CEO                  11    0     0     11
# FLUORESCENT           3    0     0      3
# REALIZATION           5    0     0      5
# ALONG                61    0     2     63
# MAIL                 10    0     1     11
# PRAYER                5    0     0      5
# INTROVERTS            4    0     0      4
# OIL                  26    0     2     28
# JAW                   8    0     0      8
# STANDARDIZED          5    0     0      5
# F                     6    0     0      6
# BRUSHING              4    0     0      4
# MILLION             109    0     2    111
# MANUFACTURER          6    0     0      6
# MECHANICAL            5    0     0      5
# ABUSE                16    0     2     18
# DRILL                 6    0     0      6
# GENERIC               4    0     0      4
# OBESITY               9    0     1     10
# VENUE                 3    0     0      3
# WITH               2170    0    34   2204
# TRIAL                25    0     0     25
# COMMUNICATION        20    0     0     20
# HOLLYWOOD             3    0     0      3
# BAGHDAD               3    0     0      3
# ROD                   3    0     0      3
# TAXES                 6    0     0      6
# INFECTIOUS            8    0     0      8
# MARATHON             14    0     0     14
# MINORITY              5    0     0      5
# YOGA                  8    0     0      8
# DEFINITIVE            3    0     0      3
# NEIL                  3    0     0      3
# GENERATOR             4    0     0      4
# RUNNING              59    0     1     60
# SISTER               35    0     0     35
# PORN                  6    0     0      6
# COOPERATE             5    0     0      5
# APPETITE              3    0     0      3
# PIE                   3    0     0      3
# BUREAUCRAT            3    0     0      3
# SURPRISING           15    0     1     16
# RURAL                11    0     0     11
# SKYPE                 4    0     0      4
# EVIL                  6    0     0      6
# BOW                   3    0     0      3
# SYMMETRY              4    0     0      4
# ATHLETE              17    0     0     17
# HUNTER                9    0     0      9
# B                    26    0     0     26
# HONEY                13    0     0     13
# DRIVING              35    0     0     35
# SAKE                  6    0     0      6
# FREAKED               6    0     0      6
# CELEBRATION           3    0     0      3
# RECOVER               4    0     0      4
# MARTIAL               3    0     0      3
# DESERT               11    0     0     11
# SEXISM                6    0     0      6
# SUGGESTING            5    0     0      5
# BLOW                  5    0     0      5
# IMPLEMENTED           6    0     0      6
# DATING                6    0     0      6
# NATIONAL             33    0     1     34
# LION                  5    0     0      5
# LINGUISTIC            5    0     0      5
# TOMBOY                4    0     0      4
# BLUE                 21    0     1     22
# STRUCTURE            36    0     2     38
# RECOVERY             10    0     0     10
# MATTER              160    0     6    166
# VIA                   4    0     0      4
# JAIL                  7    0     0      7
# INTERVIEWING          4    0     0      4
# SIBLING               4    0     0      4
# SIGN                 44    0     1     45
# CONSENSUS             4    0     0      4
# ONLINE               59    0     0     59
# SITUATION            58    0     1     59
# YORUBA                3    0     0      3
# OWN                 267    0     7    274
# HACKER                6    0     0      6
# TARAHUMARA            5    0     0      5
# MOSES                 3    0     0      3
# EAR                  13    0     0     13
# FRONT                62    0     3     65
# LIGHTING              7    0     0      7
# OVERALL              15    0     0     15
# PERSONALLY           10    0     0     10
# PARTY                38    0     1     39
# BUTTER                4    0     0      4
# LINED                 3    0     0      3
# WHOLE               172    0     4    176
# EDUCATION            84    0     6     90
# PLANTATION            3    0     0      3
# STUDIED              27    0     1     28
# A                  8403    0   227   8630
# FLAG                  5    0     0      5
# RHYME                 4    0     0      4
# FRUSTRATED           17    0     1     18
# ACCOUNTING            4    0     0      4
# LUNCH                12    0     0     12
# PROCESS             108    0     3    111
# IDENTICAL             7    0     0      7
# EVIDENCE             46    0     1     47
# PANAMA                3    0     0      3
# MOTEL                 5    0     0      5
# HAS                 615    0    25    640
# SHOWN                32    0     1     33
# DIOXIDE               3    0     0      3
# TRACKER               3    0     0      3
# AID                  26    0     2     28
# KIDDING               4    0     0      4
# NONPROFIT             7    0     0      7
# EATING               36    0     0     36
# RID                  25    0     0     25
# BEETLE                3    0     0      3
# RELIABLE              7    0     0      7
# TRUSTED               3    0     0      3
# CAR                 125    0     4    129
# FAMOUS               18    0     2     20
# ESSENTIAL            18    0     0     18
# ORGASM                4    0     0      4
# ABRAHAM'S             3    0     0      3
# BIRTH                16    0     2     18
# LINEAR                5    0     0      5
# CADAVER               3    0     0      3
# NETWORKING            4    0     0      4
# PLANT                49    0     0     49
# ADOLESCENT            6    0     0      6
# REJECTED             11    0     2     13
# POSITION             32    0     0     32
# INVESTIGATE           8    0     0      8
# NEURAL               10    0     0     10
# GENETIC              11    0     0     11
# PROPOSITION           9    0     0      9
# EVERYBODY           105    0     5    110
# DEAL                 63    0     1     64
# PLAY                166    0     2    168
# ADDITION              8    0     0      8
# POSSIBLE            107    0     6    113
# LIGHT                90    0     3     93
# FIGURING              7    0     0      7
# SPOKE                17    0     0     17
# SUN                  20    0     1     21
# INCENTIVE             7    0     0      7
# ANNOUNCE              4    0     0      4
# ENGAGING             11    0     1     12
# TRANSGENDER           9    0     0      9
# BUTTON               12    0     0     12
# WELLNESS              4    0     0      4
# VIABLE                4    0     0      4
# DROP                 31    0     0     31
# CENTURY              51    0     0     51
# MAHATMA               3    0     0      3
# FISHERIES             5    0     0      5
# SUSTAINABLE          12    0     0     12
# THUS                  6    0     0      6
# OFFER                55    0     2     57
# ACCENT                4    0     0      4
# REVEAL                8    0     0      8
# LANE                  4    0     0      4
# WORKED              102    0     6    108
# ACTIVIST             10    0     1     11
# FROM               1087    0    22   1109
# UNIT                 12    0     0     12
# HEAVILY               6    0     1      7
# NATURALLY            23    0     2     25
# SCREENING             4    0     0      4
# SPEED                28    0     1     29
# FOOTPRINT             3    0     1      4
# CLEARLY              17    0     0     17
# EARTHQUAKE            5    0     1      6
# TOMORROW             21    0     0     21
# WILDLIFE              4    0     0      4
# SMOKE                16    0     0     16
# SAINT                 7    0     0      7
# PHRASE               17    0     0     17
# SHELF                 6    0     0      6
# TRAFFIC              15    0     0     15
# STAGE                77    0     1     78
# PASSED               21    0     0     21
# FRENCH               13    0     0     13
# DRY                   5    0     2      7
# NASA                  6    0     0      6
# MAYOR                10    0     1     11
# R                    11    0     0     11
# ALGORITHM            14    0     0     14
# MINI                  5    0     0      5
# TRAINING             47    0     0     47
# GARDEN               15    0     0     15
# SUPERSTAR             5    0     0      5
# PRECISELY             3    0     0      3
# CAPTAIN               3    0     0      3
# CUSTOM                9    0     0      9
# UNLEASHED             3    0     0      3
# WEAK                  9    0     0      9
# CO                   21    0     0     21
# GROUP               143    0     5    148
# BOX                  34    0     0     34
# CONSUMING             6    0     1      7
# WALKED               33    0     1     34
# APPLIES              10    0     0     10
# WHAT'S              229    0     6    235
# MEDITATION            9    0     0      9
# ANOTHER             212    0     4    216
# LADIES               17    0     0     17
# ASSEMBLY              4    0     0      4
# MASTER               16    0     0     16
# TABLE                41    0     2     43
# REBEL                 3    0     0      3
# APPLYING              3    0     0      3
# ZOO                   3    0     0      3
# FOLK                 18    0     0     18
# SPLIT                 4    0     0      4
# DEALT                 4    0     0      4
# SHOULDN'T            33    0     2     35
# GOLD                 10    0     1     11
# ANSWER              148    0     9    157
# ENDING                7    0     0      7
# NEUROSCIENCE          6    0     0      6
# SCHOLAR               6    0     0      6
# SEXUAL               28    0     2     30
# REPLACED              9    0     0      9
# IRAQ                 13    0     1     14
# PRETEND               9    0     0      9
# UNAWARE               5    0     0      5
# VEHICLE              10    0     0     10
# TOILET               11    0     0     11
# MIX                   5    0     0      5
# BRAND                29    0     0     29
# BOUND                 8    0     1      9
# RESILIENCE           10    0     0     10
# RESENTED              3    0     0      3
# INTEGRATED            5    0     0      5
# SHOULD'VE             3    0     0      3
# WINTER                8    0     0      8
# WIDOW                 4    0     0      4
# LEBANON               3    0     0      3
# RUGBY                 5    0     0      5
# BEGAN                73    0     1     74
# SECRETARY             6    0     0      6
# LAUNCHED             10    0     0     10
# MARIJUANA             9    0     0      9
# NOVELTY               3    0     0      3
# FAMILY'S              5    0     0      5
# NEXT                209    0     3    212
# MAINTENANCE           5    0     0      5
# PULLED               18    0     0     18
# SLOW                 23    0     0     23
# FLASHLIGHT            3    0     0      3
# EVALUATE              5    0     0      5
# AROUND              370    0    15    385
# SECTOR               15    0     0     15
# SUGGESTION           13    0     1     14
# HAPPINESS            36    0     0     36
# EMBRACED              5    0     0      5
# SMITH                 4    0     0      4
# EARTH                48    0     0     48
# DRIFT                 3    0     0      3
# Y                     3    0     0      3
# FLAT                  9    0     1     10
# COUNSEL               3    0     0      3
# GLOBALIZATION        11    0     0     11
# VOICE                64    0     1     65
# VALUE               100    0     4    104
# STEPHEN               7    0     0      7
# LOUSY                 4    0     0      4
# WORLDVIEW             4    0     0      4
# ROVER                 6    0     0      6
# SECOND              188    0     5    193
# VITAL                 7    0     0      7
# FEDERAL              17    0     0     17
# HELPING              33    0     0     33
# SEND                 53    0     0     53
# ENTHUSIASTIC          3    0     0      3
# INCOME               32    0     0     32
# HABITAT               7    0     0      7
# CONCEPT              50    0     0     50
# WRAPPED               6    0     0      6
# POLLUTION             6    0     0      6
# THEORETICAL           4    0     0      4
# VITAMIN               4    0     0      4
# WANNA                 5    0     1      6
# GRIEF                 6    0     0      6
# COWARD                3    0     0      3
# ACCOUNTANT            5    0     0      5
# ROW                   8    0     0      8
# WAGE                  5    0     0      5
# DROWNING              3    0     0      3
# STRANGER             17    0     1     18
# GROWER                4    0     0      4
# CLASSMATE             7    0     0      7
# EARN                  5    0     0      5
# INVOLVED             56    0     2     58
# CHOLESTEROL           6    0     0      6
# TRADITION            21    0     1     22
# OPENNESS              5    0     0      5
# CAPABILITIES          6    0     0      6
# INEFFICIENT           3    0     0      3
# TRIUMPH               3    0     0      3
# METAPHOR             15    0     1     16
# STIMULATE             5    0     0      5
# CREATE              159    0     8    167
# OCCURRED              7    0     0      7
# ACTING                7    0     0      7
# IDENTITY             26    0     0     26
# BANK                 33    0     2     35
# LESS                101    0     1    102
# FOXES                 3    0     0      3
# WORLD               576    0    12    588
# MYSTERIES             4    0     0      4
# PLUS                 10    0     1     11
# GIFT                 17    0     0     17
# STORYTELLING          6    0     1      7
# SHORT                47    0     1     48
# REEF                  4    0     0      4
# SOVIET                6    0     0      6
# REPRESENT            21    0     1     22
# ISOLATED             14    0     0     14
# TRIP                 18    0     0     18
# TREMENDOUSLY          4    0     0      4
# SOME                747    0    15    762
# THOUGH              114    0     1    115
# HALL                  8    0     1      9
# DEAD                 38    0     0     38
# JEWISH                9    0     0      9
# MILK                  3    0     0      3
# WHEN               1320    0    38   1358
# INTERACT             17    0     0     17
# JEFF                  4    0     0      4
# RETAIL                3    0     0      3
# FOOL                  9    0     1     10
# EXPERIMENTAL          3    0     0      3
# FUND                 17    0     0     17
# FRANKLY               9    0     1     10
# LICENSED              4    0     0      4
# MARINE               16    0     0     16
# ABSURD                4    0     0      4
# ANTIBODIES            5    0     0      5
# DISAPPEAR             5    0     1      6
# FRIENDLY              5    0     1      6
# FORWARD              61    0     0     61
# PENNY                 3    0     0      3
# PATTERN              45    0     1     46
# SIZED                 4    0     0      4
# COMMITMENT            5    0     0      5
# USA                   3    0     0      3
# NOUN                  4    0     0      4
# LIFESPAN              5    0     0      5
# PLUG                  3    0     0      3
# CHURCH               17    0     1     18
# BACKYARD              8    0     0      8
# SERVANT               3    0     0      3
# STUDY               115    0     3    118
# THEY'RE             395    0    15    410
# DROPPING              4    0     0      4
# GLAD                  8    0     0      8
# STEPPED               8    0     0      8
# PROGRESSIVE           4    0     1      5
# TWITTER              15    0     0     15
# HISTORICAL            5    0     0      5
# LATEST                8    0     0      8
# JOURNAL               8    0     0      8
# KEEP                139    0     2    141
# TIE                   6    0     0      6
# TRANSPARENT           5    0     0      5
# CHANGER               8    0     1      9
# TOUCHING              5    0     0      5
# DIVINE                3    0     0      3
# ALLEN                 3    0     0      3
# CHEMISTRY            19    0     0     19
# THREAT               23    0     0     23
# EXCHANGE             16    0     0     16
# FRAGMENTS             4    0     0      4
# DIVE                  7    0     0      7
# TALK                332    0     7    339
# VACCINATION           4    0     0      4
# SUPREME               6    0     1      7
# STRANGE              21    0     0     21
# RITE                  3    0     0      3
# FADE                  3    0     0      3
# AFFECTING             8    0     0      8
# BLOWING               3    0     0      3
# RELEVANT             10    0     0     10
# QUEUE                 3    0     0      3
# PSYCHIATRIC           4    0     0      4
# WIFE                 32    0     2     34
# ASSIGNED              5    0     0      5
# WILLING              35    0     1     36
# ROBOT                40    0     3     43
# MISSES                4    0     1      5
# SUPPOSE              13    0     0     13
# STRUCTURED            3    0     0      3
# PHENOMENON           13    0     1     14
# RESUME                7    0     0      7
# RESTRICTION           3    0     0      3
# MENTALITY             6    0     0      6
# STRANGELY             3    0     0      3
# BREATH               25    0     0     25
# J                     4    0     0      4
# SPELL                 4    0     0      4
# SMALLEST              4    0     0      4
# RWANDA                3    0     0      3
# LIBERAL              11    0     0     11
# SAN                  14    0     0     14
# SERIES               19    0     1     20
# ASSURE                4    0     0      4
# YARD                  4    0     0      4
# REGISTER              5    0     0      5
# FUEL                 18    0     0     18
# GLOBE                 5    0     0      5
# STUDENT             115    0     1    116
# PROVEN                4    0     0      4
# FAIL                 15    0     2     17
# CROCHET               3    0     0      3
# SCARE                 5    0     0      5
# ESTATE                3    0     0      3
# OCCUR                 9    0     0      9
# H                     9    0     0      9
# ANALOG                7    0     0      7
# DETERMINED            6    0     0      6
# WALKABLE              3    0     0      3
# NAVIGATE              9    0     1     10
# RARELY               12    0     0     12
# NARCISSISTS           4    0     0      4
# PROCESSED            11    0     0     11
# SHUT                  8    0     2     10
# CONNECT              24    0     1     25
# FORMATION             3    0     0      3
# COMEDY                7    0     1      8
# ROUGH                 8    0     0      8
# COUNTRY'S             6    0     0      6
# MISERABLE             9    0     0      9
# EARNED                3    0     1      4
# EXPANDING             3    0     0      3
# VALIDATION            3    0     0      3
# FILED                 3    0     0      3
# VIRTUAL              17    0     0     17
# PULL                 20    0     2     22
# NOTICE               36    0     3     39
# MINDFULNESS           5    0     0      5
# EDGE                  9    0     1     10
# RECYCLED              4    0     0      4
# LAUGH                16    0     1     17
# SLOWED                4    0     0      4
# FALLING               7    0     0      7
# REALITIES             6    0     0      6
# STRAND                3    0     0      3
# RACING                3    0     0      3
# AUSTRALIAN            8    0     0      8
# HOTEL                16    0     0     16
# BLESS                 3    0     0      3
# CHIMPANZEE            9    0     0      9
# RESTROOM              6    0     0      6
# PLANNED               4    0     0      4
# MEASURING             4    0     0      4
# PARTLY                6    0     0      6
# PAKISTAN              5    0     0      5
# KATRINA               3    0     0      3
# ADAPT                13    0     0     13
# CONCRETE             13    0     0     13
# MUST                 96    0     2     98
# VALLEY                7    0     1      8
# SINGLE              117    0     3    120
# SECTION               5    0     0      5
# CHEATING              4    0     0      4
# CORPORATE            11    0     0     11
# EXCEPT               20    0     0     20
# DETECTOR              6    0     0      6
# SCREAM                3    0     0      3
# DETENTION             5    0     0      5
# BESIDE               11    0     0     11
# MOTIVATED            11    0     0     11
# PROJECTING            3    0     0      3
# SIX                  62    0     4     66
# MONOPOLY              3    0     0      3
# DECIDED              92    0     4     96
# INTUITION            10    0     0     10
# DRAWING              13    0     1     14
# NATURAL              60    0     2     62
# OUTDOOR               5    0     0      5
# DIMENSION             9    0     0      9
# SHARE               122    0     4    126
# SOLAR                29    0     0     29
# SWITZERLAND           6    0     0      6
# CONFRONTED            5    0     0      5
# DYSFUNCTION           6    0     0      6
# HONESTLY             12    0     0     12
# ASSESSMENT            3    0     0      3
# COFFEE               19    0     0     19
# LEADING              20    0     0     20
# BELOW                 8    0     1      9
# SHINE                 3    0     0      3
# EVERYDAY             32    0     0     32
# PHD                   8    0     0      8
# PERPETRATOR           7    0     0      7
# THROWING             10    0     0     10
# CONSIDERED           25    0     2     27
# FUNCTIONAL            6    0     0      6
# TOLERATE              6    0     1      7
# EXPLOITED             4    0     0      4
# SHADOW               11    0     0     11
# FOG                   3    0     0      3
# REVOLVE               3    0     0      3
# G                     9    0     0      9
# APART                32    0     0     32
# RUSSIAN              12    0     0     12
# ALLIANCE              4    0     0      4
# FASCINATED           10    0     1     11
# MOLDOVA               5    0     0      5
# SPARKED               3    0     0      3
# MS                    8    0     0      8
# BEEN                607    0    12    619
# WISHED                5    0     0      5
# TAKE                478    0    19    497
# OURSELVES           126    0     3    129
# MAINTAIN              8    0     1      9
# MARROW                3    0     0      3
# SWEEP                 5    0     0      5
# POT                   3    0     0      3
# RENEWABLE             7    0     0      7
# EXERCISE             33    0     1     34
# WELFARE               5    0     0      5
# TIDE                  4    0     0      4
# STAND                55    0     4     59
# CLEVER                7    0     0      7
# DISAPPEARED           3    0     0      3
# MISERY                3    0     0      3
# HAROLD                3    0     0      3
# RAISE                29    0     1     30
# SURRENDER             6    0     0      6
# FAMILY              181    0     3    184
# STAY                 66    0     6     72
# DICTATOR              3    0     1      4
# COMPOUND              5    0     0      5
# TRASH                 5    0     1      6
# APPROXIMATION         3    0     0      3
# PESSIMIST             3    0     0      3
# VERSUS                9    0     0      9
# PREPARING             8    0     0      8
# CONFIDENTLY           4    0     0      4
# SIR                  11    0     0     11
# HONEST               23    0     1     24
# PASSPORT              4    0     0      4
# SPONGE                4    0     0      4
# ACRONYM               3    0     0      3
# MID                  10    0     0     10
# OLDER                33    0     0     33
# WEIGH                 9    0     0      9
# DISCOVERING           7    0     0      7
# DUTCH                 6    0     0      6
# MINUS                 7    0     0      7
# SOMEWHERE            51    0     1     52
# SCHIZOPHRENIA         9    0     0      9
# GONNA                16    0     0     16
# DUG                   5    0     0      5
# GRADE                35    0     0     35
# ...
# ISN'T                86    0     3     89
# APPRECIATION          8    0     0      8
# INTERPRETATION        3    0     0      3
# COLLAPSED             4    0     0      4
# CHILD'S               9    0     0      9
# RECALL                8    0     0      8
# NETWORK              50    0     2     52
# HOSTAGE               3    0     0      3
# DISASTER             14    0     0     14
# STRAIGHTFORWARD       4    0     0      4
# ISSUE               103    0     5    108
# BEE                  21    0     0     21
# REVOLUTIONARY         4    0     0      4
# SCULPTURE             3    0     1      4
# ESTABLISHED           5    0     0      5
# FOREST               25    0     1     26
# PIZZA                 4    0     1      5
# WORKFORCE             3    0     2      5
# ONE                1513    0    50   1563
# SEARCH               29    0     0     29
# NUCLEAR              16    0     1     17
# CONTAIN               5    0     0      5
# SOAP                  4    0     0      4
# KEEN                  4    0     0      4
# STRUCK                5    0     0      5
# REMARKABLY            5    0     0      5
# RANDOMLY              6    0     0      6
# HAWAIIANS             4    0     0      4
# GENITAL               4    0     0      4
# CROWD                 7    0     0      7
# JURISDICTION          3    0     0      3
# UK                   19    0     0     19
# PERMISSION           19    0     1     20
# TERRIBLE             40    0     2     42
# CLUSTER               4    0     1      5
# SOUNDSCAPE            4    0     0      4
# COMING              112    0     3    115
# SUBJECTIVE            3    0     0      3
# PLANNER               4    0     0      4
# MINING                5    0     0      5
# IRONIC                5    0     0      5
# D                    24    0     0     24
# ENABLE               12    0     0     12
# GROCERY               5    0     0      5
# RETURN               12    0     0     12
# GREAT               285    0    11    296
# INCREASING           10    0     0     10
# KNIT                  5    0     0      5
# SIMPLY               70    0     1     71
# CONFIDENT            14    0     0     14
# CLICHE                3    0     0      3
# LITER                 5    0     0      5
# ELEVATE               3    0     0      3
# LIKELIHOOD            4    0     0      4
# BLOOD                52    0     0     52
# REPEAT               12    0     0     12
# DISPOSAL              4    0     0      4
# BORROW                6    0     0      6
# HOLY                  8    0     2     10
# STRETCH               7    0     0      7
# WEBSITE              30    0     1     31
# NASTY                 6    0     1      7
# YESTERDAY            15    0     0     15
# NORM                  9    0     1     10
# USEFUL               16    0     2     18
# LASER                 5    0     0      5
# SE                    3    0     0      3
# EXAGGERATION          3    0     0      3
# LEGEND                7    0     0      7
# ABUSED                4    0     0      4
# SENT                 28    0     1     29
# UNLUCKY               3    0     0      3
# SMILING               3    0     1      4
# SQUARE               13    0     0     13
# NEEDING               3    0     0      3
# LAWYER               24    0     0     24
# HEAVY                 6    0     1      7
# EMPOWERED             6    0     0      6
# DEFINE               26    0     0     26
# BLIND                29    0     0     29
# LIP                   3    0     0      3
# ADULT                48    0     0     48
# AMBULANCE             4    0     0      4
# CHASING               4    0     0      4
# DISCOVERED           46    0     0     46
# FLORIDA               5    0     1      6
# REGRET                9    0     0      9
# THREAD                4    0     0      4
# GAME                100    0     3    103
# REUNITE               3    0     0      3
# UNBELIEVABLE          3    0     0      3
# AUGMENTED             3    0     0      3
# RENAISSANCE           4    0     0      4
# REDUCE               25    0     0     25
# COMMAND               6    0     0      6
# FIFTY                 4    0     0      4
# BLAST                 3    0     0      3
# TREE                 35    0     1     36
# ROTTEN                3    0     0      3
# CONSULTANT            5    0     0      5
# BEAR                 14    0     2     16
# PROMISE              28    0     0     28
# ENGINEER             29    0     0     29
# FUN                  47    0     2     49
# ACTIVITY             24    0     0     24
# SNOWDEN               4    0     0      4
# BOAT                 17    0     0     17
# OMEGA                 4    0     0      4
# FLOWING               3    0     0      3
# SLIP                  4    0     0      4
# ADDICTED              6    0     0      6
# CONSENT              16    0     0     16
# PERCEIVE             15    0     0     15
# EQUIVALENT            4    0     0      4
# PARADIGM              9    0     0      9
# LAVA                  3    0     0      3
# GRADUATION            3    0     0      3
# DOUBLED               4    0     0      4
# COHEN                 3    0     0      3
# EMPIRICAL             3    0     0      3
# CONGESTION            3    0     0      3
# CAROLINA              4    0     0      4
# TOOK                146    0     3    149
# GOLF                  5    0     0      5
# PHILOSOPHY           20    0     0     20
# MANUFACTURE           6    0     0      6
# PLANTED               5    0     0      5
# ISLAMIST              3    0     0      3
# VS                    4    0     0      4
# STRICT                3    0     0      3
# DOCTOR              101    0     4    105
# MUM                  10    0     0     10
# NORMAN                3    0     0      3
# CABLE                 6    0     0      6
# QUICK                12    0     0     12
# GONE                 54    0     3     57
# NAKED                 3    0     0      3
# EXPENSE               7    0     0      7
# DANCE                16    0     1     17
# HANGING               5    0     0      5
# LOSING               19    0     2     21
# FULFILLING            4    0     1      5
# POSE                  7    0     0      7
# COMMITTEE             4    0     0      4
# TOWARD               62    0     1     63
# DECENT                3    0     0      3
# WASHINGTON           13    0     0     13
# PRE                  12    0     1     13
# HORMONE              17    0     2     19
# WEAPON               19    0     1     20
# ABLE                273    0     6    279
# CRYSTALS              3    0     0      3
# MARK                 21    0     0     21
# COOPERATIVE           4    0     0      4
# ASTONISHED            3    0     0      3
# STRATEGIC             3    0     0      3
# BONUS                 3    0     0      3
# DEPEND               15    0     0     15
# MINISTER              8    0     0      8
# SERGIO                3    0     0      3
# EXPLAIN              53    0     0     53
# RELYING               3    0     0      3
# WORKPLACE             9    0     0      9
# NICE                 62    0     1     63
# UNLIKELY              4    0     0      4
# PULSE                 3    0     0      3
# UCLA                  4    0     0      4
# READ                105    0     2    107
# FELT                106    0     2    108
# ICE                  19    0     0     19
# FORTY                 5    0     0      5
# PRINCIPAL             5    0     0      5
# MODEL                94    0     0     94
# HERE'S               64    0     4     68
# DOES                283    0    16    299
# SELFISH               5    0     0      5
# SYNAPSES              3    0     0      3
# HORRIFYING            3    0     0      3
# UPRIGHT               3    0     0      3
# VOTING               14    0     0     14
# BROUGHT              47    0     2     49
# CONSUMED              4    0     0      4
# KEPT                 53    0     1     54
# PHOTO                23    0     1     24
# RANCHER               3    0     0      3
# UNKNOWN               7    0     0      7
# ONLY                464    0    12    476
# MIGRATION             5    0     1      6
# PRODUCER              6    0     0      6
# STAYED               16    0     0     16
# EMPOWERMENT           3    0     0      3
# VICTIM               37    0     0     37
# FULLY                19    0     1     20
# INSPIRED             37    0     1     38
# FILMING               5    0     0      5
# CORE                 18    0     1     19
# SYNDROME              9    0     0      9
# MARKET               59    0     1     60
# ADDICTIVE             5    0     0      5
# CONTRADICTION         3    0     2      5
# PUSH                 38    0     1     39
# MOBILE               29    0     2     31
# ITSELF               47    0     0     47
# OVERDOSE              4    0     0      4
# PRESCRIPTION          7    0     0      7
# NELSON                4    0     0      4
# ROYAL                 3    0     0      3
# NUDGING               3    0     0      3
# TACKLE               10    0     0     10
# JUDGEMENT             4    0     0      4
# APPLIED              14    0     0     14
# RATIONALE             3    0     0      3
# WEIRD                26    0     0     26
# COLLECTIVELY          5    0     0      5
# SLIPPED               4    0     0      4
# TRANSFERRED           5    0     0      5
# PINT                  3    0     0      3
# INDEED               25    0     1     26
# STANFORD              9    0     1     10
# COOPERATION           3    0     0      3
# IMPLANT               5    0     0      5
# DIVERSITY            19    0     0     19
# ARAB                  9    0     5     14
# SHOULD              270    0     8    278
# TRUSTING              3    0     0      3
# VOTE                 28    0     0     28
# BREEDING              4    0     1      5
# LEWIS                 3    0     0      3
# PERIOD               28    0     1     29
# ENCOUNTER             7    0     0      7
# WORRIES               5    0     0      5
# VOCABULARY            6    0     0      6
# JACK                  6    0     0      6
# YEAH                 61    0     1     62
# CORPORATION           6    0     0      6
# FAILED               22    0     0     22
# MET                  66    0     3     69
# MALE                 55    0     0     55
# DETECT                8    0     0      8
# HAVEN'T              52    0     2     54
# ROCKET                9    0     2     11
# ALREADY             135    0     1    136
# LINE                 71    0     2     73
# OXYGEN               16    0     2     18
# GHOST                 3    0     0      3
# IMPORTANT           262    0    12    274
# HIGHWAY               4    0     0      4
# SICK                 18    0     1     19
# WORD                206    0     4    210
# IMAGINATION          23    0     1     24
# SPARK                 3    0     0      3
# OWNED                 6    0     0      6
# TUNNEL                8    0     0      8
# ASTRONAUT             5    0     0      5
# HER                 397    0    11    408
# UNTRUE                3    0     0      3
# WIRED                 7    0     0      7
# LETTER               39    0     0     39
# APPROACHED            6    0     0      6
# CONNECTED            24    0     1     25
# ON                 1893    0    48   1941
# FARM                 23    0     1     24
# INTERVENE             4    0     0      4
# YES                  92    0     3     95
# COAST                10    0     0     10
# MIDST                 6    0     0      6
# TRACKING              3    0     0      3
# SEARCHING             7    0     0      7
# FORBIDDEN             3    0     0      3
# OK                  104    0     0    104
# KOSOVO                3    0     0      3
# AWARD                 7    0     1      8
# PEACH                 3    0     0      3
# ACCUMULATION          3    0     0      3
# SAM                   6    0     0      6
# COVERED              10    0     0     10
# CRYING               21    0     0     21
# MONASTERY             3    0     0      3
# HAMILTON              2    0     2      4
# VIOLENT              12    0     0     12
# CONTEST               3    0     0      3
# WILLINGNESS           5    0     0      5
# VOLUME               11    0     0     11
# M                    18    0     0     18
# NEWSPAPER            11    0     0     11
# TRADITIONAL          27    0     0     27
# DYNAMIC              20    0     0     20
# LIMIT                20    0     1     21
# TERM                110    0     2    112
# CORPSE                4    0     0      4
# INTO                521    0     5    526
# RATE                 60    0     2     62
# UNDERSTAND          203    0     6    209
# MANHOOD               3    0     0      3
# INNOVATE              7    0     0      7
# CAPITAL              18    0     0     18
# ALGEBRA               4    0     0      4
# MILD                  5    0     0      5
# COMMENT               8    0     0      8
# OAKLAND               3    0     0      3
# INSULT                3    0     0      3
# LIMITED              12    0     1     13
# MOOD                  7    0     0      7
# DIAGNOSE              8    0     0      8
# SAVED                12    0     0     12
# EMBODIMENT            3    0     0      3
# DEVELOPER             4    0     0      4
# TRANSLATING           4    0     0      4
# MOTHER              111    0     3    114
# THRILLED              3    0     0      3
# HITTING               3    0     1      4
# ENVIRONMENTAL        11    0     0     11
# SPIRITUALITY          4    0     0      4
# MINOR                 5    0     0      5
# INVENTOR              5    0     1      6
# GERMAN               17    0     0     17
# MIRACLE               5    0     0      5
# ASSET                 7    0     0      7
# BRIEFLY               7    0     0      7
# PAIN                 54    0     2     56
# DULL                  3    0     0      3
# AD                   10    0     1     11
# SHIP                  5    0     0      5
# AGREEMENT             5    0     0      5
# ACQUIRE               7    0     0      7
# DESPERATELY           6    0     2      8
# SOFTWARE             25    0     1     26
# EXPLODING             3    0     0      3
# SOCIETIES             6    0     0      6
# SEARCHES              4    0     0      4
# STORYTELLER           7    0     0      7
# ABDOMINAL             3    0     0      3
# DIGGING               3    0     0      3
# BULLET                7    0     0      7
# IN                 5560    0    95   5655
# CLUE                  6    0     0      6
# POEM                 23    0     0     23
# ATTRACTED             5    0     0      5
# REPAIR                4    0     0      4
# COPE                  8    0     0      8
# CONFUSING             6    0     0      6
# LESSON               33    0     1     34
# RESOLUTION            5    0     0      5
# CONTRAST              7    0     0      7
# KING                 17    0     1     18
# LGBT                  5    0     0      5
# REMOVING              3    0     0      3
# FROG                  7    0     0      7
# CONSUME              11    0     0     11
# SECRET               30    0     0     30
# BREAKING              7    0     0      7
# THOMAS                5    0     1      6
# FOLD                  8    0     0      8
# ADVERTISEMENT         5    0     0      5
# MUSTER                3    0     0      3
# GRANT                 9    0     0      9
# CLIMB                 7    0     0      7
# AM                  272    0    11    283
# TESTING              14    0     0     14
# HEARTBREAKING         3    0     0      3
# BOIL                  3    0     0      3
# ENJOY                26    0     1     27
# ANALYZED              3    0     0      3
# PURELY                6    0     0      6
# EXACT                26    0     2     28
# HETEROSEXUAL          9    0     0      9
# GERMANY              13    0     2     15
# EARLY                65    0     1     66
# CUTTING              14    0     1     15
# STILL               189    0     3    192
# BLAMED                3    0     0      3
# BRIGHT               14    0     2     16
# CHROMOSOME            5    0     0      5
# DISRUPT               4    0     0      4
# SPRING               14    0     0     14
# HUMOR                 8    0     0      8
# THIS               3363    0    95   3458
# MEAT                 14    0     0     14
# PROVIDER              4    0     0      4
# ACTIVE               18    0     0     18

# %%
# 7. All the words that have total = 4, and 3 is in train
# make it put 1 from train in the empty set
words_4_files_3_train = words_with_zeros[(words_with_zeros['total'] == 4) & (words_with_zeros['train'] == 3) ]
print(f"Number of words: {len(words_4_files_3_train)}")
print(words_4_files_3_train)
# Out:
# Number of words: 70
#                train  val  test  total
# LUTHER             3    0     1      4
# GEIGER             3    0     1      4
# METHANE            3    0     1      4
# WEALTHY            3    0     1      4
# SICKNESS           3    0     1      4
# UNCONDITIONAL      3    0     1      4
# UNEXPECTED         3    0     1      4
# FOOTPRINT          3    0     1      4
# EARNED             3    0     1      4
# DICTATOR           3    0     1      4
# BEIJING            3    0     1      4
# VIETNAM            3    0     1      4
# OUTRAGED           3    0     1      4
# NONSENSE           3    0     1      4
# IVY                3    0     1      4
# THIRTY             3    0     1      4
# STICKY             3    0     1      4
# DAN                3    0     1      4
# HEALER             3    0     1      4
# COMPLAIN           3    0     1      4
# COPYING            3    0     1      4
# JUNK               3    0     1      4
# DADDY              3    0     1      4
# INVADED            3    0     1      4
# ANNOYING           3    0     1      4
# TORN               3    0     1      4
# ROB                3    0     1      4
# GRID               3    0     1      4
# ACADEMY            3    0     1      4
# PHYSICIAN          3    0     1      4
# INSULIN            3    0     1      4
# INSPIRATIONAL      3    0     1      4
# SPIRAL             3    0     1      4
# INVESTOR           3    0     1      4
# CONTRIBUTING       3    0     1      4
# HARVEST            3    0     1      4
# SHINY              3    0     1      4
# ORIGINALLY         3    0     1      4
# FLIES              3    0     1      4
# BAKER              3    0     1      4
# SUSPENDED          3    0     1      4
# LUXURY             3    0     1      4
# SKIPPING           3    0     1      4
# TREK               3    0     1      4
# NEARBY             3    0     1      4
# MANHATTAN          3    0     1      4
# UNBELIEVABLY       3    0     1      4
# SETTLED            3    0     1      4
# CONVICTED          3    0     1      4
# CALCULATE          3    0     1      4
# MARKER             3    0     1      4
# CRITICISM          3    0     1      4
# PUNISH             3    0     1      4
# INSPIRING          3    0     1      4
# JELLYFISH          3    0     1      4
# SKIP               3    0     1      4
# MEMORABLE          3    0     1      4
# CONSTRAINED        3    0     1      4
# TERMINAL           3    0     1      4
# HAITI              3    0     1      4
# COVERAGE           3    0     1      4
# HARBOR             3    0     1      4
# CONFORM            3    0     1      4
# BLESSED            3    0     1      4
# MESSY              3    0     1      4
# POSTER             3    0     1      4
# CELLULAR           3    0     1      4
# SCULPTURE          3    0     1      4
# SMILING            3    0     1      4
# HITTING            3    0     1      4

# %%
moved = 0

for word in words_4_files_3_train.index:
    train_path = os.path.join(dir, word, 'train')
    val_path = os.path.join(dir, word, 'val')
    test_path = os.path.join(dir, word, 'test')

    # Determine which set is empty
    target_path = None
    if len(os.listdir(val_path)) == 0:
        target_path = val_path
    elif len(os.listdir(test_path)) == 0:
        target_path = test_path

    if target_path and os.path.exists(train_path):
        train_files = [f for f in os.listdir(train_path) if f.endswith('.mp4')]

        if len(train_files) == 3:
            # Select 1 file to move
            file_to_move = random.choice(train_files)

            src_npz = os.path.join(train_path, file_to_move)
            dst_npz = os.path.join(target_path, file_to_move)
            shutil.move(src_npz, dst_npz)
            # shutil.move(src_npz.replace(".npz", ".txt"), dst_npz.replace(".npz", ".txt"))

            print(f"Moved {file_to_move} from {train_path} to {target_path}")
            moved += 1

print(f"Total files moved: {moved}")
# Out:
# Moved LUTHER_eMdh57x1UBQ_50003.mp4 from ../lrs3_may/preprocessed_videos_all/LUTHER/train to ../lrs3_may/preprocessed_videos_all/LUTHER/val
# Moved GEIGER_BoRUrWcdkQ4_50010.mp4 from ../lrs3_may/preprocessed_videos_all/GEIGER/train to ../lrs3_may/preprocessed_videos_all/GEIGER/val
# Moved METHANE_wsIrdxDJpSQ_50004.mp4 from ../lrs3_may/preprocessed_videos_all/METHANE/train to ../lrs3_may/preprocessed_videos_all/METHANE/val
# Moved WEALTHY_aeiSXpmMQys_50020.mp4 from ../lrs3_may/preprocessed_videos_all/WEALTHY/train to ../lrs3_may/preprocessed_videos_all/WEALTHY/val
# Moved SICKNESS_QISHX5UKky0_50003.mp4 from ../lrs3_may/preprocessed_videos_all/SICKNESS/train to ../lrs3_may/preprocessed_videos_all/SICKNESS/val
# Moved UNCONDITIONAL_A71OktxTPac_50016.mp4 from ../lrs3_may/preprocessed_videos_all/UNCONDITIONAL/train to ../lrs3_may/preprocessed_videos_all/UNCONDITIONAL/val
# Moved UNEXPECTED_lnvkNGc6YYM_50005.mp4 from ../lrs3_may/preprocessed_videos_all/UNEXPECTED/train to ../lrs3_may/preprocessed_videos_all/UNEXPECTED/val
# Moved FOOTPRINT_1LSE7KCN9xg_50002.mp4 from ../lrs3_may/preprocessed_videos_all/FOOTPRINT/train to ../lrs3_may/preprocessed_videos_all/FOOTPRINT/val
# Moved EARNED_6XNrzmh0EVs_50011.mp4 from ../lrs3_may/preprocessed_videos_all/EARNED/train to ../lrs3_may/preprocessed_videos_all/EARNED/val
# Moved DICTATORS_5tUnSuoYKoE_50013.mp4 from ../lrs3_may/preprocessed_videos_all/DICTATOR/train to ../lrs3_may/preprocessed_videos_all/DICTATOR/val
# Moved BEIJING_8XQ1onjXJK0_50003.mp4 from ../lrs3_may/preprocessed_videos_all/BEIJING/train to ../lrs3_may/preprocessed_videos_all/BEIJING/val
# Moved VIETNAM_eNDhBSR1DZ0_50003.mp4 from ../lrs3_may/preprocessed_videos_all/VIETNAM/train to ../lrs3_may/preprocessed_videos_all/VIETNAM/val
# Moved OUTRAGED_0SW0HFy9Et4_50015.mp4 from ../lrs3_may/preprocessed_videos_all/OUTRAGED/train to ../lrs3_may/preprocessed_videos_all/OUTRAGED/val
# Moved NONSENSE_2Oe6HUgrRlQ_50008.mp4 from ../lrs3_may/preprocessed_videos_all/NONSENSE/train to ../lrs3_may/preprocessed_videos_all/NONSENSE/val
# Moved IVY_NjpXs8Ymr14_50005.mp4 from ../lrs3_may/preprocessed_videos_all/IVY/train to ../lrs3_may/preprocessed_videos_all/IVY/val
# Moved THIRTY_dRic5yJC8UY_50010.mp4 from ../lrs3_may/preprocessed_videos_all/THIRTY/train to ../lrs3_may/preprocessed_videos_all/THIRTY/val
# Moved STICKY_tkIgSSxPzTA_50002.mp4 from ../lrs3_may/preprocessed_videos_all/STICKY/train to ../lrs3_may/preprocessed_videos_all/STICKY/val
# Moved DAN_iE7YRHxwoDs_50006.mp4 from ../lrs3_may/preprocessed_videos_all/DAN/train to ../lrs3_may/preprocessed_videos_all/DAN/val
# Moved HEALERS_3phTundagzQ_50015.mp4 from ../lrs3_may/preprocessed_videos_all/HEALER/train to ../lrs3_may/preprocessed_videos_all/HEALER/val
# Moved COMPLAIN_bCGlWQnzDVE_50004.mp4 from ../lrs3_may/preprocessed_videos_all/COMPLAIN/train to ../lrs3_may/preprocessed_videos_all/COMPLAIN/val
# Moved COPYING_b4kSKPELNcc_50002.mp4 from ../lrs3_may/preprocessed_videos_all/COPYING/train to ../lrs3_may/preprocessed_videos_all/COPYING/val
# Moved JUNK_aUBawr1hUwo_50002.mp4 from ../lrs3_may/preprocessed_videos_all/JUNK/train to ../lrs3_may/preprocessed_videos_all/JUNK/val
# Moved DADDY_YsUAEFJsOdA_50006.mp4 from ../lrs3_may/preprocessed_videos_all/DADDY/train to ../lrs3_may/preprocessed_videos_all/DADDY/val
# Moved INVADED_SK095wuESeE_50003.mp4 from ../lrs3_may/preprocessed_videos_all/INVADED/train to ../lrs3_may/preprocessed_videos_all/INVADED/val
# Moved ANNOYING_hscdmpKGqrQ_50003.mp4 from ../lrs3_may/preprocessed_videos_all/ANNOYING/train to ../lrs3_may/preprocessed_videos_all/ANNOYING/val
# Moved TORN_gWPFJgLAzu4_50007.mp4 from ../lrs3_may/preprocessed_videos_all/TORN/train to ../lrs3_may/preprocessed_videos_all/TORN/val
# Moved ROB_oS4R8TG9e5Y_50001.mp4 from ../lrs3_may/preprocessed_videos_all/ROB/train to ../lrs3_may/preprocessed_videos_all/ROB/val
# Moved GRIDS_ZHOyfyGwpes_50001.mp4 from ../lrs3_may/preprocessed_videos_all/GRID/train to ../lrs3_may/preprocessed_videos_all/GRID/val
# Moved ACADEMY_4GKTEDqbQIw_50032.mp4 from ../lrs3_may/preprocessed_videos_all/ACADEMY/train to ../lrs3_may/preprocessed_videos_all/ACADEMY/val
# Moved PHYSICIAN_d5wfMNNr3ak_50011.mp4 from ../lrs3_may/preprocessed_videos_all/PHYSICIAN/train to ../lrs3_may/preprocessed_videos_all/PHYSICIAN/val
# Moved INSULIN_MF2Q6CcGN7E_50003.mp4 from ../lrs3_may/preprocessed_videos_all/INSULIN/train to ../lrs3_may/preprocessed_videos_all/INSULIN/val
# Moved INSPIRATIONAL_7TXEZ4tP06c_50011.mp4 from ../lrs3_may/preprocessed_videos_all/INSPIRATIONAL/train to ../lrs3_may/preprocessed_videos_all/INSPIRATIONAL/val
# Moved SPIRALS_M9pPgIraoOM_50003.mp4 from ../lrs3_may/preprocessed_videos_all/SPIRAL/train to ../lrs3_may/preprocessed_videos_all/SPIRAL/val
# Moved INVESTORS_ulLFP8axZVQ_50009.mp4 from ../lrs3_may/preprocessed_videos_all/INVESTOR/train to ../lrs3_may/preprocessed_videos_all/INVESTOR/val
# Moved CONTRIBUTING_2a2724wcfcc_50003.mp4 from ../lrs3_may/preprocessed_videos_all/CONTRIBUTING/train to ../lrs3_may/preprocessed_videos_all/CONTRIBUTING/val
# Moved HARVESTS_8Ug1MnU6LKw_50020.mp4 from ../lrs3_may/preprocessed_videos_all/HARVEST/train to ../lrs3_may/preprocessed_videos_all/HARVEST/val
# Moved SHINY_waRCSCQnoeY_50004.mp4 from ../lrs3_may/preprocessed_videos_all/SHINY/train to ../lrs3_may/preprocessed_videos_all/SHINY/val
# Moved ORIGINALLY_9ijS6iMi9gA_50005.mp4 from ../lrs3_may/preprocessed_videos_all/ORIGINALLY/train to ../lrs3_may/preprocessed_videos_all/ORIGINALLY/val
# Moved FLIES_P65XdTlk4vA_50002.mp4 from ../lrs3_may/preprocessed_videos_all/FLIES/train to ../lrs3_may/preprocessed_videos_all/FLIES/val
# Moved BAKER_d5wfMNNr3ak_50010.mp4 from ../lrs3_may/preprocessed_videos_all/BAKER/train to ../lrs3_may/preprocessed_videos_all/BAKER/val
# Moved SUSPENDED_bX32UShfri4_50012.mp4 from ../lrs3_may/preprocessed_videos_all/SUSPENDED/train to ../lrs3_may/preprocessed_videos_all/SUSPENDED/val
# Moved LUXURY_BwC4WRKi5QY_50003.mp4 from ../lrs3_may/preprocessed_videos_all/LUXURY/train to ../lrs3_may/preprocessed_videos_all/LUXURY/val
# Moved SKIPPING_SV2FB4ZmsTQ_50001.mp4 from ../lrs3_may/preprocessed_videos_all/SKIPPING/train to ../lrs3_may/preprocessed_videos_all/SKIPPING/val
# Moved TREK_eS44GSkE8lE_50001.mp4 from ../lrs3_may/preprocessed_videos_all/TREK/train to ../lrs3_may/preprocessed_videos_all/TREK/val
# Moved NEARBY_11Mq9ZuxZMc_50001.mp4 from ../lrs3_may/preprocessed_videos_all/NEARBY/train to ../lrs3_may/preprocessed_videos_all/NEARBY/val
# Moved MANHATTAN_JaFSfq2Zn7I_50006.mp4 from ../lrs3_may/preprocessed_videos_all/MANHATTAN/train to ../lrs3_may/preprocessed_videos_all/MANHATTAN/val
# Moved UNBELIEVABLY_sWN13pKVp9s_50022.mp4 from ../lrs3_may/preprocessed_videos_all/UNBELIEVABLY/train to ../lrs3_may/preprocessed_videos_all/UNBELIEVABLY/val
# Moved SETTLED_bClWV3eeETA_50009.mp4 from ../lrs3_may/preprocessed_videos_all/SETTLED/train to ../lrs3_may/preprocessed_videos_all/SETTLED/val
# Moved CONVICTED_H1fvr9rGgSg_50001.mp4 from ../lrs3_may/preprocessed_videos_all/CONVICTED/train to ../lrs3_may/preprocessed_videos_all/CONVICTED/val
# Moved CALCULATE_SPLooRl0PSU_50002.mp4 from ../lrs3_may/preprocessed_videos_all/CALCULATE/train to ../lrs3_may/preprocessed_videos_all/CALCULATE/val
# Moved MARKER_Lh9lDWPMWrM_50006.mp4 from ../lrs3_may/preprocessed_videos_all/MARKER/train to ../lrs3_may/preprocessed_videos_all/MARKER/val
# Moved CRITICISM_Lrdn4lazVBc_50004.mp4 from ../lrs3_may/preprocessed_videos_all/CRITICISM/train to ../lrs3_may/preprocessed_videos_all/CRITICISM/val
# Moved PUNISH_FTUpFYo0rMI_50009.mp4 from ../lrs3_may/preprocessed_videos_all/PUNISH/train to ../lrs3_may/preprocessed_videos_all/PUNISH/val
# Moved INSPIRING_qgv8VoyJ3wA_50002.mp4 from ../lrs3_may/preprocessed_videos_all/INSPIRING/train to ../lrs3_may/preprocessed_videos_all/INSPIRING/val
# Moved JELLYFISH_u0VHC1SDOS8_50005.mp4 from ../lrs3_may/preprocessed_videos_all/JELLYFISH/train to ../lrs3_may/preprocessed_videos_all/JELLYFISH/val
# Moved SKIP_vQILP19qABk_50003.mp4 from ../lrs3_may/preprocessed_videos_all/SKIP/train to ../lrs3_may/preprocessed_videos_all/SKIP/val
# Moved MEMORABLE_DnbC2Tii0S8_50009.mp4 from ../lrs3_may/preprocessed_videos_all/MEMORABLE/train to ../lrs3_may/preprocessed_videos_all/MEMORABLE/val
# Moved CONSTRAINED_nubSKdtzLcE_50006.mp4 from ../lrs3_may/preprocessed_videos_all/CONSTRAINED/train to ../lrs3_may/preprocessed_videos_all/CONSTRAINED/val
# Moved TERMINAL_yyW9W3e9VD0_50003.mp4 from ../lrs3_may/preprocessed_videos_all/TERMINAL/train to ../lrs3_may/preprocessed_videos_all/TERMINAL/val
# Moved HAITI_DkocjGrWwvc_50004.mp4 from ../lrs3_may/preprocessed_videos_all/HAITI/train to ../lrs3_may/preprocessed_videos_all/HAITI/val
# Moved COVERAGE_HjnclEhy960_50003.mp4 from ../lrs3_may/preprocessed_videos_all/COVERAGE/train to ../lrs3_may/preprocessed_videos_all/COVERAGE/val
# Moved HARBOR_SeQ8vdtSXB4_50011.mp4 from ../lrs3_may/preprocessed_videos_all/HARBOR/train to ../lrs3_may/preprocessed_videos_all/HARBOR/val
# Moved CONFORM_csnxJFQw98k_50003.mp4 from ../lrs3_may/preprocessed_videos_all/CONFORM/train to ../lrs3_may/preprocessed_videos_all/CONFORM/val
# Moved BLESSED_9YR8jNtV4BE_50011.mp4 from ../lrs3_may/preprocessed_videos_all/BLESSED/train to ../lrs3_may/preprocessed_videos_all/BLESSED/val
# Moved MESSY_TOSSkVIkY6A_50002.mp4 from ../lrs3_may/preprocessed_videos_all/MESSY/train to ../lrs3_may/preprocessed_videos_all/MESSY/val
# Moved POSTER_UJ7QaCFbizo_50006.mp4 from ../lrs3_may/preprocessed_videos_all/POSTER/train to ../lrs3_may/preprocessed_videos_all/POSTER/val
# Moved CELLULAR_73rUjrow5pI_50003.mp4 from ../lrs3_may/preprocessed_videos_all/CELLULAR/train to ../lrs3_may/preprocessed_videos_all/CELLULAR/val
# Moved SCULPTURE_MO0LSLY2hRA_50002.mp4 from ../lrs3_may/preprocessed_videos_all/SCULPTURE/train to ../lrs3_may/preprocessed_videos_all/SCULPTURE/val
# Moved SMILING_uHRG3Vr9qyI_50019.mp4 from ../lrs3_may/preprocessed_videos_all/SMILING/train to ../lrs3_may/preprocessed_videos_all/SMILING/val
# Moved HITTING_gmjSazFbpkA_50008.mp4 from ../lrs3_may/preprocessed_videos_all/HITTING/train to ../lrs3_may/preprocessed_videos_all/HITTING/val
# Total files moved: 70

# %%
# Check updated
updated_df = create_df(dir)
updated_words_4_files_3_train = updated_df[(updated_df['total'] == 4) & (updated_df['train'] == 3) ]
print(updated_words_4_files_3_train)
print(f"Number of words: {len(updated_words_4_files_3_train)}")
# Out:
# Empty DataFrame
# Columns: [train, val, test, total]
# Index: []
# Number of words: 0

# %%
# 9. All the words that have total = 4, and 2 is in train and 0 in val
# put 1 from test into val
# 10. All the words that have total = 4, and 2 is in train and 0 in test
# put 1 from val into test
words_4_files_2_test_2val = updated_df[(updated_df['total'] == 4) & (updated_df['train'] == 2) & (updated_df['test'] == 0) | (updated_df['total'] == 4) & (updated_df['train'] == 2) & (updated_df['val'] == 0)]
print(words_4_files_2_test_2val)
print(f"Number of words: {len(words_4_files_2_test_2val)}")
# Out:
#               train  val  test  total
# ASPIRE            2    0     2      4
# UPGRADE           2    0     2      4
# JEFFERSON         2    0     2      4
# CAPTURING         2    0     2      4
# MANIPULATION      2    0     2      4
# INTERFACE         2    0     2      4
# MOMENTUM          2    0     2      4
# HAMILTON          2    0     2      4
# Number of words: 8

# %%
moved = 0

for word in words_4_files_2_test_2val.index:
    test_path = os.path.join(dir, word, 'test')
    val_path = os.path.join(dir, word, 'val')

    if os.path.exists(test_path) and os.path.exists(val_path):
        test_files = [f for f in os.listdir(test_path) if f.endswith('.mp4')]
        val_files = [f for f in os.listdir(val_path) if f.endswith('.mp4')]

        # Case 1: If train = 2 and val = 0, move 1 file from test to val
        if len(test_files) == 2 and len(val_files) == 0:
            file_to_move = random.choice(test_files)
            
            src_npz = os.path.join(test_path, file_to_move)
            dst_npz = os.path.join(val_path, file_to_move)
            shutil.move(src_npz, dst_npz)
            #shutil.move(src_npz.replace(".npz", ".txt"), dst_npz.replace(".npz", ".txt"))

            print(f"Moved {file_to_move} from {test_path} to {val_path}")
            moved += 1

        # Case 2: If train = 2 and test = 0, move 1 file from val to test
        elif len(val_files) == 2 and len(test_files) == 0:
            file_to_move = random.choice(val_files)
            
            src_npz = os.path.join(val_path, file_to_move)
            dst_npz = os.path.join(test_path, file_to_move)
            shutil.move(src_npz, dst_npz)
            #shutil.move(src_npz.replace(".npz", ".txt"), dst_npz.replace(".npz", ".txt"))

            print(f"Moved {file_to_move} from {val_path} to {test_path}")
            moved += 1

print(f"Total files moved: {moved}")
# Out:
# Moved ASPIRE_YzGjO5aHShQ_00007.mp4 from ../lrs3_may/preprocessed_videos_all/ASPIRE/test to ../lrs3_may/preprocessed_videos_all/ASPIRE/val
# Moved UPGRADE_fxbCHn6gE3U_00005.mp4 from ../lrs3_may/preprocessed_videos_all/UPGRADE/test to ../lrs3_may/preprocessed_videos_all/UPGRADE/val
# Moved JEFFERSON_3uSQlcGCHUU_00017.mp4 from ../lrs3_may/preprocessed_videos_all/JEFFERSON/test to ../lrs3_may/preprocessed_videos_all/JEFFERSON/val
# Moved CAPTURING_mc0vhSseGk4_00001.mp4 from ../lrs3_may/preprocessed_videos_all/CAPTURING/test to ../lrs3_may/preprocessed_videos_all/CAPTURING/val
# Moved MANIPULATION_AO4In7d6XSc_00001.mp4 from ../lrs3_may/preprocessed_videos_all/MANIPULATION/test to ../lrs3_may/preprocessed_videos_all/MANIPULATION/val
# Moved INTERFACE_uzKBGtf0i0M_00004.mp4 from ../lrs3_may/preprocessed_videos_all/INTERFACE/test to ../lrs3_may/preprocessed_videos_all/INTERFACE/val
# Moved MOMENTUM_VIgzTLDyObo_00001.mp4 from ../lrs3_may/preprocessed_videos_all/MOMENTUM/test to ../lrs3_may/preprocessed_videos_all/MOMENTUM/val
# Moved HAMILTON_3uSQlcGCHUU_00017.mp4 from ../lrs3_may/preprocessed_videos_all/HAMILTON/test to ../lrs3_may/preprocessed_videos_all/HAMILTON/val
# Total files moved: 8

# %%
# Check updated
updated_df = create_df(dir)
updated_words_4_files_2_test_2val = updated_df[(updated_df['total'] == 4) & (updated_df['train'] == 2) & (updated_df['test'] == 0) | (updated_df['total'] == 4) & (updated_df['train'] == 2) & (updated_df['val'] == 0)]
print(updated_words_4_files_2_test_2val)
print(f"Number of words: {len(updated_words_4_files_2_test_2val)}")
# Out:
# Empty DataFrame
# Columns: [train, val, test, total]
# Index: []
# Number of words: 0

# %%
# 11. All the words that have total = 4, and 1 is in train
# move 1 from val to train and 1 to test
words_4_files_1_train = updated_df[(updated_df['total'] == 4) & (updated_df['train'] == 1)]
print(words_4_files_1_train)
print(f"Number of words: {len(words_4_files_1_train)}")
# Out:
# Empty DataFrame
# Columns: [train, val, test, total]
# Index: []
# Number of words: 0

# %%
moved = 0

for word in words_4_files_1_train.index:
    val_path = os.path.join(dir, word, 'val')
    train_path = os.path.join(dir, word, 'train')
    test_path = os.path.join(dir, word, 'test')

    if os.path.exists(val_path):
        val_files = [f for f in os.listdir(val_path) if f.endswith('.mp4')]
        
        if len(val_files) >= 2:
            os.makedirs(train_path, exist_ok=True)
            os.makedirs(test_path, exist_ok=True)

            # Move one file to train
            file_to_train = val_files.pop(random.randint(0, len(val_files) - 1))
            shutil.move(os.path.join(val_path, file_to_train), os.path.join(train_path, file_to_train))
            #shutil.move(os.path.join(val_path, file_to_train.replace(".npz", ".txt")),
                        #os.path.join(train_path, file_to_train.replace(".npz", ".txt")))
            
            # Move one file to test
            file_to_test = val_files.pop()
            shutil.move(os.path.join(val_path, file_to_test), os.path.join(test_path, file_to_test))
            #shutil.move(os.path.join(val_path, file_to_test.replace(".npz", ".txt")),
                        #os.path.join(test_path, file_to_test.replace(".npz", ".txt")))

            moved += 1

print(f"Total files moved: {moved}")

# %%
# Check updated
updated_df = create_df(dir)
updated_words_4_files_1_train = updated_df[(updated_df['total'] == 4) & (updated_df['train'] == 1)]
print(updated_words_4_files_1_train)
print(f"Number of words: {len(updated_words_4_files_1_train)}")
# Out:
# Empty DataFrame
# Columns: [train, val, test, total]
# Index: []
# Number of words: 0

# %%
# 12. All the words that have total = 5, and 4 is in train
# put 1 from train into the empty set
words_5_files_4_train = words_with_zeros[(words_with_zeros['total'] == 5) & (words_with_zeros['train'] == 4)]
print(words_5_files_4_train)
print(f"Number of words: {len(words_5_files_4_train)}")
# Out:
#                 train  val  test  total
# STAGGERING          4    0     1      5
# HUMANITARIAN        4    0     1      5
# DEMANDING           4    0     1      5
# MOORE'S             4    0     1      5
# COMPARISON          4    0     1      5
# HARNESS             4    0     1      5
# PROGRESSIVE         4    0     1      5
# MISSES              4    0     1      5
# BOSNIA              4    0     1      5
# EXAMINED            4    0     1      5
# TANK                4    0     1      5
# AUDIO               4    0     1      5
# ADOPT               4    0     1      5
# NAZI                4    0     1      5
# CRACKED             4    0     1      5
# COW                 4    0     1      5
# CRITICALLY          4    0     1      5
# SLOGAN              4    0     1      5
# LUMP                4    0     1      5
# SILICON             4    0     1      5
# REPLACEMENT         4    0     1      5
# GREENHOUSE          4    0     1      5
# PREDATOR            4    0     1      5
# DREAMED             4    0     1      5
# GORGEOUS            4    0     1      5
# WARN                4    0     1      5
# FISHING             4    0     1      5
# CAUTION             4    0     1      5
# DISCRIMINATE        4    0     1      5
# EXTERNAL            4    0     1      5
# BROADCAST           4    0     1      5
# MONITOR             4    0     1      5
# CHANNEL             4    0     1      5
# MOTIVE              4    0     1      5
# TOURISTS            4    0     1      5
# ORGANIZING          4    0     1      5
# BIZARRE             4    0     1      5
# SUSTAINABILITY      4    0     1      5
# FRIENDSHIP          4    0     1      5
# VETERAN             4    0     1      5
# BRAVERY             4    0     1      5
# ADMINISTER          4    0     1      5
# COMBINING           4    0     1      5
# COMPETE             4    0     1      5
# ACTIVATION          4    0     1      5
# TUNE                4    0     1      5
# PIZZA               4    0     1      5
# CLUSTER             4    0     1      5
# FULFILLING          4    0     1      5
# BREEDING            4    0     1      5
# Number of words: 50

# %%
moved = 0

for word in words_5_files_4_train.index:
    train_path = os.path.join(dir, word, 'train')
    val_path = os.path.join(dir, word, 'val')
    test_path = os.path.join(dir, word, 'test')

    train_files = [f for f in os.listdir(train_path) if f.endswith('.mp4')]
    val_files = [f for f in os.listdir(val_path) if f.endswith('.mp4')]
    test_files = [f for f in os.listdir(test_path) if f.endswith('.mp4')]

    if len(train_files) >= 1:
        file_to_move = random.choice(train_files)

        # Move to the empty set (prioritize val, then test)
        if len(val_files) == 0:
            dst_path = val_path
        elif len(test_files) == 0:
            dst_path = test_path
        else:
            continue  # Skip if both val and test are non-empty

        # Ensure the destination directory exists
        os.makedirs(dst_path, exist_ok=True)

        # Move both .npz and .txt files
        shutil.move(os.path.join(train_path, file_to_move), os.path.join(dst_path, file_to_move))
        #shutil.move(os.path.join(train_path, file_to_move.replace(".npz", ".txt")), 
                    #os.path.join(dst_path, file_to_move.replace(".npz", ".txt")))

        print(f"Moved {file_to_move} from {train_path} to {dst_path}")
        moved += 1

print(f"Total files moved: {moved}")
# Out:
# Moved STAGGERING_BBSVLGf7zPI_50001.mp4 from ../lrs3_may/preprocessed_videos_all/STAGGERING/train to ../lrs3_may/preprocessed_videos_all/STAGGERING/val
# Moved HUMANITARIAN_4N5N0pQUFbI_50001.mp4 from ../lrs3_may/preprocessed_videos_all/HUMANITARIAN/train to ../lrs3_may/preprocessed_videos_all/HUMANITARIAN/val
# Moved DEMANDING_Df2JBnql8lc_50005.mp4 from ../lrs3_may/preprocessed_videos_all/DEMANDING/train to ../lrs3_may/preprocessed_videos_all/DEMANDING/val
# Moved MOORE'S_APgMXDjLcT4_50006_2.mp4 from ../lrs3_may/preprocessed_videos_all/MOORE'S/train to ../lrs3_may/preprocessed_videos_all/MOORE'S/val
# Moved COMPARISON_qQDC7c2I8l8_50006.mp4 from ../lrs3_may/preprocessed_videos_all/COMPARISON/train to ../lrs3_may/preprocessed_videos_all/COMPARISON/val
# Moved HARNESS_0FQXicAGy5U_50008.mp4 from ../lrs3_may/preprocessed_videos_all/HARNESS/train to ../lrs3_may/preprocessed_videos_all/HARNESS/val
# Moved PROGRESSIVE_tTvIEUGCigk_50003.mp4 from ../lrs3_may/preprocessed_videos_all/PROGRESSIVE/train to ../lrs3_may/preprocessed_videos_all/PROGRESSIVE/val
# Moved MISSES_VehHPwAVL9g_50005.mp4 from ../lrs3_may/preprocessed_videos_all/MISSES/train to ../lrs3_may/preprocessed_videos_all/MISSES/val
# Moved BOSNIA_tiWwrdMqvvM_50001.mp4 from ../lrs3_may/preprocessed_videos_all/BOSNIA/train to ../lrs3_may/preprocessed_videos_all/BOSNIA/val
# Moved EXAMINED_wSF82AwSDiU_50003.mp4 from ../lrs3_may/preprocessed_videos_all/EXAMINED/train to ../lrs3_may/preprocessed_videos_all/EXAMINED/val
# Moved TANK_501FEzbB1JI_50017.mp4 from ../lrs3_may/preprocessed_videos_all/TANK/train to ../lrs3_may/preprocessed_videos_all/TANK/val
# Moved AUDIO_2NENlXsW4pM_50007.mp4 from ../lrs3_may/preprocessed_videos_all/AUDIO/train to ../lrs3_may/preprocessed_videos_all/AUDIO/val
# Moved ADOPT_CypPMzZinys_50009.mp4 from ../lrs3_may/preprocessed_videos_all/ADOPT/train to ../lrs3_may/preprocessed_videos_all/ADOPT/val
# Moved NAZI_IHyR7p6Shn0_50037.mp4 from ../lrs3_may/preprocessed_videos_all/NAZI/train to ../lrs3_may/preprocessed_videos_all/NAZI/val
# Moved CRACKED_cnxEP6bzg7o_50001.mp4 from ../lrs3_may/preprocessed_videos_all/CRACKED/train to ../lrs3_may/preprocessed_videos_all/CRACKED/val
# Moved COWS_oeL72c6scAs_50002.mp4 from ../lrs3_may/preprocessed_videos_all/COW/train to ../lrs3_may/preprocessed_videos_all/COW/val
# Moved CRITICALLY_VoCOzuWOgSY_50022.mp4 from ../lrs3_may/preprocessed_videos_all/CRITICALLY/train to ../lrs3_may/preprocessed_videos_all/CRITICALLY/val
# Moved SLOGANS_6weGCM3sWKc_50001.mp4 from ../lrs3_may/preprocessed_videos_all/SLOGAN/train to ../lrs3_may/preprocessed_videos_all/SLOGAN/val
# Moved LUMP_2j00U6lUCSc_50016.mp4 from ../lrs3_may/preprocessed_videos_all/LUMP/train to ../lrs3_may/preprocessed_videos_all/LUMP/val
# Moved SILICON_LH8MPbFoRjw_50012.mp4 from ../lrs3_may/preprocessed_videos_all/SILICON/train to ../lrs3_may/preprocessed_videos_all/SILICON/val
# Moved REPLACEMENT_sPQViNNOAkw_50006.mp4 from ../lrs3_may/preprocessed_videos_all/REPLACEMENT/train to ../lrs3_may/preprocessed_videos_all/REPLACEMENT/val
# Moved GREENHOUSE_3QZp6smeSQA_50004.mp4 from ../lrs3_may/preprocessed_videos_all/GREENHOUSE/train to ../lrs3_may/preprocessed_videos_all/GREENHOUSE/val
# Moved PREDATOR_jv8m8rycnQs_50005.mp4 from ../lrs3_may/preprocessed_videos_all/PREDATOR/train to ../lrs3_may/preprocessed_videos_all/PREDATOR/val
# Moved DREAMED_2W1jvTEjc1s_50004.mp4 from ../lrs3_may/preprocessed_videos_all/DREAMED/train to ../lrs3_may/preprocessed_videos_all/DREAMED/val
# Moved GORGEOUS_B4xOFsygwr4_50024.mp4 from ../lrs3_may/preprocessed_videos_all/GORGEOUS/train to ../lrs3_may/preprocessed_videos_all/GORGEOUS/val
# Moved WARN_bvAEJ8G9l9U_50007.mp4 from ../lrs3_may/preprocessed_videos_all/WARN/train to ../lrs3_may/preprocessed_videos_all/WARN/val
# Moved FISHING_SjaWs87t5UM_50001.mp4 from ../lrs3_may/preprocessed_videos_all/FISHING/train to ../lrs3_may/preprocessed_videos_all/FISHING/val
# Moved CAUTION_AGivotqSrd0_50021.mp4 from ../lrs3_may/preprocessed_videos_all/CAUTION/train to ../lrs3_may/preprocessed_videos_all/CAUTION/val
# Moved DISCRIMINATE_Ytw0I6ytRto_50008.mp4 from ../lrs3_may/preprocessed_videos_all/DISCRIMINATE/train to ../lrs3_may/preprocessed_videos_all/DISCRIMINATE/val
# Moved EXTERNAL_E0M1beV91js_50006.mp4 from ../lrs3_may/preprocessed_videos_all/EXTERNAL/train to ../lrs3_may/preprocessed_videos_all/EXTERNAL/val
# Moved BROADCAST_quJdL9ggETI_50005.mp4 from ../lrs3_may/preprocessed_videos_all/BROADCAST/train to ../lrs3_may/preprocessed_videos_all/BROADCAST/val
# Moved MONITOR_HAKea48B3oM_50008.mp4 from ../lrs3_may/preprocessed_videos_all/MONITOR/train to ../lrs3_may/preprocessed_videos_all/MONITOR/val
# Moved CHANNELS_KxDwieKpawg_50003.mp4 from ../lrs3_may/preprocessed_videos_all/CHANNEL/train to ../lrs3_may/preprocessed_videos_all/CHANNEL/val
# Moved MOTIVE_rugSZIFY7mc_50016.mp4 from ../lrs3_may/preprocessed_videos_all/MOTIVE/train to ../lrs3_may/preprocessed_videos_all/MOTIVE/val
# Moved TOURISTS_sBaiRpIpPKQ_50012.mp4 from ../lrs3_may/preprocessed_videos_all/TOURISTS/train to ../lrs3_may/preprocessed_videos_all/TOURISTS/val
# Moved ORGANIZING_ImmtTHYU5GQ_50001.mp4 from ../lrs3_may/preprocessed_videos_all/ORGANIZING/train to ../lrs3_may/preprocessed_videos_all/ORGANIZING/val
# Moved BIZARRE_VfKWd7iXMSo_50016.mp4 from ../lrs3_may/preprocessed_videos_all/BIZARRE/train to ../lrs3_may/preprocessed_videos_all/BIZARRE/val
# Moved SUSTAINABILITY_SSJkV8IzsZA_50004.mp4 from ../lrs3_may/preprocessed_videos_all/SUSTAINABILITY/train to ../lrs3_may/preprocessed_videos_all/SUSTAINABILITY/val
# Moved FRIENDSHIP_ZVRbSuY3h9w_50005.mp4 from ../lrs3_may/preprocessed_videos_all/FRIENDSHIP/train to ../lrs3_may/preprocessed_videos_all/FRIENDSHIP/val
# Moved VETERANS_SwMTKRixZIE_50012.mp4 from ../lrs3_may/preprocessed_videos_all/VETERAN/train to ../lrs3_may/preprocessed_videos_all/VETERAN/val
# Moved BRAVERY_xbagFzcyNiM_50018.mp4 from ../lrs3_may/preprocessed_videos_all/BRAVERY/train to ../lrs3_may/preprocessed_videos_all/BRAVERY/val
# Moved ADMINISTER_IkJTwfHPv6A_50001.mp4 from ../lrs3_may/preprocessed_videos_all/ADMINISTER/train to ../lrs3_may/preprocessed_videos_all/ADMINISTER/val
# Moved COMBINING_dskNubEgzCk_50008.mp4 from ../lrs3_may/preprocessed_videos_all/COMBINING/train to ../lrs3_may/preprocessed_videos_all/COMBINING/val
# Moved COMPETE_3F2jACWwKdU_50004.mp4 from ../lrs3_may/preprocessed_videos_all/COMPETE/train to ../lrs3_may/preprocessed_videos_all/COMPETE/val
# Moved ACTIVATION_hqQSTqVNnOY_50014.mp4 from ../lrs3_may/preprocessed_videos_all/ACTIVATION/train to ../lrs3_may/preprocessed_videos_all/ACTIVATION/val
# Moved TUNES_2KSP7HvSZwg_50003.mp4 from ../lrs3_may/preprocessed_videos_all/TUNE/train to ../lrs3_may/preprocessed_videos_all/TUNE/val
# Moved PIZZA_I64CQp6z0Pk_50003.mp4 from ../lrs3_may/preprocessed_videos_all/PIZZA/train to ../lrs3_may/preprocessed_videos_all/PIZZA/val
# Moved CLUSTERS_gXvblfSgwg4_50008.mp4 from ../lrs3_may/preprocessed_videos_all/CLUSTER/train to ../lrs3_may/preprocessed_videos_all/CLUSTER/val
# Moved FULFILLING_6MBaFL7sCb8_50040_2.mp4 from ../lrs3_may/preprocessed_videos_all/FULFILLING/train to ../lrs3_may/preprocessed_videos_all/FULFILLING/val
# Moved BREEDING_8b2vNkEtfpc_50013.mp4 from ../lrs3_may/preprocessed_videos_all/BREEDING/train to ../lrs3_may/preprocessed_videos_all/BREEDING/val
# Total files moved: 50

# %%
# Check updated
updated_df = create_df(dir)
updated_words_5_files_4_train = updated_df[(updated_df['total'] == 5) & (updated_df['train'] == 4)]
print(updated_words_5_files_4_train)
print(f"Number of words: {len(updated_words_5_files_4_train)}")
# Out:
# Empty DataFrame
# Columns: [train, val, test, total]
# Index: []
# Number of words: 0

# %%
# 13. All the words that have total = 5, and 3 is in train and test is empty
# put 1 from val into test
# 14. All the words that have total = 5, and 3 is in train and val is empty
# put 1 from test into val
words_5_files_0_testval = words_with_zeros[(updated_df['total'] == 5) & (updated_df['train'] == 3) & (updated_df['test'] == 0) | (updated_df['total'] == 5) & (updated_df['train'] == 3) & (updated_df['val'] == 0)]
print(words_5_files_0_testval)
print(f"Number of words: {len(words_5_files_0_testval)}")
# Out:
#                train  val  test  total
# SUPPORTED          3    0     2      5
# WORKFORCE          3    0     2      5
# CONTRADICTION      3    0     2      5
# Number of words: 3

# %%
moved = 0

for word in words_5_files_0_testval.index:
    val_path = os.path.join(dir, word, 'val')
    test_path = os.path.join(dir, word, 'test')

    val_files = [f for f in os.listdir(val_path) if f.endswith('.mp4')]
    test_files = [f for f in os.listdir(test_path) if f.endswith('.mp4')]

    # Case 1: Test is empty → Move 1 file from val to test
    if len(test_files) == 0 and len(val_files) == 2:
        file_to_move = random.choice(val_files)

        os.makedirs(test_path, exist_ok=True)

        shutil.move(os.path.join(val_path, file_to_move), os.path.join(test_path, file_to_move))
        #shutil.move(os.path.join(val_path, file_to_move.replace(".npz", ".txt")), 
                   # os.path.join(test_path, file_to_move.replace(".npz", ".txt")))

        print(f"Moved {file_to_move} from {val_path} to {test_path}")
        moved += 1

    # Case 2: Val is empty → Move 1 file from test to val
    elif len(val_files) == 0 and len(test_files) == 2:
        file_to_move = random.choice(test_files)

        os.makedirs(val_path, exist_ok=True)  # Ensure val folder exists

        shutil.move(os.path.join(test_path, file_to_move), os.path.join(val_path, file_to_move))
        #shutil.move(os.path.join(test_path, file_to_move.replace(".npz", ".txt")), 
                   # os.path.join(val_path, file_to_move.replace(".npz", ".txt")))

        print(f"Moved {file_to_move} from {test_path} to {val_path}")
        moved += 1

print(f"Total files moved: {moved}")
# Out:
# Moved SUPPORTED_87AEeLpodnE_00001.mp4 from ../lrs3_may/preprocessed_videos_all/SUPPORTED/test to ../lrs3_may/preprocessed_videos_all/SUPPORTED/val
# Moved WORKFORCE_AegIbt2j0sU_00001.mp4 from ../lrs3_may/preprocessed_videos_all/WORKFORCE/test to ../lrs3_may/preprocessed_videos_all/WORKFORCE/val
# Moved CONTRADICTIONS_FxtSMZKMdes_00005.mp4 from ../lrs3_may/preprocessed_videos_all/CONTRADICTION/test to ../lrs3_may/preprocessed_videos_all/CONTRADICTION/val
# Total files moved: 3

# %%
updated_df = create_df(dir)
updated_words_5_files_0_testval = updated_df[(updated_df['total'] == 5) & (updated_df['train'] == 3) & (updated_df['test'] == 0) | (updated_df['total'] == 5) & (updated_df['train'] == 3) & (updated_df['val'] == 0)]
print(updated_words_5_files_0_testval)
print(f"Number of words: {len(updated_words_5_files_0_testval)}")
# Out:
# Empty DataFrame
# Columns: [train, val, test, total]
# Index: []
# Number of words: 0

# %%
# 14. All the words that have total = 5, and 2 is in train
# put 1 from val to train and 1 to test
words_5_files_2_train = updated_df[(updated_df['total'] == 5) & (updated_df['train'] == 2)]
print(f"Number of words: {len(words_5_files_2_train)}")
print(words_5_files_2_train)
# Out:
# Number of words: 0
# Empty DataFrame
# Columns: [train, val, test, total]
# Index: []

# %%
moved_to_train = 0
moved_to_test = 0

for word in words_5_files_2_train.index:
    val_path = os.path.join(dir, word, 'val')
    train_path = os.path.join(dir, word, 'train')
    test_path = os.path.join(dir, word, 'test')

    val_files = [f for f in os.listdir(val_path) if f.endswith('.npz')] if os.path.exists(val_path) else []

    # Move 1 file from val → train
    if len(val_files) > 1:  # Ensure at least 2 files in val
        file_to_move = random.choice(val_files)

        os.makedirs(train_path, exist_ok=True)  # Ensure train folder exists

        shutil.move(os.path.join(val_path, file_to_move), os.path.join(train_path, file_to_move))
        shutil.move(os.path.join(val_path, file_to_move.replace(".npz", ".txt")), 
                    os.path.join(train_path, file_to_move.replace(".npz", ".txt")))

        print(f"Moved {file_to_move} from {val_path} to {train_path}")
        moved_to_train += 1

        val_files.remove(file_to_move)  # Update remaining val files

    # Move 1 file from val → test
    if len(val_files) > 0:  # Ensure at least 1 file remains in val
        file_to_move = random.choice(val_files)

        os.makedirs(test_path, exist_ok=True)  # Ensure test folder exists

        shutil.move(os.path.join(val_path, file_to_move), os.path.join(test_path, file_to_move))
        shutil.move(os.path.join(val_path, file_to_move.replace(".npz", ".txt")), 
                    os.path.join(test_path, file_to_move.replace(".npz", ".txt")))

        print(f"Moved {file_to_move} from {val_path} to {test_path}")
        moved_to_test += 1

print(f"Total files moved: {moved_to_train} to train, {moved_to_test} to test")

# %%
# Check updated
updated_df = create_df(dir)
updated_words_5_files_2_train = updated_df[(updated_df['total'] == 5) & (updated_df['train'] == 2)]
print(f"Number of words: {len(updated_words_5_files_2_train)}")
print(updated_words_5_files_2_train)
# Out:
# Number of words: 0
# Empty DataFrame
# Columns: [train, val, test, total]
# Index: []

# %%
# Check where test set >= train
# Move 1 to train and 1 to val
updated_words_test_higher = updated_df[(updated_df['test'] >= updated_df['train'])]
print(f"Number of words: {len(updated_words_test_higher)}")
print(updated_words_test_higher)
# Out:
# Number of words: 1
#          train  val  test  total
# TEXTING      3    0     3      6

# %%
moved_to_train = 0
moved_to_val = 0

for word in updated_words_test_higher.index:
    val_path = os.path.join(dir, word, 'val')
    train_path = os.path.join(dir, word, 'train')
    test_path = os.path.join(dir, word, 'test')

    test_files = [f for f in os.listdir(test_path) if f.endswith('.mp4')] if os.path.exists(test_path) else []
    '''
    # Move 1 file from test → train
    if len(test_path) > 1:  # Ensure at least 2 files in test
        file_to_move = random.choice(test_files)

        os.makedirs(train_path, exist_ok=True)

        shutil.move(os.path.join(test_path, file_to_move), os.path.join(train_path, file_to_move))
        #shutil.move(os.path.join(test_path, file_to_move.replace(".npz", ".txt")), 
                    #os.path.join(train_path, file_to_move.replace(".npz", ".txt")))

        print(f"Moved {file_to_move} from {test_path} to {train_path}")
        moved_to_train += 1

        test_files.remove(file_to_move)  # Update remaining val files
    '''
    # Move 1 file from test → val
    if len(test_path) > 0:  # Ensure at least 1 file remains in test
        file_to_move = random.choice(test_files)

        os.makedirs(val_path, exist_ok=True)

        shutil.move(os.path.join(test_path, file_to_move), os.path.join(val_path, file_to_move))
        #shutil.move(os.path.join(test_path, file_to_move.replace(".npz", ".txt")), 
                    #os.path.join(val_path, file_to_move.replace(".npz", ".txt")))

        print(f"Moved {file_to_move} from {test_path} to {val_path}")
        test_files += 1
    
print(f"Total files moved: {moved_to_train} to train, {moved_to_val} to test")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 13
#      11 # Move 1 file from test → train
#      12 if len(test_path) > 1:  # Ensure at least 2 files in test
# ---> 13     file_to_move = random.choice(test_files)
#      15     os.makedirs(train_path, exist_ok=True)
#      17     shutil.move(os.path.join(val_path, file_to_move), os.path.join(train_path, file_to_move))
#
# File /opt/tljh/user/lib/python3.10/random.py:378, in Random.choice(self, seq)
#     376 """Choose a random element from a non-empty sequence."""
#     377 # raises IndexError if seq is empty
# --> 378 return seq[self._randbelow(len(seq))]
#
# IndexError: list index out of range

# %%
# Check updated
updated_df = create_df(dir)
updated_words_test_higher = updated_df[(updated_df['test'] >= updated_df['train'])]
print(f"Number of words: {len(updated_words_test_higher)}")
print(updated_words_test_higher)
# Out:
# Number of words: 0
# Empty DataFrame
# Columns: [train, val, test, total]
# Index: []

# %%
print(updated_df.loc["TEXTING"])
# Out:
# train    4
# val      1
# test     1
# total    6
# Name: TEXTING, dtype: int64

# %%
# Duplicate folder for checkpoint
source_folder = "../lrs3_may/preprocessed_videos_all"
destination_folder = "../lrs3_may/preprocessed_videos_all_copy"

if not os.path.exists(destination_folder):
    shutil.copytree(source_folder, destination_folder)
    print(f"Copied {source_folder} to {destination_folder}")
else:
    print(f"Destination folder '{destination_folder}' already exists!")
# Out:
# Copied ../lrs3_may/preprocessed_videos_all to ../lrs3_may/preprocessed_videos_all_copy

# %%
# Skip words with proper splits
updated_skip_words = updated_df[
    ((updated_df['total'] == 4) & (updated_df['train'] == 2) & (updated_df['val'] == 1)) |
    ((updated_df['total'] == 5) & (updated_df['train'] == 3) & (updated_df['val'] == 1)) |
    ((updated_df['total'] == 6) & (updated_df['train'] == 4) & (updated_df['val'] == 1))
]
print(updated_skip_words)
# Out:
#                 train  val  test  total
# STAGGERING          3    1     1      5
# HUMANITARIAN        3    1     1      5
# TEXTING             4    1     1      6
# LUTHER              2    1     1      4
# GEIGER              2    1     1      4
# DEMANDING           3    1     1      5
# METHANE             2    1     1      4
# MOORE'S             3    1     1      5
# COMPARISON          3    1     1      5
# WEALTHY             2    1     1      4
# SICKNESS            2    1     1      4
# ASPIRE              2    1     1      4
# UPGRADE             2    1     1      4
# UNCONDITIONAL       2    1     1      4
# UNEXPECTED          2    1     1      4
# HARNESS             3    1     1      5
# FOOTPRINT           2    1     1      4
# PROGRESSIVE         3    1     1      5
# MISSES              3    1     1      5
# EARNED              2    1     1      4
# DICTATOR            2    1     1      4
# BEIJING             2    1     1      4
# VIETNAM             2    1     1      4
# BOSNIA              3    1     1      5
# EXAMINED            3    1     1      5
# TANK                3    1     1      5
# AUDIO               3    1     1      5
# ADOPT               3    1     1      5
# NAZI                3    1     1      5
# OUTRAGED            2    1     1      4
# NONSENSE            2    1     1      4
# IVY                 2    1     1      4
# THIRTY              2    1     1      4
# STICKY              2    1     1      4
# JEFFERSON           2    1     1      4
# CAPTURING           2    1     1      4
# DAN                 2    1     1      4
# CRACKED             3    1     1      5
# COW                 3    1     1      5
# CRITICALLY          3    1     1      5
# HEALER              2    1     1      4
# COMPLAIN            2    1     1      4
# COPYING             2    1     1      4
# JUNK                2    1     1      4
# SLOGAN              3    1     1      5
# DADDY               2    1     1      4
# INVADED             2    1     1      4
# ANNOYING            2    1     1      4
# SUPPORTED           3    1     1      5
# TORN                2    1     1      4
# ROB                 2    1     1      4
# GRID                2    1     1      4
# LUMP                3    1     1      5
# SILICON             3    1     1      5
# ACADEMY             2    1     1      4
# PHYSICIAN           2    1     1      4
# REPLACEMENT         3    1     1      5
# GREENHOUSE          3    1     1      5
# INSULIN             2    1     1      4
# INSPIRATIONAL       2    1     1      4
# PREDATOR            3    1     1      5
# SPIRAL              2    1     1      4
# INVESTOR            2    1     1      4
# CONTRIBUTING        2    1     1      4
# HARVEST             2    1     1      4
# SHINY               2    1     1      4
# ORIGINALLY          2    1     1      4
# DREAMED             3    1     1      5
# FLIES               2    1     1      4
# BAKER               2    1     1      4
# SUSPENDED           2    1     1      4
# LUXURY              2    1     1      4
# SKIPPING            2    1     1      4
# GORGEOUS            3    1     1      5
# WARN                3    1     1      5
# FISHING             3    1     1      5
# CAUTION             3    1     1      5
# TREK                2    1     1      4
# DISCRIMINATE        3    1     1      5
# NEARBY              2    1     1      4
# MANIPULATION        2    1     1      4
# MANHATTAN           2    1     1      4
# UNBELIEVABLY        2    1     1      4
# SETTLED             2    1     1      4
# CONVICTED           2    1     1      4
# EXTERNAL            3    1     1      5
# BROADCAST           3    1     1      5
# CALCULATE           2    1     1      4
# MONITOR             3    1     1      5
# CHANNEL             3    1     1      5
# MOTIVE              3    1     1      5
# TOURISTS            3    1     1      5
# ORGANIZING          3    1     1      5
# BIZARRE             3    1     1      5
# MARKER              2    1     1      4
# SUSTAINABILITY      3    1     1      5
# CRITICISM           2    1     1      4
# PUNISH              2    1     1      4
# FRIENDSHIP          3    1     1      5
# VETERAN             3    1     1      5
# INSPIRING           2    1     1      4
# BRAVERY             3    1     1      5
# ADMINISTER          3    1     1      5
# INTERFACE           2    1     1      4
# JELLYFISH           2    1     1      4
# SKIP                2    1     1      4
# MEMORABLE           2    1     1      4
# CONSTRAINED         2    1     1      4
# COMBINING           3    1     1      5
# TERMINAL            2    1     1      4
# HAITI               2    1     1      4
# COVERAGE            2    1     1      4
# HARBOR              2    1     1      4
# CONFORM             2    1     1      4
# COMPETE             3    1     1      5
# ACTIVATION          3    1     1      5
# MOMENTUM            2    1     1      4
# TUNE                3    1     1      5
# BLESSED             2    1     1      4
# MESSY               2    1     1      4
# POSTER              2    1     1      4
# CELLULAR            2    1     1      4
# SCULPTURE           2    1     1      4
# PIZZA               3    1     1      5
# WORKFORCE           3    1     1      5
# CLUSTER             3    1     1      5
# SMILING             2    1     1      4
# FULFILLING          3    1     1      5
# CONTRADICTION       3    1     1      5
# BREEDING            3    1     1      5
# HAMILTON            2    1     1      4
# HITTING             2    1     1      4

# %%
for word in os.listdir(dir):  
    if word in updated_skip_words.index:  # Skip words that are in the skip list
        print(f"Skipping {word}, already properly split.")
        continue

    train_folder = os.path.join(dir, word, 'train')
    val_folder = os.path.join(dir, word, 'val')
    test_folder = os.path.join(dir, word, 'test')

    os.makedirs(train_folder, exist_ok=True)
    os.makedirs(val_folder, exist_ok=True)
    os.makedirs(test_folder, exist_ok=True)
    # Collect all .npz files
    train_files = [os.path.join(train_folder, f) for f in os.listdir(train_folder) if f.endswith('.mp4')]
    val_files = [os.path.join(val_folder, f) for f in os.listdir(val_folder) if f.endswith('.mp4')]
    test_files = [os.path.join(test_folder, f) for f in os.listdir(test_folder) if f.endswith('.mp4')]

    # Get total file count
    total_files = len(train_files) + len(val_files) + len(test_files)

    # Calculate the ideal split
    target_train = round(0.7 * total_files)
    target_val = round(0.15 * total_files)
    target_test = total_files - target_train - target_val
    
    if total_files == 3:
        target_train, target_val, target_test = 2, 1, 0
    elif total_files == 4:
        target_train, target_val, target_test = 2, 1, 1
    elif total_files == 5:
        target_train, target_val, target_test = 3, 1, 1
        
    # Shuffle train files for redistribution
    remaining_files = train_files.copy()
    random.shuffle(remaining_files)

    # Adjust the test set first (if needed)
    while len(test_files) < target_test and remaining_files:
        file_to_move = remaining_files.pop()
        #txt_file = file_to_move.replace(".npz", ".txt")
        
        shutil.move(file_to_move, os.path.join(test_folder, os.path.basename(file_to_move)))
        
       #if os.path.exists(txt_file):
            #shutil.move(txt_file, os.path.join(test_folder, os.path.basename(txt_file)))
        
        test_files.append(file_to_move)


    # Assign remaining files to train and val
    new_train_files = remaining_files[:target_train]
    new_val_files = remaining_files[target_train:]
    
    for file in new_train_files:
        #txt_file = file.replace(".npz", ".txt")
        
        shutil.move(file, os.path.join(train_folder, os.path.basename(file)))
        
        #if os.path.exists(txt_file):
            #shutil.move(txt_file, os.path.join(train_folder, os.path.basename(txt_file)))
    for file in new_val_files:
        #txt_file = file.replace(".npz", ".txt")
        
        shutil.move(file, os.path.join(val_folder, os.path.basename(file)))
        
        #if os.path.exists(txt_file):
            #shutil.move(txt_file, os.path.join(val_folder, os.path.basename(txt_file)))
        
        
    print(f"Distributed {total_files} files for {word}:")
    print(f"  Train: {len([f for f in os.listdir(train_folder) if f.endswith('.mp4')])}, " 
      f"Val: {len([f for f in os.listdir(val_folder) if f.endswith('.mp4')])}, "
      f"Test: {len([f for f in os.listdir(test_folder) if f.endswith('.mp4')])}")
# Out:
# Distributed 5 files for VIEWED:
#   Train: 3, Val: 1, Test: 1
# Distributed 31 files for RECENTLY:
#   Train: 22, Val: 5, Test: 4
# Distributed 8 files for ARRIVE:
#   Train: 6, Val: 1, Test: 1
# Distributed 852 files for THEIR:
#   Train: 596, Val: 128, Test: 128
# Distributed 3 files for ARABIC:
#   Train: 2, Val: 1, Test: 0
# Distributed 6 files for CHEMOTHERAPY:
#   Train: 4, Val: 1, Test: 1
# Distributed 4 files for BOLD:
#   Train: 2, Val: 1, Test: 1
# Distributed 11 files for PASSING:
#   Train: 8, Val: 2, Test: 1
# Distributed 35 files for PARTICULAR:
#   Train: 24, Val: 5, Test: 6
# Distributed 7 files for BASKET:
#   Train: 5, Val: 1, Test: 1
# Distributed 10 files for INFORMED:
#   Train: 7, Val: 2, Test: 1
# Distributed 3 files for ANTHROPOLOGY:
#   Train: 2, Val: 1, Test: 0
# Distributed 34 files for KILL:
#   Train: 24, Val: 5, Test: 5
# Distributed 3 files for GLAND:
#   Train: 2, Val: 1, Test: 0
# Distributed 3 files for SHAKING:
#   Train: 2, Val: 1, Test: 0
# Distributed 22 files for SUM:
#   Train: 15, Val: 3, Test: 4
# Distributed 5 files for SYRIA:
#   Train: 3, Val: 1, Test: 1
# Distributed 10 files for RESEARCHING:
#   Train: 7, Val: 2, Test: 1
# Distributed 8 files for INNOVATOR:
#   Train: 6, Val: 1, Test: 1
# Distributed 6 files for SHOCK:
#   Train: 4, Val: 1, Test: 1
# Distributed 3 files for SYMPHONY:
#   Train: 2, Val: 1, Test: 0
# Distributed 9 files for FUNERAL:
#   Train: 6, Val: 1, Test: 2
# Distributed 16 files for CHOSE:
#   Train: 11, Val: 2, Test: 3
# Distributed 15 files for DEEPER:
#   Train: 10, Val: 2, Test: 3
# Distributed 8 files for FUNDAMENTALLY:
#   Train: 6, Val: 1, Test: 1
# Distributed 3 files for DECEPTION:
#   Train: 2, Val: 1, Test: 0
# Distributed 91 files for UNTIL:
#   Train: 64, Val: 14, Test: 13
# Distributed 8 files for PLACED:
#   Train: 6, Val: 1, Test: 1
# Distributed 3 files for ANSWERING:
#   Train: 2, Val: 1, Test: 0
# Distributed 4 files for FEARLESS:
#   Train: 2, Val: 1, Test: 1
# Distributed 6 files for CHEESE:
#   Train: 4, Val: 1, Test: 1
# Distributed 4 files for MARGIN:
#   Train: 2, Val: 1, Test: 1
# Distributed 3 files for BRIDE:
#   Train: 2, Val: 1, Test: 0
# Distributed 38 files for LIVED:
#   Train: 27, Val: 6, Test: 5
# Distributed 5 files for FLU:
#   Train: 3, Val: 1, Test: 1
# Distributed 23 files for INDIAN:
#   Train: 16, Val: 3, Test: 4
# Distributed 58 files for SHE'S:
#   Train: 41, Val: 9, Test: 8
# Distributed 22 files for ACCORDING:
#   Train: 15, Val: 3, Test: 4
# Distributed 4 files for MASSIVELY:
#   Train: 2, Val: 1, Test: 1
# Distributed 111 files for CANCER:
#   Train: 78, Val: 17, Test: 16
# Distributed 8 files for CHIP:
#   Train: 6, Val: 1, Test: 1
# Distributed 4 files for INFECTED:
#   Train: 2, Val: 1, Test: 1
# Distributed 4 files for FIRSTLY:
#   Train: 2, Val: 1, Test: 1
# Distributed 5 files for CROSSES:
#   Train: 3, Val: 1, Test: 1
# Distributed 14 files for INVESTMENT:
#   Train: 10, Val: 2, Test: 2
# Distributed 7 files for DISCUSS:
#   Train: 5, Val: 1, Test: 1
# Distributed 11 files for ERROR:
#   Train: 8, Val: 2, Test: 1
# Distributed 4 files for FACILITIES:
#   Train: 2, Val: 1, Test: 1
# Distributed 25 files for VILLAGE:
#   Train: 18, Val: 4, Test: 3
# Distributed 3 files for CLAPPING:
#   Train: 2, Val: 1, Test: 0
# Distributed 6 files for SOLO:
#   Train: 4, Val: 1, Test: 1
# Distributed 5 files for PREVIOUSLY:
#   Train: 3, Val: 1, Test: 1
# Distributed 6 files for SURPRISINGLY:
#   Train: 4, Val: 1, Test: 1
# Distributed 19 files for JOKE:
#   Train: 13, Val: 3, Test: 3
# Distributed 10 files for RITUAL:
#   Train: 7, Val: 0, Test: 3
# Distributed 4 files for ACTIVATED:
#   Train: 2, Val: 1, Test: 1
# Distributed 17 files for DIRECT:
#   Train: 12, Val: 3, Test: 2
# Distributed 40 files for PHYSICAL:
#   Train: 28, Val: 6, Test: 6
# Distributed 3 files for APPRENTICESHIP:
#   Train: 2, Val: 1, Test: 0
# Distributed 7 files for EXISTING:
#   Train: 5, Val: 1, Test: 1
# Distributed 10 files for ENTERPRISE:
#   Train: 7, Val: 2, Test: 1
# Distributed 4 files for CUBA:
#   Train: 2, Val: 1, Test: 1
# Distributed 4 files for CYBER:
#   Train: 2, Val: 1, Test: 1
# Distributed 3 files for FREQUENTLY:
#   Train: 2, Val: 1, Test: 0
# Distributed 3 files for WANDER:
#   Train: 2, Val: 1, Test: 0
# Distributed 6 files for LAZY:
#   Train: 4, Val: 1, Test: 1
# Distributed 17 files for JOURNALIST:
#   Train: 12, Val: 3, Test: 2
# Distributed 3 files for TOLERANT:
#   Train: 2, Val: 1, Test: 0
# Distributed 8773 files for THAT:
#   Train: 6141, Val: 1316, Test: 1316
# Distributed 14 files for AIM:
#   Train: 10, Val: 2, Test: 2
# Distributed 4 files for PERFORMED:
#   Train: 2, Val: 1, Test: 1
# Distributed 5 files for GREECE:
#   Train: 3, Val: 1, Test: 1
# Distributed 4 files for ELECTRONS:
#   Train: 2, Val: 1, Test: 1
# Distributed 3 files for EXILE:
#   Train: 2, Val: 1, Test: 0
# Distributed 8 files for TURKEY:
#   Train: 6, Val: 1, Test: 1
# Distributed 54 files for EITHER:
#   Train: 38, Val: 8, Test: 8
# Distributed 4 files for PRIORITIZE:
#   Train: 2, Val: 1, Test: 1
# Distributed 8 files for SHEET:
#   Train: 6, Val: 1, Test: 1
# Distributed 3 files for MCDONALD'S:
#   Train: 2, Val: 1, Test: 0
# Distributed 6 files for PINK:
#   Train: 4, Val: 1, Test: 1
# Distributed 7 files for OWL:
#   Train: 5, Val: 1, Test: 1
# Distributed 22 files for CLEAR:
#   Train: 15, Val: 3, Test: 4
# Distributed 5 files for DIAPHRAGM:
#   Train: 3, Val: 1, Test: 1
# Distributed 3 files for MOISTURE:
#   Train: 2, Val: 1, Test: 0
# Distributed 5 files for IOWA:
#   Train: 3, Val: 1, Test: 1
# Distributed 3 files for PERSIST:
#   Train: 2, Val: 1, Test: 0
# Distributed 31 files for OUTCOME:
#   Train: 22, Val: 5, Test: 4
# Distributed 454 files for EVEN:
#   Train: 318, Val: 68, Test: 68
# Distributed 13 files for MALL:
#   Train: 9, Val: 2, Test: 2
# Distributed 4 files for IGNORANCE:
#   Train: 2, Val: 1, Test: 1
# Distributed 3 files for STRAY:
#   Train: 2, Val: 1, Test: 0
# Distributed 3 files for SOMEPLACE:
#   Train: 2, Val: 1, Test: 0
# Distributed 13 files for BLOCK:
#   Train: 9, Val: 2, Test: 2
# Distributed 9 files for READER:
#   Train: 6, Val: 1, Test: 2
# Distributed 7 files for FORGIVE:
#   Train: 5, Val: 1, Test: 1
# Skipping STAGGERING, already properly split.
# Distributed 3 files for COMPETING:
#   Train: 2, Val: 1, Test: 0
# Distributed 4 files for INVESTING:
#   Train: 2, Val: 1, Test: 1
# Distributed 6 files for DIVORCE:
#   Train: 4, Val: 1, Test: 1
# Distributed 3 files for SAUCE:
#   Train: 2, Val: 1, Test: 0
# Distributed 165 files for FEW:
#   Train: 115, Val: 25, Test: 25
# Distributed 10 files for NOR:
#   Train: 7, Val: 2, Test: 1
# Distributed 9 files for GREEK:
#   Train: 6, Val: 1, Test: 2
# Distributed 11 files for ASSUME:
#   Train: 8, Val: 2, Test: 1
# Distributed 1215 files for YOUR:
#   Train: 850, Val: 182, Test: 183
# Distributed 3 files for OUTLET:
#   Train: 2, Val: 1, Test: 0
# Distributed 63 files for BEGIN:
#   Train: 44, Val: 9, Test: 10
# Distributed 14 files for ROUGHLY:
#   Train: 10, Val: 2, Test: 2
# Distributed 16 files for POCKET:
#   Train: 11, Val: 2, Test: 3
# Distributed 24 files for COVER:
#   Train: 17, Val: 4, Test: 3
# Distributed 3 files for DENYING:
#   Train: 2, Val: 1, Test: 0
# Distributed 3 files for BUNK:
#   Train: 2, Val: 1, Test: 0
# Distributed 6 files for ALCOHOL:
#   Train: 4, Val: 1, Test: 1
# Distributed 3 files for PROGRESSION:
#   Train: 2, Val: 1, Test: 0
# Distributed 10 files for ENSURE:
#   Train: 7, Val: 2, Test: 1
# Distributed 30 files for ENGLISH:
#   Train: 21, Val: 4, Test: 5
# Skipping HUMANITARIAN, already properly split.
# Distributed 4 files for EXPECTING:
#   Train: 2, Val: 1, Test: 1
# Distributed 3 files for ESCAPED:
#   Train: 2, Val: 1, Test: 0
# Distributed 4 files for TRANSFORMATIVE:
#   Train: 2, Val: 1, Test: 1
# Distributed 20 files for EXPRESSION:
#   Train: 14, Val: 3, Test: 3
# Distributed 3 files for PRAIRIE:
#   Train: 2, Val: 1, Test: 0
# Distributed 45 files for INCREDIBLY:
#   Train: 31, Val: 7, Test: 7
# Distributed 13 files for PROTECTION:
#   Train: 9, Val: 2, Test: 2
# Distributed 10 files for SWIMMING:
#   Train: 7, Val: 2, Test: 1
# Distributed 23 files for CAMP:
#   Train: 16, Val: 3, Test: 4
# Distributed 8 files for UGLY:
#   Train: 6, Val: 1, Test: 1
# Distributed 5 files for WASTING:
#   Train: 3, Val: 1, Test: 1
# Distributed 4 files for CHEAPER:
#   Train: 2, Val: 1, Test: 1
# Distributed 5 files for PUNCH:
#   Train: 3, Val: 1, Test: 1
# Distributed 4 files for TUBE:
#   Train: 2, Val: 1, Test: 1
# Distributed 10 files for ATTEMPT:
#   Train: 7, Val: 2, Test: 1
# Distributed 96 files for COUPLE:
#   Train: 67, Val: 14, Test: 15
# Distributed 185 files for HOME:
#   Train: 130, Val: 28, Test: 27
# Distributed 108 files for INTERESTING:
#   Train: 76, Val: 16, Test: 16
# Distributed 52 files for FORCE:
#   Train: 36, Val: 8, Test: 8
# Distributed 10 files for INVESTED:
#   Train: 7, Val: 2, Test: 1
# Distributed 56 files for EXPERIMENT:
#   Train: 39, Val: 8, Test: 9
# Distributed 5 files for CHUTZPAH:
#   Train: 3, Val: 1, Test: 1
# Distributed 3 files for CLOTH:
#   Train: 2, Val: 1, Test: 0
# Distributed 5 files for DISTRIBUTION:
#   Train: 3, Val: 1, Test: 1
# Distributed 4 files for EXTRACT:
#   Train: 2, Val: 1, Test: 1
# Distributed 52 files for STRESS:
#   Train: 36, Val: 8, Test: 8
# Skipping TEXTING, already properly split.
# Distributed 3 files for GRAFFITI:
#   Train: 2, Val: 1, Test: 0
# Distributed 13 files for HI:
#   Train: 9, Val: 2, Test: 2
# Skipping LUTHER, already properly split.
# Distributed 6 files for PROMISED:
#   Train: 4, Val: 1, Test: 1
# Distributed 9 files for WASTED:
#   Train: 6, Val: 1, Test: 2
# Distributed 5 files for SPIDER:
#   Train: 3, Val: 1, Test: 1
# Distributed 24 files for YOUTH:
#   Train: 17, Val: 4, Test: 3
# Distributed 3 files for ADMISSION:
#   Train: 2, Val: 1, Test: 0
# Distributed 6 files for SPHERE:
#   Train: 4, Val: 1, Test: 1
# Distributed 13 files for RELEASED:
#   Train: 9, Val: 2, Test: 2
# Distributed 9 files for RUBBISH:
#   Train: 6, Val: 1, Test: 2
# Distributed 3 files for LOAF:
#   Train: 2, Val: 1, Test: 0
# Distributed 5 files for ACCEPTING:
#   Train: 3, Val: 1, Test: 1
# Distributed 5 files for DEPENDING:
#   Train: 3, Val: 1, Test: 1
# Distributed 17 files for FAIR:
#   Train: 12, Val: 3, Test: 2
# Distributed 4 files for EVOLUTIONARY:
#   Train: 2, Val: 1, Test: 1
# Distributed 16 files for EXECUTIVE:
#   Train: 11, Val: 2, Test: 3
# Distributed 4 files for LASTED:
#   Train: 2, Val: 1, Test: 1
# Distributed 34 files for EFFECTIVE:
#   Train: 24, Val: 5, Test: 5
# Distributed 43 files for PROTECT:
#   Train: 30, Val: 6, Test: 7
# Distributed 6 files for LOAD:
#   Train: 4, Val: 1, Test: 1
# Distributed 10 files for TOXIC:
#   Train: 7, Val: 2, Test: 1
# Distributed 59 files for ROLE:
#   Train: 41, Val: 9, Test: 9
# Distributed 4 files for PALLIATIVE:
#   Train: 2, Val: 1, Test: 1
# Distributed 3 files for MUNCHKIN:
#   Train: 2, Val: 1, Test: 0
# Distributed 10 files for PURE:
#   Train: 7, Val: 2, Test: 1
# Distributed 16 files for PERSONALITY:
#   Train: 11, Val: 2, Test: 3
# Distributed 6 files for POLL:
#   Train: 4, Val: 0, Test: 2
# Distributed 5 files for PREVENTED:
#   Train: 3, Val: 1, Test: 1
# Distributed 34 files for LISTEN:
#   Train: 24, Val: 5, Test: 5
# Distributed 9 files for WILLIAM:
#   Train: 6, Val: 1, Test: 2
# Distributed 12 files for HERO:
#   Train: 8, Val: 2, Test: 2
# Distributed 977 files for GET:
#   Train: 684, Val: 147, Test: 146
# Distributed 4 files for EVIDENT:
#   Train: 2, Val: 1, Test: 1
# Distributed 20 files for PEACE:
#   Train: 14, Val: 3, Test: 3
# Distributed 18 files for CLAIM:
#   Train: 13, Val: 3, Test: 2
# Distributed 81 files for GOAL:
#   Train: 57, Val: 12, Test: 12
# Distributed 3 files for INTERESTINGLY:
#   Train: 2, Val: 1, Test: 0
# Distributed 4 files for DIFFICULTIES:
#   Train: 2, Val: 1, Test: 1
# Distributed 15 files for LARGER:
#   Train: 10, Val: 2, Test: 3
# Distributed 5 files for DISCIPLINE:
#   Train: 3, Val: 1, Test: 1
# Distributed 9 files for NERVOUS:
#   Train: 6, Val: 1, Test: 2
# Distributed 24 files for DRAW:
#   Train: 17, Val: 4, Test: 3
# Distributed 7 files for SAFELY:
#   Train: 5, Val: 1, Test: 1
# Distributed 4 files for RYAN:
#   Train: 2, Val: 1, Test: 1
# Distributed 5 files for BOOT:
#   Train: 3, Val: 1, Test: 1
# Distributed 17 files for DAMAGE:
#   Train: 12, Val: 3, Test: 2
# Distributed 88 files for INTERNET:
#   Train: 62, Val: 13, Test: 13
# Distributed 3 files for DANCER:
#   Train: 2, Val: 1, Test: 0
# Distributed 38 files for MATERIAL:
#   Train: 27, Val: 6, Test: 5
# Distributed 9 files for UNABLE:
#   Train: 6, Val: 1, Test: 2
# Distributed 24 files for COURT:
#   Train: 17, Val: 4, Test: 3
# Distributed 8 files for CHASE:
#   Train: 6, Val: 1, Test: 1
# Distributed 20 files for CAUGHT:
#   Train: 14, Val: 3, Test: 3
# Distributed 5 files for MOTOR:
#   Train: 3, Val: 1, Test: 1
# Distributed 26 files for DAILY:
#   Train: 18, Val: 4, Test: 4
# Distributed 74 files for HUGE:
#   Train: 52, Val: 11, Test: 11
# Distributed 6 files for PERFECTIONIST:
#   Train: 4, Val: 1, Test: 1
# Skipping GEIGER, already properly split.
# Distributed 5 files for THIN:
#   Train: 3, Val: 1, Test: 1
# Distributed 12 files for CHOSEN:
#   Train: 8, Val: 2, Test: 2
# Distributed 5 files for CAGE:
#   Train: 3, Val: 1, Test: 1
# Distributed 148 files for GUY:
#   Train: 104, Val: 22, Test: 22
# Distributed 3 files for PORT:
#   Train: 2, Val: 1, Test: 0
# Distributed 4 files for CRASHED:
#   Train: 2, Val: 1, Test: 1
# Distributed 308 files for GIVE:
#   Train: 216, Val: 46, Test: 46
# Distributed 59 files for GIVEN:
#   Train: 41, Val: 9, Test: 9
# Skipping DEMANDING, already properly split.
# Distributed 3 files for CALCULUS:
#   Train: 2, Val: 1, Test: 0
# Distributed 5 files for EMPLOYMENT:
#   Train: 3, Val: 1, Test: 1
# Distributed 25 files for ESPECIALLY:
#   Train: 18, Val: 4, Test: 3
# Distributed 10 files for CRY:
#   Train: 7, Val: 2, Test: 1
# Distributed 3 files for ECONOMIES:
#   Train: 2, Val: 1, Test: 0
# Distributed 71 files for OUTSIDE:
#   Train: 50, Val: 11, Test: 10
# Distributed 5 files for DISAPPOINTMENT:
#   Train: 3, Val: 1, Test: 1
# Distributed 5 files for MICROBIAL:
#   Train: 3, Val: 1, Test: 1
# Distributed 6 files for SERVING:
#   Train: 4, Val: 1, Test: 1
# Distributed 7 files for MORTALITY:
#   Train: 5, Val: 1, Test: 1
# Distributed 3 files for CRUSHING:
#   Train: 2, Val: 1, Test: 0
# Distributed 3 files for ABUNDANCE:
#   Train: 2, Val: 1, Test: 0
# Distributed 6 files for MUSICAL:
#   Train: 4, Val: 1, Test: 1
# Distributed 3 files for FLOSS:
#   Train: 2, Val: 1, Test: 0
# Distributed 4 files for PODCAST:
#   Train: 2, Val: 1, Test: 1
# Distributed 5 files for TULSA:
#   Train: 3, Val: 1, Test: 1
# Distributed 10 files for GAINED:
#   Train: 7, Val: 2, Test: 1
# Distributed 192 files for LAST:
#   Train: 134, Val: 29, Test: 29
# Distributed 39 files for WASTE:
#   Train: 27, Val: 6, Test: 6
# Distributed 8 files for JUICE:
#   Train: 6, Val: 1, Test: 1
# Distributed 8 files for DEFINING:
#   Train: 6, Val: 1, Test: 1
# Distributed 23 files for FOUNDATION:
#   Train: 16, Val: 3, Test: 4
# Distributed 3 files for TABOO:
#   Train: 2, Val: 1, Test: 0
# Distributed 3 files for CEREMONY:
#   Train: 2, Val: 1, Test: 0
# Distributed 4 files for SHORTCUT:
#   Train: 2, Val: 1, Test: 1
# Distributed 4 files for PROMOTION:
#   Train: 2, Val: 1, Test: 1
# Distributed 312 files for THOUGHT:
#   Train: 218, Val: 47, Test: 47
# Distributed 4 files for MAN'S:
#   Train: 2, Val: 1, Test: 1
# Distributed 24 files for COLD:
#   Train: 17, Val: 4, Test: 3
# Distributed 3 files for QUIETLY:
#   Train: 2, Val: 1, Test: 0
# Distributed 4 files for FIGHTERS:
#   Train: 2, Val: 1, Test: 1
# Distributed 3 files for MASTERY:
#   Train: 2, Val: 1, Test: 0
# Distributed 4 files for MINDFUL:
#   Train: 2, Val: 1, Test: 1
# Distributed 5 files for POINTED:
#   Train: 3, Val: 1, Test: 1
# Distributed 3 files for MONOGAMY:
#   Train: 2, Val: 1, Test: 0
# Distributed 14 files for PHOTOGRAPH:
#   Train: 10, Val: 2, Test: 2
# Distributed 58 files for PAPER:
#   Train: 41, Val: 9, Test: 8
# Distributed 5 files for INTRODUCE:
#   Train: 3, Val: 1, Test: 1
# Distributed 4 files for BREAKUP:
#   Train: 2, Val: 1, Test: 1
# Distributed 28 files for EXPERT:
#   Train: 20, Val: 4, Test: 4
# Distributed 3 files for CRACKING:
#   Train: 2, Val: 1, Test: 0
# Distributed 5 files for DAMN:
#   Train: 3, Val: 1, Test: 1
# Distributed 10 files for INTENTION:
#   Train: 7, Val: 2, Test: 1
# Distributed 4 files for SELECT:
#   Train: 2, Val: 1, Test: 1
# Distributed 24 files for TEENAGER:
#   Train: 17, Val: 4, Test: 3
# Distributed 10 files for SOPHISTICATED:
#   Train: 7, Val: 2, Test: 1
# Distributed 43 files for PLEASE:
#   Train: 30, Val: 6, Test: 7
# Distributed 3 files for SOLELY:
#   Train: 2, Val: 1, Test: 0
# Distributed 3 files for STRIPE:
#   Train: 2, Val: 1, Test: 0
# Distributed 10 files for LIKED:
#   Train: 7, Val: 2, Test: 1
# Distributed 23 files for SOLDIER:
#   Train: 16, Val: 3, Test: 4
# Distributed 8 files for GDP:
#   Train: 6, Val: 1, Test: 1
# Distributed 6 files for METROPOLITAN:
#   Train: 4, Val: 1, Test: 1
# Distributed 3 files for VALUED:
#   Train: 2, Val: 1, Test: 0
# Distributed 28 files for DESIGNED:
#   Train: 20, Val: 4, Test: 4
# Distributed 3 files for INGEST:
#   Train: 2, Val: 1, Test: 0
# Distributed 35 files for NEGATIVE:
#   Train: 24, Val: 5, Test: 6
# Distributed 4 files for ELSEWHERE:
#   Train: 2, Val: 1, Test: 1
# Distributed 3 files for INVASIVE:
#   Train: 2, Val: 1, Test: 0
# Distributed 11 files for APPROPRIATE:
#   Train: 8, Val: 2, Test: 1
# Distributed 5 files for PAN:
#   Train: 3, Val: 1, Test: 1
# Distributed 8 files for REPUBLICAN:
#   Train: 6, Val: 1, Test: 1
# Distributed 3 files for POSED:
#   Train: 2, Val: 1, Test: 0
# Distributed 5 files for BOWLING:
#   Train: 3, Val: 1, Test: 1
# Distributed 37 files for RACE:
#   Train: 26, Val: 6, Test: 5
# Distributed 38 files for NORMAL:
#   Train: 27, Val: 6, Test: 5
# Distributed 5 files for COPYRIGHT:
#   Train: 3, Val: 1, Test: 1
# Distributed 3 files for BERLIN:
#   Train: 2, Val: 1, Test: 0
# Distributed 6 files for SELECTED:
#   Train: 4, Val: 1, Test: 1
# Distributed 40 files for NATION:
#   Train: 28, Val: 6, Test: 6
# Distributed 21 files for ENGAGED:
#   Train: 15, Val: 3, Test: 3
# Distributed 3 files for EM:
#   Train: 2, Val: 1, Test: 0
# Distributed 12 files for SHOE:
#   Train: 8, Val: 2, Test: 2
# Distributed 9 files for SOFT:
#   Train: 6, Val: 1, Test: 2
# Distributed 5 files for INTERDEPENDENT:
#   Train: 3, Val: 1, Test: 1
# Distributed 8 files for FIBER:
#   Train: 6, Val: 1, Test: 1
# Distributed 17 files for FORGOTTEN:
#   Train: 12, Val: 3, Test: 2
# Distributed 87 files for POWERFUL:
#   Train: 61, Val: 13, Test: 13
# Distributed 5 files for PSYCHIATRIST:
#   Train: 3, Val: 1, Test: 1
# Distributed 21 files for POTENTIALLY:
#   Train: 15, Val: 3, Test: 3
# Distributed 73 files for SERVICE:
#   Train: 51, Val: 11, Test: 11
# Distributed 57 files for WATCH:
#   Train: 40, Val: 9, Test: 8
# Distributed 3 files for WILLENDORF:
#   Train: 2, Val: 1, Test: 0
# Skipping METHANE, already properly split.
# Distributed 3 files for COSTUME:
#   Train: 2, Val: 1, Test: 0
# Skipping MOORE'S, already properly split.
# Distributed 4 files for EL:
#   Train: 2, Val: 1, Test: 1
# Distributed 3 files for SLEEVE:
#   Train: 2, Val: 1, Test: 0
# Distributed 17 files for COMMITTED:
#   Train: 12, Val: 3, Test: 2
# Distributed 2049 files for BE:
#   Train: 1434, Val: 307, Test: 308
# Distributed 10 files for SOMEDAY:
#   Train: 7, Val: 2, Test: 1
# Distributed 14 files for IMPORTANCE:
#   Train: 10, Val: 2, Test: 2
# Distributed 8 files for P:
#   Train: 6, Val: 1, Test: 1
# Distributed 6 files for DOWNTOWN:
#   Train: 4, Val: 1, Test: 1
# Distributed 6 files for DEADLINE:
#   Train: 4, Val: 1, Test: 1
# Distributed 9 files for ESTEEM:
#   Train: 6, Val: 1, Test: 2
# Distributed 13 files for BEAUTY:
#   Train: 9, Val: 2, Test: 2
# Distributed 31 files for LIST:
#   Train: 22, Val: 5, Test: 4
# Distributed 16 files for LIFESTYLE:
#   Train: 11, Val: 2, Test: 3
# Distributed 1435 files for IF:
#   Train: 1004, Val: 215, Test: 216
# Distributed 3 files for POINTING:
#   Train: 2, Val: 1, Test: 0
# Distributed 4 files for CLIMBED:
#   Train: 2, Val: 1, Test: 1
# Distributed 27 files for LITERALLY:
#   Train: 19, Val: 4, Test: 4
# Skipping COMPARISON, already properly split.
# Distributed 4 files for STOLEN:
#   Train: 2, Val: 1, Test: 1
# Distributed 4 files for SECULAR:
#   Train: 2, Val: 1, Test: 1
# Distributed 11 files for SHE'D:
#   Train: 8, Val: 2, Test: 1
# Distributed 5 files for SOUP:
#   Train: 3, Val: 1, Test: 1
# Distributed 6 files for PASSAGE:
#   Train: 4, Val: 1, Test: 1
# Distributed 8 files for IMMIGRATION:
#   Train: 6, Val: 1, Test: 1
# Distributed 8 files for SELVES:
#   Train: 6, Val: 1, Test: 1
# Skipping WEALTHY, already properly split.
# Distributed 18 files for FACING:
#   Train: 13, Val: 3, Test: 2
# Distributed 10 files for COUNTY:
#   Train: 7, Val: 2, Test: 1
# Distributed 66 files for PIECE:
#   Train: 46, Val: 10, Test: 10
# Skipping SICKNESS, already properly split.
# Distributed 17 files for DAVID:
#   Train: 12, Val: 3, Test: 2
# Distributed 6 files for EPIGENETIC:
#   Train: 4, Val: 1, Test: 1
# Distributed 14 files for REPLACE:
#   Train: 10, Val: 2, Test: 2
# Distributed 5 files for DISRUPTIVE:
#   Train: 3, Val: 1, Test: 1
# Distributed 304 files for THROUGH:
#   Train: 213, Val: 46, Test: 45
# Distributed 3 files for WITHDREW:
#   Train: 2, Val: 1, Test: 0
# Distributed 14 files for WHENEVER:
#   Train: 10, Val: 2, Test: 2
# Distributed 3 files for CASKET:
#   Train: 2, Val: 1, Test: 0
# Distributed 4 files for PROMOTED:
#   Train: 2, Val: 1, Test: 1
# Distributed 12 files for IRAN:
#   Train: 8, Val: 2, Test: 2
# Distributed 4 files for MINIMUM:
#   Train: 2, Val: 1, Test: 1
# Distributed 5 files for PORNOGRAPHY:
#   Train: 3, Val: 1, Test: 1
# Distributed 14 files for X:
#   Train: 10, Val: 2, Test: 2
# Distributed 3 files for WALMART:
#   Train: 2, Val: 1, Test: 0
# Distributed 21 files for RAPE:
#   Train: 15, Val: 3, Test: 3
# Distributed 3 files for THRUST:
#   Train: 2, Val: 1, Test: 0
# Distributed 15 files for INTERVENTION:
#   Train: 10, Val: 2, Test: 3
# Distributed 37 files for WAKE:
#   Train: 26, Val: 6, Test: 5
# Distributed 124 files for BETWEEN:
#   Train: 87, Val: 19, Test: 18
# Skipping ASPIRE, already properly split.
# Distributed 189 files for MONEY:
#   Train: 132, Val: 28, Test: 29
# Distributed 8 files for CARING:
#   Train: 6, Val: 1, Test: 1
# Distributed 14 files for HABIT:
#   Train: 10, Val: 2, Test: 2
# Distributed 4 files for SHOCKED:
#   Train: 2, Val: 1, Test: 1
# Distributed 5 files for REALIZING:
#   Train: 3, Val: 1, Test: 1
# Distributed 8 files for ROSE:
#   Train: 6, Val: 1, Test: 1
# Distributed 17 files for PRIVACY:
#   Train: 12, Val: 3, Test: 2
# Distributed 19 files for ENTIRELY:
#   Train: 13, Val: 3, Test: 3
# Distributed 22 files for RAISED:
#   Train: 15, Val: 3, Test: 4
# Distributed 5 files for SCHOLARSHIP:
#   Train: 3, Val: 1, Test: 1
# Distributed 71 files for CREATED:
#   Train: 50, Val: 11, Test: 10
# Distributed 3 files for DERVISH:
#   Train: 2, Val: 1, Test: 0
# Distributed 32 files for PERFORMANCE:
#   Train: 22, Val: 5, Test: 5
# Distributed 4 files for EXPLICIT:
#   Train: 2, Val: 1, Test: 1
# Distributed 8 files for PAIR:
#   Train: 6, Val: 1, Test: 1
# Distributed 127 files for SPACE:
#   Train: 89, Val: 19, Test: 19
# Skipping UPGRADE, already properly split.
# Distributed 7 files for AGED:
#   Train: 5, Val: 1, Test: 1
# Distributed 24 files for STRUGGLE:
#   Train: 17, Val: 4, Test: 3
# Skipping UNCONDITIONAL, already properly split.
# Distributed 6 files for PRIORITY:
#   Train: 4, Val: 1, Test: 1
# Distributed 3 files for TENET:
#   Train: 2, Val: 1, Test: 0
# Distributed 16 files for MOLECULE:
#   Train: 11, Val: 2, Test: 3
# Distributed 4 files for BREATHING:
#   Train: 2, Val: 1, Test: 1
# Distributed 10 files for STRESSFUL:
#   Train: 7, Val: 2, Test: 1
# Distributed 4 files for REWARDING:
#   Train: 2, Val: 1, Test: 1
# Distributed 5 files for DEMOCRAT:
#   Train: 3, Val: 1, Test: 1
# Distributed 20 files for ILLNESS:
#   Train: 14, Val: 3, Test: 3
# Distributed 3 files for CRUCIALLY:
#   Train: 2, Val: 1, Test: 0
# Distributed 53 files for PERSPECTIVE:
#   Train: 37, Val: 8, Test: 8
# Distributed 4 files for SYMBOLIC:
#   Train: 2, Val: 1, Test: 1
# Distributed 5 files for STARK:
#   Train: 3, Val: 1, Test: 1
# Distributed 5 files for IMPROVED:
#   Train: 3, Val: 1, Test: 1
# Distributed 46 files for STAR:
#   Train: 32, Val: 7, Test: 7
# Distributed 23 files for UNDERSTOOD:
#   Train: 16, Val: 3, Test: 4
# Distributed 131 files for GOES:
#   Train: 92, Val: 20, Test: 19
# Distributed 8 files for EMBARRASSED:
#   Train: 6, Val: 1, Test: 1
# Distributed 9 files for CLOSET:
#   Train: 6, Val: 1, Test: 2
# Distributed 7 files for HIRE:
#   Train: 5, Val: 1, Test: 1
# Distributed 42 files for MEETING:
#   Train: 29, Val: 6, Test: 7
# Distributed 8 files for TRANSITION:
#   Train: 6, Val: 1, Test: 1
# Distributed 3 files for COMMONALITIES:
#   Train: 2, Val: 1, Test: 0
# Distributed 14 files for RELATIVE:
#   Train: 10, Val: 2, Test: 2
# Distributed 12 files for CHRONIC:
#   Train: 8, Val: 2, Test: 2
# Distributed 185 files for END:
#   Train: 130, Val: 28, Test: 27
# Distributed 5 files for SOCIALLY:
#   Train: 3, Val: 1, Test: 1
# Distributed 3 files for FORT:
#   Train: 2, Val: 1, Test: 0
# Distributed 5 files for OUTFIT:
#   Train: 3, Val: 1, Test: 1
# Distributed 7 files for TRANSLATE:
#   Train: 5, Val: 1, Test: 1
# Distributed 3 files for EXPONENTIALLY:
#   Train: 2, Val: 1, Test: 0
# Distributed 4 files for DIEGO:
#   Train: 2, Val: 1, Test: 1
# Distributed 5 files for TWELVE:
#   Train: 3, Val: 1, Test: 1
# Distributed 15 files for INSPIRATION:
#   Train: 10, Val: 2, Test: 3
# Distributed 11 files for OFFICER:
#   Train: 8, Val: 2, Test: 1
# Distributed 5 files for CARED:
#   Train: 3, Val: 1, Test: 1
# Distributed 8 files for NETHERLANDS:
#   Train: 6, Val: 1, Test: 1
# Distributed 23 files for COMPETITION:
#   Train: 16, Val: 3, Test: 4
# Distributed 4 files for HOPEFUL:
#   Train: 2, Val: 1, Test: 1
# Distributed 7 files for AVENUE:
#   Train: 5, Val: 1, Test: 1
# Distributed 5 files for INCIDENT:
#   Train: 3, Val: 1, Test: 1
# Distributed 7 files for CARDBOARD:
#   Train: 5, Val: 1, Test: 1
# Distributed 65 files for RATHER:
#   Train: 46, Val: 10, Test: 9
# Distributed 4 files for JIM:
#   Train: 2, Val: 1, Test: 1
# Distributed 6 files for ADS:
#   Train: 4, Val: 1, Test: 1
# Distributed 9 files for WARMING:
#   Train: 6, Val: 1, Test: 2
# Distributed 3 files for HOMO:
#   Train: 2, Val: 1, Test: 0
# Distributed 3 files for CARPENTRY:
#   Train: 2, Val: 1, Test: 0
# Distributed 46 files for LEAD:
#   Train: 32, Val: 7, Test: 7
# Distributed 3 files for SWIRLING:
#   Train: 2, Val: 1, Test: 0
# Distributed 11 files for REACHING:
#   Train: 8, Val: 2, Test: 1
# Distributed 21 files for DISCOVERY:
#   Train: 15, Val: 3, Test: 3
# Distributed 4 files for VOLCANO:
#   Train: 2, Val: 1, Test: 1
# Distributed 86 files for ANYONE:
#   Train: 60, Val: 13, Test: 13
# Distributed 3 files for LEMONADE:
#   Train: 2, Val: 1, Test: 0
# Distributed 5 files for THERE'RE:
#   Train: 3, Val: 1, Test: 1
# Distributed 166 files for REASON:
#   Train: 116, Val: 25, Test: 25
# Distributed 3 files for BATH:
#   Train: 2, Val: 1, Test: 0
# Distributed 4 files for O:
#   Train: 2, Val: 1, Test: 1
# Distributed 8 files for UNEMPLOYMENT:
#   Train: 6, Val: 1, Test: 1
# Distributed 5 files for ANSWERED:
#   Train: 3, Val: 1, Test: 1
# Distributed 1344 files for OUR:
#   Train: 941, Val: 202, Test: 201
# Distributed 68 files for SEEING:
#   Train: 48, Val: 10, Test: 10
# Skipping UNEXPECTED, already properly split.
# Distributed 3 files for PHOTOGRAPHED:
#   Train: 2, Val: 1, Test: 0
# Distributed 34 files for SPEECH:
#   Train: 24, Val: 5, Test: 5
# Distributed 20 files for GENERATE:
#   Train: 14, Val: 3, Test: 3
# Distributed 8 files for LAPTOP:
#   Train: 6, Val: 1, Test: 1
# Distributed 10 files for DIVERSE:
#   Train: 7, Val: 2, Test: 1
# Distributed 15 files for UPSET:
#   Train: 10, Val: 2, Test: 3
# Distributed 4 files for MONK:
#   Train: 2, Val: 1, Test: 1
# Distributed 5 files for BLINDNESS:
#   Train: 3, Val: 1, Test: 1
# Distributed 28 files for SAVE:
#   Train: 20, Val: 4, Test: 4
# Distributed 10 files for INCREASED:
#   Train: 7, Val: 2, Test: 1
# Distributed 4 files for JEWELRY:
#   Train: 2, Val: 1, Test: 1
# Distributed 10 files for TERRORIST:
#   Train: 7, Val: 2, Test: 1
# Distributed 4 files for THIRDLY:
#   Train: 2, Val: 1, Test: 1
# Distributed 40 files for EXCITED:
#   Train: 28, Val: 6, Test: 6
# Distributed 16 files for COGNITIVE:
#   Train: 11, Val: 2, Test: 3
# Distributed 15 files for BASE:
#   Train: 10, Val: 2, Test: 3
# Distributed 3 files for WOKEN:
#   Train: 2, Val: 1, Test: 0
# Distributed 25 files for EQUAL:
#   Train: 18, Val: 4, Test: 3
# Distributed 3 files for GUESSING:
#   Train: 2, Val: 1, Test: 0
# Distributed 4 files for PUBLICATION:
#   Train: 2, Val: 1, Test: 1
# Skipping HARNESS, already properly split.
# Distributed 11 files for COLLAPSE:
#   Train: 8, Val: 2, Test: 1
# Distributed 4 files for HEADING:
#   Train: 2, Val: 1, Test: 1
# Distributed 23 files for PLATFORM:
#   Train: 16, Val: 3, Test: 4
# Distributed 23 files for SUPER:
#   Train: 16, Val: 3, Test: 4
# Distributed 5 files for PLANTING:
#   Train: 3, Val: 1, Test: 1
# Distributed 3 files for BLA:
#   Train: 2, Val: 1, Test: 0
# Distributed 3 files for MENTORING:
#   Train: 2, Val: 1, Test: 0
# Distributed 22 files for NOTICED:
#   Train: 15, Val: 3, Test: 4
# Distributed 3 files for AUDITION:
#   Train: 2, Val: 1, Test: 0
# Distributed 5 files for KOREAN:
#   Train: 3, Val: 1, Test: 1
# Distributed 414 files for BEING:
#   Train: 290, Val: 62, Test: 62
# Distributed 19 files for REVOLUTION:
#   Train: 13, Val: 3, Test: 3
# Distributed 3 files for COX:
#   Train: 2, Val: 1, Test: 0
# Distributed 11 files for METAL:
#   Train: 8, Val: 2, Test: 1
# Distributed 11 files for GRAVE:
#   Train: 8, Val: 2, Test: 1
# Distributed 27 files for EFFORT:
#   Train: 19, Val: 4, Test: 4
# Distributed 9 files for CHARITY:
#   Train: 6, Val: 1, Test: 2
# Distributed 2252 files for ABOUT:
#   Train: 1576, Val: 338, Test: 338
# Distributed 3 files for ETHICS:
#   Train: 2, Val: 1, Test: 0
# Distributed 23 files for STATEMENT:
#   Train: 16, Val: 3, Test: 4
# Distributed 3 files for SPORTING:
#   Train: 2, Val: 1, Test: 0
# Distributed 35 files for ISLAND:
#   Train: 24, Val: 5, Test: 6
# Distributed 9 files for CAKE:
#   Train: 6, Val: 1, Test: 2
# Distributed 4 files for IRELAND:
#   Train: 2, Val: 1, Test: 1
# Distributed 3 files for FUELED:
#   Train: 2, Val: 1, Test: 0
# Distributed 6 files for EXPLORATION:
#   Train: 4, Val: 1, Test: 1
# Distributed 4 files for PROPOSED:
#   Train: 2, Val: 1, Test: 1
# Distributed 8 files for REDUCED:
#   Train: 6, Val: 1, Test: 1
# Distributed 1064 files for THING:
#   Train: 745, Val: 160, Test: 159
# Distributed 3 files for ELLEN:
#   Train: 2, Val: 1, Test: 0
# Distributed 3 files for THRILL:
#   Train: 2, Val: 1, Test: 0
# Distributed 194 files for HAND:
#   Train: 136, Val: 29, Test: 29
# Distributed 62 files for OKAY:
#   Train: 43, Val: 9, Test: 10
# Distributed 3 files for COMPROMISE:
#   Train: 2, Val: 1, Test: 0
# Distributed 18 files for NEIGHBOR:
#   Train: 13, Val: 3, Test: 2
# Distributed 4 files for LHC:
#   Train: 2, Val: 1, Test: 1
# Distributed 3 files for MATTHEW:
#   Train: 2, Val: 1, Test: 0
# Distributed 74 files for DIFFERENCE:
#   Train: 52, Val: 11, Test: 11
# Distributed 4 files for DOCUMENTARY:
#   Train: 2, Val: 1, Test: 1
# Distributed 7 files for WIKIPEDIA:
#   Train: 5, Val: 1, Test: 1
# Distributed 7 files for LOG:
#   Train: 5, Val: 1, Test: 1
# Distributed 355 files for DOING:
#   Train: 248, Val: 53, Test: 54
# Distributed 126 files for TECHNOLOGY:
#   Train: 88, Val: 19, Test: 19
# Distributed 32 files for POSSIBLY:
#   Train: 22, Val: 5, Test: 5
# Distributed 143 files for RESEARCH:
#   Train: 100, Val: 21, Test: 22
# Distributed 10 files for VACATION:
#   Train: 7, Val: 2, Test: 1
# Distributed 3 files for BRUSHED:
#   Train: 2, Val: 1, Test: 0
# Distributed 14 files for COLLABORATION:
#   Train: 10, Val: 2, Test: 2
# Distributed 26 files for APPLICATION:
#   Train: 18, Val: 4, Test: 4
# Distributed 219 files for ASK:
#   Train: 153, Val: 33, Test: 33
# Distributed 4 files for WIDER:
#   Train: 2, Val: 1, Test: 1
# Distributed 272 files for BRAIN:
#   Train: 190, Val: 41, Test: 41
# Distributed 18 files for TWICE:
#   Train: 13, Val: 3, Test: 2
# Distributed 67 files for COMPANIES:
#   Train: 47, Val: 10, Test: 10
# Distributed 138 files for ASKED:
#   Train: 97, Val: 21, Test: 20
# Distributed 6 files for DENIAL:
#   Train: 4, Val: 1, Test: 1
# Distributed 3 files for ISN:
#   Train: 2, Val: 1, Test: 0
# Distributed 66 files for CAUSE:
#   Train: 46, Val: 10, Test: 10
# Distributed 216 files for PERSON:
#   Train: 151, Val: 32, Test: 33
# Distributed 51 files for EVENT:
#   Train: 36, Val: 8, Test: 7
# Distributed 6 files for FUNCTIONING:
#   Train: 4, Val: 1, Test: 1
# Distributed 3 files for PAINTER:
#   Train: 2, Val: 1, Test: 0
# Distributed 48 files for COMPLEX:
#   Train: 34, Val: 7, Test: 7
# Distributed 3 files for JURY:
#   Train: 2, Val: 1, Test: 0
# Distributed 5 files for SECONDARY:
#   Train: 3, Val: 1, Test: 1
# Distributed 5 files for ASSUMED:
#   Train: 3, Val: 1, Test: 1
# Distributed 10 files for PHYSICALLY:
#   Train: 7, Val: 2, Test: 1
# Distributed 59 files for EVENTUALLY:
#   Train: 41, Val: 9, Test: 9
# Distributed 74 files for RISK:
#   Train: 52, Val: 11, Test: 11
# Distributed 3 files for QUALIFIED:
#   Train: 2, Val: 1, Test: 0
# Distributed 15 files for ERA:
#   Train: 10, Val: 2, Test: 3
# Distributed 981 files for MORE:
#   Train: 687, Val: 147, Test: 147
# Distributed 3 files for FICTIONAL:
#   Train: 2, Val: 1, Test: 0
# Distributed 17 files for ORGANIC:
#   Train: 12, Val: 3, Test: 2
# Distributed 6 files for ORG:
#   Train: 4, Val: 1, Test: 1
# Distributed 6 files for SUICIDAL:
#   Train: 4, Val: 1, Test: 1
# Distributed 16 files for OBJECTIVE:
#   Train: 11, Val: 2, Test: 3
# Distributed 4997 files for IT:
#   Train: 3498, Val: 750, Test: 749
# Distributed 184 files for TOGETHER:
#   Train: 129, Val: 28, Test: 27
# Distributed 3 files for APPALLING:
#   Train: 2, Val: 1, Test: 0
# Distributed 18 files for CAPABLE:
#   Train: 13, Val: 3, Test: 2
# Distributed 7 files for DIVIDED:
#   Train: 5, Val: 1, Test: 1
# Distributed 5 files for INSECURITY:
#   Train: 3, Val: 1, Test: 1
# Distributed 3 files for LAPILLI:
#   Train: 2, Val: 1, Test: 0
# Distributed 4 files for REGULATE:
#   Train: 2, Val: 1, Test: 1
# Distributed 7 files for DE:
#   Train: 5, Val: 1, Test: 1
# Distributed 6 files for BRUSH:
#   Train: 4, Val: 1, Test: 1
# Distributed 10 files for EVOLVE:
#   Train: 7, Val: 2, Test: 1
# Distributed 10 files for PHASE:
#   Train: 7, Val: 2, Test: 1
# Distributed 6 files for ERIC:
#   Train: 4, Val: 1, Test: 1
# Distributed 7 files for BASEMENT:
#   Train: 5, Val: 1, Test: 1
# Distributed 4 files for REFRIGERATOR:
#   Train: 2, Val: 1, Test: 1
# Distributed 4 files for JUNE:
#   Train: 2, Val: 1, Test: 1
# Distributed 3 files for MOSQUE:
#   Train: 2, Val: 1, Test: 0
# Distributed 6 files for CURRENCY:
#   Train: 4, Val: 1, Test: 1
# Distributed 9 files for MEASUREMENT:
#   Train: 6, Val: 1, Test: 2
# Distributed 89 files for RELATIONSHIP:
#   Train: 62, Val: 13, Test: 14
# Distributed 16 files for RELEASE:
#   Train: 11, Val: 2, Test: 3
# Distributed 65 files for TYPE:
#   Train: 46, Val: 10, Test: 9
# Distributed 4 files for GRIMMS:
#   Train: 2, Val: 1, Test: 1
# Distributed 56 files for DECIDE:
#   Train: 39, Val: 8, Test: 9
# Distributed 56 files for IMAGE:
#   Train: 39, Val: 8, Test: 9
# Distributed 4 files for SLAM:
#   Train: 2, Val: 1, Test: 1
# Distributed 5 files for DEAF:
#   Train: 3, Val: 1, Test: 1
# Distributed 4 files for GRANDSON:
#   Train: 2, Val: 1, Test: 1
# Distributed 9 files for REPORTER:
#   Train: 6, Val: 1, Test: 2
# Distributed 4 files for NUMB:
#   Train: 2, Val: 1, Test: 1
# Distributed 3 files for DEAN:
#   Train: 2, Val: 1, Test: 0
# Distributed 8 files for MOZART:
#   Train: 6, Val: 1, Test: 1
# Distributed 5 files for MENOPAUSE:
#   Train: 3, Val: 1, Test: 1
# Distributed 13 files for BROWN:
#   Train: 9, Val: 2, Test: 2
# Distributed 209 files for COURSE:
#   Train: 146, Val: 31, Test: 32
# Distributed 4 files for BIRMINGHAM:
#   Train: 2, Val: 1, Test: 1
# Distributed 5 files for FEE:
#   Train: 3, Val: 1, Test: 1
# Distributed 3 files for BETA:
#   Train: 2, Val: 1, Test: 0
# Distributed 17 files for VULNERABLE:
#   Train: 12, Val: 3, Test: 2
# Distributed 5 files for RISING:
#   Train: 3, Val: 1, Test: 1
# Distributed 32 files for POLITICS:
#   Train: 22, Val: 5, Test: 5
# Distributed 7 files for BOTHER:
#   Train: 5, Val: 1, Test: 1
# Distributed 39 files for WAITING:
#   Train: 27, Val: 6, Test: 6
# Distributed 295 files for HAPPEN:
#   Train: 206, Val: 44, Test: 45
# Distributed 10 files for STABLE:
#   Train: 7, Val: 2, Test: 1
# Distributed 3 files for COLORED:
#   Train: 2, Val: 1, Test: 0
# Distributed 4 files for SIMPLIFY:
#   Train: 2, Val: 1, Test: 1
# Distributed 6 files for DIGIT:
#   Train: 4, Val: 1, Test: 1
# Distributed 248 files for HIM:
#   Train: 174, Val: 37, Test: 37
# Distributed 3 files for REACTIVE:
#   Train: 2, Val: 1, Test: 0
# Distributed 16 files for VALUABLE:
#   Train: 11, Val: 2, Test: 3
# Distributed 5 files for ANIMATOR:
#   Train: 3, Val: 1, Test: 1
# Distributed 3 files for UPTAKE:
#   Train: 2, Val: 1, Test: 0
# Distributed 8 files for ADVANCED:
#   Train: 6, Val: 1, Test: 1
# Distributed 11 files for CEO:
#   Train: 8, Val: 2, Test: 1
# Distributed 3 files for FLUORESCENT:
#   Train: 2, Val: 1, Test: 0
# Distributed 5 files for REALIZATION:
#   Train: 3, Val: 1, Test: 1
# Distributed 63 files for ALONG:
#   Train: 44, Val: 9, Test: 10
# Distributed 11 files for MAIL:
#   Train: 8, Val: 2, Test: 1
# Distributed 5 files for PRAYER:
#   Train: 3, Val: 1, Test: 1
# Distributed 4 files for INTROVERTS:
#   Train: 2, Val: 1, Test: 1
# Distributed 28 files for OIL:
#   Train: 20, Val: 4, Test: 4
# Distributed 8 files for JAW:
#   Train: 6, Val: 1, Test: 1
# Distributed 5 files for STANDARDIZED:
#   Train: 3, Val: 1, Test: 1
# Distributed 6 files for F:
#   Train: 4, Val: 1, Test: 1
# Distributed 4 files for BRUSHING:
#   Train: 2, Val: 1, Test: 1
# Distributed 111 files for MILLION:
#   Train: 78, Val: 17, Test: 16
# Distributed 6 files for MANUFACTURER:
#   Train: 4, Val: 1, Test: 1
# Distributed 5 files for MECHANICAL:
#   Train: 3, Val: 1, Test: 1
# Distributed 18 files for ABUSE:
#   Train: 13, Val: 3, Test: 2
# Distributed 6 files for DRILL:
#   Train: 4, Val: 1, Test: 1
# Distributed 4 files for GENERIC:
#   Train: 2, Val: 1, Test: 1
# Distributed 10 files for OBESITY:
#   Train: 7, Val: 2, Test: 1
# Distributed 3 files for VENUE:
#   Train: 2, Val: 1, Test: 0
# Distributed 2204 files for WITH:
#   Train: 1543, Val: 331, Test: 330
# Distributed 25 files for TRIAL:
#   Train: 18, Val: 4, Test: 3
# Distributed 20 files for COMMUNICATION:
#   Train: 14, Val: 3, Test: 3
# Distributed 3 files for HOLLYWOOD:
#   Train: 2, Val: 1, Test: 0
# Distributed 3 files for BAGHDAD:
#   Train: 2, Val: 1, Test: 0
# Distributed 3 files for ROD:
#   Train: 2, Val: 1, Test: 0
# Distributed 6 files for TAXES:
#   Train: 4, Val: 1, Test: 1
# Distributed 8 files for INFECTIOUS:
#   Train: 6, Val: 1, Test: 1
# Distributed 14 files for MARATHON:
#   Train: 10, Val: 2, Test: 2
# Distributed 5 files for MINORITY:
#   Train: 3, Val: 1, Test: 1
# Distributed 8 files for YOGA:
#   Train: 6, Val: 1, Test: 1
# Distributed 3 files for DEFINITIVE:
#   Train: 2, Val: 1, Test: 0
# Distributed 3 files for NEIL:
#   Train: 2, Val: 1, Test: 0
# Distributed 4 files for GENERATOR:
#   Train: 2, Val: 1, Test: 1
# Distributed 60 files for RUNNING:
#   Train: 42, Val: 9, Test: 9
# Distributed 35 files for SISTER:
#   Train: 24, Val: 5, Test: 6
# Distributed 6 files for PORN:
#   Train: 4, Val: 1, Test: 1
# Distributed 5 files for COOPERATE:
#   Train: 3, Val: 1, Test: 1
# Distributed 3 files for APPETITE:
#   Train: 2, Val: 1, Test: 0
# Distributed 3 files for PIE:
#   Train: 2, Val: 1, Test: 0
# Distributed 3 files for BUREAUCRAT:
#   Train: 2, Val: 1, Test: 0
# Distributed 16 files for SURPRISING:
#   Train: 11, Val: 2, Test: 3
# Distributed 11 files for RURAL:
#   Train: 8, Val: 2, Test: 1
# Distributed 4 files for SKYPE:
#   Train: 2, Val: 1, Test: 1
# Distributed 6 files for EVIL:
#   Train: 4, Val: 1, Test: 1
# Distributed 3 files for BOW:
#   Train: 2, Val: 1, Test: 0
# Distributed 4 files for SYMMETRY:
#   Train: 2, Val: 1, Test: 1
# Distributed 17 files for ATHLETE:
#   Train: 12, Val: 3, Test: 2
# Distributed 9 files for HUNTER:
#   Train: 6, Val: 1, Test: 2
# Distributed 26 files for B:
#   Train: 18, Val: 4, Test: 4
# Distributed 13 files for HONEY:
#   Train: 9, Val: 2, Test: 2
# Distributed 35 files for DRIVING:
#   Train: 24, Val: 5, Test: 6
# Distributed 6 files for SAKE:
#   Train: 4, Val: 1, Test: 1
# Distributed 6 files for FREAKED:
#   Train: 4, Val: 1, Test: 1
# Distributed 3 files for CELEBRATION:
#   Train: 2, Val: 1, Test: 0
# Distributed 4 files for RECOVER:
#   Train: 2, Val: 1, Test: 1
# Distributed 3 files for MARTIAL:
#   Train: 2, Val: 1, Test: 0
# Distributed 11 files for DESERT:
#   Train: 8, Val: 2, Test: 1
# Distributed 6 files for SEXISM:
#   Train: 4, Val: 1, Test: 1
# Distributed 5 files for SUGGESTING:
#   Train: 3, Val: 1, Test: 1
# Distributed 5 files for BLOW:
#   Train: 3, Val: 1, Test: 1
# Distributed 6 files for IMPLEMENTED:
#   Train: 4, Val: 1, Test: 1
# Distributed 6 files for DATING:
#   Train: 4, Val: 1, Test: 1
# Distributed 34 files for NATIONAL:
#   Train: 24, Val: 5, Test: 5
# Distributed 5 files for LION:
#   Train: 3, Val: 1, Test: 1
# Distributed 5 files for LINGUISTIC:
#   Train: 3, Val: 1, Test: 1
# Distributed 4 files for TOMBOY:
#   Train: 2, Val: 1, Test: 1
# Distributed 22 files for BLUE:
#   Train: 15, Val: 3, Test: 4
# Distributed 38 files for STRUCTURE:
#   Train: 27, Val: 6, Test: 5
# Distributed 10 files for RECOVERY:
#   Train: 7, Val: 2, Test: 1
# Distributed 166 files for MATTER:
#   Train: 116, Val: 25, Test: 25
# Distributed 4 files for VIA:
#   Train: 2, Val: 1, Test: 1
# Distributed 7 files for JAIL:
#   Train: 5, Val: 1, Test: 1
# Distributed 4 files for INTERVIEWING:
#   Train: 2, Val: 1, Test: 1
# Distributed 4 files for SIBLING:
#   Train: 2, Val: 1, Test: 1
# Distributed 45 files for SIGN:
#   Train: 31, Val: 7, Test: 7
# Distributed 4 files for CONSENSUS:
#   Train: 2, Val: 1, Test: 1
# Distributed 59 files for ONLINE:
#   Train: 41, Val: 9, Test: 9
# Distributed 59 files for SITUATION:
#   Train: 41, Val: 9, Test: 9
# Distributed 3 files for YORUBA:
#   Train: 2, Val: 1, Test: 0
# Distributed 274 files for OWN:
#   Train: 192, Val: 41, Test: 41
# Distributed 6 files for HACKER:
#   Train: 4, Val: 1, Test: 1
# Distributed 5 files for TARAHUMARA:
#   Train: 3, Val: 1, Test: 1
# Distributed 3 files for MOSES:
#   Train: 2, Val: 1, Test: 0
# Distributed 13 files for EAR:
#   Train: 9, Val: 2, Test: 2
# Distributed 65 files for FRONT:
#   Train: 46, Val: 10, Test: 9
# Distributed 7 files for LIGHTING:
#   Train: 5, Val: 1, Test: 1
# Distributed 15 files for OVERALL:
#   Train: 10, Val: 2, Test: 3
# Distributed 10 files for PERSONALLY:
#   Train: 7, Val: 2, Test: 1
# Distributed 39 files for PARTY:
#   Train: 27, Val: 6, Test: 6
# Distributed 4 files for BUTTER:
#   Train: 2, Val: 1, Test: 1
# Distributed 3 files for LINED:
#   Train: 2, Val: 1, Test: 0
# Distributed 176 files for WHOLE:
#   Train: 123, Val: 26, Test: 27
# Distributed 90 files for EDUCATION:
#   Train: 63, Val: 14, Test: 13
# Distributed 3 files for PLANTATION:
#   Train: 2, Val: 1, Test: 0
# Distributed 28 files for STUDIED:
#   Train: 20, Val: 4, Test: 4
# Distributed 8630 files for A:
#   Train: 6041, Val: 1294, Test: 1295
# Distributed 5 files for FLAG:
#   Train: 3, Val: 1, Test: 1
# Distributed 4 files for RHYME:
#   Train: 2, Val: 1, Test: 1
# Distributed 18 files for FRUSTRATED:
#   Train: 13, Val: 3, Test: 2
# Distributed 4 files for ACCOUNTING:
#   Train: 2, Val: 1, Test: 1
# Distributed 12 files for LUNCH:
#   Train: 8, Val: 2, Test: 2
# Distributed 111 files for PROCESS:
#   Train: 78, Val: 17, Test: 16
# Distributed 7 files for IDENTICAL:
#   Train: 5, Val: 1, Test: 1
# Distributed 47 files for EVIDENCE:
#   Train: 33, Val: 7, Test: 7
# Distributed 3 files for PANAMA:
#   Train: 2, Val: 1, Test: 0
# Distributed 5 files for MOTEL:
#   Train: 3, Val: 1, Test: 1
# Distributed 640 files for HAS:
#   Train: 448, Val: 96, Test: 96
# Distributed 33 files for SHOWN:
#   Train: 23, Val: 5, Test: 5
# Distributed 3 files for DIOXIDE:
#   Train: 2, Val: 1, Test: 0
# Distributed 3 files for TRACKER:
#   Train: 2, Val: 1, Test: 0
# Distributed 28 files for AID:
#   Train: 20, Val: 4, Test: 4
# Distributed 4 files for KIDDING:
#   Train: 2, Val: 1, Test: 1
# Distributed 7 files for NONPROFIT:
#   Train: 5, Val: 1, Test: 1
# Distributed 36 files for EATING:
#   Train: 25, Val: 5, Test: 6
# Distributed 25 files for RID:
#   Train: 18, Val: 4, Test: 3
# Distributed 3 files for BEETLE:
#   Train: 2, Val: 1, Test: 0
# Distributed 7 files for RELIABLE:
#   Train: 5, Val: 1, Test: 1
# Distributed 3 files for TRUSTED:
#   Train: 2, Val: 1, Test: 0
# Distributed 129 files for CAR:
#   Train: 90, Val: 19, Test: 20
# Distributed 20 files for FAMOUS:
#   Train: 14, Val: 3, Test: 3
# Distributed 18 files for ESSENTIAL:
#   Train: 13, Val: 3, Test: 2
# Distributed 4 files for ORGASM:
#   Train: 2, Val: 1, Test: 1
# Distributed 3 files for ABRAHAM'S:
#   Train: 2, Val: 1, Test: 0
# Distributed 18 files for BIRTH:
#   Train: 13, Val: 3, Test: 2
# Distributed 5 files for LINEAR:
#   Train: 3, Val: 1, Test: 1
# Distributed 3 files for CADAVER:
#   Train: 2, Val: 1, Test: 0
# Distributed 4 files for NETWORKING:
#   Train: 2, Val: 1, Test: 1
# Distributed 49 files for PLANT:
#   Train: 34, Val: 7, Test: 8
# Distributed 6 files for ADOLESCENT:
#   Train: 4, Val: 1, Test: 1
# Distributed 13 files for REJECTED:
#   Train: 9, Val: 2, Test: 2
# Distributed 32 files for POSITION:
#   Train: 22, Val: 5, Test: 5
# Distributed 8 files for INVESTIGATE:
#   Train: 6, Val: 1, Test: 1
# Distributed 10 files for NEURAL:
#   Train: 7, Val: 2, Test: 1
# Distributed 11 files for GENETIC:
#   Train: 8, Val: 2, Test: 1
# Distributed 9 files for PROPOSITION:
#   Train: 6, Val: 1, Test: 2
# Distributed 110 files for EVERYBODY:
#   Train: 77, Val: 16, Test: 17
# Distributed 64 files for DEAL:
#   Train: 45, Val: 10, Test: 9
# Distributed 168 files for PLAY:
#   Train: 118, Val: 25, Test: 25
# Distributed 8 files for ADDITION:
#   Train: 6, Val: 1, Test: 1
# Distributed 113 files for POSSIBLE:
#   Train: 79, Val: 17, Test: 17
# Distributed 93 files for LIGHT:
#   Train: 65, Val: 14, Test: 14
# Distributed 7 files for FIGURING:
#   Train: 5, Val: 1, Test: 1
# Distributed 17 files for SPOKE:
#   Train: 12, Val: 3, Test: 2
# Distributed 21 files for SUN:
#   Train: 15, Val: 3, Test: 3
# Distributed 7 files for INCENTIVE:
#   Train: 5, Val: 1, Test: 1
# Distributed 4 files for ANNOUNCE:
#   Train: 2, Val: 1, Test: 1
# Distributed 12 files for ENGAGING:
#   Train: 8, Val: 2, Test: 2
# Distributed 9 files for TRANSGENDER:
#   Train: 6, Val: 1, Test: 2
# Distributed 12 files for BUTTON:
#   Train: 8, Val: 2, Test: 2
# Distributed 4 files for WELLNESS:
#   Train: 2, Val: 1, Test: 1
# Distributed 4 files for VIABLE:
#   Train: 2, Val: 1, Test: 1
# Distributed 31 files for DROP:
#   Train: 22, Val: 5, Test: 4
# Distributed 51 files for CENTURY:
#   Train: 36, Val: 8, Test: 7
# Distributed 3 files for MAHATMA:
#   Train: 2, Val: 1, Test: 0
# Distributed 5 files for FISHERIES:
#   Train: 3, Val: 1, Test: 1
# Distributed 12 files for SUSTAINABLE:
#   Train: 8, Val: 2, Test: 2
# Distributed 6 files for THUS:
#   Train: 4, Val: 1, Test: 1
# Distributed 57 files for OFFER:
#   Train: 40, Val: 9, Test: 8
# Distributed 4 files for ACCENT:
#   Train: 2, Val: 1, Test: 1
# Distributed 8 files for REVEAL:
#   Train: 6, Val: 1, Test: 1
# Distributed 4 files for LANE:
#   Train: 2, Val: 1, Test: 1
# Distributed 108 files for WORKED:
#   Train: 76, Val: 16, Test: 16
# Distributed 11 files for ACTIVIST:
#   Train: 8, Val: 2, Test: 1
# Distributed 1109 files for FROM:
#   Train: 776, Val: 166, Test: 167
# Distributed 12 files for UNIT:
#   Train: 8, Val: 2, Test: 2
# Distributed 7 files for HEAVILY:
#   Train: 5, Val: 1, Test: 1
# Distributed 25 files for NATURALLY:
#   Train: 18, Val: 4, Test: 3
# Distributed 4 files for SCREENING:
#   Train: 2, Val: 1, Test: 1
# Distributed 29 files for SPEED:
#   Train: 20, Val: 4, Test: 5
# Skipping FOOTPRINT, already properly split.
# Distributed 17 files for CLEARLY:
#   Train: 12, Val: 3, Test: 2
# Distributed 6 files for EARTHQUAKE:
#   Train: 4, Val: 1, Test: 1
# Distributed 21 files for TOMORROW:
#   Train: 15, Val: 3, Test: 3
# Distributed 4 files for WILDLIFE:
#   Train: 2, Val: 1, Test: 1
# Distributed 16 files for SMOKE:
#   Train: 11, Val: 2, Test: 3
# Distributed 7 files for SAINT:
#   Train: 5, Val: 1, Test: 1
# Distributed 17 files for PHRASE:
#   Train: 12, Val: 3, Test: 2
# Distributed 6 files for SHELF:
#   Train: 4, Val: 1, Test: 1
# Distributed 15 files for TRAFFIC:
#   Train: 10, Val: 2, Test: 3
# Distributed 78 files for STAGE:
#   Train: 55, Val: 12, Test: 11
# Distributed 21 files for PASSED:
#   Train: 15, Val: 3, Test: 3
# Distributed 13 files for FRENCH:
#   Train: 9, Val: 2, Test: 2
# Distributed 7 files for DRY:
#   Train: 5, Val: 0, Test: 2
# Distributed 6 files for NASA:
#   Train: 4, Val: 1, Test: 1
# Distributed 11 files for MAYOR:
#   Train: 8, Val: 2, Test: 1
# Distributed 11 files for R:
#   Train: 8, Val: 2, Test: 1
# Distributed 14 files for ALGORITHM:
#   Train: 10, Val: 2, Test: 2
# Distributed 5 files for MINI:
#   Train: 3, Val: 1, Test: 1
# Distributed 47 files for TRAINING:
#   Train: 33, Val: 7, Test: 7
# Distributed 15 files for GARDEN:
#   Train: 10, Val: 2, Test: 3
# Distributed 5 files for SUPERSTAR:
#   Train: 3, Val: 1, Test: 1
# Distributed 3 files for PRECISELY:
#   Train: 2, Val: 1, Test: 0
# Distributed 3 files for CAPTAIN:
#   Train: 2, Val: 1, Test: 0
# Distributed 9 files for CUSTOM:
#   Train: 6, Val: 1, Test: 2
# Distributed 3 files for UNLEASHED:
#   Train: 2, Val: 1, Test: 0
# Distributed 9 files for WEAK:
# ...
# Distributed 3 files for CONGESTION:
#   Train: 2, Val: 1, Test: 0
# Distributed 4 files for CAROLINA:
#   Train: 2, Val: 1, Test: 1
# Distributed 149 files for TOOK:
#   Train: 104, Val: 22, Test: 23
# Distributed 5 files for GOLF:
#   Train: 3, Val: 1, Test: 1
# Distributed 20 files for PHILOSOPHY:
#   Train: 14, Val: 3, Test: 3
# Distributed 6 files for MANUFACTURE:
#   Train: 4, Val: 1, Test: 1
# Distributed 5 files for PLANTED:
#   Train: 3, Val: 1, Test: 1
# Distributed 3 files for ISLAMIST:
#   Train: 2, Val: 1, Test: 0
# Distributed 4 files for VS:
#   Train: 2, Val: 1, Test: 1
# Distributed 3 files for STRICT:
#   Train: 2, Val: 1, Test: 0
# Distributed 105 files for DOCTOR:
#   Train: 74, Val: 16, Test: 15
# Distributed 10 files for MUM:
#   Train: 7, Val: 2, Test: 1
# Distributed 3 files for NORMAN:
#   Train: 2, Val: 1, Test: 0
# Distributed 6 files for CABLE:
#   Train: 4, Val: 1, Test: 1
# Distributed 12 files for QUICK:
#   Train: 8, Val: 2, Test: 2
# Distributed 57 files for GONE:
#   Train: 40, Val: 9, Test: 8
# Distributed 3 files for NAKED:
#   Train: 2, Val: 1, Test: 0
# Distributed 7 files for EXPENSE:
#   Train: 5, Val: 1, Test: 1
# Distributed 17 files for DANCE:
#   Train: 12, Val: 3, Test: 2
# Distributed 5 files for HANGING:
#   Train: 3, Val: 1, Test: 1
# Distributed 21 files for LOSING:
#   Train: 15, Val: 3, Test: 3
# Skipping FULFILLING, already properly split.
# Distributed 7 files for POSE:
#   Train: 5, Val: 1, Test: 1
# Distributed 4 files for COMMITTEE:
#   Train: 2, Val: 1, Test: 1
# Distributed 63 files for TOWARD:
#   Train: 44, Val: 9, Test: 10
# Distributed 3 files for DECENT:
#   Train: 2, Val: 1, Test: 0
# Distributed 13 files for WASHINGTON:
#   Train: 9, Val: 2, Test: 2
# Distributed 13 files for PRE:
#   Train: 9, Val: 2, Test: 2
# Distributed 19 files for HORMONE:
#   Train: 13, Val: 3, Test: 3
# Distributed 20 files for WEAPON:
#   Train: 14, Val: 3, Test: 3
# Distributed 279 files for ABLE:
#   Train: 195, Val: 42, Test: 42
# Distributed 3 files for CRYSTALS:
#   Train: 2, Val: 1, Test: 0
# Distributed 21 files for MARK:
#   Train: 15, Val: 3, Test: 3
# Distributed 4 files for COOPERATIVE:
#   Train: 2, Val: 1, Test: 1
# Distributed 3 files for ASTONISHED:
#   Train: 2, Val: 1, Test: 0
# Distributed 3 files for STRATEGIC:
#   Train: 2, Val: 1, Test: 0
# Distributed 3 files for BONUS:
#   Train: 2, Val: 1, Test: 0
# Distributed 15 files for DEPEND:
#   Train: 10, Val: 2, Test: 3
# Distributed 8 files for MINISTER:
#   Train: 6, Val: 1, Test: 1
# Distributed 3 files for SERGIO:
#   Train: 2, Val: 1, Test: 0
# Distributed 53 files for EXPLAIN:
#   Train: 37, Val: 8, Test: 8
# Distributed 3 files for RELYING:
#   Train: 2, Val: 1, Test: 0
# Distributed 9 files for WORKPLACE:
#   Train: 6, Val: 1, Test: 2
# Distributed 63 files for NICE:
#   Train: 44, Val: 9, Test: 10
# Distributed 4 files for UNLIKELY:
#   Train: 2, Val: 1, Test: 1
# Distributed 3 files for PULSE:
#   Train: 2, Val: 1, Test: 0
# Distributed 4 files for UCLA:
#   Train: 2, Val: 1, Test: 1
# Distributed 107 files for READ:
#   Train: 75, Val: 16, Test: 16
# Distributed 108 files for FELT:
#   Train: 76, Val: 16, Test: 16
# Distributed 19 files for ICE:
#   Train: 13, Val: 3, Test: 3
# Distributed 5 files for FORTY:
#   Train: 3, Val: 1, Test: 1
# Distributed 5 files for PRINCIPAL:
#   Train: 3, Val: 1, Test: 1
# Distributed 94 files for MODEL:
#   Train: 66, Val: 14, Test: 14
# Distributed 68 files for HERE'S:
#   Train: 48, Val: 10, Test: 10
# Distributed 299 files for DOES:
#   Train: 209, Val: 45, Test: 45
# Distributed 5 files for SELFISH:
#   Train: 3, Val: 1, Test: 1
# Distributed 3 files for SYNAPSES:
#   Train: 2, Val: 1, Test: 0
# Distributed 3 files for HORRIFYING:
#   Train: 2, Val: 1, Test: 0
# Distributed 3 files for UPRIGHT:
#   Train: 2, Val: 1, Test: 0
# Distributed 14 files for VOTING:
#   Train: 10, Val: 2, Test: 2
# Distributed 49 files for BROUGHT:
#   Train: 34, Val: 7, Test: 8
# Distributed 4 files for CONSUMED:
#   Train: 2, Val: 1, Test: 1
# Distributed 54 files for KEPT:
#   Train: 38, Val: 8, Test: 8
# Distributed 24 files for PHOTO:
#   Train: 17, Val: 4, Test: 3
# Distributed 3 files for RANCHER:
#   Train: 2, Val: 1, Test: 0
# Distributed 7 files for UNKNOWN:
#   Train: 5, Val: 1, Test: 1
# Distributed 476 files for ONLY:
#   Train: 333, Val: 71, Test: 72
# Distributed 6 files for MIGRATION:
#   Train: 4, Val: 1, Test: 1
# Distributed 6 files for PRODUCER:
#   Train: 4, Val: 1, Test: 1
# Distributed 16 files for STAYED:
#   Train: 11, Val: 2, Test: 3
# Distributed 3 files for EMPOWERMENT:
#   Train: 2, Val: 1, Test: 0
# Distributed 37 files for VICTIM:
#   Train: 26, Val: 6, Test: 5
# Distributed 20 files for FULLY:
#   Train: 14, Val: 3, Test: 3
# Distributed 38 files for INSPIRED:
#   Train: 27, Val: 6, Test: 5
# Distributed 5 files for FILMING:
#   Train: 3, Val: 1, Test: 1
# Distributed 19 files for CORE:
#   Train: 13, Val: 3, Test: 3
# Distributed 9 files for SYNDROME:
#   Train: 6, Val: 1, Test: 2
# Distributed 60 files for MARKET:
#   Train: 42, Val: 9, Test: 9
# Distributed 5 files for ADDICTIVE:
#   Train: 3, Val: 1, Test: 1
# Skipping CONTRADICTION, already properly split.
# Distributed 39 files for PUSH:
#   Train: 27, Val: 6, Test: 6
# Distributed 31 files for MOBILE:
#   Train: 22, Val: 5, Test: 4
# Distributed 47 files for ITSELF:
#   Train: 33, Val: 7, Test: 7
# Distributed 4 files for OVERDOSE:
#   Train: 2, Val: 1, Test: 1
# Distributed 7 files for PRESCRIPTION:
#   Train: 5, Val: 1, Test: 1
# Distributed 4 files for NELSON:
#   Train: 2, Val: 1, Test: 1
# Distributed 3 files for ROYAL:
#   Train: 2, Val: 1, Test: 0
# Distributed 3 files for NUDGING:
#   Train: 2, Val: 1, Test: 0
# Distributed 10 files for TACKLE:
#   Train: 7, Val: 2, Test: 1
# Distributed 4 files for JUDGEMENT:
#   Train: 2, Val: 1, Test: 1
# Distributed 14 files for APPLIED:
#   Train: 10, Val: 2, Test: 2
# Distributed 3 files for RATIONALE:
#   Train: 2, Val: 1, Test: 0
# Distributed 26 files for WEIRD:
#   Train: 18, Val: 4, Test: 4
# Distributed 5 files for COLLECTIVELY:
#   Train: 3, Val: 1, Test: 1
# Distributed 4 files for SLIPPED:
#   Train: 2, Val: 1, Test: 1
# Distributed 5 files for TRANSFERRED:
#   Train: 3, Val: 1, Test: 1
# Distributed 3 files for PINT:
#   Train: 2, Val: 1, Test: 0
# Distributed 26 files for INDEED:
#   Train: 18, Val: 4, Test: 4
# Distributed 10 files for STANFORD:
#   Train: 7, Val: 2, Test: 1
# Distributed 3 files for COOPERATION:
#   Train: 2, Val: 1, Test: 0
# Distributed 5 files for IMPLANT:
#   Train: 3, Val: 1, Test: 1
# Distributed 19 files for DIVERSITY:
#   Train: 13, Val: 3, Test: 3
# Distributed 14 files for ARAB:
#   Train: 9, Val: 0, Test: 5
# Distributed 278 files for SHOULD:
#   Train: 195, Val: 42, Test: 41
# Distributed 3 files for TRUSTING:
#   Train: 2, Val: 1, Test: 0
# Distributed 28 files for VOTE:
#   Train: 20, Val: 4, Test: 4
# Skipping BREEDING, already properly split.
# Distributed 3 files for LEWIS:
#   Train: 2, Val: 1, Test: 0
# Distributed 29 files for PERIOD:
#   Train: 20, Val: 4, Test: 5
# Distributed 7 files for ENCOUNTER:
#   Train: 5, Val: 1, Test: 1
# Distributed 5 files for WORRIES:
#   Train: 3, Val: 1, Test: 1
# Distributed 6 files for VOCABULARY:
#   Train: 4, Val: 1, Test: 1
# Distributed 6 files for JACK:
#   Train: 4, Val: 1, Test: 1
# Distributed 62 files for YEAH:
#   Train: 43, Val: 9, Test: 10
# Distributed 6 files for CORPORATION:
#   Train: 4, Val: 1, Test: 1
# Distributed 22 files for FAILED:
#   Train: 15, Val: 3, Test: 4
# Distributed 69 files for MET:
#   Train: 48, Val: 10, Test: 11
# Distributed 55 files for MALE:
#   Train: 38, Val: 8, Test: 9
# Distributed 8 files for DETECT:
#   Train: 6, Val: 1, Test: 1
# Distributed 54 files for HAVEN'T:
#   Train: 38, Val: 8, Test: 8
# Distributed 11 files for ROCKET:
#   Train: 8, Val: 1, Test: 2
# Distributed 136 files for ALREADY:
#   Train: 95, Val: 20, Test: 21
# Distributed 73 files for LINE:
#   Train: 51, Val: 11, Test: 11
# Distributed 18 files for OXYGEN:
#   Train: 13, Val: 3, Test: 2
# Distributed 3 files for GHOST:
#   Train: 2, Val: 1, Test: 0
# Distributed 274 files for IMPORTANT:
#   Train: 192, Val: 41, Test: 41
# Distributed 4 files for HIGHWAY:
#   Train: 2, Val: 1, Test: 1
# Distributed 19 files for SICK:
#   Train: 13, Val: 3, Test: 3
# Distributed 210 files for WORD:
#   Train: 147, Val: 32, Test: 31
# Distributed 24 files for IMAGINATION:
#   Train: 17, Val: 4, Test: 3
# Distributed 3 files for SPARK:
#   Train: 2, Val: 1, Test: 0
# Distributed 6 files for OWNED:
#   Train: 4, Val: 1, Test: 1
# Distributed 8 files for TUNNEL:
#   Train: 6, Val: 1, Test: 1
# Distributed 5 files for ASTRONAUT:
#   Train: 3, Val: 1, Test: 1
# Distributed 408 files for HER:
#   Train: 286, Val: 61, Test: 61
# Distributed 3 files for UNTRUE:
#   Train: 2, Val: 1, Test: 0
# Distributed 7 files for WIRED:
#   Train: 5, Val: 1, Test: 1
# Distributed 39 files for LETTER:
#   Train: 27, Val: 6, Test: 6
# Distributed 6 files for APPROACHED:
#   Train: 4, Val: 1, Test: 1
# Distributed 25 files for CONNECTED:
#   Train: 18, Val: 4, Test: 3
# Distributed 1941 files for ON:
#   Train: 1359, Val: 291, Test: 291
# Distributed 24 files for FARM:
#   Train: 17, Val: 4, Test: 3
# Distributed 4 files for INTERVENE:
#   Train: 2, Val: 1, Test: 1
# Distributed 95 files for YES:
#   Train: 66, Val: 14, Test: 15
# Distributed 10 files for COAST:
#   Train: 7, Val: 2, Test: 1
# Distributed 6 files for MIDST:
#   Train: 4, Val: 1, Test: 1
# Distributed 3 files for TRACKING:
#   Train: 2, Val: 1, Test: 0
# Distributed 7 files for SEARCHING:
#   Train: 5, Val: 1, Test: 1
# Distributed 3 files for FORBIDDEN:
#   Train: 2, Val: 1, Test: 0
# Distributed 104 files for OK:
#   Train: 73, Val: 16, Test: 15
# Distributed 3 files for KOSOVO:
#   Train: 2, Val: 1, Test: 0
# Distributed 8 files for AWARD:
#   Train: 6, Val: 1, Test: 1
# Distributed 3 files for PEACH:
#   Train: 2, Val: 1, Test: 0
# Distributed 3 files for ACCUMULATION:
#   Train: 2, Val: 1, Test: 0
# Distributed 6 files for SAM:
#   Train: 4, Val: 1, Test: 1
# Distributed 10 files for COVERED:
#   Train: 7, Val: 2, Test: 1
# Distributed 21 files for CRYING:
#   Train: 15, Val: 3, Test: 3
# Distributed 3 files for MONASTERY:
#   Train: 2, Val: 1, Test: 0
# Skipping HAMILTON, already properly split.
# Distributed 12 files for VIOLENT:
#   Train: 8, Val: 2, Test: 2
# Distributed 3 files for CONTEST:
#   Train: 2, Val: 1, Test: 0
# Distributed 5 files for WILLINGNESS:
#   Train: 3, Val: 1, Test: 1
# Distributed 11 files for VOLUME:
#   Train: 8, Val: 2, Test: 1
# Distributed 18 files for M:
#   Train: 13, Val: 3, Test: 2
# Distributed 11 files for NEWSPAPER:
#   Train: 8, Val: 2, Test: 1
# Distributed 27 files for TRADITIONAL:
#   Train: 19, Val: 4, Test: 4
# Distributed 20 files for DYNAMIC:
#   Train: 14, Val: 3, Test: 3
# Distributed 21 files for LIMIT:
#   Train: 15, Val: 3, Test: 3
# Distributed 112 files for TERM:
#   Train: 78, Val: 17, Test: 17
# Distributed 4 files for CORPSE:
#   Train: 2, Val: 1, Test: 1
# Distributed 526 files for INTO:
#   Train: 368, Val: 79, Test: 79
# Distributed 62 files for RATE:
#   Train: 43, Val: 9, Test: 10
# Distributed 209 files for UNDERSTAND:
#   Train: 146, Val: 31, Test: 32
# Distributed 3 files for MANHOOD:
#   Train: 2, Val: 1, Test: 0
# Distributed 7 files for INNOVATE:
#   Train: 5, Val: 1, Test: 1
# Distributed 18 files for CAPITAL:
#   Train: 13, Val: 3, Test: 2
# Distributed 4 files for ALGEBRA:
#   Train: 2, Val: 1, Test: 1
# Distributed 5 files for MILD:
#   Train: 3, Val: 1, Test: 1
# Distributed 8 files for COMMENT:
#   Train: 6, Val: 1, Test: 1
# Distributed 3 files for OAKLAND:
#   Train: 2, Val: 1, Test: 0
# Distributed 3 files for INSULT:
#   Train: 2, Val: 1, Test: 0
# Distributed 13 files for LIMITED:
#   Train: 9, Val: 2, Test: 2
# Distributed 7 files for MOOD:
#   Train: 5, Val: 1, Test: 1
# Distributed 8 files for DIAGNOSE:
#   Train: 6, Val: 1, Test: 1
# Distributed 12 files for SAVED:
#   Train: 8, Val: 2, Test: 2
# Distributed 3 files for EMBODIMENT:
#   Train: 2, Val: 1, Test: 0
# Distributed 4 files for DEVELOPER:
#   Train: 2, Val: 1, Test: 1
# Distributed 4 files for TRANSLATING:
#   Train: 2, Val: 1, Test: 1
# Distributed 114 files for MOTHER:
#   Train: 80, Val: 17, Test: 17
# Distributed 3 files for THRILLED:
#   Train: 2, Val: 1, Test: 0
# Skipping HITTING, already properly split.
# Distributed 11 files for ENVIRONMENTAL:
#   Train: 8, Val: 2, Test: 1
# Distributed 4 files for SPIRITUALITY:
#   Train: 2, Val: 1, Test: 1
# Distributed 5 files for MINOR:
#   Train: 3, Val: 1, Test: 1
# Distributed 6 files for INVENTOR:
#   Train: 4, Val: 1, Test: 1
# Distributed 17 files for GERMAN:
#   Train: 12, Val: 3, Test: 2
# Distributed 5 files for MIRACLE:
#   Train: 3, Val: 1, Test: 1
# Distributed 7 files for ASSET:
#   Train: 5, Val: 1, Test: 1
# Distributed 7 files for BRIEFLY:
#   Train: 5, Val: 1, Test: 1
# Distributed 56 files for PAIN:
#   Train: 39, Val: 8, Test: 9
# Distributed 3 files for DULL:
#   Train: 2, Val: 1, Test: 0
# Distributed 11 files for AD:
#   Train: 8, Val: 2, Test: 1
# Distributed 5 files for SHIP:
#   Train: 3, Val: 1, Test: 1
# Distributed 5 files for AGREEMENT:
#   Train: 3, Val: 1, Test: 1
# Distributed 7 files for ACQUIRE:
#   Train: 5, Val: 1, Test: 1
# Distributed 8 files for DESPERATELY:
#   Train: 6, Val: 0, Test: 2
# Distributed 26 files for SOFTWARE:
#   Train: 18, Val: 4, Test: 4
# Distributed 3 files for EXPLODING:
#   Train: 2, Val: 1, Test: 0
# Distributed 6 files for SOCIETIES:
#   Train: 4, Val: 1, Test: 1
# Distributed 4 files for SEARCHES:
#   Train: 2, Val: 1, Test: 1
# Distributed 7 files for STORYTELLER:
#   Train: 5, Val: 1, Test: 1
# Distributed 3 files for ABDOMINAL:
#   Train: 2, Val: 1, Test: 0
# Distributed 3 files for DIGGING:
#   Train: 2, Val: 1, Test: 0
# Distributed 7 files for BULLET:
#   Train: 5, Val: 1, Test: 1
# Distributed 5655 files for IN:
#   Train: 3958, Val: 848, Test: 849
# Distributed 6 files for CLUE:
#   Train: 4, Val: 1, Test: 1
# Distributed 23 files for POEM:
#   Train: 16, Val: 3, Test: 4
# Distributed 5 files for ATTRACTED:
#   Train: 3, Val: 1, Test: 1
# Distributed 4 files for REPAIR:
#   Train: 2, Val: 1, Test: 1
# Distributed 8 files for COPE:
#   Train: 6, Val: 1, Test: 1
# Distributed 6 files for CONFUSING:
#   Train: 4, Val: 1, Test: 1
# Distributed 34 files for LESSON:
#   Train: 24, Val: 5, Test: 5
# Distributed 5 files for RESOLUTION:
#   Train: 3, Val: 1, Test: 1
# Distributed 7 files for CONTRAST:
#   Train: 5, Val: 1, Test: 1
# Distributed 18 files for KING:
#   Train: 13, Val: 3, Test: 2
# Distributed 5 files for LGBT:
#   Train: 3, Val: 1, Test: 1
# Distributed 3 files for REMOVING:
#   Train: 2, Val: 1, Test: 0
# Distributed 7 files for FROG:
#   Train: 5, Val: 1, Test: 1
# Distributed 11 files for CONSUME:
#   Train: 8, Val: 2, Test: 1
# Distributed 30 files for SECRET:
#   Train: 21, Val: 4, Test: 5
# Distributed 7 files for BREAKING:
#   Train: 5, Val: 1, Test: 1
# Distributed 6 files for THOMAS:
#   Train: 4, Val: 1, Test: 1
# Distributed 8 files for FOLD:
#   Train: 6, Val: 1, Test: 1
# Distributed 5 files for ADVERTISEMENT:
#   Train: 3, Val: 1, Test: 1
# Distributed 3 files for MUSTER:
#   Train: 2, Val: 1, Test: 0
# Distributed 9 files for GRANT:
#   Train: 6, Val: 1, Test: 2
# Distributed 7 files for CLIMB:
#   Train: 5, Val: 1, Test: 1
# Distributed 283 files for AM:
#   Train: 198, Val: 42, Test: 43
# Distributed 14 files for TESTING:
#   Train: 10, Val: 2, Test: 2
# Distributed 3 files for HEARTBREAKING:
#   Train: 2, Val: 1, Test: 0
# Distributed 3 files for BOIL:
#   Train: 2, Val: 1, Test: 0
# Distributed 27 files for ENJOY:
#   Train: 19, Val: 4, Test: 4
# Distributed 3 files for ANALYZED:
#   Train: 2, Val: 1, Test: 0
# Distributed 6 files for PURELY:
#   Train: 4, Val: 1, Test: 1
# Distributed 28 files for EXACT:
#   Train: 20, Val: 4, Test: 4
# Distributed 9 files for HETEROSEXUAL:
#   Train: 6, Val: 1, Test: 2
# Distributed 15 files for GERMANY:
#   Train: 10, Val: 2, Test: 3
# Distributed 66 files for EARLY:
#   Train: 46, Val: 10, Test: 10
# Distributed 15 files for CUTTING:
#   Train: 10, Val: 2, Test: 3
# Distributed 192 files for STILL:
#   Train: 134, Val: 29, Test: 29
# Distributed 3 files for BLAMED:
#   Train: 2, Val: 1, Test: 0
# Distributed 16 files for BRIGHT:
#   Train: 11, Val: 2, Test: 3
# Distributed 5 files for CHROMOSOME:
#   Train: 3, Val: 1, Test: 1
# Distributed 4 files for DISRUPT:
#   Train: 2, Val: 1, Test: 1
# Distributed 14 files for SPRING:
#   Train: 10, Val: 2, Test: 2
# Distributed 8 files for HUMOR:
#   Train: 6, Val: 1, Test: 1
# Distributed 3458 files for THIS:
#   Train: 2421, Val: 519, Test: 518
# Distributed 14 files for MEAT:
#   Train: 10, Val: 2, Test: 2
# Distributed 4 files for PROVIDER:
#   Train: 2, Val: 1, Test: 1
# Distributed 18 files for ACTIVE:
#   Train: 13, Val: 3, Test: 2

# %%
# Check updated
updated_df = create_df(dir)
print(updated_df)
# Out:
#                   train   val  test  total
# VIEWED                3     1     1      5
# RECENTLY             22     5     4     31
# ARRIVE                6     1     1      8
# THEIR               596   128   128    852
# ARABIC                2     1     0      3
# CHEMOTHERAPY          4     1     1      6
# BOLD                  2     1     1      4
# PASSING               8     2     1     11
# PARTICULAR           24     5     6     35
# BASKET                5     1     1      7
# INFORMED              7     2     1     10
# ANTHROPOLOGY          2     1     0      3
# KILL                 24     5     5     34
# GLAND                 2     1     0      3
# SHAKING               2     1     0      3
# SUM                  15     3     4     22
# SYRIA                 3     1     1      5
# RESEARCHING           7     2     1     10
# INNOVATOR             6     1     1      8
# SHOCK                 4     1     1      6
# SYMPHONY              2     1     0      3
# FUNERAL               6     1     2      9
# CHOSE                11     2     3     16
# DEEPER               10     2     3     15
# FUNDAMENTALLY         6     1     1      8
# DECEPTION             2     1     0      3
# UNTIL                64    14    13     91
# PLACED                6     1     1      8
# ANSWERING             2     1     0      3
# FEARLESS              2     1     1      4
# CHEESE                4     1     1      6
# MARGIN                2     1     1      4
# BRIDE                 2     1     0      3
# LIVED                27     6     5     38
# FLU                   3     1     1      5
# INDIAN               16     3     4     23
# SHE'S                41     9     8     58
# ACCORDING            15     3     4     22
# MASSIVELY             2     1     1      4
# CANCER               78    17    16    111
# CHIP                  6     1     1      8
# INFECTED              2     1     1      4
# FIRSTLY               2     1     1      4
# CROSSES               3     1     1      5
# INVESTMENT           10     2     2     14
# DISCUSS               5     1     1      7
# ERROR                 8     2     1     11
# FACILITIES            2     1     1      4
# VILLAGE              18     4     3     25
# CLAPPING              2     1     0      3
# SOLO                  4     1     1      6
# PREVIOUSLY            3     1     1      5
# SURPRISINGLY          4     1     1      6
# JOKE                 13     3     3     19
# RITUAL                7     0     3     10
# ACTIVATED             2     1     1      4
# DIRECT               12     3     2     17
# PHYSICAL             28     6     6     40
# APPRENTICESHIP        2     1     0      3
# EXISTING              5     1     1      7
# ENTERPRISE            7     2     1     10
# CUBA                  2     1     1      4
# CYBER                 2     1     1      4
# FREQUENTLY            2     1     0      3
# WANDER                2     1     0      3
# LAZY                  4     1     1      6
# JOURNALIST           12     3     2     17
# TOLERANT              2     1     0      3
# THAT               6141  1316  1316   8773
# AIM                  10     2     2     14
# PERFORMED             2     1     1      4
# GREECE                3     1     1      5
# ELECTRONS             2     1     1      4
# EXILE                 2     1     0      3
# TURKEY                6     1     1      8
# EITHER               38     8     8     54
# PRIORITIZE            2     1     1      4
# SHEET                 6     1     1      8
# MCDONALD'S            2     1     0      3
# PINK                  4     1     1      6
# OWL                   5     1     1      7
# CLEAR                15     3     4     22
# DIAPHRAGM             3     1     1      5
# MOISTURE              2     1     0      3
# IOWA                  3     1     1      5
# PERSIST               2     1     0      3
# OUTCOME              22     5     4     31
# EVEN                318    68    68    454
# MALL                  9     2     2     13
# IGNORANCE             2     1     1      4
# STRAY                 2     1     0      3
# SOMEPLACE             2     1     0      3
# BLOCK                 9     2     2     13
# READER                6     1     2      9
# FORGIVE               5     1     1      7
# STAGGERING            3     1     1      5
# COMPETING             2     1     0      3
# INVESTING             2     1     1      4
# DIVORCE               4     1     1      6
# SAUCE                 2     1     0      3
# FEW                 115    25    25    165
# NOR                   7     2     1     10
# GREEK                 6     1     2      9
# ASSUME                8     2     1     11
# YOUR                850   182   183   1215
# OUTLET                2     1     0      3
# BEGIN                44     9    10     63
# ROUGHLY              10     2     2     14
# POCKET               11     2     3     16
# COVER                17     4     3     24
# DENYING               2     1     0      3
# BUNK                  2     1     0      3
# ALCOHOL               4     1     1      6
# PROGRESSION           2     1     0      3
# ENSURE                7     2     1     10
# ENGLISH              21     4     5     30
# HUMANITARIAN          3     1     1      5
# EXPECTING             2     1     1      4
# ESCAPED               2     1     0      3
# TRANSFORMATIVE        2     1     1      4
# EXPRESSION           14     3     3     20
# PRAIRIE               2     1     0      3
# INCREDIBLY           31     7     7     45
# PROTECTION            9     2     2     13
# SWIMMING              7     2     1     10
# CAMP                 16     3     4     23
# UGLY                  6     1     1      8
# WASTING               3     1     1      5
# CHEAPER               2     1     1      4
# PUNCH                 3     1     1      5
# TUBE                  2     1     1      4
# ATTEMPT               7     2     1     10
# COUPLE               67    14    15     96
# HOME                130    28    27    185
# INTERESTING          76    16    16    108
# FORCE                36     8     8     52
# INVESTED              7     2     1     10
# EXPERIMENT           39     8     9     56
# CHUTZPAH              3     1     1      5
# CLOTH                 2     1     0      3
# DISTRIBUTION          3     1     1      5
# EXTRACT               2     1     1      4
# STRESS               36     8     8     52
# TEXTING               4     1     1      6
# GRAFFITI              2     1     0      3
# HI                    9     2     2     13
# LUTHER                2     1     1      4
# PROMISED              4     1     1      6
# WASTED                6     1     2      9
# SPIDER                3     1     1      5
# YOUTH                17     4     3     24
# ADMISSION             2     1     0      3
# SPHERE                4     1     1      6
# RELEASED              9     2     2     13
# RUBBISH               6     1     2      9
# LOAF                  2     1     0      3
# ACCEPTING             3     1     1      5
# DEPENDING             3     1     1      5
# FAIR                 12     3     2     17
# EVOLUTIONARY          2     1     1      4
# EXECUTIVE            11     2     3     16
# LASTED                2     1     1      4
# EFFECTIVE            24     5     5     34
# PROTECT              30     6     7     43
# LOAD                  4     1     1      6
# TOXIC                 7     2     1     10
# ROLE                 41     9     9     59
# PALLIATIVE            2     1     1      4
# MUNCHKIN              2     1     0      3
# PURE                  7     2     1     10
# PERSONALITY          11     2     3     16
# POLL                  4     0     2      6
# PREVENTED             3     1     1      5
# LISTEN               24     5     5     34
# WILLIAM               6     1     2      9
# HERO                  8     2     2     12
# GET                 684   147   146    977
# EVIDENT               2     1     1      4
# PEACE                14     3     3     20
# CLAIM                13     3     2     18
# GOAL                 57    12    12     81
# INTERESTINGLY         2     1     0      3
# DIFFICULTIES          2     1     1      4
# LARGER               10     2     3     15
# DISCIPLINE            3     1     1      5
# NERVOUS               6     1     2      9
# DRAW                 17     4     3     24
# SAFELY                5     1     1      7
# RYAN                  2     1     1      4
# BOOT                  3     1     1      5
# DAMAGE               12     3     2     17
# INTERNET             62    13    13     88
# DANCER                2     1     0      3
# MATERIAL             27     6     5     38
# UNABLE                6     1     2      9
# COURT                17     4     3     24
# CHASE                 6     1     1      8
# CAUGHT               14     3     3     20
# MOTOR                 3     1     1      5
# DAILY                18     4     4     26
# HUGE                 52    11    11     74
# PERFECTIONIST         4     1     1      6
# GEIGER                2     1     1      4
# THIN                  3     1     1      5
# CHOSEN                8     2     2     12
# CAGE                  3     1     1      5
# GUY                 104    22    22    148
# PORT                  2     1     0      3
# CRASHED               2     1     1      4
# GIVE                216    46    46    308
# GIVEN                41     9     9     59
# DEMANDING             3     1     1      5
# CALCULUS              2     1     0      3
# EMPLOYMENT            3     1     1      5
# ESPECIALLY           18     4     3     25
# CRY                   7     2     1     10
# ECONOMIES             2     1     0      3
# OUTSIDE              50    11    10     71
# DISAPPOINTMENT        3     1     1      5
# MICROBIAL             3     1     1      5
# SERVING               4     1     1      6
# MORTALITY             5     1     1      7
# CRUSHING              2     1     0      3
# ABUNDANCE             2     1     0      3
# MUSICAL               4     1     1      6
# FLOSS                 2     1     0      3
# PODCAST               2     1     1      4
# TULSA                 3     1     1      5
# GAINED                7     2     1     10
# LAST                134    29    29    192
# WASTE                27     6     6     39
# JUICE                 6     1     1      8
# DEFINING              6     1     1      8
# FOUNDATION           16     3     4     23
# TABOO                 2     1     0      3
# CEREMONY              2     1     0      3
# SHORTCUT              2     1     1      4
# PROMOTION             2     1     1      4
# THOUGHT             218    47    47    312
# MAN'S                 2     1     1      4
# COLD                 17     4     3     24
# QUIETLY               2     1     0      3
# FIGHTERS              2     1     1      4
# MASTERY               2     1     0      3
# MINDFUL               2     1     1      4
# POINTED               3     1     1      5
# MONOGAMY              2     1     0      3
# PHOTOGRAPH           10     2     2     14
# PAPER                41     9     8     58
# INTRODUCE             3     1     1      5
# BREAKUP               2     1     1      4
# EXPERT               20     4     4     28
# CRACKING              2     1     0      3
# DAMN                  3     1     1      5
# INTENTION             7     2     1     10
# SELECT                2     1     1      4
# TEENAGER             17     4     3     24
# SOPHISTICATED         7     2     1     10
# PLEASE               30     6     7     43
# SOLELY                2     1     0      3
# STRIPE                2     1     0      3
# LIKED                 7     2     1     10
# SOLDIER              16     3     4     23
# GDP                   6     1     1      8
# METROPOLITAN          4     1     1      6
# VALUED                2     1     0      3
# DESIGNED             20     4     4     28
# INGEST                2     1     0      3
# NEGATIVE             24     5     6     35
# ELSEWHERE             2     1     1      4
# INVASIVE              2     1     0      3
# APPROPRIATE           8     2     1     11
# PAN                   3     1     1      5
# REPUBLICAN            6     1     1      8
# POSED                 2     1     0      3
# BOWLING               3     1     1      5
# RACE                 26     6     5     37
# NORMAL               27     6     5     38
# COPYRIGHT             3     1     1      5
# BERLIN                2     1     0      3
# SELECTED              4     1     1      6
# NATION               28     6     6     40
# ENGAGED              15     3     3     21
# EM                    2     1     0      3
# SHOE                  8     2     2     12
# SOFT                  6     1     2      9
# INTERDEPENDENT        3     1     1      5
# FIBER                 6     1     1      8
# FORGOTTEN            12     3     2     17
# POWERFUL             61    13    13     87
# PSYCHIATRIST          3     1     1      5
# POTENTIALLY          15     3     3     21
# SERVICE              51    11    11     73
# WATCH                40     9     8     57
# WILLENDORF            2     1     0      3
# METHANE               2     1     1      4
# COSTUME               2     1     0      3
# MOORE'S               3     1     1      5
# EL                    2     1     1      4
# SLEEVE                2     1     0      3
# COMMITTED            12     3     2     17
# BE                 1434   307   308   2049
# SOMEDAY               7     2     1     10
# IMPORTANCE           10     2     2     14
# P                     6     1     1      8
# DOWNTOWN              4     1     1      6
# DEADLINE              4     1     1      6
# ESTEEM                6     1     2      9
# BEAUTY                9     2     2     13
# LIST                 22     5     4     31
# LIFESTYLE            11     2     3     16
# IF                 1004   215   216   1435
# POINTING              2     1     0      3
# CLIMBED               2     1     1      4
# LITERALLY            19     4     4     27
# COMPARISON            3     1     1      5
# STOLEN                2     1     1      4
# SECULAR               2     1     1      4
# SHE'D                 8     2     1     11
# SOUP                  3     1     1      5
# PASSAGE               4     1     1      6
# IMMIGRATION           6     1     1      8
# SELVES                6     1     1      8
# WEALTHY               2     1     1      4
# FACING               13     3     2     18
# COUNTY                7     2     1     10
# PIECE                46    10    10     66
# SICKNESS              2     1     1      4
# DAVID                12     3     2     17
# EPIGENETIC            4     1     1      6
# REPLACE              10     2     2     14
# DISRUPTIVE            3     1     1      5
# THROUGH             213    46    45    304
# WITHDREW              2     1     0      3
# WHENEVER             10     2     2     14
# CASKET                2     1     0      3
# PROMOTED              2     1     1      4
# IRAN                  8     2     2     12
# MINIMUM               2     1     1      4
# PORNOGRAPHY           3     1     1      5
# X                    10     2     2     14
# WALMART               2     1     0      3
# RAPE                 15     3     3     21
# THRUST                2     1     0      3
# INTERVENTION         10     2     3     15
# WAKE                 26     6     5     37
# BETWEEN              87    19    18    124
# ASPIRE                2     1     1      4
# MONEY               132    28    29    189
# CARING                6     1     1      8
# HABIT                10     2     2     14
# SHOCKED               2     1     1      4
# REALIZING             3     1     1      5
# ROSE                  6     1     1      8
# PRIVACY              12     3     2     17
# ENTIRELY             13     3     3     19
# RAISED               15     3     4     22
# SCHOLARSHIP           3     1     1      5
# CREATED              50    11    10     71
# DERVISH               2     1     0      3
# PERFORMANCE          22     5     5     32
# EXPLICIT              2     1     1      4
# PAIR                  6     1     1      8
# SPACE                89    19    19    127
# UPGRADE               2     1     1      4
# AGED                  5     1     1      7
# STRUGGLE             17     4     3     24
# UNCONDITIONAL         2     1     1      4
# PRIORITY              4     1     1      6
# TENET                 2     1     0      3
# MOLECULE             11     2     3     16
# BREATHING             2     1     1      4
# STRESSFUL             7     2     1     10
# REWARDING             2     1     1      4
# DEMOCRAT              3     1     1      5
# ILLNESS              14     3     3     20
# CRUCIALLY             2     1     0      3
# PERSPECTIVE          37     8     8     53
# SYMBOLIC              2     1     1      4
# STARK                 3     1     1      5
# IMPROVED              3     1     1      5
# STAR                 32     7     7     46
# UNDERSTOOD           16     3     4     23
# GOES                 92    20    19    131
# EMBARRASSED           6     1     1      8
# CLOSET                6     1     2      9
# HIRE                  5     1     1      7
# MEETING              29     6     7     42
# TRANSITION            6     1     1      8
# COMMONALITIES         2     1     0      3
# RELATIVE             10     2     2     14
# CHRONIC               8     2     2     12
# END                 130    28    27    185
# SOCIALLY              3     1     1      5
# FORT                  2     1     0      3
# OUTFIT                3     1     1      5
# TRANSLATE             5     1     1      7
# EXPONENTIALLY         2     1     0      3
# DIEGO                 2     1     1      4
# TWELVE                3     1     1      5
# INSPIRATION          10     2     3     15
# OFFICER               8     2     1     11
# CARED                 3     1     1      5
# NETHERLANDS           6     1     1      8
# COMPETITION          16     3     4     23
# HOPEFUL               2     1     1      4
# AVENUE                5     1     1      7
# INCIDENT              3     1     1      5
# CARDBOARD             5     1     1      7
# RATHER               46    10     9     65
# JIM                   2     1     1      4
# ADS                   4     1     1      6
# WARMING               6     1     2      9
# HOMO                  2     1     0      3
# CARPENTRY             2     1     0      3
# LEAD                 32     7     7     46
# SWIRLING              2     1     0      3
# REACHING              8     2     1     11
# DISCOVERY            15     3     3     21
# VOLCANO               2     1     1      4
# ANYONE               60    13    13     86
# LEMONADE              2     1     0      3
# THERE'RE              3     1     1      5
# REASON              116    25    25    166
# BATH                  2     1     0      3
# O                     2     1     1      4
# UNEMPLOYMENT          6     1     1      8
# ANSWERED              3     1     1      5
# OUR                 941   202   201   1344
# SEEING               48    10    10     68
# UNEXPECTED            2     1     1      4
# PHOTOGRAPHED          2     1     0      3
# SPEECH               24     5     5     34
# GENERATE             14     3     3     20
# LAPTOP                6     1     1      8
# DIVERSE               7     2     1     10
# UPSET                10     2     3     15
# MONK                  2     1     1      4
# BLINDNESS             3     1     1      5
# SAVE                 20     4     4     28
# INCREASED             7     2     1     10
# JEWELRY               2     1     1      4
# TERRORIST             7     2     1     10
# THIRDLY               2     1     1      4
# EXCITED              28     6     6     40
# COGNITIVE            11     2     3     16
# BASE                 10     2     3     15
# WOKEN                 2     1     0      3
# EQUAL                18     4     3     25
# GUESSING              2     1     0      3
# PUBLICATION           2     1     1      4
# HARNESS               3     1     1      5
# COLLAPSE              8     2     1     11
# HEADING               2     1     1      4
# PLATFORM             16     3     4     23
# SUPER                16     3     4     23
# PLANTING              3     1     1      5
# BLA                   2     1     0      3
# MENTORING             2     1     0      3
# NOTICED              15     3     4     22
# AUDITION              2     1     0      3
# KOREAN                3     1     1      5
# BEING               290    62    62    414
# REVOLUTION           13     3     3     19
# COX                   2     1     0      3
# METAL                 8     2     1     11
# GRAVE                 8     2     1     11
# EFFORT               19     4     4     27
# CHARITY               6     1     2      9
# ABOUT              1576   338   338   2252
# ETHICS                2     1     0      3
# STATEMENT            16     3     4     23
# SPORTING              2     1     0      3
# ISLAND               24     5     6     35
# CAKE                  6     1     2      9
# IRELAND               2     1     1      4
# FUELED                2     1     0      3
# EXPLORATION           4     1     1      6
# PROPOSED              2     1     1      4
# REDUCED               6     1     1      8
# THING               745   160   159   1064
# ELLEN                 2     1     0      3
# THRILL                2     1     0      3
# HAND                136    29    29    194
# OKAY                 43     9    10     62
# COMPROMISE            2     1     0      3
# NEIGHBOR             13     3     2     18
# LHC                   2     1     1      4
# MATTHEW               2     1     0      3
# DIFFERENCE           52    11    11     74
# DOCUMENTARY           2     1     1      4
# WIKIPEDIA             5     1     1      7
# LOG                   5     1     1      7
# DOING               248    53    54    355
# TECHNOLOGY           88    19    19    126
# POSSIBLY             22     5     5     32
# RESEARCH            100    21    22    143
# VACATION              7     2     1     10
# BRUSHED               2     1     0      3
# COLLABORATION        10     2     2     14
# APPLICATION          18     4     4     26
# ASK                 153    33    33    219
# WIDER                 2     1     1      4
# BRAIN               190    41    41    272
# TWICE                13     3     2     18
# COMPANIES            47    10    10     67
# ASKED                97    21    20    138
# DENIAL                4     1     1      6
# ISN                   2     1     0      3
# CAUSE                46    10    10     66
# PERSON              151    32    33    216
# EVENT                36     8     7     51
# FUNCTIONING           4     1     1      6
# PAINTER               2     1     0      3
# COMPLEX              34     7     7     48
# JURY                  2     1     0      3
# SECONDARY             3     1     1      5
# ASSUMED               3     1     1      5
# PHYSICALLY            7     2     1     10
# EVENTUALLY           41     9     9     59
# RISK                 52    11    11     74
# QUALIFIED             2     1     0      3
# ERA                  10     2     3     15
# MORE                687   147   147    981
# FICTIONAL             2     1     0      3
# ORGANIC              12     3     2     17
# ORG                   4     1     1      6
# SUICIDAL              4     1     1      6
# OBJECTIVE            11     2     3     16
# IT                 3498   750   749   4997
# TOGETHER            129    28    27    184
# APPALLING             2     1     0      3
# CAPABLE              13     3     2     18
# DIVIDED               5     1     1      7
# INSECURITY            3     1     1      5
# LAPILLI               2     1     0      3
# REGULATE              2     1     1      4
# DE                    5     1     1      7
# BRUSH                 4     1     1      6
# EVOLVE                7     2     1     10
# PHASE                 7     2     1     10
# ERIC                  4     1     1      6
# BASEMENT              5     1     1      7
# REFRIGERATOR          2     1     1      4
# JUNE                  2     1     1      4
# MOSQUE                2     1     0      3
# CURRENCY              4     1     1      6
# MEASUREMENT           6     1     2      9
# RELATIONSHIP         62    13    14     89
# RELEASE              11     2     3     16
# TYPE                 46    10     9     65
# GRIMMS                2     1     1      4
# DECIDE               39     8     9     56
# IMAGE                39     8     9     56
# SLAM                  2     1     1      4
# DEAF                  3     1     1      5
# GRANDSON              2     1     1      4
# REPORTER              6     1     2      9
# NUMB                  2     1     1      4
# DEAN                  2     1     0      3
# MOZART                6     1     1      8
# MENOPAUSE             3     1     1      5
# BROWN                 9     2     2     13
# COURSE              146    31    32    209
# BIRMINGHAM            2     1     1      4
# FEE                   3     1     1      5
# BETA                  2     1     0      3
# VULNERABLE           12     3     2     17
# RISING                3     1     1      5
# POLITICS             22     5     5     32
# BOTHER                5     1     1      7
# WAITING              27     6     6     39
# HAPPEN              206    44    45    295
# STABLE                7     2     1     10
# COLORED               2     1     0      3
# SIMPLIFY              2     1     1      4
# DIGIT                 4     1     1      6
# HIM                 174    37    37    248
# REACTIVE              2     1     0      3
# VALUABLE             11     2     3     16
# ANIMATOR              3     1     1      5
# UPTAKE                2     1     0      3
# ADVANCED              6     1     1      8
# CEO                   8     2     1     11
# FLUORESCENT           2     1     0      3
# REALIZATION           3     1     1      5
# ALONG                44     9    10     63
# MAIL                  8     2     1     11
# PRAYER                3     1     1      5
# INTROVERTS            2     1     1      4
# OIL                  20     4     4     28
# JAW                   6     1     1      8
# STANDARDIZED          3     1     1      5
# F                     4     1     1      6
# BRUSHING              2     1     1      4
# MILLION              78    17    16    111
# MANUFACTURER          4     1     1      6
# MECHANICAL            3     1     1      5
# ABUSE                13     3     2     18
# DRILL                 4     1     1      6
# GENERIC               2     1     1      4
# OBESITY               7     2     1     10
# VENUE                 2     1     0      3
# WITH               1543   331   330   2204
# TRIAL                18     4     3     25
# COMMUNICATION        14     3     3     20
# HOLLYWOOD             2     1     0      3
# BAGHDAD               2     1     0      3
# ROD                   2     1     0      3
# TAXES                 4     1     1      6
# INFECTIOUS            6     1     1      8
# MARATHON             10     2     2     14
# MINORITY              3     1     1      5
# YOGA                  6     1     1      8
# DEFINITIVE            2     1     0      3
# NEIL                  2     1     0      3
# GENERATOR             2     1     1      4
# RUNNING              42     9     9     60
# SISTER               24     5     6     35
# PORN                  4     1     1      6
# COOPERATE             3     1     1      5
# APPETITE              2     1     0      3
# PIE                   2     1     0      3
# BUREAUCRAT            2     1     0      3
# SURPRISING           11     2     3     16
# RURAL                 8     2     1     11
# SKYPE                 2     1     1      4
# EVIL                  4     1     1      6
# BOW                   2     1     0      3
# SYMMETRY              2     1     1      4
# ATHLETE              12     3     2     17
# HUNTER                6     1     2      9
# B                    18     4     4     26
# HONEY                 9     2     2     13
# DRIVING              24     5     6     35
# SAKE                  4     1     1      6
# FREAKED               4     1     1      6
# CELEBRATION           2     1     0      3
# RECOVER               2     1     1      4
# MARTIAL               2     1     0      3
# DESERT                8     2     1     11
# SEXISM                4     1     1      6
# SUGGESTING            3     1     1      5
# BLOW                  3     1     1      5
# IMPLEMENTED           4     1     1      6
# DATING                4     1     1      6
# NATIONAL             24     5     5     34
# LION                  3     1     1      5
# LINGUISTIC            3     1     1      5
# TOMBOY                2     1     1      4
# BLUE                 15     3     4     22
# STRUCTURE            27     6     5     38
# RECOVERY              7     2     1     10
# MATTER              116    25    25    166
# VIA                   2     1     1      4
# JAIL                  5     1     1      7
# INTERVIEWING          2     1     1      4
# SIBLING               2     1     1      4
# SIGN                 31     7     7     45
# CONSENSUS             2     1     1      4
# ONLINE               41     9     9     59
# SITUATION            41     9     9     59
# YORUBA                2     1     0      3
# OWN                 192    41    41    274
# HACKER                4     1     1      6
# TARAHUMARA            3     1     1      5
# MOSES                 2     1     0      3
# EAR                   9     2     2     13
# FRONT                46    10     9     65
# LIGHTING              5     1     1      7
# OVERALL              10     2     3     15
# PERSONALLY            7     2     1     10
# PARTY                27     6     6     39
# BUTTER                2     1     1      4
# LINED                 2     1     0      3
# WHOLE               123    26    27    176
# EDUCATION            63    14    13     90
# PLANTATION            2     1     0      3
# STUDIED              20     4     4     28
# A                  6041  1294  1295   8630
# FLAG                  3     1     1      5
# RHYME                 2     1     1      4
# FRUSTRATED           13     3     2     18
# ACCOUNTING            2     1     1      4
# LUNCH                 8     2     2     12
# PROCESS              78    17    16    111
# IDENTICAL             5     1     1      7
# EVIDENCE             33     7     7     47
# PANAMA                2     1     0      3
# MOTEL                 3     1     1      5
# HAS                 448    96    96    640
# SHOWN                23     5     5     33
# DIOXIDE               2     1     0      3
# TRACKER               2     1     0      3
# AID                  20     4     4     28
# KIDDING               2     1     1      4
# NONPROFIT             5     1     1      7
# EATING               25     5     6     36
# RID                  18     4     3     25
# BEETLE                2     1     0      3
# RELIABLE              5     1     1      7
# TRUSTED               2     1     0      3
# CAR                  90    19    20    129
# FAMOUS               14     3     3     20
# ESSENTIAL            13     3     2     18
# ORGASM                2     1     1      4
# ABRAHAM'S             2     1     0      3
# BIRTH                13     3     2     18
# LINEAR                3     1     1      5
# CADAVER               2     1     0      3
# NETWORKING            2     1     1      4
# PLANT                34     7     8     49
# ADOLESCENT            4     1     1      6
# REJECTED              9     2     2     13
# POSITION             22     5     5     32
# INVESTIGATE           6     1     1      8
# NEURAL                7     2     1     10
# GENETIC               8     2     1     11
# PROPOSITION           6     1     2      9
# EVERYBODY            77    16    17    110
# DEAL                 45    10     9     64
# PLAY                118    25    25    168
# ADDITION              6     1     1      8
# POSSIBLE             79    17    17    113
# LIGHT                65    14    14     93
# FIGURING              5     1     1      7
# SPOKE                12     3     2     17
# SUN                  15     3     3     21
# INCENTIVE             5     1     1      7
# ANNOUNCE              2     1     1      4
# ENGAGING              8     2     2     12
# TRANSGENDER           6     1     2      9
# BUTTON                8     2     2     12
# WELLNESS              2     1     1      4
# VIABLE                2     1     1      4
# DROP                 22     5     4     31
# CENTURY              36     8     7     51
# MAHATMA               2     1     0      3
# FISHERIES             3     1     1      5
# SUSTAINABLE           8     2     2     12
# THUS                  4     1     1      6
# OFFER                40     9     8     57
# ACCENT                2     1     1      4
# REVEAL                6     1     1      8
# LANE                  2     1     1      4
# WORKED               76    16    16    108
# ACTIVIST              8     2     1     11
# FROM                776   166   167   1109
# UNIT                  8     2     2     12
# HEAVILY               5     1     1      7
# NATURALLY            18     4     3     25
# SCREENING             2     1     1      4
# SPEED                20     4     5     29
# FOOTPRINT             2     1     1      4
# CLEARLY              12     3     2     17
# EARTHQUAKE            4     1     1      6
# TOMORROW             15     3     3     21
# WILDLIFE              2     1     1      4
# SMOKE                11     2     3     16
# SAINT                 5     1     1      7
# PHRASE               12     3     2     17
# SHELF                 4     1     1      6
# TRAFFIC              10     2     3     15
# STAGE                55    12    11     78
# PASSED               15     3     3     21
# FRENCH                9     2     2     13
# DRY                   5     0     2      7
# NASA                  4     1     1      6
# MAYOR                 8     2     1     11
# R                     8     2     1     11
# ALGORITHM            10     2     2     14
# MINI                  3     1     1      5
# TRAINING             33     7     7     47
# GARDEN               10     2     3     15
# SUPERSTAR             3     1     1      5
# PRECISELY             2     1     0      3
# CAPTAIN               2     1     0      3
# CUSTOM                6     1     2      9
# UNLEASHED             2     1     0      3
# WEAK                  6     1     2      9
# CO                   15     3     3     21
# GROUP               104    22    22    148
# BOX                  24     5     5     34
# CONSUMING             5     1     1      7
# WALKED               24     5     5     34
# APPLIES               7     2     1     10
# WHAT'S              164    35    36    235
# MEDITATION            6     1     2      9
# ANOTHER             151    32    33    216
# LADIES               12     3     2     17
# ASSEMBLY              2     1     1      4
# MASTER               11     2     3     16
# TABLE                30     6     7     43
# REBEL                 2     1     0      3
# APPLYING              2     1     0      3
# ZOO                   2     1     0      3
# FOLK                 13     3     2     18
# SPLIT                 2     1     1      4
# DEALT                 2     1     1      4
# SHOULDN'T            24     5     6     35
# GOLD                  8     2     1     11
# ANSWER              110    24    23    157
# ENDING                5     1     1      7
# NEUROSCIENCE          4     1     1      6
# SCHOLAR               4     1     1      6
# SEXUAL               21     4     5     30
# REPLACED              6     1     2      9
# IRAQ                 10     2     2     14
# PRETEND               6     1     2      9
# UNAWARE               3     1     1      5
# VEHICLE               7     2     1     10
# TOILET                8     2     1     11
# MIX                   3     1     1      5
# BRAND                20     4     5     29
# BOUND                 6     1     2      9
# RESILIENCE            7     2     1     10
# RESENTED              2     1     0      3
# INTEGRATED            3     1     1      5
# SHOULD'VE             2     1     0      3
# WINTER                6     1     1      8
# WIDOW                 2     1     1      4
# LEBANON               2     1     0      3
# RUGBY                 3     1     1      5
# BEGAN                52    11    11     74
# SECRETARY             4     1     1      6
# LAUNCHED              7     2     1     10
# MARIJUANA             6     1     2      9
# NOVELTY               2     1     0      3
# FAMILY'S              3     1     1      5
# NEXT                148    32    32    212
# MAINTENANCE           3     1     1      5
# PULLED               13     3     2     18
# SLOW                 16     3     4     23
# FLASHLIGHT            2     1     0      3
# EVALUATE              3     1     1      5
# AROUND              270    58    57    385
# SECTOR               10     2     3     15
# SUGGESTION           10     2     2     14
# HAPPINESS            25     5     6     36
# EMBRACED              3     1     1      5
# SMITH                 2     1     1      4
# EARTH                34     7     7     48
# DRIFT                 2     1     0      3
# Y                     2     1     0      3
# FLAT                  7     2     1     10
# COUNSEL               2     1     0      3
# GLOBALIZATION         8     2     1     11
# VOICE                46    10     9     65
# VALUE                73    16    15    104
# STEPHEN               5     1     1      7
# LOUSY                 2     1     1      4
# WORLDVIEW             2     1     1      4
# ROVER                 4     1     1      6
# SECOND              135    29    29    193
# VITAL                 5     1     1      7
# FEDERAL              12     3     2     17
# HELPING              23     5     5     33
# SEND                 37     8     8     53
# ENTHUSIASTIC          2     1     0      3
# INCOME               22     5     5     32
# HABITAT               5     1     1      7
# CONCEPT              35     8     7     50
# WRAPPED               4     1     1      6
# POLLUTION             4     1     1      6
# THEORETICAL           2     1     1      4
# VITAMIN               2     1     1      4
# WANNA                 4     1     1      6
# GRIEF                 4     1     1      6
# COWARD                2     1     0      3
# ACCOUNTANT            3     1     1      5
# ROW                   6     1     1      8
# WAGE                  3     1     1      5
# DROWNING              2     1     0      3
# STRANGER             13     3     2     18
# GROWER                2     1     1      4
# CLASSMATE             5     1     1      7
# EARN                  3     1     1      5
# INVOLVED             41     9     8     58
# CHOLESTEROL           4     1     1      6
# TRADITION            15     3     4     22
# OPENNESS              3     1     1      5
# CAPABILITIES          4     1     1      6
# INEFFICIENT           2     1     0      3
# TRIUMPH               2     1     0      3
# METAPHOR             11     2     3     16
# STIMULATE             3     1     1      5
# CREATE              117    25    25    167
# OCCURRED              5     1     1      7
# ACTING                5     1     1      7
# IDENTITY             18     4     4     26
# BANK                 24     5     6     35
# LESS                 71    15    16    102
# FOXES                 2     1     0      3
# WORLD               412    88    88    588
# MYSTERIES             2     1     1      4
# PLUS                  8     2     1     11
# GIFT                 12     3     2     17
# STORYTELLING          5     1     1      7
# SHORT                34     7     7     48
# REEF                  2     1     1      4
# SOVIET                4     1     1      6
# REPRESENT            15     3     4     22
# ISOLATED             10     2     2     14
# TRIP                 13     3     2     18
# TREMENDOUSLY          2     1     1      4
# SOME                533   114   115    762
# THOUGH               80    17    18    115
# HALL                  6     1     2      9
# DEAD                 27     6     5     38
# JEWISH                6     1     2      9
# MILK                  2     1     0      3
# WHEN                951   204   203   1358
# INTERACT             12     3     2     17
# JEFF                  2     1     1      4
# RETAIL                2     1     0      3
# FOOL                  7     2     1     10
# EXPERIMENTAL          2     1     0      3
# FUND                 12     3     2     17
# FRANKLY               7     2     1     10
# LICENSED              2     1     1      4
# MARINE               11     2     3     16
# ABSURD                2     1     1      4
# ANTIBODIES            3     1     1      5
# DISAPPEAR             4     1     1      6
# FRIENDLY              4     1     1      6
# FORWARD              43     9     9     61
# PENNY                 2     1     0      3
# PATTERN              32     7     7     46
# SIZED                 2     1     1      4
# COMMITMENT            3     1     1      5
# USA                   2     1     0      3
# NOUN                  2     1     1      4
# LIFESPAN              3     1     1      5
# PLUG                  2     1     0      3
# CHURCH               13     3     2     18
# BACKYARD              6     1     1      8
# SERVANT               2     1     0      3
# STUDY                83    18    17    118
# THEY'RE             287    62    61    410
# DROPPING              2     1     1      4
# GLAD                  6     1     1      8
# STEPPED               6     1     1      8
# PROGRESSIVE           3     1     1      5
# TWITTER              10     2     3     15
# HISTORICAL            3     1     1      5
# LATEST                6     1     1      8
# JOURNAL               6     1     1      8
# KEEP                 99    21    21    141
# TIE                   4     1     1      6
# TRANSPARENT           3     1     1      5
# CHANGER               6     1     2      9
# TOUCHING              3     1     1      5
# DIVINE                2     1     0      3
# ALLEN                 2     1     0      3
# CHEMISTRY            13     3     3     19
# THREAT               16     3     4     23
# EXCHANGE             11     2     3     16
# FRAGMENTS             2     1     1      4
# DIVE                  5     1     1      7
# TALK                237    51    51    339
# VACCINATION           2     1     1      4
# SUPREME               5     1     1      7
# STRANGE              15     3     3     21
# RITE                  2     1     0      3
# FADE                  2     1     0      3
# AFFECTING             6     1     1      8
# BLOWING               2     1     0      3
# RELEVANT              7     2     1     10
# QUEUE                 2     1     0      3
# PSYCHIATRIC           2     1     1      4
# WIFE                 24     5     5     34
# ASSIGNED              3     1     1      5
# WILLING              25     5     6     36
# ROBOT                30     6     7     43
# MISSES                3     1     1      5
# SUPPOSE               9     2     2     13
# STRUCTURED            2     1     0      3
# PHENOMENON           10     2     2     14
# RESUME                5     1     1      7
# RESTRICTION           2     1     0      3
# MENTALITY             4     1     1      6
# STRANGELY             2     1     0      3
# BREATH               18     4     3     25
# J                     2     1     1      4
# SPELL                 2     1     1      4
# SMALLEST              2     1     1      4
# RWANDA                2     1     0      3
# LIBERAL               8     2     1     11
# SAN                  10     2     2     14
# SERIES               14     3     3     20
# ASSURE                2     1     1      4
# YARD                  2     1     1      4
# REGISTER              3     1     1      5
# FUEL                 13     3     2     18
# GLOBE                 3     1     1      5
# STUDENT              81    17    18    116
# PROVEN                2     1     1      4
# FAIL                 12     3     2     17
# CROCHET               2     1     0      3
# SCARE                 3     1     1      5
# ESTATE                2     1     0      3
# OCCUR                 6     1     2      9
# H                     6     1     2      9
# ANALOG                5     1     1      7
# DETERMINED            4     1     1      6
# WALKABLE              2     1     0      3
# NAVIGATE              7     2     1     10
# RARELY                8     2     2     12
# NARCISSISTS           2     1     1      4
# PROCESSED             8     2     1     11
# SHUT                  7     1     2     10
# CONNECT              18     4     3     25
# FORMATION             2     1     0      3
# COMEDY                6     1     1      8
# ROUGH                 6     1     1      8
# COUNTRY'S             4     1     1      6
# MISERABLE             6     1     2      9
# EARNED                2     1     1      4
# EXPANDING             2     1     0      3
# VALIDATION            2     1     0      3
# FILED                 2     1     0      3
# VIRTUAL              12     3     2     17
# PULL                 15     3     4     22
# NOTICE               27     6     6     39
# MINDFULNESS           3     1     1      5
# EDGE                  7     2     1     10
# RECYCLED              2     1     1      4
# LAUGH                12     3     2     17
# SLOWED                2     1     1      4
# FALLING               5     1     1      7
# REALITIES             4     1     1      6
# STRAND                2     1     0      3
# RACING                2     1     0      3
# AUSTRALIAN            6     1     1      8
# HOTEL                11     2     3     16
# BLESS                 2     1     0      3
# CHIMPANZEE            6     1     2      9
# RESTROOM              4     1     1      6
# PLANNED               2     1     1      4
# MEASURING             2     1     1      4
# PARTLY                4     1     1      6
# PAKISTAN              3     1     1      5
# KATRINA               2     1     0      3
# ADAPT                 9     2     2     13
# CONCRETE              9     2     2     13
# MUST                 69    15    14     98
# VALLEY                6     1     1      8
# SINGLE               84    18    18    120
# SECTION               3     1     1      5
# CHEATING              2     1     1      4
# CORPORATE             8     2     1     11
# EXCEPT               14     3     3     20
# DETECTOR              4     1     1      6
# SCREAM                2     1     0      3
# DETENTION             3     1     1      5
# BESIDE                8     2     1     11
# MOTIVATED             8     2     1     11
# PROJECTING            2     1     0      3
# SIX                  46    10    10     66
# MONOPOLY              2     1     0      3
# DECIDED              67    14    15     96
# INTUITION             7     2     1     10
# DRAWING              10     2     2     14
# NATURAL              43     9    10     62
# OUTDOOR               3     1     1      5
# DIMENSION             6     1     2      9
# SHARE                88    19    19    126
# SOLAR                20     4     5     29
# SWITZERLAND           4     1     1      6
# CONFRONTED            3     1     1      5
# DYSFUNCTION           4     1     1      6
# HONESTLY              8     2     2     12
# ASSESSMENT            2     1     0      3
# COFFEE               13     3     3     19
# LEADING              14     3     3     20
# BELOW                 6     1     2      9
# SHINE                 2     1     0      3
# EVERYDAY             22     5     5     32
# PHD                   6     1     1      8
# PERPETRATOR           5     1     1      7
# THROWING              7     2     1     10
# CONSIDERED           19     4     4     27
# FUNCTIONAL            4     1     1      6
# TOLERATE              5     1     1      7
# EXPLOITED             2     1     1      4
# SHADOW                8     2     1     11
# FOG                   2     1     0      3
# REVOLVE               2     1     0      3
# G                     6     1     2      9
# APART                22     5     5     32
# RUSSIAN               8     2     2     12
# ALLIANCE              2     1     1      4
# FASCINATED            8     2     1     11
# MOLDOVA               3     1     1      5
# SPARKED               2     1     0      3
# MS                    6     1     1      8
# BEEN                433    93    93    619
# WISHED                3     1     1      5
# TAKE                348    75    74    497
# OURSELVES            90    19    20    129
# MAINTAIN              6     1     2      9
# MARROW                2     1     0      3
# SWEEP                 3     1     1      5
# POT                   2     1     0      3
# RENEWABLE             5     1     1      7
# EXERCISE             24     5     5     34
# WELFARE               3     1     1      5
# TIDE                  2     1     1      4
# STAND                41     9     9     59
# CLEVER                5     1     1      7
# DISAPPEARED           2     1     0      3
# MISERY                2     1     0      3
# HAROLD                2     1     0      3
# RAISE                21     4     5     30
# SURRENDER             4     1     1      6
# ...
# DISASTER             10     2     2     14
# STRAIGHTFORWARD       2     1     1      4
# ISSUE                76    16    16    108
# BEE                  15     3     3     21
# REVOLUTIONARY         2     1     1      4
# SCULPTURE             2     1     1      4
# ESTABLISHED           3     1     1      5
# FOREST               18     4     4     26
# PIZZA                 3     1     1      5
# WORKFORCE             3     1     1      5
# ONE                1094   234   235   1563
# SEARCH               20     4     5     29
# NUCLEAR              12     3     2     17
# CONTAIN               3     1     1      5
# SOAP                  2     1     1      4
# KEEN                  2     1     1      4
# STRUCK                3     1     1      5
# REMARKABLY            3     1     1      5
# RANDOMLY              4     1     1      6
# HAWAIIANS             2     1     1      4
# GENITAL               2     1     1      4
# CROWD                 5     1     1      7
# JURISDICTION          2     1     0      3
# UK                   13     3     3     19
# PERMISSION           14     3     3     20
# TERRIBLE             29     6     7     42
# CLUSTER               3     1     1      5
# SOUNDSCAPE            2     1     1      4
# COMING               80    17    18    115
# SUBJECTIVE            2     1     0      3
# PLANNER               2     1     1      4
# MINING                3     1     1      5
# IRONIC                3     1     1      5
# D                    17     4     3     24
# ENABLE                8     2     2     12
# GROCERY               3     1     1      5
# RETURN                8     2     2     12
# GREAT               207    44    45    296
# INCREASING            7     2     1     10
# KNIT                  3     1     1      5
# SIMPLY               50    11    10     71
# CONFIDENT            10     2     2     14
# CLICHE                2     1     0      3
# LITER                 3     1     1      5
# ELEVATE               2     1     0      3
# LIKELIHOOD            2     1     1      4
# BLOOD                36     8     8     52
# REPEAT                8     2     2     12
# DISPOSAL              2     1     1      4
# BORROW                4     1     1      6
# HOLY                  7     1     2     10
# STRETCH               5     1     1      7
# WEBSITE              22     5     4     31
# NASTY                 5     1     1      7
# YESTERDAY            10     2     3     15
# NORM                  7     2     1     10
# USEFUL               13     3     2     18
# LASER                 3     1     1      5
# SE                    2     1     0      3
# EXAGGERATION          2     1     0      3
# LEGEND                5     1     1      7
# ABUSED                2     1     1      4
# SENT                 20     4     5     29
# UNLUCKY               2     1     0      3
# SMILING               2     1     1      4
# SQUARE                9     2     2     13
# NEEDING               2     1     0      3
# LAWYER               17     4     3     24
# HEAVY                 5     1     1      7
# EMPOWERED             4     1     1      6
# DEFINE               18     4     4     26
# BLIND                20     4     5     29
# LIP                   2     1     0      3
# ADULT                34     7     7     48
# AMBULANCE             2     1     1      4
# CHASING               2     1     1      4
# DISCOVERED           32     7     7     46
# FLORIDA               4     1     1      6
# REGRET                6     1     2      9
# THREAD                2     1     1      4
# GAME                 72    15    16    103
# REUNITE               2     1     0      3
# UNBELIEVABLE          2     1     0      3
# AUGMENTED             2     1     0      3
# RENAISSANCE           2     1     1      4
# REDUCE               18     4     3     25
# COMMAND               4     1     1      6
# FIFTY                 2     1     1      4
# BLAST                 2     1     0      3
# TREE                 25     5     6     36
# ROTTEN                2     1     0      3
# CONSULTANT            3     1     1      5
# BEAR                 11     2     3     16
# PROMISE              20     4     4     28
# ENGINEER             20     4     5     29
# FUN                  34     7     8     49
# ACTIVITY             17     4     3     24
# SNOWDEN               2     1     1      4
# BOAT                 12     3     2     17
# OMEGA                 2     1     1      4
# FLOWING               2     1     0      3
# SLIP                  2     1     1      4
# ADDICTED              4     1     1      6
# CONSENT              11     2     3     16
# PERCEIVE             10     2     3     15
# EQUIVALENT            2     1     1      4
# PARADIGM              6     1     2      9
# LAVA                  2     1     0      3
# GRADUATION            2     1     0      3
# DOUBLED               2     1     1      4
# COHEN                 2     1     0      3
# EMPIRICAL             2     1     0      3
# CONGESTION            2     1     0      3
# CAROLINA              2     1     1      4
# TOOK                104    22    23    149
# GOLF                  3     1     1      5
# PHILOSOPHY           14     3     3     20
# MANUFACTURE           4     1     1      6
# PLANTED               3     1     1      5
# ISLAMIST              2     1     0      3
# VS                    2     1     1      4
# STRICT                2     1     0      3
# DOCTOR               74    16    15    105
# MUM                   7     2     1     10
# NORMAN                2     1     0      3
# CABLE                 4     1     1      6
# QUICK                 8     2     2     12
# GONE                 40     9     8     57
# NAKED                 2     1     0      3
# EXPENSE               5     1     1      7
# DANCE                12     3     2     17
# HANGING               3     1     1      5
# LOSING               15     3     3     21
# FULFILLING            3     1     1      5
# POSE                  5     1     1      7
# COMMITTEE             2     1     1      4
# TOWARD               44     9    10     63
# DECENT                2     1     0      3
# WASHINGTON            9     2     2     13
# PRE                   9     2     2     13
# HORMONE              13     3     3     19
# WEAPON               14     3     3     20
# ABLE                195    42    42    279
# CRYSTALS              2     1     0      3
# MARK                 15     3     3     21
# COOPERATIVE           2     1     1      4
# ASTONISHED            2     1     0      3
# STRATEGIC             2     1     0      3
# BONUS                 2     1     0      3
# DEPEND               10     2     3     15
# MINISTER              6     1     1      8
# SERGIO                2     1     0      3
# EXPLAIN              37     8     8     53
# RELYING               2     1     0      3
# WORKPLACE             6     1     2      9
# NICE                 44     9    10     63
# UNLIKELY              2     1     1      4
# PULSE                 2     1     0      3
# UCLA                  2     1     1      4
# READ                 75    16    16    107
# FELT                 76    16    16    108
# ICE                  13     3     3     19
# FORTY                 3     1     1      5
# PRINCIPAL             3     1     1      5
# MODEL                66    14    14     94
# HERE'S               48    10    10     68
# DOES                209    45    45    299
# SELFISH               3     1     1      5
# SYNAPSES              2     1     0      3
# HORRIFYING            2     1     0      3
# UPRIGHT               2     1     0      3
# VOTING               10     2     2     14
# BROUGHT              34     7     8     49
# CONSUMED              2     1     1      4
# KEPT                 38     8     8     54
# PHOTO                17     4     3     24
# RANCHER               2     1     0      3
# UNKNOWN               5     1     1      7
# ONLY                333    71    72    476
# MIGRATION             4     1     1      6
# PRODUCER              4     1     1      6
# STAYED               11     2     3     16
# EMPOWERMENT           2     1     0      3
# VICTIM               26     6     5     37
# FULLY                14     3     3     20
# INSPIRED             27     6     5     38
# FILMING               3     1     1      5
# CORE                 13     3     3     19
# SYNDROME              6     1     2      9
# MARKET               42     9     9     60
# ADDICTIVE             3     1     1      5
# CONTRADICTION         3     1     1      5
# PUSH                 27     6     6     39
# MOBILE               22     5     4     31
# ITSELF               33     7     7     47
# OVERDOSE              2     1     1      4
# PRESCRIPTION          5     1     1      7
# NELSON                2     1     1      4
# ROYAL                 2     1     0      3
# NUDGING               2     1     0      3
# TACKLE                7     2     1     10
# JUDGEMENT             2     1     1      4
# APPLIED              10     2     2     14
# RATIONALE             2     1     0      3
# WEIRD                18     4     4     26
# COLLECTIVELY          3     1     1      5
# SLIPPED               2     1     1      4
# TRANSFERRED           3     1     1      5
# PINT                  2     1     0      3
# INDEED               18     4     4     26
# STANFORD              7     2     1     10
# COOPERATION           2     1     0      3
# IMPLANT               3     1     1      5
# DIVERSITY            13     3     3     19
# ARAB                  9     0     5     14
# SHOULD              195    42    41    278
# TRUSTING              2     1     0      3
# VOTE                 20     4     4     28
# BREEDING              3     1     1      5
# LEWIS                 2     1     0      3
# PERIOD               20     4     5     29
# ENCOUNTER             5     1     1      7
# WORRIES               3     1     1      5
# VOCABULARY            4     1     1      6
# JACK                  4     1     1      6
# YEAH                 43     9    10     62
# CORPORATION           4     1     1      6
# FAILED               15     3     4     22
# MET                  48    10    11     69
# MALE                 38     8     9     55
# DETECT                6     1     1      8
# HAVEN'T              38     8     8     54
# ROCKET                8     1     2     11
# ALREADY              95    20    21    136
# LINE                 51    11    11     73
# OXYGEN               13     3     2     18
# GHOST                 2     1     0      3
# IMPORTANT           192    41    41    274
# HIGHWAY               2     1     1      4
# SICK                 13     3     3     19
# WORD                147    32    31    210
# IMAGINATION          17     4     3     24
# SPARK                 2     1     0      3
# OWNED                 4     1     1      6
# TUNNEL                6     1     1      8
# ASTRONAUT             3     1     1      5
# HER                 286    61    61    408
# UNTRUE                2     1     0      3
# WIRED                 5     1     1      7
# LETTER               27     6     6     39
# APPROACHED            4     1     1      6
# CONNECTED            18     4     3     25
# ON                 1359   291   291   1941
# FARM                 17     4     3     24
# INTERVENE             2     1     1      4
# YES                  66    14    15     95
# COAST                 7     2     1     10
# MIDST                 4     1     1      6
# TRACKING              2     1     0      3
# SEARCHING             5     1     1      7
# FORBIDDEN             2     1     0      3
# OK                   73    16    15    104
# KOSOVO                2     1     0      3
# AWARD                 6     1     1      8
# PEACH                 2     1     0      3
# ACCUMULATION          2     1     0      3
# SAM                   4     1     1      6
# COVERED               7     2     1     10
# CRYING               15     3     3     21
# MONASTERY             2     1     0      3
# HAMILTON              2     1     1      4
# VIOLENT               8     2     2     12
# CONTEST               2     1     0      3
# WILLINGNESS           3     1     1      5
# VOLUME                8     2     1     11
# M                    13     3     2     18
# NEWSPAPER             8     2     1     11
# TRADITIONAL          19     4     4     27
# DYNAMIC              14     3     3     20
# LIMIT                15     3     3     21
# TERM                 78    17    17    112
# CORPSE                2     1     1      4
# INTO                368    79    79    526
# RATE                 43     9    10     62
# UNDERSTAND          146    31    32    209
# MANHOOD               2     1     0      3
# INNOVATE              5     1     1      7
# CAPITAL              13     3     2     18
# ALGEBRA               2     1     1      4
# MILD                  3     1     1      5
# COMMENT               6     1     1      8
# OAKLAND               2     1     0      3
# INSULT                2     1     0      3
# LIMITED               9     2     2     13
# MOOD                  5     1     1      7
# DIAGNOSE              6     1     1      8
# SAVED                 8     2     2     12
# EMBODIMENT            2     1     0      3
# DEVELOPER             2     1     1      4
# TRANSLATING           2     1     1      4
# MOTHER               80    17    17    114
# THRILLED              2     1     0      3
# HITTING               2     1     1      4
# ENVIRONMENTAL         8     2     1     11
# SPIRITUALITY          2     1     1      4
# MINOR                 3     1     1      5
# INVENTOR              4     1     1      6
# GERMAN               12     3     2     17
# MIRACLE               3     1     1      5
# ASSET                 5     1     1      7
# BRIEFLY               5     1     1      7
# PAIN                 39     8     9     56
# DULL                  2     1     0      3
# AD                    8     2     1     11
# SHIP                  3     1     1      5
# AGREEMENT             3     1     1      5
# ACQUIRE               5     1     1      7
# DESPERATELY           6     0     2      8
# SOFTWARE             18     4     4     26
# EXPLODING             2     1     0      3
# SOCIETIES             4     1     1      6
# SEARCHES              2     1     1      4
# STORYTELLER           5     1     1      7
# ABDOMINAL             2     1     0      3
# DIGGING               2     1     0      3
# BULLET                5     1     1      7
# IN                 3958   848   849   5655
# CLUE                  4     1     1      6
# POEM                 16     3     4     23
# ATTRACTED             3     1     1      5
# REPAIR                2     1     1      4
# COPE                  6     1     1      8
# CONFUSING             4     1     1      6
# LESSON               24     5     5     34
# RESOLUTION            3     1     1      5
# CONTRAST              5     1     1      7
# KING                 13     3     2     18
# LGBT                  3     1     1      5
# REMOVING              2     1     0      3
# FROG                  5     1     1      7
# CONSUME               8     2     1     11
# SECRET               21     4     5     30
# BREAKING              5     1     1      7
# THOMAS                4     1     1      6
# FOLD                  6     1     1      8
# ADVERTISEMENT         3     1     1      5
# MUSTER                2     1     0      3
# GRANT                 6     1     2      9
# CLIMB                 5     1     1      7
# AM                  198    42    43    283
# TESTING              10     2     2     14
# HEARTBREAKING         2     1     0      3
# BOIL                  2     1     0      3
# ENJOY                19     4     4     27
# ANALYZED              2     1     0      3
# PURELY                4     1     1      6
# EXACT                20     4     4     28
# HETEROSEXUAL          6     1     2      9
# GERMANY              10     2     3     15
# EARLY                46    10    10     66
# CUTTING              10     2     3     15
# STILL               134    29    29    192
# BLAMED                2     1     0      3
# BRIGHT               11     2     3     16
# CHROMOSOME            3     1     1      5
# DISRUPT               2     1     1      4
# SPRING               10     2     2     14
# HUMOR                 6     1     1      8
# THIS               2421   519   518   3458
# MEAT                 10     2     2     14
# PROVIDER              2     1     1      4
# ACTIVE               13     3     2     18

# %%
updated_total_train = updated_df['train'].sum()
updated_total_val = updated_df['val'].sum()
updated_total_test = updated_df['test'].sum()

print(f"\nTotal train: {updated_total_train}")
print(f"Total val: {updated_total_val}")
print(f"Total test: {updated_total_test}")
# Out:
# Total train: 246460
# Total val: 54120
# Total test: 53000

# %%
updated_v2_df = create_df(dir)

# %%
print("Number of classes not in test set: ", len(updated_v2_df[updated_v2_df['test'] == 0]), "/", len(updated_v2_df))
print("Number of classes in test set: ", len(updated_v2_df[updated_v2_df['test'] != 0]), "/", len(updated_v2_df))
# Out:
# Number of classes not in test set:  1121 / 6125
# Number of classes in test set:  5004 / 6125

# %%
updated_df = create_df(dir)

min = print(updated_df['total'].min())
max = print(updated_df['total'].max())
max_value = updated_df['total'].max()  # Get the max value from the 'total' column
for i in range(0, max_value + 1):  # Use max_value instead of max
    total = (updated_df['total'] == i).sum()
    if total != 0:
        print(f"{i} files - {total}")
# Out:
# 3
# 14395
# 3 files - 1121
# 4 files - 772
# 5 files - 525
# 6 files - 415
# 7 files - 303
# 8 files - 238
# 9 files - 223
# 10 files - 181
# 11 files - 161
# 12 files - 122
# 13 files - 95
# 14 files - 99
# 15 files - 80
# 16 files - 93
# 17 files - 85
# 18 files - 74
# 19 files - 56
# 20 files - 60
# 21 files - 52
# 22 files - 41
# 23 files - 45
# 24 files - 48
# 25 files - 41
# 26 files - 41
# 27 files - 28
# 28 files - 27
# 29 files - 25
# 30 files - 21
# 31 files - 28
# 32 files - 20
# 33 files - 16
# 34 files - 25
# 35 files - 28
# 36 files - 13
# 37 files - 15
# 38 files - 22
# 39 files - 21
# 40 files - 29
# 41 files - 5
# 42 files - 18
# 43 files - 14
# 44 files - 15
# 45 files - 11
# 46 files - 20
# 47 files - 14
# 48 files - 12
# 49 files - 11
# 50 files - 7
# 51 files - 14
# 52 files - 13
# 53 files - 11
# 54 files - 11
# 55 files - 13
# 56 files - 10
# 57 files - 5
# 58 files - 8
# 59 files - 10
# 60 files - 8
# 61 files - 9
# 62 files - 6
# 63 files - 6
# 64 files - 7
# 65 files - 12
# 66 files - 10
# 67 files - 8
# 68 files - 6
# 69 files - 6
# 70 files - 1
# 71 files - 6
# 72 files - 4
# 73 files - 5
# 74 files - 8
# 75 files - 3
# 76 files - 5
# 77 files - 5
# 78 files - 5
# 79 files - 3
# 80 files - 7
# 81 files - 7
# 82 files - 4
# 83 files - 2
# 84 files - 2
# 85 files - 5
# 86 files - 2
# 87 files - 7
# 88 files - 7
# 89 files - 4
# 90 files - 1
# 91 files - 6
# 92 files - 3
# 93 files - 6
# 94 files - 4
# 95 files - 5
# 96 files - 2
# 97 files - 2
# 98 files - 4
# 99 files - 1
# 101 files - 2
# 102 files - 4
# 103 files - 3
# 104 files - 5
# 105 files - 5
# 106 files - 4
# 107 files - 2
# 108 files - 7
# 110 files - 2
# 111 files - 4
# 112 files - 7
# 113 files - 4
# 114 files - 5
# 115 files - 4
# 116 files - 2
# 117 files - 3
# 118 files - 2
# 119 files - 1
# 120 files - 2
# 121 files - 4
# 122 files - 1
# 123 files - 4
# 124 files - 3
# 125 files - 3
# 126 files - 5
# 127 files - 4
# 128 files - 2
# 129 files - 3
# 130 files - 1
# 131 files - 3
# 132 files - 1
# 133 files - 1
# 134 files - 1
# 135 files - 2
# 136 files - 5
# 137 files - 1
# 138 files - 2
# 139 files - 2
# 140 files - 1
# 141 files - 3
# 142 files - 1
# 143 files - 5
# 144 files - 2
# 145 files - 1
# 146 files - 1
# 147 files - 1
# 148 files - 3
# 149 files - 2
# 151 files - 1
# 153 files - 1
# 154 files - 1
# 157 files - 1
# 158 files - 1
# 160 files - 2
# 162 files - 2
# 163 files - 2
# 164 files - 1
# 165 files - 2
# 166 files - 3
# 167 files - 1
# 168 files - 1
# 171 files - 1
# 172 files - 3
# 173 files - 1
# 176 files - 3
# 178 files - 2
# 180 files - 2
# 181 files - 1
# 184 files - 3
# 185 files - 2
# 186 files - 1
# 187 files - 2
# 188 files - 1
# 189 files - 1
# 190 files - 1
# 191 files - 2
# 192 files - 2
# 193 files - 1
# 194 files - 3
# 196 files - 2
# 197 files - 1
# 198 files - 3
# 200 files - 2
# 202 files - 1
# 205 files - 1
# 207 files - 1
# 208 files - 1
# 209 files - 2
# 210 files - 2
# 211 files - 1
# 212 files - 2
# 216 files - 2
# 219 files - 1
# 224 files - 1
# 228 files - 1
# 229 files - 2
# 230 files - 1
# 234 files - 1
# 235 files - 2
# 238 files - 1
# 244 files - 1
# 248 files - 1
# 252 files - 1
# 254 files - 1
# 255 files - 2
# 256 files - 1
# 257 files - 1
# 261 files - 1
# 262 files - 1
# 265 files - 1
# 270 files - 2
# 272 files - 2
# 274 files - 2
# 278 files - 2
# 279 files - 1
# 281 files - 2
# 282 files - 1
# 283 files - 1
# 284 files - 3
# 293 files - 1
# 294 files - 2
# 295 files - 1
# 296 files - 1
# 299 files - 1
# 300 files - 1
# 301 files - 1
# 302 files - 1
# 304 files - 1
# 305 files - 1
# 306 files - 1
# 308 files - 1
# 310 files - 1
# 311 files - 2
# 312 files - 1
# 313 files - 1
# 326 files - 1
# 339 files - 2
# 355 files - 1
# 358 files - 1
# 359 files - 1
# 368 files - 1
# 370 files - 1
# 376 files - 2
# 385 files - 1
# 387 files - 1
# 394 files - 1
# 400 files - 1
# 402 files - 1
# 404 files - 1
# 407 files - 1
# 408 files - 2
# 410 files - 1
# 414 files - 1
# 415 files - 1
# 422 files - 1
# 424 files - 1
# 435 files - 1
# 436 files - 1
# 444 files - 1
# 452 files - 1
# 454 files - 2
# 459 files - 1
# 462 files - 1
# 476 files - 1
# 486 files - 1
# 487 files - 1
# 489 files - 1
# 492 files - 1
# 493 files - 1
# 495 files - 1
# 497 files - 1
# 501 files - 1
# 503 files - 1
# 522 files - 1
# 526 files - 1
# 542 files - 2
# 544 files - 1
# 545 files - 1
# 574 files - 1
# 583 files - 1
# 585 files - 1
# 588 files - 1
# 590 files - 1
# 594 files - 1
# 610 files - 1
# 615 files - 1
# 619 files - 1
# 620 files - 1
# 622 files - 1
# 640 files - 1
# 657 files - 1
# 663 files - 1
# 677 files - 1
# 679 files - 1
# 688 files - 1
# 690 files - 1
# 720 files - 2
# 734 files - 1
# 746 files - 1
# 760 files - 1
# 762 files - 1
# 773 files - 1
# 794 files - 1
# 851 files - 1
# 852 files - 1
# 868 files - 1
# 896 files - 1
# 898 files - 1
# 940 files - 1
# 947 files - 1
# 953 files - 1
# 955 files - 1
# 963 files - 1
# 976 files - 1
# 977 files - 1
# 981 files - 1
# 1001 files - 1
# 1063 files - 1
# 1064 files - 2
# 1068 files - 1
# 1080 files - 1
# 1084 files - 1
# 1088 files - 1
# 1092 files - 1
# 1095 files - 1
# 1102 files - 1
# 1103 files - 1
# 1109 files - 1
# 1121 files - 1
# 1195 files - 1
# 1198 files - 1
# 1215 files - 1
# 1249 files - 1
# 1262 files - 1
# 1344 files - 1
# 1348 files - 1
# 1358 files - 1
# 1423 files - 1
# 1435 files - 1
# 1460 files - 1
# 1496 files - 1
# 1563 files - 1
# 1591 files - 1
# 1647 files - 1
# 1676 files - 1
# 1749 files - 1
# 1941 files - 1
# 2049 files - 1
# 2083 files - 1
# 2129 files - 1
# 2204 files - 1
# 2252 files - 1
# 2359 files - 1
# 2428 files - 1
# 2499 files - 1
# 2701 files - 1
# 2716 files - 1
# 2750 files - 1
# 2842 files - 1
# 2887 files - 1
# 3363 files - 1
# 3368 files - 1
# 3458 files - 1
# 4997 files - 1
# 5066 files - 1
# 5380 files - 1
# 5655 files - 1
# 6171 files - 1
# 8124 files - 1
# 8630 files - 1
# 8715 files - 1
# 8773 files - 1
# 11138 files - 1
# 11688 files - 1
# 14395 files - 1

# %%
total_100 = (updated_df['total'] <= 100).sum()
print(f"<= 100 files - {total_100}")
total_100_high = (updated_df['total'] > 100).sum()
print(f"> 100 files - {total_100_high}")
# Out:
# <= 100 files - 5715
# > 100 files - 410

# %%
def create_npz_df(dir):
    word_data_counts = defaultdict(lambda: defaultdict(lambda: defaultdict(int)))
    
    for word in os.listdir(dir):
        word_path = os.path.join(dir, word)
    
        if not os.path.isdir(word_path):
            print(f"Skipping {word}: not a directory.")
            continue
    
        for split in ['train', 'val', 'test']:
            split_path = os.path.join(word_path, split)
            
            if not os.path.isdir(split_path):
                continue
        
            file_count = sum(1 for file in os.listdir(split_path) if file.endswith(".npz"))
            word_data_counts[word][split]["total"] = file_count

    df = pd.DataFrame(columns=["train", "val", "test"])
    
    for word, splits in word_data_counts.items():
        row = {}
        row["train"] = splits["train"]["total"]
        row["val"] = splits["val"]["total"]
        row["test"] = splits["test"]["total"]
        df.loc[word] = row
    
    df['total'] = df[['train', 'val', 'test']].sum(axis=1)
    return df

# %%
# Check updated (after converting npz files)
new_dir = "../../../models/DC-TCN/datasets/lrs3_words_may"
updated_df = create_npz_df(new_dir)
print(updated_df)

updated_total_train = updated_df['train'].sum()
updated_total_val = updated_df['val'].sum()
updated_total_test = updated_df['test'].sum()

print(f"\nTotal train: {updated_total_train}")
print(f"Total val: {updated_total_val}")
print(f"Total test: {updated_total_test}")
# Out:
#              train  val  test  total
# VIEWED           2    1     1      4
# HOGG             0    0     0      0
# CABBAGE          0    0     0      0
# RECENTLY        22    5     4     31
# SHAMELESSLY      0    0     0      0
# ...            ...  ...   ...    ...
# HUMOR            6    1     1      8
# THIS          2421  519   518   3458
# MEAT            10    2     2     14
# PROVIDER         2    1     1      4
# ACTIVE          13    3     2     18
#
# [6775 rows x 4 columns]
#
# Total train: 246003
# Total val: 54013
# Total test: 52900

# %%
# drop/delete the word folders that only contain 0 files (accidentally create duration for the wrong folder)
words_to_delete = updated_df[updated_df['total'].isin([0])].index
print(words_to_delete)
deleted = 0

for word in words_to_delete:
    folder_path = os.path.join(new_dir, word)

    if os.path.exists(folder_path):
        shutil.rmtree(folder_path)
        deleted += 1
print(f"total deleted: {deleted}")
# Out:
# Index(['HOGG', 'CABBAGE', 'SHAMELESSLY', 'FREESTYLE', 'PHILOSOPHERS',
#        'WARHEAD', 'GASCOIGNE', 'INVARIABLY', 'HERBAL', 'WELLS',
#        ...
#        'SMELLS', 'NOBILITY', 'NEEDLEWORK', 'NORTHWEST', 'JAY', 'CUDDLE',
#        'CHARGER', 'PRESERVATION', 'MISLEADING', 'FARNESE'],
#       dtype='object', length=705)
# total deleted: 705

# %%
# Check updated (after converting npz files)
new_dir = "../../../models/DC-TCN/datasets/lrs3_words_may"
updated_df = create_npz_df(new_dir)
print(updated_df)

updated_total_train = updated_df['train'].sum()
updated_total_val = updated_df['val'].sum()
updated_total_test = updated_df['test'].sum()

print(f"\nTotal train: {updated_total_train}")
print(f"Total val: {updated_total_val}")
print(f"Total test: {updated_total_test}")
# Out:
#           train  val  test  total
# VIEWED        2    1     1      4
# RECENTLY     22    5     4     31
# ARRIVE        6    1     1      8
# THEIR       596  128   128    852
# ARABIC        2    1     0      3
# ...         ...  ...   ...    ...
# HUMOR         6    1     1      8
# THIS       2421  519   518   3458
# MEAT         10    2     2     14
# PROVIDER      2    1     1      4
# ACTIVE       13    3     2     18
#
# [6070 rows x 4 columns]
#
# Total train: 246003
# Total val: 54013
# Total test: 52900

# %%
print("Number of classes not in test set: ", len(updated_df[updated_df['test'] == 0]), "/", len(updated_df))
print("Number of classes in test set: ", len(updated_df[updated_df['test'] != 0]), "/", len(updated_df))
# Out:
# Number of classes not in test set:  1113 / 6070
# Number of classes in test set:  4957 / 6070

# %%
total_100 = (updated_df['total'] <= 100).sum()
print(f"<= 100 files - {total_100}")
total_100_high = (updated_df['total'] > 100).sum()
print(f"> 100 files - {total_100_high}")
# Out:
# <= 100 files - 5661
# > 100 files - 409

# %%
# Check updated (after converting npz files)
new_dir = "../../../models/DC-TCN/datasets/lrs3_words_may"
updated_df = create_npz_df(new_dir)
updated_df_sorted = updated_df.sort_values(by=['total'], ascending=False)
print(updated_df_sorted.head(10))

updated_total_train = updated_df['train'].sum()
updated_total_val = updated_df['val'].sum()
updated_total_test = updated_df['test'].sum()

print(f"\nTotal train: {updated_total_train}")
print(f"Total val: {updated_total_val}")
print(f"Total test: {updated_total_test}")
# Out:
#       train   val  test  total
# THE   10076  2159  2160  14395
# TO     8182  1753  1753  11688
# AND    7797  1671  1670  11138
# THAT   6141  1316  1316   8773
# I      6100  1307  1308   8715
# A      6040  1294  1295   8629
# OF     5844  1253  1251   8348
# WE     4320   926   925   6171
# IN     3958   848   849   5655
# YOU    3766   807   807   5380
#
# Total train: 246003
# Total val: 54013
# Total test: 52900

# %%
# drop words that dont exist in the test set
updated_skip_words = updated_df[updated_df['test'] == 0]
print(updated_skip_words)
# Out:
#                train  val  test  total
# ARABIC             2    1     0      3
# ANTHROPOLOGY       2    1     0      3
# GLAND              2    1     0      3
# SHAKING            2    1     0      3
# SYMPHONY           2    1     0      3
# ...              ...  ...   ...    ...
# MUSTER             2    1     0      3
# HEARTBREAKING      2    1     0      3
# BOIL               2    1     0      3
# ANALYZED           2    1     0      3
# BLAMED             2    1     0      3
#
# [1113 rows x 4 columns]

# %%
# drop words that dont exist in the test set
source_dir = "../../../models/DC-TCN/datasets/lrs3_words_may_dropped"
target_dir = "../../../models/DC-TCN/datasets/lrs3_words_may"

os.makedirs(target_dir, exist_ok=True)

moved = 0

for word in updated_skip_words.index:
    folder_path = os.path.join(source_dir, word)

    if os.path.exists(folder_path):
        target_folder_path = os.path.join(target_dir, word)
        shutil.move(folder_path, target_folder_path)
        print(f"Moved {word} to {target_folder_path}")
        moved += 1
print(f"total moved: {moved}")
# Out:
# Moved ARABIC to ../../../models/DC-TCN/datasets/lrs3_words_may/ARABIC
# Moved ANTHROPOLOGY to ../../../models/DC-TCN/datasets/lrs3_words_may/ANTHROPOLOGY
# Moved GLAND to ../../../models/DC-TCN/datasets/lrs3_words_may/GLAND
# Moved SHAKING to ../../../models/DC-TCN/datasets/lrs3_words_may/SHAKING
# Moved SYMPHONY to ../../../models/DC-TCN/datasets/lrs3_words_may/SYMPHONY
# Moved DECEPTION to ../../../models/DC-TCN/datasets/lrs3_words_may/DECEPTION
# Moved ANSWERING to ../../../models/DC-TCN/datasets/lrs3_words_may/ANSWERING
# Moved BRIDE to ../../../models/DC-TCN/datasets/lrs3_words_may/BRIDE
# Moved CLAPPING to ../../../models/DC-TCN/datasets/lrs3_words_may/CLAPPING
# Moved APPRENTICESHIP to ../../../models/DC-TCN/datasets/lrs3_words_may/APPRENTICESHIP
# Moved FREQUENTLY to ../../../models/DC-TCN/datasets/lrs3_words_may/FREQUENTLY
# Moved WANDER to ../../../models/DC-TCN/datasets/lrs3_words_may/WANDER
# Moved TOLERANT to ../../../models/DC-TCN/datasets/lrs3_words_may/TOLERANT
# Moved EXILE to ../../../models/DC-TCN/datasets/lrs3_words_may/EXILE
# Moved MCDONALD'S to ../../../models/DC-TCN/datasets/lrs3_words_may/MCDONALD'S
# Moved MOISTURE to ../../../models/DC-TCN/datasets/lrs3_words_may/MOISTURE
# Moved PERSIST to ../../../models/DC-TCN/datasets/lrs3_words_may/PERSIST
# Moved STRAY to ../../../models/DC-TCN/datasets/lrs3_words_may/STRAY
# Moved SOMEPLACE to ../../../models/DC-TCN/datasets/lrs3_words_may/SOMEPLACE
# Moved COMPETING to ../../../models/DC-TCN/datasets/lrs3_words_may/COMPETING
# Moved SAUCE to ../../../models/DC-TCN/datasets/lrs3_words_may/SAUCE
# Moved OUTLET to ../../../models/DC-TCN/datasets/lrs3_words_may/OUTLET
# Moved DENYING to ../../../models/DC-TCN/datasets/lrs3_words_may/DENYING
# Moved BUNK to ../../../models/DC-TCN/datasets/lrs3_words_may/BUNK
# Moved PROGRESSION to ../../../models/DC-TCN/datasets/lrs3_words_may/PROGRESSION
# Moved ESCAPED to ../../../models/DC-TCN/datasets/lrs3_words_may/ESCAPED
# Moved PRAIRIE to ../../../models/DC-TCN/datasets/lrs3_words_may/PRAIRIE
# Moved CLOTH to ../../../models/DC-TCN/datasets/lrs3_words_may/CLOTH
# Moved GRAFFITI to ../../../models/DC-TCN/datasets/lrs3_words_may/GRAFFITI
# Moved ADMISSION to ../../../models/DC-TCN/datasets/lrs3_words_may/ADMISSION
# Moved LOAF to ../../../models/DC-TCN/datasets/lrs3_words_may/LOAF
# Moved MUNCHKIN to ../../../models/DC-TCN/datasets/lrs3_words_may/MUNCHKIN
# Moved INTERESTINGLY to ../../../models/DC-TCN/datasets/lrs3_words_may/INTERESTINGLY
# Moved DANCER to ../../../models/DC-TCN/datasets/lrs3_words_may/DANCER
# Moved PORT to ../../../models/DC-TCN/datasets/lrs3_words_may/PORT
# Moved CALCULUS to ../../../models/DC-TCN/datasets/lrs3_words_may/CALCULUS
# Moved ECONOMIES to ../../../models/DC-TCN/datasets/lrs3_words_may/ECONOMIES
# Moved CRUSHING to ../../../models/DC-TCN/datasets/lrs3_words_may/CRUSHING
# Moved ABUNDANCE to ../../../models/DC-TCN/datasets/lrs3_words_may/ABUNDANCE
# Moved FLOSS to ../../../models/DC-TCN/datasets/lrs3_words_may/FLOSS
# Moved TABOO to ../../../models/DC-TCN/datasets/lrs3_words_may/TABOO
# Moved CEREMONY to ../../../models/DC-TCN/datasets/lrs3_words_may/CEREMONY
# Moved QUIETLY to ../../../models/DC-TCN/datasets/lrs3_words_may/QUIETLY
# Moved MASTERY to ../../../models/DC-TCN/datasets/lrs3_words_may/MASTERY
# Moved MONOGAMY to ../../../models/DC-TCN/datasets/lrs3_words_may/MONOGAMY
# Moved CRACKING to ../../../models/DC-TCN/datasets/lrs3_words_may/CRACKING
# Moved SOLELY to ../../../models/DC-TCN/datasets/lrs3_words_may/SOLELY
# Moved STRIPE to ../../../models/DC-TCN/datasets/lrs3_words_may/STRIPE
# Moved VALUED to ../../../models/DC-TCN/datasets/lrs3_words_may/VALUED
# Moved INGEST to ../../../models/DC-TCN/datasets/lrs3_words_may/INGEST
# Moved INVASIVE to ../../../models/DC-TCN/datasets/lrs3_words_may/INVASIVE
# Moved POSED to ../../../models/DC-TCN/datasets/lrs3_words_may/POSED
# Moved BERLIN to ../../../models/DC-TCN/datasets/lrs3_words_may/BERLIN
# Moved EM to ../../../models/DC-TCN/datasets/lrs3_words_may/EM
# Moved WILLENDORF to ../../../models/DC-TCN/datasets/lrs3_words_may/WILLENDORF
# Moved COSTUME to ../../../models/DC-TCN/datasets/lrs3_words_may/COSTUME
# Moved SLEEVE to ../../../models/DC-TCN/datasets/lrs3_words_may/SLEEVE
# Moved POINTING to ../../../models/DC-TCN/datasets/lrs3_words_may/POINTING
# Moved WITHDREW to ../../../models/DC-TCN/datasets/lrs3_words_may/WITHDREW
# Moved CASKET to ../../../models/DC-TCN/datasets/lrs3_words_may/CASKET
# Moved WALMART to ../../../models/DC-TCN/datasets/lrs3_words_may/WALMART
# Moved THRUST to ../../../models/DC-TCN/datasets/lrs3_words_may/THRUST
# Moved DERVISH to ../../../models/DC-TCN/datasets/lrs3_words_may/DERVISH
# Moved TENET to ../../../models/DC-TCN/datasets/lrs3_words_may/TENET
# Moved CRUCIALLY to ../../../models/DC-TCN/datasets/lrs3_words_may/CRUCIALLY
# Moved COMMONALITIES to ../../../models/DC-TCN/datasets/lrs3_words_may/COMMONALITIES
# Moved FORT to ../../../models/DC-TCN/datasets/lrs3_words_may/FORT
# Moved EXPONENTIALLY to ../../../models/DC-TCN/datasets/lrs3_words_may/EXPONENTIALLY
# Moved HOMO to ../../../models/DC-TCN/datasets/lrs3_words_may/HOMO
# Moved CARPENTRY to ../../../models/DC-TCN/datasets/lrs3_words_may/CARPENTRY
# Moved SWIRLING to ../../../models/DC-TCN/datasets/lrs3_words_may/SWIRLING
# Moved LEMONADE to ../../../models/DC-TCN/datasets/lrs3_words_may/LEMONADE
# Moved BATH to ../../../models/DC-TCN/datasets/lrs3_words_may/BATH
# Moved PHOTOGRAPHED to ../../../models/DC-TCN/datasets/lrs3_words_may/PHOTOGRAPHED
# Moved WOKEN to ../../../models/DC-TCN/datasets/lrs3_words_may/WOKEN
# Moved GUESSING to ../../../models/DC-TCN/datasets/lrs3_words_may/GUESSING
# Moved BLA to ../../../models/DC-TCN/datasets/lrs3_words_may/BLA
# Moved MENTORING to ../../../models/DC-TCN/datasets/lrs3_words_may/MENTORING
# Moved AUDITION to ../../../models/DC-TCN/datasets/lrs3_words_may/AUDITION
# Moved COX to ../../../models/DC-TCN/datasets/lrs3_words_may/COX
# Moved ETHICS to ../../../models/DC-TCN/datasets/lrs3_words_may/ETHICS
# Moved SPORTING to ../../../models/DC-TCN/datasets/lrs3_words_may/SPORTING
# Moved FUELED to ../../../models/DC-TCN/datasets/lrs3_words_may/FUELED
# Moved ELLEN to ../../../models/DC-TCN/datasets/lrs3_words_may/ELLEN
# Moved THRILL to ../../../models/DC-TCN/datasets/lrs3_words_may/THRILL
# Moved COMPROMISE to ../../../models/DC-TCN/datasets/lrs3_words_may/COMPROMISE
# Moved MATTHEW to ../../../models/DC-TCN/datasets/lrs3_words_may/MATTHEW
# Moved BRUSHED to ../../../models/DC-TCN/datasets/lrs3_words_may/BRUSHED
# Moved PAINTER to ../../../models/DC-TCN/datasets/lrs3_words_may/PAINTER
# Moved JURY to ../../../models/DC-TCN/datasets/lrs3_words_may/JURY
# Moved QUALIFIED to ../../../models/DC-TCN/datasets/lrs3_words_may/QUALIFIED
# Moved FICTIONAL to ../../../models/DC-TCN/datasets/lrs3_words_may/FICTIONAL
# Moved APPALLING to ../../../models/DC-TCN/datasets/lrs3_words_may/APPALLING
# Moved LAPILLI to ../../../models/DC-TCN/datasets/lrs3_words_may/LAPILLI
# Moved MOSQUE to ../../../models/DC-TCN/datasets/lrs3_words_may/MOSQUE
# Moved DEAN to ../../../models/DC-TCN/datasets/lrs3_words_may/DEAN
# Moved BETA to ../../../models/DC-TCN/datasets/lrs3_words_may/BETA
# Moved COLORED to ../../../models/DC-TCN/datasets/lrs3_words_may/COLORED
# Moved REACTIVE to ../../../models/DC-TCN/datasets/lrs3_words_may/REACTIVE
# Moved UPTAKE to ../../../models/DC-TCN/datasets/lrs3_words_may/UPTAKE
# Moved FLUORESCENT to ../../../models/DC-TCN/datasets/lrs3_words_may/FLUORESCENT
# Moved VENUE to ../../../models/DC-TCN/datasets/lrs3_words_may/VENUE
# Moved HOLLYWOOD to ../../../models/DC-TCN/datasets/lrs3_words_may/HOLLYWOOD
# Moved BAGHDAD to ../../../models/DC-TCN/datasets/lrs3_words_may/BAGHDAD
# Moved ROD to ../../../models/DC-TCN/datasets/lrs3_words_may/ROD
# Moved DEFINITIVE to ../../../models/DC-TCN/datasets/lrs3_words_may/DEFINITIVE
# Moved NEIL to ../../../models/DC-TCN/datasets/lrs3_words_may/NEIL
# Moved APPETITE to ../../../models/DC-TCN/datasets/lrs3_words_may/APPETITE
# Moved PIE to ../../../models/DC-TCN/datasets/lrs3_words_may/PIE
# Moved BUREAUCRAT to ../../../models/DC-TCN/datasets/lrs3_words_may/BUREAUCRAT
# Moved BOW to ../../../models/DC-TCN/datasets/lrs3_words_may/BOW
# Moved CELEBRATION to ../../../models/DC-TCN/datasets/lrs3_words_may/CELEBRATION
# Moved MARTIAL to ../../../models/DC-TCN/datasets/lrs3_words_may/MARTIAL
# Moved YORUBA to ../../../models/DC-TCN/datasets/lrs3_words_may/YORUBA
# Moved MOSES to ../../../models/DC-TCN/datasets/lrs3_words_may/MOSES
# Moved LINED to ../../../models/DC-TCN/datasets/lrs3_words_may/LINED
# Moved PLANTATION to ../../../models/DC-TCN/datasets/lrs3_words_may/PLANTATION
# Moved PANAMA to ../../../models/DC-TCN/datasets/lrs3_words_may/PANAMA
# Moved DIOXIDE to ../../../models/DC-TCN/datasets/lrs3_words_may/DIOXIDE
# Moved TRACKER to ../../../models/DC-TCN/datasets/lrs3_words_may/TRACKER
# Moved BEETLE to ../../../models/DC-TCN/datasets/lrs3_words_may/BEETLE
# Moved TRUSTED to ../../../models/DC-TCN/datasets/lrs3_words_may/TRUSTED
# Moved ABRAHAM'S to ../../../models/DC-TCN/datasets/lrs3_words_may/ABRAHAM'S
# Moved CADAVER to ../../../models/DC-TCN/datasets/lrs3_words_may/CADAVER
# Moved MAHATMA to ../../../models/DC-TCN/datasets/lrs3_words_may/MAHATMA
# Moved PRECISELY to ../../../models/DC-TCN/datasets/lrs3_words_may/PRECISELY
# Moved CAPTAIN to ../../../models/DC-TCN/datasets/lrs3_words_may/CAPTAIN
# Moved UNLEASHED to ../../../models/DC-TCN/datasets/lrs3_words_may/UNLEASHED
# Moved REBEL to ../../../models/DC-TCN/datasets/lrs3_words_may/REBEL
# Moved APPLYING to ../../../models/DC-TCN/datasets/lrs3_words_may/APPLYING
# Moved ZOO to ../../../models/DC-TCN/datasets/lrs3_words_may/ZOO
# Moved RESENTED to ../../../models/DC-TCN/datasets/lrs3_words_may/RESENTED
# Moved SHOULD'VE to ../../../models/DC-TCN/datasets/lrs3_words_may/SHOULD'VE
# Moved LEBANON to ../../../models/DC-TCN/datasets/lrs3_words_may/LEBANON
# Moved NOVELTY to ../../../models/DC-TCN/datasets/lrs3_words_may/NOVELTY
# Moved FLASHLIGHT to ../../../models/DC-TCN/datasets/lrs3_words_may/FLASHLIGHT
# Moved DRIFT to ../../../models/DC-TCN/datasets/lrs3_words_may/DRIFT
# Moved COUNSEL to ../../../models/DC-TCN/datasets/lrs3_words_may/COUNSEL
# Moved ENTHUSIASTIC to ../../../models/DC-TCN/datasets/lrs3_words_may/ENTHUSIASTIC
# Moved COWARD to ../../../models/DC-TCN/datasets/lrs3_words_may/COWARD
# Moved DROWNING to ../../../models/DC-TCN/datasets/lrs3_words_may/DROWNING
# Moved INEFFICIENT to ../../../models/DC-TCN/datasets/lrs3_words_may/INEFFICIENT
# Moved TRIUMPH to ../../../models/DC-TCN/datasets/lrs3_words_may/TRIUMPH
# Moved FOXES to ../../../models/DC-TCN/datasets/lrs3_words_may/FOXES
# Moved MILK to ../../../models/DC-TCN/datasets/lrs3_words_may/MILK
# Moved RETAIL to ../../../models/DC-TCN/datasets/lrs3_words_may/RETAIL
# Moved EXPERIMENTAL to ../../../models/DC-TCN/datasets/lrs3_words_may/EXPERIMENTAL
# Moved PENNY to ../../../models/DC-TCN/datasets/lrs3_words_may/PENNY
# Moved USA to ../../../models/DC-TCN/datasets/lrs3_words_may/USA
# Moved PLUG to ../../../models/DC-TCN/datasets/lrs3_words_may/PLUG
# Moved SERVANT to ../../../models/DC-TCN/datasets/lrs3_words_may/SERVANT
# Moved DIVINE to ../../../models/DC-TCN/datasets/lrs3_words_may/DIVINE
# Moved ALLEN to ../../../models/DC-TCN/datasets/lrs3_words_may/ALLEN
# Moved RITE to ../../../models/DC-TCN/datasets/lrs3_words_may/RITE
# Moved FADE to ../../../models/DC-TCN/datasets/lrs3_words_may/FADE
# Moved BLOWING to ../../../models/DC-TCN/datasets/lrs3_words_may/BLOWING
# Moved QUEUE to ../../../models/DC-TCN/datasets/lrs3_words_may/QUEUE
# Moved STRUCTURED to ../../../models/DC-TCN/datasets/lrs3_words_may/STRUCTURED
# Moved RESTRICTION to ../../../models/DC-TCN/datasets/lrs3_words_may/RESTRICTION
# Moved STRANGELY to ../../../models/DC-TCN/datasets/lrs3_words_may/STRANGELY
# Moved RWANDA to ../../../models/DC-TCN/datasets/lrs3_words_may/RWANDA
# Moved CROCHET to ../../../models/DC-TCN/datasets/lrs3_words_may/CROCHET
# Moved ESTATE to ../../../models/DC-TCN/datasets/lrs3_words_may/ESTATE
# Moved WALKABLE to ../../../models/DC-TCN/datasets/lrs3_words_may/WALKABLE
# Moved FORMATION to ../../../models/DC-TCN/datasets/lrs3_words_may/FORMATION
# Moved EXPANDING to ../../../models/DC-TCN/datasets/lrs3_words_may/EXPANDING
# Moved VALIDATION to ../../../models/DC-TCN/datasets/lrs3_words_may/VALIDATION
# Moved FILED to ../../../models/DC-TCN/datasets/lrs3_words_may/FILED
# Moved STRAND to ../../../models/DC-TCN/datasets/lrs3_words_may/STRAND
# Moved RACING to ../../../models/DC-TCN/datasets/lrs3_words_may/RACING
# Moved BLESS to ../../../models/DC-TCN/datasets/lrs3_words_may/BLESS
# Moved KATRINA to ../../../models/DC-TCN/datasets/lrs3_words_may/KATRINA
# Moved SCREAM to ../../../models/DC-TCN/datasets/lrs3_words_may/SCREAM
# Moved PROJECTING to ../../../models/DC-TCN/datasets/lrs3_words_may/PROJECTING
# Moved MONOPOLY to ../../../models/DC-TCN/datasets/lrs3_words_may/MONOPOLY
# Moved ASSESSMENT to ../../../models/DC-TCN/datasets/lrs3_words_may/ASSESSMENT
# Moved SHINE to ../../../models/DC-TCN/datasets/lrs3_words_may/SHINE
# Moved FOG to ../../../models/DC-TCN/datasets/lrs3_words_may/FOG
# Moved REVOLVE to ../../../models/DC-TCN/datasets/lrs3_words_may/REVOLVE
# Moved SPARKED to ../../../models/DC-TCN/datasets/lrs3_words_may/SPARKED
# Moved MARROW to ../../../models/DC-TCN/datasets/lrs3_words_may/MARROW
# Moved POT to ../../../models/DC-TCN/datasets/lrs3_words_may/POT
# Moved DISAPPEARED to ../../../models/DC-TCN/datasets/lrs3_words_may/DISAPPEARED
# Moved MISERY to ../../../models/DC-TCN/datasets/lrs3_words_may/MISERY
# Moved HAROLD to ../../../models/DC-TCN/datasets/lrs3_words_may/HAROLD
# Moved APPROXIMATION to ../../../models/DC-TCN/datasets/lrs3_words_may/APPROXIMATION
# Moved PESSIMIST to ../../../models/DC-TCN/datasets/lrs3_words_may/PESSIMIST
# Moved ACRONYM to ../../../models/DC-TCN/datasets/lrs3_words_may/ACRONYM
# Moved IDAHO to ../../../models/DC-TCN/datasets/lrs3_words_may/IDAHO
# Moved INFANT to ../../../models/DC-TCN/datasets/lrs3_words_may/INFANT
# Moved SEBASTIAN to ../../../models/DC-TCN/datasets/lrs3_words_may/SEBASTIAN
# Moved RUPEES to ../../../models/DC-TCN/datasets/lrs3_words_may/RUPEES
# Moved SELECTIVELY to ../../../models/DC-TCN/datasets/lrs3_words_may/SELECTIVELY
# Moved ETCHED to ../../../models/DC-TCN/datasets/lrs3_words_may/ETCHED
# Moved ALTOGETHER to ../../../models/DC-TCN/datasets/lrs3_words_may/ALTOGETHER
# Moved ULTRASOUND to ../../../models/DC-TCN/datasets/lrs3_words_may/ULTRASOUND
# Moved BATMAN to ../../../models/DC-TCN/datasets/lrs3_words_may/BATMAN
# Moved NEGOTIATING to ../../../models/DC-TCN/datasets/lrs3_words_may/NEGOTIATING
# Moved LADDER to ../../../models/DC-TCN/datasets/lrs3_words_may/LADDER
# Moved DISAPPOINTED to ../../../models/DC-TCN/datasets/lrs3_words_may/DISAPPOINTED
# Moved GIGANTIC to ../../../models/DC-TCN/datasets/lrs3_words_may/GIGANTIC
# Moved BANANA to ../../../models/DC-TCN/datasets/lrs3_words_may/BANANA
# Moved REPEATED to ../../../models/DC-TCN/datasets/lrs3_words_may/REPEATED
# Moved URANIUM to ../../../models/DC-TCN/datasets/lrs3_words_may/URANIUM
# Moved TIDY to ../../../models/DC-TCN/datasets/lrs3_words_may/TIDY
# Moved HOW'S to ../../../models/DC-TCN/datasets/lrs3_words_may/HOW'S
# Moved SEPARATING to ../../../models/DC-TCN/datasets/lrs3_words_may/SEPARATING
# Moved GUESSED to ../../../models/DC-TCN/datasets/lrs3_words_may/GUESSED
# Moved BANNING to ../../../models/DC-TCN/datasets/lrs3_words_may/BANNING
# Moved RECLAIM to ../../../models/DC-TCN/datasets/lrs3_words_may/RECLAIM
# Moved SIMPLICITY to ../../../models/DC-TCN/datasets/lrs3_words_may/SIMPLICITY
# Moved KICK to ../../../models/DC-TCN/datasets/lrs3_words_may/KICK
# Moved DISCUSSED to ../../../models/DC-TCN/datasets/lrs3_words_may/DISCUSSED
# Moved PROSTHETIC to ../../../models/DC-TCN/datasets/lrs3_words_may/PROSTHETIC
# Moved LAUNDRY to ../../../models/DC-TCN/datasets/lrs3_words_may/LAUNDRY
# Moved PENSION to ../../../models/DC-TCN/datasets/lrs3_words_may/PENSION
# Moved EMIT to ../../../models/DC-TCN/datasets/lrs3_words_may/EMIT
# Moved MATHEMATICIAN to ../../../models/DC-TCN/datasets/lrs3_words_may/MATHEMATICIAN
# Moved ARIZONA to ../../../models/DC-TCN/datasets/lrs3_words_may/ARIZONA
# Moved ILLNESSES to ../../../models/DC-TCN/datasets/lrs3_words_may/ILLNESSES
# Moved INSTRUCTOR to ../../../models/DC-TCN/datasets/lrs3_words_may/INSTRUCTOR
# Moved INTERNALIZED to ../../../models/DC-TCN/datasets/lrs3_words_may/INTERNALIZED
# Moved DISPARATE to ../../../models/DC-TCN/datasets/lrs3_words_may/DISPARATE
# Moved CRICKET to ../../../models/DC-TCN/datasets/lrs3_words_may/CRICKET
# Moved DEREGULATION to ../../../models/DC-TCN/datasets/lrs3_words_may/DEREGULATION
# Moved RIDDLE to ../../../models/DC-TCN/datasets/lrs3_words_may/RIDDLE
# Moved PAROLE to ../../../models/DC-TCN/datasets/lrs3_words_may/PAROLE
# Moved SEPARATED to ../../../models/DC-TCN/datasets/lrs3_words_may/SEPARATED
# Moved WHISPERING to ../../../models/DC-TCN/datasets/lrs3_words_may/WHISPERING
# Moved INTERRUPTING to ../../../models/DC-TCN/datasets/lrs3_words_may/INTERRUPTING
# Moved POLARIZED to ../../../models/DC-TCN/datasets/lrs3_words_may/POLARIZED
# Moved TEARING to ../../../models/DC-TCN/datasets/lrs3_words_may/TEARING
# Moved PROTOTYPING to ../../../models/DC-TCN/datasets/lrs3_words_may/PROTOTYPING
# Moved BOOTH to ../../../models/DC-TCN/datasets/lrs3_words_may/BOOTH
# Moved ULTRA to ../../../models/DC-TCN/datasets/lrs3_words_may/ULTRA
# Moved SUPPLEMENT to ../../../models/DC-TCN/datasets/lrs3_words_may/SUPPLEMENT
# Moved RAPISTS to ../../../models/DC-TCN/datasets/lrs3_words_may/RAPISTS
# Moved EQUATE to ../../../models/DC-TCN/datasets/lrs3_words_may/EQUATE
# Moved CONVERSATIONAL to ../../../models/DC-TCN/datasets/lrs3_words_may/CONVERSATIONAL
# Moved VIRTUALLY to ../../../models/DC-TCN/datasets/lrs3_words_may/VIRTUALLY
# Moved SEXIST to ../../../models/DC-TCN/datasets/lrs3_words_may/SEXIST
# Moved BIN to ../../../models/DC-TCN/datasets/lrs3_words_may/BIN
# Moved OBSERVING to ../../../models/DC-TCN/datasets/lrs3_words_may/OBSERVING
# Moved DRUNKEN to ../../../models/DC-TCN/datasets/lrs3_words_may/DRUNKEN
# Moved CALCULATED to ../../../models/DC-TCN/datasets/lrs3_words_may/CALCULATED
# Moved CYCLISTS to ../../../models/DC-TCN/datasets/lrs3_words_may/CYCLISTS
# Moved PREVAILING to ../../../models/DC-TCN/datasets/lrs3_words_may/PREVAILING
# Moved FLOATING to ../../../models/DC-TCN/datasets/lrs3_words_may/FLOATING
# Moved AUTISTIC to ../../../models/DC-TCN/datasets/lrs3_words_may/AUTISTIC
# Moved URGENCY to ../../../models/DC-TCN/datasets/lrs3_words_may/URGENCY
# Moved ARCHAEOLOGIST to ../../../models/DC-TCN/datasets/lrs3_words_may/ARCHAEOLOGIST
# Moved CALENDAR to ../../../models/DC-TCN/datasets/lrs3_words_may/CALENDAR
# Moved MARCHING to ../../../models/DC-TCN/datasets/lrs3_words_may/MARCHING
# Moved TEA to ../../../models/DC-TCN/datasets/lrs3_words_may/TEA
# Moved HOCKEY to ../../../models/DC-TCN/datasets/lrs3_words_may/HOCKEY
# Moved ASTRONOMICAL to ../../../models/DC-TCN/datasets/lrs3_words_may/ASTRONOMICAL
# Moved SHIPPED to ../../../models/DC-TCN/datasets/lrs3_words_may/SHIPPED
# Moved UNIFORM to ../../../models/DC-TCN/datasets/lrs3_words_may/UNIFORM
# Moved SWEEPING to ../../../models/DC-TCN/datasets/lrs3_words_may/SWEEPING
# Moved STIMULATING to ../../../models/DC-TCN/datasets/lrs3_words_may/STIMULATING
# Moved SPECIALIZE to ../../../models/DC-TCN/datasets/lrs3_words_may/SPECIALIZE
# Moved RUIN to ../../../models/DC-TCN/datasets/lrs3_words_may/RUIN
# Moved GINGER to ../../../models/DC-TCN/datasets/lrs3_words_may/GINGER
# Moved MCDOW to ../../../models/DC-TCN/datasets/lrs3_words_may/MCDOW
# Moved SCRATCHED to ../../../models/DC-TCN/datasets/lrs3_words_may/SCRATCHED
# Moved SENATOR to ../../../models/DC-TCN/datasets/lrs3_words_may/SENATOR
# Moved BRIAN to ../../../models/DC-TCN/datasets/lrs3_words_may/BRIAN
# Moved ANTHROPOLOGIST to ../../../models/DC-TCN/datasets/lrs3_words_may/ANTHROPOLOGIST
# Moved VISA to ../../../models/DC-TCN/datasets/lrs3_words_may/VISA
# Moved COD to ../../../models/DC-TCN/datasets/lrs3_words_may/COD
# Moved FOOTSTEPS to ../../../models/DC-TCN/datasets/lrs3_words_may/FOOTSTEPS
# Moved CHASED to ../../../models/DC-TCN/datasets/lrs3_words_may/CHASED
# Moved CONTROVERSIAL to ../../../models/DC-TCN/datasets/lrs3_words_may/CONTROVERSIAL
# Moved EXPONENTIAL to ../../../models/DC-TCN/datasets/lrs3_words_may/EXPONENTIAL
# Moved GROUNDED to ../../../models/DC-TCN/datasets/lrs3_words_may/GROUNDED
# Moved GREY to ../../../models/DC-TCN/datasets/lrs3_words_may/GREY
# Moved IMAGINATIVE to ../../../models/DC-TCN/datasets/lrs3_words_may/IMAGINATIVE
# Moved HOSPITALIZED to ../../../models/DC-TCN/datasets/lrs3_words_may/HOSPITALIZED
# Moved DAMAGING to ../../../models/DC-TCN/datasets/lrs3_words_may/DAMAGING
# Moved FACIAL to ../../../models/DC-TCN/datasets/lrs3_words_may/FACIAL
# Moved DREAMER to ../../../models/DC-TCN/datasets/lrs3_words_may/DREAMER
# Moved VIAGRA to ../../../models/DC-TCN/datasets/lrs3_words_may/VIAGRA
# Moved BARACK to ../../../models/DC-TCN/datasets/lrs3_words_may/BARACK
# Moved EXTREMIST to ../../../models/DC-TCN/datasets/lrs3_words_may/EXTREMIST
# Moved VISITED to ../../../models/DC-TCN/datasets/lrs3_words_may/VISITED
# Moved BUYER to ../../../models/DC-TCN/datasets/lrs3_words_may/BUYER
# Moved CONTAMINATE to ../../../models/DC-TCN/datasets/lrs3_words_may/CONTAMINATE
# Moved INTACT to ../../../models/DC-TCN/datasets/lrs3_words_may/INTACT
# Moved LANDLORD to ../../../models/DC-TCN/datasets/lrs3_words_may/LANDLORD
# Moved DISTINGUISHING to ../../../models/DC-TCN/datasets/lrs3_words_may/DISTINGUISHING
# Moved NAP to ../../../models/DC-TCN/datasets/lrs3_words_may/NAP
# Moved ALIKE to ../../../models/DC-TCN/datasets/lrs3_words_may/ALIKE
# Moved ALTITUDE to ../../../models/DC-TCN/datasets/lrs3_words_may/ALTITUDE
# Moved SETUP to ../../../models/DC-TCN/datasets/lrs3_words_may/SETUP
# Moved HUMBLE to ../../../models/DC-TCN/datasets/lrs3_words_may/HUMBLE
# Moved DETECTION to ../../../models/DC-TCN/datasets/lrs3_words_may/DETECTION
# Moved HERD to ../../../models/DC-TCN/datasets/lrs3_words_may/HERD
# Moved AW to ../../../models/DC-TCN/datasets/lrs3_words_may/AW
# Moved FORD to ../../../models/DC-TCN/datasets/lrs3_words_may/FORD
# Moved EVE to ../../../models/DC-TCN/datasets/lrs3_words_may/EVE
# Moved PREDICTING to ../../../models/DC-TCN/datasets/lrs3_words_may/PREDICTING
# Moved VACUUMING to ../../../models/DC-TCN/datasets/lrs3_words_may/VACUUMING
# Moved FEASIBLE to ../../../models/DC-TCN/datasets/lrs3_words_may/FEASIBLE
# Moved ISRAELI to ../../../models/DC-TCN/datasets/lrs3_words_may/ISRAELI
# Moved COMMANDER to ../../../models/DC-TCN/datasets/lrs3_words_may/COMMANDER
# Moved DIMENSIONAL to ../../../models/DC-TCN/datasets/lrs3_words_may/DIMENSIONAL
# Moved LEATHER to ../../../models/DC-TCN/datasets/lrs3_words_may/LEATHER
# Moved RECYCLING to ../../../models/DC-TCN/datasets/lrs3_words_may/RECYCLING
# Moved STRAW to ../../../models/DC-TCN/datasets/lrs3_words_may/STRAW
# Moved MARIA to ../../../models/DC-TCN/datasets/lrs3_words_may/MARIA
# Moved AVATAR to ../../../models/DC-TCN/datasets/lrs3_words_may/AVATAR
# Moved BOMBSIGHT to ../../../models/DC-TCN/datasets/lrs3_words_may/BOMBSIGHT
# Moved MASTERED to ../../../models/DC-TCN/datasets/lrs3_words_may/MASTERED
# Moved EROTIC to ../../../models/DC-TCN/datasets/lrs3_words_may/EROTIC
# Moved PARALYZED to ../../../models/DC-TCN/datasets/lrs3_words_may/PARALYZED
# Moved DORM to ../../../models/DC-TCN/datasets/lrs3_words_may/DORM
# Moved BASIN to ../../../models/DC-TCN/datasets/lrs3_words_may/BASIN
# Moved BROADWAY to ../../../models/DC-TCN/datasets/lrs3_words_may/BROADWAY
# Moved GROSS to ../../../models/DC-TCN/datasets/lrs3_words_may/GROSS
# Moved ALEX to ../../../models/DC-TCN/datasets/lrs3_words_may/ALEX
# Moved BEGGING to ../../../models/DC-TCN/datasets/lrs3_words_may/BEGGING
# Moved PAKISTANI to ../../../models/DC-TCN/datasets/lrs3_words_may/PAKISTANI
# Moved THINKERS to ../../../models/DC-TCN/datasets/lrs3_words_may/THINKERS
# Moved ESCAPING to ../../../models/DC-TCN/datasets/lrs3_words_may/ESCAPING
# Moved UNCOMMON to ../../../models/DC-TCN/datasets/lrs3_words_may/UNCOMMON
# Moved CROWDSOURCING to ../../../models/DC-TCN/datasets/lrs3_words_may/CROWDSOURCING
# Moved KINDERGARTEN to ../../../models/DC-TCN/datasets/lrs3_words_may/KINDERGARTEN
# Moved DIAPER to ../../../models/DC-TCN/datasets/lrs3_words_may/DIAPER
# Moved HATCHED to ../../../models/DC-TCN/datasets/lrs3_words_may/HATCHED
# Moved BULGARIAN to ../../../models/DC-TCN/datasets/lrs3_words_may/BULGARIAN
# Moved ATYPICAL to ../../../models/DC-TCN/datasets/lrs3_words_may/ATYPICAL
# Moved CHARLIE to ../../../models/DC-TCN/datasets/lrs3_words_may/CHARLIE
# Moved ATTRIBUTE to ../../../models/DC-TCN/datasets/lrs3_words_may/ATTRIBUTE
# Moved EMBEDDED to ../../../models/DC-TCN/datasets/lrs3_words_may/EMBEDDED
# Moved DIVERGENT to ../../../models/DC-TCN/datasets/lrs3_words_may/DIVERGENT
# Moved SLEPT to ../../../models/DC-TCN/datasets/lrs3_words_may/SLEPT
# Moved CANAL to ../../../models/DC-TCN/datasets/lrs3_words_may/CANAL
# Moved IMPRESSED to ../../../models/DC-TCN/datasets/lrs3_words_may/IMPRESSED
# Moved LISTENED to ../../../models/DC-TCN/datasets/lrs3_words_may/LISTENED
# Moved BRIEF to ../../../models/DC-TCN/datasets/lrs3_words_may/BRIEF
# Moved MESSING to ../../../models/DC-TCN/datasets/lrs3_words_may/MESSING
# Moved ARCHITECTURAL to ../../../models/DC-TCN/datasets/lrs3_words_may/ARCHITECTURAL
# Moved BOUNCED to ../../../models/DC-TCN/datasets/lrs3_words_may/BOUNCED
# Moved FAKING to ../../../models/DC-TCN/datasets/lrs3_words_may/FAKING
# Moved HOMOPHOBIC to ../../../models/DC-TCN/datasets/lrs3_words_may/HOMOPHOBIC
# Moved CONSISTS to ../../../models/DC-TCN/datasets/lrs3_words_may/CONSISTS
# Moved VENEZUELA to ../../../models/DC-TCN/datasets/lrs3_words_may/VENEZUELA
# Moved FASHIONED to ../../../models/DC-TCN/datasets/lrs3_words_may/FASHIONED
# Moved RORY to ../../../models/DC-TCN/datasets/lrs3_words_may/RORY
# Moved COMPLIANCE to ../../../models/DC-TCN/datasets/lrs3_words_may/COMPLIANCE
# Moved HALLWAYS to ../../../models/DC-TCN/datasets/lrs3_words_may/HALLWAYS
# Moved BRANCHES to ../../../models/DC-TCN/datasets/lrs3_words_may/BRANCHES
# Moved BEND to ../../../models/DC-TCN/datasets/lrs3_words_may/BEND
# Moved EARLIEST to ../../../models/DC-TCN/datasets/lrs3_words_may/EARLIEST
# Moved ATTACHED to ../../../models/DC-TCN/datasets/lrs3_words_may/ATTACHED
# Moved COACHES to ../../../models/DC-TCN/datasets/lrs3_words_may/COACHES
# Moved GPA to ../../../models/DC-TCN/datasets/lrs3_words_may/GPA
# Moved THURSDAY to ../../../models/DC-TCN/datasets/lrs3_words_may/THURSDAY
# Moved IMAGINED to ../../../models/DC-TCN/datasets/lrs3_words_may/IMAGINED
# Moved SUPREMELY to ../../../models/DC-TCN/datasets/lrs3_words_may/SUPREMELY
# Moved REFUEL to ../../../models/DC-TCN/datasets/lrs3_words_may/REFUEL
# Moved BOUNDARY to ../../../models/DC-TCN/datasets/lrs3_words_may/BOUNDARY
# Moved COHERENT to ../../../models/DC-TCN/datasets/lrs3_words_may/COHERENT
# Moved CONSULTING to ../../../models/DC-TCN/datasets/lrs3_words_may/CONSULTING
# Moved SEDUCTIVE to ../../../models/DC-TCN/datasets/lrs3_words_may/SEDUCTIVE
# Moved HUGGED to ../../../models/DC-TCN/datasets/lrs3_words_may/HUGGED
# Moved METAPHORICALLY to ../../../models/DC-TCN/datasets/lrs3_words_may/METAPHORICALLY
# Moved BACKUP to ../../../models/DC-TCN/datasets/lrs3_words_may/BACKUP
# Moved UNPRECEDENTED to ../../../models/DC-TCN/datasets/lrs3_words_may/UNPRECEDENTED
# Moved MANNER to ../../../models/DC-TCN/datasets/lrs3_words_may/MANNER
# Moved SANK to ../../../models/DC-TCN/datasets/lrs3_words_may/SANK
# Moved FAME to ../../../models/DC-TCN/datasets/lrs3_words_may/FAME
# Moved ROSETTA to ../../../models/DC-TCN/datasets/lrs3_words_may/ROSETTA
# Moved JASPER to ../../../models/DC-TCN/datasets/lrs3_words_may/JASPER
# Moved DECLARED to ../../../models/DC-TCN/datasets/lrs3_words_may/DECLARED
# Moved CANADIAN to ../../../models/DC-TCN/datasets/lrs3_words_may/CANADIAN
# Moved CONFINED to ../../../models/DC-TCN/datasets/lrs3_words_may/CONFINED
# Moved MARGARET to ../../../models/DC-TCN/datasets/lrs3_words_may/MARGARET
# Moved SKIING to ../../../models/DC-TCN/datasets/lrs3_words_may/SKIING
# Moved INDIGENOUS to ../../../models/DC-TCN/datasets/lrs3_words_may/INDIGENOUS
# Moved CONVENIENCE to ../../../models/DC-TCN/datasets/lrs3_words_may/CONVENIENCE
# Moved BOOGIE to ../../../models/DC-TCN/datasets/lrs3_words_may/BOOGIE
# Moved LAWN to ../../../models/DC-TCN/datasets/lrs3_words_may/LAWN
# Moved SPINE to ../../../models/DC-TCN/datasets/lrs3_words_may/SPINE
# Moved MEERKAT to ../../../models/DC-TCN/datasets/lrs3_words_may/MEERKAT
# Moved CONVERT to ../../../models/DC-TCN/datasets/lrs3_words_may/CONVERT
# Moved RESISTED to ../../../models/DC-TCN/datasets/lrs3_words_may/RESISTED
# Moved REPRESENTATIVE to ../../../models/DC-TCN/datasets/lrs3_words_may/REPRESENTATIVE
# Moved DIAGRAM to ../../../models/DC-TCN/datasets/lrs3_words_may/DIAGRAM
# Moved FOUNDING to ../../../models/DC-TCN/datasets/lrs3_words_may/FOUNDING
# Moved SCANNING to ../../../models/DC-TCN/datasets/lrs3_words_may/SCANNING
# Moved MAT to ../../../models/DC-TCN/datasets/lrs3_words_may/MAT
# Moved DOORWAY to ../../../models/DC-TCN/datasets/lrs3_words_may/DOORWAY
# Moved DEFAULT to ../../../models/DC-TCN/datasets/lrs3_words_may/DEFAULT
# Moved AMATEUR to ../../../models/DC-TCN/datasets/lrs3_words_may/AMATEUR
# Moved GRANDIN to ../../../models/DC-TCN/datasets/lrs3_words_may/GRANDIN
# Moved BEEF to ../../../models/DC-TCN/datasets/lrs3_words_may/BEEF
# Moved RESORT to ../../../models/DC-TCN/datasets/lrs3_words_may/RESORT
# Moved PUBLICLY to ../../../models/DC-TCN/datasets/lrs3_words_may/PUBLICLY
# Moved RELEASING to ../../../models/DC-TCN/datasets/lrs3_words_may/RELEASING
# Moved AGRICULTURAL to ../../../models/DC-TCN/datasets/lrs3_words_may/AGRICULTURAL
# Moved CAYMAN to ../../../models/DC-TCN/datasets/lrs3_words_may/CAYMAN
# Moved BRANCH to ../../../models/DC-TCN/datasets/lrs3_words_may/BRANCH
# Moved SARS to ../../../models/DC-TCN/datasets/lrs3_words_may/SARS
# Moved EFFICIENCY to ../../../models/DC-TCN/datasets/lrs3_words_may/EFFICIENCY
# Moved HUT to ../../../models/DC-TCN/datasets/lrs3_words_may/HUT
# Moved EXTRAORDINARILY to ../../../models/DC-TCN/datasets/lrs3_words_may/EXTRAORDINARILY
# Moved NEUTRON to ../../../models/DC-TCN/datasets/lrs3_words_may/NEUTRON
# Moved COP to ../../../models/DC-TCN/datasets/lrs3_words_may/COP
# Moved JULIA to ../../../models/DC-TCN/datasets/lrs3_words_may/JULIA
# Moved PACIFIC to ../../../models/DC-TCN/datasets/lrs3_words_may/PACIFIC
# Moved CONTEMPORARY to ../../../models/DC-TCN/datasets/lrs3_words_may/CONTEMPORARY
# Moved AWAIT to ../../../models/DC-TCN/datasets/lrs3_words_may/AWAIT
# Moved SUPERMAN to ../../../models/DC-TCN/datasets/lrs3_words_may/SUPERMAN
# Moved FAMED to ../../../models/DC-TCN/datasets/lrs3_words_may/FAMED
# Moved PLEASED to ../../../models/DC-TCN/datasets/lrs3_words_may/PLEASED
# Moved THERAPEUTIC to ../../../models/DC-TCN/datasets/lrs3_words_may/THERAPEUTIC
# Moved RILEY to ../../../models/DC-TCN/datasets/lrs3_words_may/RILEY
# Moved GREETING to ../../../models/DC-TCN/datasets/lrs3_words_may/GREETING
# Moved EXECUTE to ../../../models/DC-TCN/datasets/lrs3_words_may/EXECUTE
# Moved WONDERFULLY to ../../../models/DC-TCN/datasets/lrs3_words_may/WONDERFULLY
# Moved ALARMED to ../../../models/DC-TCN/datasets/lrs3_words_may/ALARMED
# Moved WIDELY to ../../../models/DC-TCN/datasets/lrs3_words_may/WIDELY
# Moved POSTCARD to ../../../models/DC-TCN/datasets/lrs3_words_may/POSTCARD
# Moved ELEGANT to ../../../models/DC-TCN/datasets/lrs3_words_may/ELEGANT
# Moved OBLIGATION to ../../../models/DC-TCN/datasets/lrs3_words_may/OBLIGATION
# Moved PORTRAY to ../../../models/DC-TCN/datasets/lrs3_words_may/PORTRAY
# Moved HARMONY to ../../../models/DC-TCN/datasets/lrs3_words_may/HARMONY
# Moved MICROALGAE to ../../../models/DC-TCN/datasets/lrs3_words_may/MICROALGAE
# Moved PROGRAMMER to ../../../models/DC-TCN/datasets/lrs3_words_may/PROGRAMMER
# Moved MINNEAPOLIS to ../../../models/DC-TCN/datasets/lrs3_words_may/MINNEAPOLIS
# Moved RESIDENTIAL to ../../../models/DC-TCN/datasets/lrs3_words_may/RESIDENTIAL
# Moved DOLPHIN to ../../../models/DC-TCN/datasets/lrs3_words_may/DOLPHIN
# Moved SOMALI to ../../../models/DC-TCN/datasets/lrs3_words_may/SOMALI
# Moved COOLER to ../../../models/DC-TCN/datasets/lrs3_words_may/COOLER
# Moved STRIVE to ../../../models/DC-TCN/datasets/lrs3_words_may/STRIVE
# Moved COLOUR to ../../../models/DC-TCN/datasets/lrs3_words_may/COLOUR
# Moved CHURCHES to ../../../models/DC-TCN/datasets/lrs3_words_may/CHURCHES
# Moved IMPACTED to ../../../models/DC-TCN/datasets/lrs3_words_may/IMPACTED
# Moved CLOSING to ../../../models/DC-TCN/datasets/lrs3_words_may/CLOSING
# Moved CONFIRMATION to ../../../models/DC-TCN/datasets/lrs3_words_may/CONFIRMATION
# Moved UNDERSTANDABLE to ../../../models/DC-TCN/datasets/lrs3_words_may/UNDERSTANDABLE
# Moved VANISHED to ../../../models/DC-TCN/datasets/lrs3_words_may/VANISHED
# Moved BEFRIEND to ../../../models/DC-TCN/datasets/lrs3_words_may/BEFRIEND
# Moved CARLO to ../../../models/DC-TCN/datasets/lrs3_words_may/CARLO
# Moved CONTRIBUTED to ../../../models/DC-TCN/datasets/lrs3_words_may/CONTRIBUTED
# Moved RESERVE to ../../../models/DC-TCN/datasets/lrs3_words_may/RESERVE
# Moved CORRIDOR to ../../../models/DC-TCN/datasets/lrs3_words_may/CORRIDOR
# Moved LIBYA to ../../../models/DC-TCN/datasets/lrs3_words_may/LIBYA
# Moved HACKING to ../../../models/DC-TCN/datasets/lrs3_words_may/HACKING
# Moved RECEPTION to ../../../models/DC-TCN/datasets/lrs3_words_may/RECEPTION
# Moved DECEMBER to ../../../models/DC-TCN/datasets/lrs3_words_may/DECEMBER
# Moved MADAGASCAR to ../../../models/DC-TCN/datasets/lrs3_words_may/MADAGASCAR
# Moved EURO to ../../../models/DC-TCN/datasets/lrs3_words_may/EURO
# Moved PROMISING to ../../../models/DC-TCN/datasets/lrs3_words_may/PROMISING
# Moved GEORGIA to ../../../models/DC-TCN/datasets/lrs3_words_may/GEORGIA
# Moved BITCH to ../../../models/DC-TCN/datasets/lrs3_words_may/BITCH
# Moved NOTED to ../../../models/DC-TCN/datasets/lrs3_words_may/NOTED
# Moved FLAWED to ../../../models/DC-TCN/datasets/lrs3_words_may/FLAWED
# Moved DISMAY to ../../../models/DC-TCN/datasets/lrs3_words_may/DISMAY
# Moved ISSUED to ../../../models/DC-TCN/datasets/lrs3_words_may/ISSUED
# Moved MIXTURE to ../../../models/DC-TCN/datasets/lrs3_words_may/MIXTURE
# Moved GRAPPLE to ../../../models/DC-TCN/datasets/lrs3_words_may/GRAPPLE
# Moved REPEATEDLY to ../../../models/DC-TCN/datasets/lrs3_words_may/REPEATEDLY
# Moved WALKER to ../../../models/DC-TCN/datasets/lrs3_words_may/WALKER
# Moved DENMARK to ../../../models/DC-TCN/datasets/lrs3_words_may/DENMARK
# Moved LENDING to ../../../models/DC-TCN/datasets/lrs3_words_may/LENDING
# Moved RESTART to ../../../models/DC-TCN/datasets/lrs3_words_may/RESTART
# Moved BIOTECHNOLOGY to ../../../models/DC-TCN/datasets/lrs3_words_may/BIOTECHNOLOGY
# Moved SUBSTANTIAL to ../../../models/DC-TCN/datasets/lrs3_words_may/SUBSTANTIAL
# Moved BERKELEY to ../../../models/DC-TCN/datasets/lrs3_words_may/BERKELEY
# Moved PAVE to ../../../models/DC-TCN/datasets/lrs3_words_may/PAVE
# Moved CHEAPEST to ../../../models/DC-TCN/datasets/lrs3_words_may/CHEAPEST
# Moved QUANTITATIVE to ../../../models/DC-TCN/datasets/lrs3_words_may/QUANTITATIVE
# Moved WIVES to ../../../models/DC-TCN/datasets/lrs3_words_may/WIVES
# Moved BOUNCE to ../../../models/DC-TCN/datasets/lrs3_words_may/BOUNCE
# Moved GUIDED to ../../../models/DC-TCN/datasets/lrs3_words_may/GUIDED
# Moved JUDGED to ../../../models/DC-TCN/datasets/lrs3_words_may/JUDGED
# Moved COMPLEMENT to ../../../models/DC-TCN/datasets/lrs3_words_may/COMPLEMENT
# Moved PUPIL to ../../../models/DC-TCN/datasets/lrs3_words_may/PUPIL
# Moved VISITORS to ../../../models/DC-TCN/datasets/lrs3_words_may/VISITORS
# Moved NFL to ../../../models/DC-TCN/datasets/lrs3_words_may/NFL
# Moved SHRUNK to ../../../models/DC-TCN/datasets/lrs3_words_may/SHRUNK
# Moved WASHER to ../../../models/DC-TCN/datasets/lrs3_words_may/WASHER
# Moved DRAMATIC to ../../../models/DC-TCN/datasets/lrs3_words_may/DRAMATIC
# Moved ORCHARD to ../../../models/DC-TCN/datasets/lrs3_words_may/ORCHARD
# Moved JUSTIFIED to ../../../models/DC-TCN/datasets/lrs3_words_may/JUSTIFIED
# Moved MAX to ../../../models/DC-TCN/datasets/lrs3_words_may/MAX
# Moved GUARANTEED to ../../../models/DC-TCN/datasets/lrs3_words_may/GUARANTEED
# Moved BURDENED to ../../../models/DC-TCN/datasets/lrs3_words_may/BURDENED
# Moved BABY'S to ../../../models/DC-TCN/datasets/lrs3_words_may/BABY'S
# Moved STUNNED to ../../../models/DC-TCN/datasets/lrs3_words_may/STUNNED
# Moved BREAKDOWN to ../../../models/DC-TCN/datasets/lrs3_words_may/BREAKDOWN
# Moved DURBAN to ../../../models/DC-TCN/datasets/lrs3_words_may/DURBAN
# Moved ARRAY to ../../../models/DC-TCN/datasets/lrs3_words_may/ARRAY
# Moved COMPUTATION to ../../../models/DC-TCN/datasets/lrs3_words_may/COMPUTATION
# Moved REFINED to ../../../models/DC-TCN/datasets/lrs3_words_may/REFINED
# Moved HARMFUL to ../../../models/DC-TCN/datasets/lrs3_words_may/HARMFUL
# Moved LEMUR to ../../../models/DC-TCN/datasets/lrs3_words_may/LEMUR
# Moved DEATHBED to ../../../models/DC-TCN/datasets/lrs3_words_may/DEATHBED
# Moved HEALING to ../../../models/DC-TCN/datasets/lrs3_words_may/HEALING
# Moved DUPLICATE to ../../../models/DC-TCN/datasets/lrs3_words_may/DUPLICATE
# Moved REGARDED to ../../../models/DC-TCN/datasets/lrs3_words_may/REGARDED
# Moved THREATENED to ../../../models/DC-TCN/datasets/lrs3_words_may/THREATENED
# Moved AIRPORT to ../../../models/DC-TCN/datasets/lrs3_words_may/AIRPORT
# Moved WASHING to ../../../models/DC-TCN/datasets/lrs3_words_may/WASHING
# Moved POMPEII to ../../../models/DC-TCN/datasets/lrs3_words_may/POMPEII
# Moved JESUS to ../../../models/DC-TCN/datasets/lrs3_words_may/JESUS
# Moved RUSSELL to ../../../models/DC-TCN/datasets/lrs3_words_may/RUSSELL
# Moved PROPORTION to ../../../models/DC-TCN/datasets/lrs3_words_may/PROPORTION
# Moved KEN to ../../../models/DC-TCN/datasets/lrs3_words_may/KEN
# Moved APPROXIMATE to ../../../models/DC-TCN/datasets/lrs3_words_may/APPROXIMATE
# Moved CATTLE to ../../../models/DC-TCN/datasets/lrs3_words_may/CATTLE
# Moved SPORES to ../../../models/DC-TCN/datasets/lrs3_words_may/SPORES
# Moved RIDER to ../../../models/DC-TCN/datasets/lrs3_words_may/RIDER
# Moved BIASED to ../../../models/DC-TCN/datasets/lrs3_words_may/BIASED
# Moved TRANSPLANT to ../../../models/DC-TCN/datasets/lrs3_words_may/TRANSPLANT
# Moved JEWS to ../../../models/DC-TCN/datasets/lrs3_words_may/JEWS
# Moved VISCERAL to ../../../models/DC-TCN/datasets/lrs3_words_may/VISCERAL
# Moved SWAM to ../../../models/DC-TCN/datasets/lrs3_words_may/SWAM
# Moved OCCASIONALLY to ../../../models/DC-TCN/datasets/lrs3_words_may/OCCASIONALLY
# Moved STATUE to ../../../models/DC-TCN/datasets/lrs3_words_may/STATUE
# Moved REACTED to ../../../models/DC-TCN/datasets/lrs3_words_may/REACTED
# Moved PROFOUNDLY to ../../../models/DC-TCN/datasets/lrs3_words_may/PROFOUNDLY
# Moved SOPHOMORE to ../../../models/DC-TCN/datasets/lrs3_words_may/SOPHOMORE
# Moved HATING to ../../../models/DC-TCN/datasets/lrs3_words_may/HATING
# Moved EXPLICITLY to ../../../models/DC-TCN/datasets/lrs3_words_may/EXPLICITLY
# Moved BENEFICIARIES to ../../../models/DC-TCN/datasets/lrs3_words_may/BENEFICIARIES
# Moved OPTIMIST to ../../../models/DC-TCN/datasets/lrs3_words_may/OPTIMIST
# Moved POWDER to ../../../models/DC-TCN/datasets/lrs3_words_may/POWDER
# Moved DALAI to ../../../models/DC-TCN/datasets/lrs3_words_may/DALAI
# Moved SPILL to ../../../models/DC-TCN/datasets/lrs3_words_may/SPILL
# Moved YACHT to ../../../models/DC-TCN/datasets/lrs3_words_may/YACHT
# Moved DROPOUT to ../../../models/DC-TCN/datasets/lrs3_words_may/DROPOUT
# Moved FRANCIS to ../../../models/DC-TCN/datasets/lrs3_words_may/FRANCIS
# Moved HONEYBEES to ../../../models/DC-TCN/datasets/lrs3_words_may/HONEYBEES
# Moved CHILDISH to ../../../models/DC-TCN/datasets/lrs3_words_may/CHILDISH
# Moved SPONTANEOUS to ../../../models/DC-TCN/datasets/lrs3_words_may/SPONTANEOUS
# Moved CATASTROPHIC to ../../../models/DC-TCN/datasets/lrs3_words_may/CATASTROPHIC
# Moved ANIMATED to ../../../models/DC-TCN/datasets/lrs3_words_may/ANIMATED
# Moved POLICEMAN to ../../../models/DC-TCN/datasets/lrs3_words_may/POLICEMAN
# Moved TACKLING to ../../../models/DC-TCN/datasets/lrs3_words_may/TACKLING
# Moved SPRAYING to ../../../models/DC-TCN/datasets/lrs3_words_may/SPRAYING
# Moved COPING to ../../../models/DC-TCN/datasets/lrs3_words_may/COPING
# Moved WRESTLER to ../../../models/DC-TCN/datasets/lrs3_words_may/WRESTLER
# Moved BEAMING to ../../../models/DC-TCN/datasets/lrs3_words_may/BEAMING
# Moved BOTHERING to ../../../models/DC-TCN/datasets/lrs3_words_may/BOTHERING
# Moved SMS to ../../../models/DC-TCN/datasets/lrs3_words_may/SMS
# Moved MISTRUST to ../../../models/DC-TCN/datasets/lrs3_words_may/MISTRUST
# Moved ENZYMES to ../../../models/DC-TCN/datasets/lrs3_words_may/ENZYMES
# Moved RULED to ../../../models/DC-TCN/datasets/lrs3_words_may/RULED
# Moved AUTONOMOUS to ../../../models/DC-TCN/datasets/lrs3_words_may/AUTONOMOUS
# Moved LACKING to ../../../models/DC-TCN/datasets/lrs3_words_may/LACKING
# Moved REINVENT to ../../../models/DC-TCN/datasets/lrs3_words_may/REINVENT
# Moved PHILANTHROPY to ../../../models/DC-TCN/datasets/lrs3_words_may/PHILANTHROPY
# Moved SELFIE to ../../../models/DC-TCN/datasets/lrs3_words_may/SELFIE
# Moved BITCOIN to ../../../models/DC-TCN/datasets/lrs3_words_may/BITCOIN
# Moved KENYAN to ../../../models/DC-TCN/datasets/lrs3_words_may/KENYAN
# Moved CODING to ../../../models/DC-TCN/datasets/lrs3_words_may/CODING
# Moved REPRODUCTION to ../../../models/DC-TCN/datasets/lrs3_words_may/REPRODUCTION
# Moved ADVOCACY to ../../../models/DC-TCN/datasets/lrs3_words_may/ADVOCACY
# Moved RECOGNITION to ../../../models/DC-TCN/datasets/lrs3_words_may/RECOGNITION
# Moved MODELING to ../../../models/DC-TCN/datasets/lrs3_words_may/MODELING
# Moved STUART to ../../../models/DC-TCN/datasets/lrs3_words_may/STUART
# Moved IRRELEVANT to ../../../models/DC-TCN/datasets/lrs3_words_may/IRRELEVANT
# Moved BRICKS to ../../../models/DC-TCN/datasets/lrs3_words_may/BRICKS
# Moved DEVELOPMENTAL to ../../../models/DC-TCN/datasets/lrs3_words_may/DEVELOPMENTAL
# Moved WIPED to ../../../models/DC-TCN/datasets/lrs3_words_may/WIPED
# Moved TEAMED to ../../../models/DC-TCN/datasets/lrs3_words_may/TEAMED
# Moved PROTECTING to ../../../models/DC-TCN/datasets/lrs3_words_may/PROTECTING
# Moved CONTINUOUSLY to ../../../models/DC-TCN/datasets/lrs3_words_may/CONTINUOUSLY
# Moved GUM to ../../../models/DC-TCN/datasets/lrs3_words_may/GUM
# Moved MARCHED to ../../../models/DC-TCN/datasets/lrs3_words_may/MARCHED
# Moved SIKH to ../../../models/DC-TCN/datasets/lrs3_words_may/SIKH
# Moved ASSASSINATED to ../../../models/DC-TCN/datasets/lrs3_words_may/ASSASSINATED
# Moved MIC to ../../../models/DC-TCN/datasets/lrs3_words_may/MIC
# Moved ARKANSAS to ../../../models/DC-TCN/datasets/lrs3_words_may/ARKANSAS
# Moved MYTHOLOGY to ../../../models/DC-TCN/datasets/lrs3_words_may/MYTHOLOGY
# Moved TOKEN to ../../../models/DC-TCN/datasets/lrs3_words_may/TOKEN
# Moved MILLIMETER to ../../../models/DC-TCN/datasets/lrs3_words_may/MILLIMETER
# Moved CONSPIRACY to ../../../models/DC-TCN/datasets/lrs3_words_may/CONSPIRACY
# Moved CELLPHONE to ../../../models/DC-TCN/datasets/lrs3_words_may/CELLPHONE
# Moved RANDOMNESS to ../../../models/DC-TCN/datasets/lrs3_words_may/RANDOMNESS
# Moved ENTREPRENEURIAL to ../../../models/DC-TCN/datasets/lrs3_words_may/ENTREPRENEURIAL
# Moved METABOLIC to ../../../models/DC-TCN/datasets/lrs3_words_may/METABOLIC
# Moved APPEAL to ../../../models/DC-TCN/datasets/lrs3_words_may/APPEAL
# Moved DAVIS to ../../../models/DC-TCN/datasets/lrs3_words_may/DAVIS
# Moved OFFLINE to ../../../models/DC-TCN/datasets/lrs3_words_may/OFFLINE
# Moved SHOOK to ../../../models/DC-TCN/datasets/lrs3_words_may/SHOOK
# Moved COMMENTARY to ../../../models/DC-TCN/datasets/lrs3_words_may/COMMENTARY
# Moved PIN to ../../../models/DC-TCN/datasets/lrs3_words_may/PIN
# Moved RABBIT to ../../../models/DC-TCN/datasets/lrs3_words_may/RABBIT
# Moved CLAIMING to ../../../models/DC-TCN/datasets/lrs3_words_may/CLAIMING
# Moved RECONCILE to ../../../models/DC-TCN/datasets/lrs3_words_may/RECONCILE
# Moved REPLIED to ../../../models/DC-TCN/datasets/lrs3_words_may/REPLIED
# Moved MERCY to ../../../models/DC-TCN/datasets/lrs3_words_may/MERCY
# Moved INTUITIVE to ../../../models/DC-TCN/datasets/lrs3_words_may/INTUITIVE
# Moved COMPOUNDING to ../../../models/DC-TCN/datasets/lrs3_words_may/COMPOUNDING
# Moved CONTAGION to ../../../models/DC-TCN/datasets/lrs3_words_may/CONTAGION
# Moved DEBATED to ../../../models/DC-TCN/datasets/lrs3_words_may/DEBATED
# Moved PROSTATE to ../../../models/DC-TCN/datasets/lrs3_words_may/PROSTATE
# Moved WHISPERED to ../../../models/DC-TCN/datasets/lrs3_words_may/WHISPERED
# Moved MUSK to ../../../models/DC-TCN/datasets/lrs3_words_may/MUSK
# Moved REPETITION to ../../../models/DC-TCN/datasets/lrs3_words_may/REPETITION
# Moved VIRGIN to ../../../models/DC-TCN/datasets/lrs3_words_may/VIRGIN
# Moved FLIPPED to ../../../models/DC-TCN/datasets/lrs3_words_may/FLIPPED
# Moved SPERM to ../../../models/DC-TCN/datasets/lrs3_words_may/SPERM
# Moved PORK to ../../../models/DC-TCN/datasets/lrs3_words_may/PORK
# Moved PSYCHIC to ../../../models/DC-TCN/datasets/lrs3_words_may/PSYCHIC
# Moved SAVANNA to ../../../models/DC-TCN/datasets/lrs3_words_may/SAVANNA
# Moved VOW to ../../../models/DC-TCN/datasets/lrs3_words_may/VOW
# Moved INTIMATELY to ../../../models/DC-TCN/datasets/lrs3_words_may/INTIMATELY
# Moved VETERINARY to ../../../models/DC-TCN/datasets/lrs3_words_may/VETERINARY
# Moved VACUUM to ../../../models/DC-TCN/datasets/lrs3_words_may/VACUUM
# Moved BLESSING to ../../../models/DC-TCN/datasets/lrs3_words_may/BLESSING
# Moved HUNGER to ../../../models/DC-TCN/datasets/lrs3_words_may/HUNGER
# Moved RESEARCHED to ../../../models/DC-TCN/datasets/lrs3_words_may/RESEARCHED
# Moved CHESS to ../../../models/DC-TCN/datasets/lrs3_words_may/CHESS
# Moved COLDEST to ../../../models/DC-TCN/datasets/lrs3_words_may/COLDEST
# Moved BANKER to ../../../models/DC-TCN/datasets/lrs3_words_may/BANKER
# Moved THOUGHTFUL to ../../../models/DC-TCN/datasets/lrs3_words_may/THOUGHTFUL
# Moved ENTITY to ../../../models/DC-TCN/datasets/lrs3_words_may/ENTITY
# Moved ENO to ../../../models/DC-TCN/datasets/lrs3_words_may/ENO
# Moved PROJECTED to ../../../models/DC-TCN/datasets/lrs3_words_may/PROJECTED
# Moved ASSAULTED to ../../../models/DC-TCN/datasets/lrs3_words_may/ASSAULTED
# Moved CITY'S to ../../../models/DC-TCN/datasets/lrs3_words_may/CITY'S
# Moved TEMPTATION to ../../../models/DC-TCN/datasets/lrs3_words_may/TEMPTATION
# Moved NURSING to ../../../models/DC-TCN/datasets/lrs3_words_may/NURSING
# Moved HEALED to ../../../models/DC-TCN/datasets/lrs3_words_may/HEALED
# Moved EVERGLADE to ../../../models/DC-TCN/datasets/lrs3_words_may/EVERGLADE
# Moved DIRT to ../../../models/DC-TCN/datasets/lrs3_words_may/DIRT
# Moved DETERMINING to ../../../models/DC-TCN/datasets/lrs3_words_may/DETERMINING
# Moved CEREMONIES to ../../../models/DC-TCN/datasets/lrs3_words_may/CEREMONIES
# Moved DESICCATE to ../../../models/DC-TCN/datasets/lrs3_words_may/DESICCATE
# Moved SCOTTISH to ../../../models/DC-TCN/datasets/lrs3_words_may/SCOTTISH
# Moved STEADY to ../../../models/DC-TCN/datasets/lrs3_words_may/STEADY
# Moved WATCHES to ../../../models/DC-TCN/datasets/lrs3_words_may/WATCHES
# Moved HETEROSEXISM to ../../../models/DC-TCN/datasets/lrs3_words_may/HETEROSEXISM
# Moved AUDIT to ../../../models/DC-TCN/datasets/lrs3_words_may/AUDIT
# Moved ADDRESSES to ../../../models/DC-TCN/datasets/lrs3_words_may/ADDRESSES
# Moved WILSON to ../../../models/DC-TCN/datasets/lrs3_words_may/WILSON
# Moved RADIOACTIVE to ../../../models/DC-TCN/datasets/lrs3_words_may/RADIOACTIVE
# Moved DEPRIVED to ../../../models/DC-TCN/datasets/lrs3_words_may/DEPRIVED
# Moved APPROVED to ../../../models/DC-TCN/datasets/lrs3_words_may/APPROVED
# Moved TONGUE to ../../../models/DC-TCN/datasets/lrs3_words_may/TONGUE
# Moved MARCH to ../../../models/DC-TCN/datasets/lrs3_words_may/MARCH
# Moved PROGRESSED to ../../../models/DC-TCN/datasets/lrs3_words_may/PROGRESSED
# Moved REQUEST to ../../../models/DC-TCN/datasets/lrs3_words_may/REQUEST
# Moved DETAILED to ../../../models/DC-TCN/datasets/lrs3_words_may/DETAILED
# Moved ABSTRACTION to ../../../models/DC-TCN/datasets/lrs3_words_may/ABSTRACTION
# Moved ACRE to ../../../models/DC-TCN/datasets/lrs3_words_may/ACRE
# Moved SENSIBLE to ../../../models/DC-TCN/datasets/lrs3_words_may/SENSIBLE
# Moved SPOTLIGHT to ../../../models/DC-TCN/datasets/lrs3_words_may/SPOTLIGHT
# Moved ANALYTICS to ../../../models/DC-TCN/datasets/lrs3_words_may/ANALYTICS
# Moved PALM to ../../../models/DC-TCN/datasets/lrs3_words_may/PALM
# Moved STAMP to ../../../models/DC-TCN/datasets/lrs3_words_may/STAMP
# Moved BELL to ../../../models/DC-TCN/datasets/lrs3_words_may/BELL
# Moved USAGE to ../../../models/DC-TCN/datasets/lrs3_words_may/USAGE
# ...
# Moved STRENGTHEN to ../../../models/DC-TCN/datasets/lrs3_words_may/STRENGTHEN
# Moved NOVICE to ../../../models/DC-TCN/datasets/lrs3_words_may/NOVICE
# Moved SAL to ../../../models/DC-TCN/datasets/lrs3_words_may/SAL
# Moved GENERATED to ../../../models/DC-TCN/datasets/lrs3_words_may/GENERATED
# Moved CUSTODY to ../../../models/DC-TCN/datasets/lrs3_words_may/CUSTODY
# Moved EXCEL to ../../../models/DC-TCN/datasets/lrs3_words_may/EXCEL
# Moved ARRIVAL to ../../../models/DC-TCN/datasets/lrs3_words_may/ARRIVAL
# Moved SESAME to ../../../models/DC-TCN/datasets/lrs3_words_may/SESAME
# Moved SIMPLISTIC to ../../../models/DC-TCN/datasets/lrs3_words_may/SIMPLISTIC
# Moved CLONE to ../../../models/DC-TCN/datasets/lrs3_words_may/CLONE
# Moved CERTIFIED to ../../../models/DC-TCN/datasets/lrs3_words_may/CERTIFIED
# Moved ATTRACTION to ../../../models/DC-TCN/datasets/lrs3_words_may/ATTRACTION
# Moved MAITREYA to ../../../models/DC-TCN/datasets/lrs3_words_may/MAITREYA
# Moved SCIENTIFICALLY to ../../../models/DC-TCN/datasets/lrs3_words_may/SCIENTIFICALLY
# Moved COMPLIMENT to ../../../models/DC-TCN/datasets/lrs3_words_may/COMPLIMENT
# Moved PARTWAY to ../../../models/DC-TCN/datasets/lrs3_words_may/PARTWAY
# Moved DONATION to ../../../models/DC-TCN/datasets/lrs3_words_may/DONATION
# Moved DELEGATE to ../../../models/DC-TCN/datasets/lrs3_words_may/DELEGATE
# Moved CAFFEINE to ../../../models/DC-TCN/datasets/lrs3_words_may/CAFFEINE
# Moved LANDMARKS to ../../../models/DC-TCN/datasets/lrs3_words_may/LANDMARKS
# Moved PORTLAND to ../../../models/DC-TCN/datasets/lrs3_words_may/PORTLAND
# Moved BEDROOM to ../../../models/DC-TCN/datasets/lrs3_words_may/BEDROOM
# Moved BUCKLE to ../../../models/DC-TCN/datasets/lrs3_words_may/BUCKLE
# Moved VETS to ../../../models/DC-TCN/datasets/lrs3_words_may/VETS
# Moved HUMILITY to ../../../models/DC-TCN/datasets/lrs3_words_may/HUMILITY
# Moved PAINTED to ../../../models/DC-TCN/datasets/lrs3_words_may/PAINTED
# Moved EXTENSIVE to ../../../models/DC-TCN/datasets/lrs3_words_may/EXTENSIVE
# Moved FRIGHTENING to ../../../models/DC-TCN/datasets/lrs3_words_may/FRIGHTENING
# Moved CREATIVELY to ../../../models/DC-TCN/datasets/lrs3_words_may/CREATIVELY
# Moved LEARNERS to ../../../models/DC-TCN/datasets/lrs3_words_may/LEARNERS
# Moved DIAMOND to ../../../models/DC-TCN/datasets/lrs3_words_may/DIAMOND
# Moved SUNRISE to ../../../models/DC-TCN/datasets/lrs3_words_may/SUNRISE
# Moved CALCULATOR to ../../../models/DC-TCN/datasets/lrs3_words_may/CALCULATOR
# Moved NOMADIC to ../../../models/DC-TCN/datasets/lrs3_words_may/NOMADIC
# Moved MAINE to ../../../models/DC-TCN/datasets/lrs3_words_may/MAINE
# Moved URGENT to ../../../models/DC-TCN/datasets/lrs3_words_may/URGENT
# Moved MOSQUITO to ../../../models/DC-TCN/datasets/lrs3_words_may/MOSQUITO
# Moved ATTACH to ../../../models/DC-TCN/datasets/lrs3_words_may/ATTACH
# Moved DARKEST to ../../../models/DC-TCN/datasets/lrs3_words_may/DARKEST
# Moved ACCOMPLISHMENT to ../../../models/DC-TCN/datasets/lrs3_words_may/ACCOMPLISHMENT
# Moved PHYSIOLOGY to ../../../models/DC-TCN/datasets/lrs3_words_may/PHYSIOLOGY
# Moved BUZZ to ../../../models/DC-TCN/datasets/lrs3_words_may/BUZZ
# Moved APPLAUD to ../../../models/DC-TCN/datasets/lrs3_words_may/APPLAUD
# Moved HONAM to ../../../models/DC-TCN/datasets/lrs3_words_may/HONAM
# Moved SCRAPE to ../../../models/DC-TCN/datasets/lrs3_words_may/SCRAPE
# Moved LIVESTOCK to ../../../models/DC-TCN/datasets/lrs3_words_may/LIVESTOCK
# Moved DROUGHT to ../../../models/DC-TCN/datasets/lrs3_words_may/DROUGHT
# Moved REIMAGINE to ../../../models/DC-TCN/datasets/lrs3_words_may/REIMAGINE
# Moved PROTAGONIST to ../../../models/DC-TCN/datasets/lrs3_words_may/PROTAGONIST
# Moved PHENOMENAL to ../../../models/DC-TCN/datasets/lrs3_words_may/PHENOMENAL
# Moved EMILY to ../../../models/DC-TCN/datasets/lrs3_words_may/EMILY
# Moved CROWDED to ../../../models/DC-TCN/datasets/lrs3_words_may/CROWDED
# Moved MEDITERRANEAN to ../../../models/DC-TCN/datasets/lrs3_words_may/MEDITERRANEAN
# Moved FINANCING to ../../../models/DC-TCN/datasets/lrs3_words_may/FINANCING
# Moved ANATOMY to ../../../models/DC-TCN/datasets/lrs3_words_may/ANATOMY
# Moved RIPPED to ../../../models/DC-TCN/datasets/lrs3_words_may/RIPPED
# Moved ADVOCATING to ../../../models/DC-TCN/datasets/lrs3_words_may/ADVOCATING
# Moved IMPROVISATION to ../../../models/DC-TCN/datasets/lrs3_words_may/IMPROVISATION
# Moved SIMPLER to ../../../models/DC-TCN/datasets/lrs3_words_may/SIMPLER
# Moved INCONSISTENT to ../../../models/DC-TCN/datasets/lrs3_words_may/INCONSISTENT
# Moved CEMETERY to ../../../models/DC-TCN/datasets/lrs3_words_may/CEMETERY
# Moved PENETRATION to ../../../models/DC-TCN/datasets/lrs3_words_may/PENETRATION
# Moved O'MALLEY to ../../../models/DC-TCN/datasets/lrs3_words_may/O'MALLEY
# Moved WOULD'VE to ../../../models/DC-TCN/datasets/lrs3_words_may/WOULD'VE
# Moved WENDY to ../../../models/DC-TCN/datasets/lrs3_words_may/WENDY
# Moved CHEER to ../../../models/DC-TCN/datasets/lrs3_words_may/CHEER
# Moved GLOW to ../../../models/DC-TCN/datasets/lrs3_words_may/GLOW
# Moved MANDATORY to ../../../models/DC-TCN/datasets/lrs3_words_may/MANDATORY
# Moved UNDERDOG to ../../../models/DC-TCN/datasets/lrs3_words_may/UNDERDOG
# Moved STEVENSON to ../../../models/DC-TCN/datasets/lrs3_words_may/STEVENSON
# Moved BUCKET to ../../../models/DC-TCN/datasets/lrs3_words_may/BUCKET
# Moved INFORM to ../../../models/DC-TCN/datasets/lrs3_words_may/INFORM
# Moved DARPA to ../../../models/DC-TCN/datasets/lrs3_words_may/DARPA
# Moved UNSTABLE to ../../../models/DC-TCN/datasets/lrs3_words_may/UNSTABLE
# Moved COMMISSION to ../../../models/DC-TCN/datasets/lrs3_words_may/COMMISSION
# Moved WHORE to ../../../models/DC-TCN/datasets/lrs3_words_may/WHORE
# Moved TRICKY to ../../../models/DC-TCN/datasets/lrs3_words_may/TRICKY
# Moved CONTACTED to ../../../models/DC-TCN/datasets/lrs3_words_may/CONTACTED
# Moved PROACTIVE to ../../../models/DC-TCN/datasets/lrs3_words_may/PROACTIVE
# Moved HANDED to ../../../models/DC-TCN/datasets/lrs3_words_may/HANDED
# Moved THYROID to ../../../models/DC-TCN/datasets/lrs3_words_may/THYROID
# Moved WORM to ../../../models/DC-TCN/datasets/lrs3_words_may/WORM
# Moved SENSITIVITY to ../../../models/DC-TCN/datasets/lrs3_words_may/SENSITIVITY
# Moved RESIGNED to ../../../models/DC-TCN/datasets/lrs3_words_may/RESIGNED
# Moved VETERINARIAN to ../../../models/DC-TCN/datasets/lrs3_words_may/VETERINARIAN
# Moved CHILDBIRTH to ../../../models/DC-TCN/datasets/lrs3_words_may/CHILDBIRTH
# Moved GRAPHENE to ../../../models/DC-TCN/datasets/lrs3_words_may/GRAPHENE
# Moved FINANCIALLY to ../../../models/DC-TCN/datasets/lrs3_words_may/FINANCIALLY
# Moved SIGNING to ../../../models/DC-TCN/datasets/lrs3_words_may/SIGNING
# Moved BADGE to ../../../models/DC-TCN/datasets/lrs3_words_may/BADGE
# Moved FLOAT to ../../../models/DC-TCN/datasets/lrs3_words_may/FLOAT
# Moved POMPOUS to ../../../models/DC-TCN/datasets/lrs3_words_may/POMPOUS
# Moved MICROPHONE to ../../../models/DC-TCN/datasets/lrs3_words_may/MICROPHONE
# Moved WRESTLING to ../../../models/DC-TCN/datasets/lrs3_words_may/WRESTLING
# Moved COOLIDGE to ../../../models/DC-TCN/datasets/lrs3_words_may/COOLIDGE
# Moved SWISS to ../../../models/DC-TCN/datasets/lrs3_words_may/SWISS
# Moved OVERCOMING to ../../../models/DC-TCN/datasets/lrs3_words_may/OVERCOMING
# Moved SOFTLY to ../../../models/DC-TCN/datasets/lrs3_words_may/SOFTLY
# Moved VENUS to ../../../models/DC-TCN/datasets/lrs3_words_may/VENUS
# Moved SACRED to ../../../models/DC-TCN/datasets/lrs3_words_may/SACRED
# Moved COLOMBIA to ../../../models/DC-TCN/datasets/lrs3_words_may/COLOMBIA
# Moved SENATE to ../../../models/DC-TCN/datasets/lrs3_words_may/SENATE
# Moved TVS to ../../../models/DC-TCN/datasets/lrs3_words_may/TVS
# Moved TIGER to ../../../models/DC-TCN/datasets/lrs3_words_may/TIGER
# Moved CRAVE to ../../../models/DC-TCN/datasets/lrs3_words_may/CRAVE
# Moved BRO to ../../../models/DC-TCN/datasets/lrs3_words_may/BRO
# Moved POLLINATION to ../../../models/DC-TCN/datasets/lrs3_words_may/POLLINATION
# Moved AIRLINE to ../../../models/DC-TCN/datasets/lrs3_words_may/AIRLINE
# Moved BENEATH to ../../../models/DC-TCN/datasets/lrs3_words_may/BENEATH
# Moved QUITTING to ../../../models/DC-TCN/datasets/lrs3_words_may/QUITTING
# Moved SHATTERED to ../../../models/DC-TCN/datasets/lrs3_words_may/SHATTERED
# Moved ARISTOTLE to ../../../models/DC-TCN/datasets/lrs3_words_may/ARISTOTLE
# Moved GATHERER to ../../../models/DC-TCN/datasets/lrs3_words_may/GATHERER
# Moved STARVE to ../../../models/DC-TCN/datasets/lrs3_words_may/STARVE
# Moved ISLAMIC to ../../../models/DC-TCN/datasets/lrs3_words_may/ISLAMIC
# Moved SHORTAGE to ../../../models/DC-TCN/datasets/lrs3_words_may/SHORTAGE
# Moved FRAGILE to ../../../models/DC-TCN/datasets/lrs3_words_may/FRAGILE
# Moved OFFENDED to ../../../models/DC-TCN/datasets/lrs3_words_may/OFFENDED
# Moved ENCOURAGEMENT to ../../../models/DC-TCN/datasets/lrs3_words_may/ENCOURAGEMENT
# Moved BUFFER to ../../../models/DC-TCN/datasets/lrs3_words_may/BUFFER
# Moved METRO to ../../../models/DC-TCN/datasets/lrs3_words_may/METRO
# Moved HANNAH to ../../../models/DC-TCN/datasets/lrs3_words_may/HANNAH
# Moved RHETORIC to ../../../models/DC-TCN/datasets/lrs3_words_may/RHETORIC
# Moved CRITICIZED to ../../../models/DC-TCN/datasets/lrs3_words_may/CRITICIZED
# Moved HOP to ../../../models/DC-TCN/datasets/lrs3_words_may/HOP
# Moved REPEATING to ../../../models/DC-TCN/datasets/lrs3_words_may/REPEATING
# Moved CLEOPATRA to ../../../models/DC-TCN/datasets/lrs3_words_may/CLEOPATRA
# Moved UNCANNY to ../../../models/DC-TCN/datasets/lrs3_words_may/UNCANNY
# Moved TAG to ../../../models/DC-TCN/datasets/lrs3_words_may/TAG
# Moved SILVER to ../../../models/DC-TCN/datasets/lrs3_words_may/SILVER
# Moved COCAINE to ../../../models/DC-TCN/datasets/lrs3_words_may/COCAINE
# Moved INDIRECT to ../../../models/DC-TCN/datasets/lrs3_words_may/INDIRECT
# Moved GENEROSITY to ../../../models/DC-TCN/datasets/lrs3_words_may/GENEROSITY
# Moved ELIMINATING to ../../../models/DC-TCN/datasets/lrs3_words_may/ELIMINATING
# Moved SWEAT to ../../../models/DC-TCN/datasets/lrs3_words_may/SWEAT
# Moved ORAL to ../../../models/DC-TCN/datasets/lrs3_words_may/ORAL
# Moved MORALLY to ../../../models/DC-TCN/datasets/lrs3_words_may/MORALLY
# Moved RUSHING to ../../../models/DC-TCN/datasets/lrs3_words_may/RUSHING
# Moved JENNIFER to ../../../models/DC-TCN/datasets/lrs3_words_may/JENNIFER
# Moved GLOVE to ../../../models/DC-TCN/datasets/lrs3_words_may/GLOVE
# Moved EXTINGUISHER to ../../../models/DC-TCN/datasets/lrs3_words_may/EXTINGUISHER
# Moved ANONYMOUS to ../../../models/DC-TCN/datasets/lrs3_words_may/ANONYMOUS
# Moved INVOLVING to ../../../models/DC-TCN/datasets/lrs3_words_may/INVOLVING
# Moved GREATLY to ../../../models/DC-TCN/datasets/lrs3_words_may/GREATLY
# Moved FORREST to ../../../models/DC-TCN/datasets/lrs3_words_may/FORREST
# Moved SOCK to ../../../models/DC-TCN/datasets/lrs3_words_may/SOCK
# Moved HAUL to ../../../models/DC-TCN/datasets/lrs3_words_may/HAUL
# Moved INTENTIONALLY to ../../../models/DC-TCN/datasets/lrs3_words_may/INTENTIONALLY
# Moved INTERPRETATION to ../../../models/DC-TCN/datasets/lrs3_words_may/INTERPRETATION
# Moved HOSTAGE to ../../../models/DC-TCN/datasets/lrs3_words_may/HOSTAGE
# Moved JURISDICTION to ../../../models/DC-TCN/datasets/lrs3_words_may/JURISDICTION
# Moved SUBJECTIVE to ../../../models/DC-TCN/datasets/lrs3_words_may/SUBJECTIVE
# Moved CLICHE to ../../../models/DC-TCN/datasets/lrs3_words_may/CLICHE
# Moved ELEVATE to ../../../models/DC-TCN/datasets/lrs3_words_may/ELEVATE
# Moved EXAGGERATION to ../../../models/DC-TCN/datasets/lrs3_words_may/EXAGGERATION
# Moved UNLUCKY to ../../../models/DC-TCN/datasets/lrs3_words_may/UNLUCKY
# Moved NEEDING to ../../../models/DC-TCN/datasets/lrs3_words_may/NEEDING
# Moved LIP to ../../../models/DC-TCN/datasets/lrs3_words_may/LIP
# Moved REUNITE to ../../../models/DC-TCN/datasets/lrs3_words_may/REUNITE
# Moved UNBELIEVABLE to ../../../models/DC-TCN/datasets/lrs3_words_may/UNBELIEVABLE
# Moved AUGMENTED to ../../../models/DC-TCN/datasets/lrs3_words_may/AUGMENTED
# Moved BLAST to ../../../models/DC-TCN/datasets/lrs3_words_may/BLAST
# Moved ROTTEN to ../../../models/DC-TCN/datasets/lrs3_words_may/ROTTEN
# Moved FLOWING to ../../../models/DC-TCN/datasets/lrs3_words_may/FLOWING
# Moved LAVA to ../../../models/DC-TCN/datasets/lrs3_words_may/LAVA
# Moved GRADUATION to ../../../models/DC-TCN/datasets/lrs3_words_may/GRADUATION
# Moved COHEN to ../../../models/DC-TCN/datasets/lrs3_words_may/COHEN
# Moved EMPIRICAL to ../../../models/DC-TCN/datasets/lrs3_words_may/EMPIRICAL
# Moved CONGESTION to ../../../models/DC-TCN/datasets/lrs3_words_may/CONGESTION
# Moved ISLAMIST to ../../../models/DC-TCN/datasets/lrs3_words_may/ISLAMIST
# Moved STRICT to ../../../models/DC-TCN/datasets/lrs3_words_may/STRICT
# Moved NORMAN to ../../../models/DC-TCN/datasets/lrs3_words_may/NORMAN
# Moved NAKED to ../../../models/DC-TCN/datasets/lrs3_words_may/NAKED
# Moved DECENT to ../../../models/DC-TCN/datasets/lrs3_words_may/DECENT
# Moved CRYSTALS to ../../../models/DC-TCN/datasets/lrs3_words_may/CRYSTALS
# Moved ASTONISHED to ../../../models/DC-TCN/datasets/lrs3_words_may/ASTONISHED
# Moved STRATEGIC to ../../../models/DC-TCN/datasets/lrs3_words_may/STRATEGIC
# Moved BONUS to ../../../models/DC-TCN/datasets/lrs3_words_may/BONUS
# Moved SERGIO to ../../../models/DC-TCN/datasets/lrs3_words_may/SERGIO
# Moved RELYING to ../../../models/DC-TCN/datasets/lrs3_words_may/RELYING
# Moved PULSE to ../../../models/DC-TCN/datasets/lrs3_words_may/PULSE
# Moved SYNAPSES to ../../../models/DC-TCN/datasets/lrs3_words_may/SYNAPSES
# Moved HORRIFYING to ../../../models/DC-TCN/datasets/lrs3_words_may/HORRIFYING
# Moved UPRIGHT to ../../../models/DC-TCN/datasets/lrs3_words_may/UPRIGHT
# Moved RANCHER to ../../../models/DC-TCN/datasets/lrs3_words_may/RANCHER
# Moved EMPOWERMENT to ../../../models/DC-TCN/datasets/lrs3_words_may/EMPOWERMENT
# Moved ROYAL to ../../../models/DC-TCN/datasets/lrs3_words_may/ROYAL
# Moved NUDGING to ../../../models/DC-TCN/datasets/lrs3_words_may/NUDGING
# Moved RATIONALE to ../../../models/DC-TCN/datasets/lrs3_words_may/RATIONALE
# Moved PINT to ../../../models/DC-TCN/datasets/lrs3_words_may/PINT
# Moved COOPERATION to ../../../models/DC-TCN/datasets/lrs3_words_may/COOPERATION
# Moved TRUSTING to ../../../models/DC-TCN/datasets/lrs3_words_may/TRUSTING
# Moved LEWIS to ../../../models/DC-TCN/datasets/lrs3_words_may/LEWIS
# Moved GHOST to ../../../models/DC-TCN/datasets/lrs3_words_may/GHOST
# Moved SPARK to ../../../models/DC-TCN/datasets/lrs3_words_may/SPARK
# Moved UNTRUE to ../../../models/DC-TCN/datasets/lrs3_words_may/UNTRUE
# Moved TRACKING to ../../../models/DC-TCN/datasets/lrs3_words_may/TRACKING
# Moved FORBIDDEN to ../../../models/DC-TCN/datasets/lrs3_words_may/FORBIDDEN
# Moved KOSOVO to ../../../models/DC-TCN/datasets/lrs3_words_may/KOSOVO
# Moved PEACH to ../../../models/DC-TCN/datasets/lrs3_words_may/PEACH
# Moved ACCUMULATION to ../../../models/DC-TCN/datasets/lrs3_words_may/ACCUMULATION
# Moved MONASTERY to ../../../models/DC-TCN/datasets/lrs3_words_may/MONASTERY
# Moved CONTEST to ../../../models/DC-TCN/datasets/lrs3_words_may/CONTEST
# Moved MANHOOD to ../../../models/DC-TCN/datasets/lrs3_words_may/MANHOOD
# Moved OAKLAND to ../../../models/DC-TCN/datasets/lrs3_words_may/OAKLAND
# Moved INSULT to ../../../models/DC-TCN/datasets/lrs3_words_may/INSULT
# Moved EMBODIMENT to ../../../models/DC-TCN/datasets/lrs3_words_may/EMBODIMENT
# Moved THRILLED to ../../../models/DC-TCN/datasets/lrs3_words_may/THRILLED
# Moved DULL to ../../../models/DC-TCN/datasets/lrs3_words_may/DULL
# Moved EXPLODING to ../../../models/DC-TCN/datasets/lrs3_words_may/EXPLODING
# Moved ABDOMINAL to ../../../models/DC-TCN/datasets/lrs3_words_may/ABDOMINAL
# Moved DIGGING to ../../../models/DC-TCN/datasets/lrs3_words_may/DIGGING
# Moved REMOVING to ../../../models/DC-TCN/datasets/lrs3_words_may/REMOVING
# Moved MUSTER to ../../../models/DC-TCN/datasets/lrs3_words_may/MUSTER
# Moved HEARTBREAKING to ../../../models/DC-TCN/datasets/lrs3_words_may/HEARTBREAKING
# Moved BOIL to ../../../models/DC-TCN/datasets/lrs3_words_may/BOIL
# Moved ANALYZED to ../../../models/DC-TCN/datasets/lrs3_words_may/ANALYZED
# Moved BLAMED to ../../../models/DC-TCN/datasets/lrs3_words_may/BLAMED
# total moved: 1113

# %%
# Check updated (after converting npz files)
new_dir = "../../../models/DC-TCN/datasets/lrs3_words_may"
updated_df = create_npz_df(new_dir)

# %%
print(f"Total of words with >= 50 test files: {(updated_df['test'] >= 50).sum()}")
print(f"Total of words with >= 100 test files: {(updated_df['test'] >= 100).sum()}")

words_50 = updated_df[(updated_df['test'] >= 50)]
words_100 = updated_df[(updated_df['test'] >= 100)]
# Out:
# Total of words with >= 50 test files: 146
# Total of words with >= 100 test files: 86

# %%
# drop words that dont exist in the test set [npz]
source_dir = "../../../models/DC-TCN/datasets/lrs3_words_may"
target_dir = "../../../models/DC-TCN/datasets/lrs3_words_may_100filtered"

os.makedirs(target_dir, exist_ok=True)

moved = 0

for word in words_100.index:
    folder_path = os.path.join(source_dir, word)

    if os.path.exists(folder_path):
        target_folder_path = os.path.join(target_dir, word)
        shutil.move(folder_path, target_folder_path)
        print(f"Moved {word} to {target_folder_path}")
        moved += 1
print(f"total moved: {moved}")
# Out:
# Moved THEIR to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/THEIR
# Moved THAT to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/THAT
# Moved YOUR to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/YOUR
# Moved GET to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/GET
# Moved BE to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/BE
# Moved IF to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/IF
# Moved OUR to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/OUR
# Moved ABOUT to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/ABOUT
# Moved THING to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/THING
# Moved MORE to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/MORE
# Moved IT to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/IT
# Moved WITH to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/WITH
# Moved A to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/A
# Moved FROM to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/FROM
# Moved SOME to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/SOME
# Moved WHEN to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/WHEN
# Moved MY to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/MY
# Moved OF to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/OF
# Moved JUST to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/JUST
# Moved WILL to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/WILL
# Moved HOW to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/HOW
# Moved WAS to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/WAS
# Moved WOULD to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/WOULD
# Moved OTHER to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/OTHER
# Moved DON'T to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/DON'T
# Moved SO to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/SO
# Moved AS to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/AS
# Moved AN to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/AN
# Moved ME to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/ME
# Moved WAY to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/WAY
# Moved BY to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/BY
# Moved HE to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/HE
# Moved REALLY to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/REALLY
# Moved WHAT to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/WHAT
# Moved THEM to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/THEM
# Moved GO to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/GO
# Moved WERE to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/WERE
# Moved IS to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/IS
# Moved NO to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/NO
# Moved CAN to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/CAN
# Moved BECAUSE to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/BECAUSE
# Moved AND to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/AND
# Moved WHERE to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/WHERE
# Moved I'M to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/I'M
# Moved GOING to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/GOING
# Moved NOT to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/NOT
# Moved I to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/I
# Moved ITS to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/ITS
# Moved TIME to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/TIME
# Moved FOR to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/FOR
# Moved ARE to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/ARE
# Moved BUT to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/BUT
# Moved THE to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/THE
# Moved WANT to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/WANT
# Moved VERY to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/VERY
# Moved ALL to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/ALL
# Moved HAVE to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/HAVE
# Moved MAKE to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/MAKE
# Moved WE to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/WE
# Moved HAD to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/HAD
# Moved LIKE to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/LIKE
# Moved YEAR to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/YEAR
# Moved OUT to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/OUT
# Moved THERE to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/THERE
# Moved DO to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/DO
# Moved THESE to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/THESE
# Moved AT to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/AT
# Moved PEOPLE to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/PEOPLE
# Moved WHY to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/WHY
# Moved THINK to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/THINK
# Moved YOU to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/YOU
# Moved KNOW to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/KNOW
# Moved UP to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/UP
# Moved OR to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/OR
# Moved SAID to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/SAID
# Moved WHO to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/WHO
# Moved TO to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/TO
# Moved SHE to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/SHE
# Moved NEED to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/NEED
# Moved US to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/US
# Moved THEY to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/THEY
# Moved NOW to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/NOW
# Moved ONE to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/ONE
# Moved ON to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/ON
# Moved IN to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/IN
# Moved THIS to ../../../models/DC-TCN/datasets/lrs3_words_may_100filtered/THIS
# total moved: 86

# %%
# drop words that dont exist in the test set [mp4]
cropped_dir = "../../../datasets/lrs3_task4/speech_unit_type/words/words_preprocessed_video/test"
cropped_target = "../../../datasets/lrs3_task4/speech_unit_type/words/words_preprocessed_video/test_filtered"
uncropped_dir = "../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test"
uncropped_target = "../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered"
word_list_path = "../lrs3_labels.txt"
source_dir = uncropped_dir
target_dir = uncropped_target

# Read words from the text file into a set
with open(word_list_path, 'r') as file:
    start_words = set(line.strip() for line in file if line.strip())

os.makedirs(target_dir, exist_ok=True)

moved = 0

for filename in os.listdir(source_dir):
    if filename.endswith(".mp4"):
        for word in start_words:
            if filename.startswith(word):
                source_file = os.path.join(source_dir, filename)
                target_file = os.path.join(target_dir, filename)
                shutil.move(source_file, target_file)
                print(f"Moved {filename} to {target_file}")
                moved += 1
                break

print(f"Total moved: {moved}")
# Out:
# Moved US_JSSc7hYKstI_00016.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/US_JSSc7hYKstI_00016.mp4
# Moved AIRTIME_ONM4JupBzSE_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/AIRTIME_ONM4JupBzSE_00005.mp4
# Moved I_SN7wO06Yz1E_00009.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/I_SN7wO06Yz1E_00009.mp4
# Moved TOLERATE_ooAIIeo4AJQ_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/TOLERATE_ooAIIeo4AJQ_00002.mp4
# Moved THE_JISHzvXk5bk_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THE_JISHzvXk5bk_00001.mp4
# Moved THE_qWNae7vYK6s_00008.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THE_qWNae7vYK6s_00008.mp4
# Moved GOOD_PrK0CifulU0_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/GOOD_PrK0CifulU0_00004.mp4
# Moved THEIR_c64M1tZyWPM_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THEIR_c64M1tZyWPM_00002.mp4
# Moved WOULD_LEx6K4P4GJc_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WOULD_LEx6K4P4GJc_00003.mp4
# Moved AND_HI7zfpitZpo_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/AND_HI7zfpitZpo_00002.mp4
# Moved SO_ZJNESMhIxQ0_00025.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/SO_ZJNESMhIxQ0_00025.mp4
# Moved LIKE_GqnJFm1CS3c_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/LIKE_GqnJFm1CS3c_00002.mp4
# Moved ONE_UAj1hsXp18c_00017.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ONE_UAj1hsXp18c_00017.mp4
# Moved I'M_Li4S1yyrsTI_00007.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/I'M_Li4S1yyrsTI_00007.mp4
# Moved OUT_qWNae7vYK6s_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/OUT_qWNae7vYK6s_00001.mp4
# Moved IT_c9V6OKlY80k_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IT_c9V6OKlY80k_00001.mp4
# Moved TO_psN1DORYYV0_00020.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/TO_psN1DORYYV0_00020.mp4
# Moved NOW_PbgB2TaYhio_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/NOW_PbgB2TaYhio_00004.mp4
# Moved OTHER_WT7VMrxTPPA_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/OTHER_WT7VMrxTPPA_00001.mp4
# Moved WAS_wG4RnDNWtJo_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WAS_wG4RnDNWtJo_00001.mp4
# Moved ALMOST_t7Xr3AsBEK4_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ALMOST_t7Xr3AsBEK4_00004.mp4
# Moved DO_MNuOmTQdFjA_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/DO_MNuOmTQdFjA_00001.mp4
# Moved THE_wG4RnDNWtJo_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THE_wG4RnDNWtJo_00004.mp4
# Moved ARE_xlUPlxSpDRo_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ARE_xlUPlxSpDRo_00001.mp4
# Moved WE_w1R4F9sSoow_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WE_w1R4F9sSoow_00001.mp4
# Moved MORE_y6MC4iXhT6I_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/MORE_y6MC4iXhT6I_00001.mp4
# Moved OUR_NA7krbsdXFA_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/OUR_NA7krbsdXFA_00002.mp4
# Moved I_GAMR5RDSLJo_00014.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/I_GAMR5RDSLJo_00014.mp4
# Moved GET_FFG2rilqT2g_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/GET_FFG2rilqT2g_00003.mp4
# Moved ABOUT_4AYE3w5TWHs_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ABOUT_4AYE3w5TWHs_00004.mp4
# Moved OF_OwgWkUIm9Gc_00009.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/OF_OwgWkUIm9Gc_00009.mp4
# Moved HOW_LEx6K4P4GJc_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/HOW_LEx6K4P4GJc_00003.mp4
# Moved YOU_n3kNlFMXslo_00010.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/YOU_n3kNlFMXslo_00010.mp4
# Moved SOMETHING_7ZymFMmpOa0_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/SOMETHING_7ZymFMmpOa0_00002.mp4
# Moved IS_sVtIuDKFO1c_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IS_sVtIuDKFO1c_00001.mp4
# Moved ASPIRE_YzGjO5aHShQ_00012.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ASPIRE_YzGjO5aHShQ_00012.mp4
# Moved IS_wlR1ojoiue0_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IS_wlR1ojoiue0_00004.mp4
# Moved GET_jcp5vvxtEaU_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/GET_jcp5vvxtEaU_00001.mp4
# Moved WHY_nCg2NcGYu34_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WHY_nCg2NcGYu34_00001.mp4
# Moved FOR_tiSiSM3pk5M_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/FOR_tiSiSM3pk5M_00002.mp4
# Moved THE_NA7krbsdXFA_00010.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THE_NA7krbsdXFA_00010.mp4
# Moved THEY'RE_fxbCHn6gE3U_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THEY'RE_fxbCHn6gE3U_00005.mp4
# Moved AND_FxtSMZKMdes_00015.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/AND_FxtSMZKMdes_00015.mp4
# Moved WAS_LiUClSItcy0_00009.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WAS_LiUClSItcy0_00009.mp4
# Moved LIKE_YzGjO5aHShQ_00006.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/LIKE_YzGjO5aHShQ_00006.mp4
# Moved A_psN1DORYYV0_00008.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/A_psN1DORYYV0_00008.mp4
# Moved INTERACTION_YzGjO5aHShQ_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/INTERACTION_YzGjO5aHShQ_00004.mp4
# Moved ABSOLUTELY_0VJqrlH9cdI_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ABSOLUTELY_0VJqrlH9cdI_00001.mp4
# Moved A_1bnzVjOJ6NM_00017.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/A_1bnzVjOJ6NM_00017.mp4
# Moved ACTUALLY_GGScU5ESei4_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ACTUALLY_GGScU5ESei4_00001.mp4
# Moved MYSELF_AsSd2nmoKNA_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/MYSELF_AsSd2nmoKNA_00002.mp4
# Moved SAID_FmpIMt95ndU_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/SAID_FmpIMt95ndU_00005.mp4
# Moved TO_UAj1hsXp18c_00021.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/TO_UAj1hsXp18c_00021.mp4
# Moved A_FD6CqD1kV8s_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/A_FD6CqD1kV8s_00004.mp4
# Moved MORE_bArH8r8jJ4g_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/MORE_bArH8r8jJ4g_00002.mp4
# Moved ON_PbgB2TaYhio_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ON_PbgB2TaYhio_00004.mp4
# Moved GOT_TGZMSmcuiXM_00013.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/GOT_TGZMSmcuiXM_00013.mp4
# Moved SOMETHING_dS8n24ZwZcQ_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/SOMETHING_dS8n24ZwZcQ_00002.mp4
# Moved THAT_fxbCHn6gE3U_00007.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THAT_fxbCHn6gE3U_00007.mp4
# Moved ASKED_psN1DORYYV0_00020.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ASKED_psN1DORYYV0_00020.mp4
# Moved FOR_rFpDK2KhAgw_00007.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/FOR_rFpDK2KhAgw_00007.mp4
# Moved HEAR_BvpmZktlBFs_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/HEAR_BvpmZktlBFs_00002.mp4
# Moved BUT_ta2Wvy9FSgA_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/BUT_ta2Wvy9FSgA_00003.mp4
# Moved UP_SFnMTHhKdkw_00008.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/UP_SFnMTHhKdkw_00008.mp4
# Moved A_VfAiNX7jn9A_00011.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/A_VfAiNX7jn9A_00011.mp4
# Moved SO_qYUmI5kGsYk_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/SO_qYUmI5kGsYk_00001.mp4
# Moved ABOUT_OM6XIICmSqo_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ABOUT_OM6XIICmSqo_00002.mp4
# Moved IT_bArH8r8jJ4g_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IT_bArH8r8jJ4g_00001.mp4
# Moved THEM_AsSd2nmoKNA_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THEM_AsSd2nmoKNA_00002.mp4
# Moved IDEA_psN1DORYYV0_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IDEA_psN1DORYYV0_00002.mp4
# Moved THING_TScetimMBL8_00006.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THING_TScetimMBL8_00006.mp4
# Moved TO_gSycQufrgK4_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/TO_gSycQufrgK4_00001.mp4
# Moved BUT_SWvJxasiSZ8_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/BUT_SWvJxasiSZ8_00004.mp4
# Moved DON'T_IWdzrZdRa38_00006.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/DON'T_IWdzrZdRa38_00006.mp4
# Moved MY_HSercnrqeN4_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/MY_HSercnrqeN4_00001.mp4
# Moved HAVE_xFSCX9mAHPo_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/HAVE_xFSCX9mAHPo_00003.mp4
# Moved IN_Sew0bn8mGAA_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IN_Sew0bn8mGAA_00002.mp4
# Moved IS_ClfBxWPkBKU_00008.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IS_ClfBxWPkBKU_00008.mp4
# Moved TO_uL5XUwfkxZw_00015.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/TO_uL5XUwfkxZw_00015.mp4
# Moved WAS_YzGjO5aHShQ_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WAS_YzGjO5aHShQ_00004.mp4
# Moved ACROSS_NqOjj1FCcVY_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ACROSS_NqOjj1FCcVY_00001.mp4
# Moved HAVE_Sew0bn8mGAA_00007.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/HAVE_Sew0bn8mGAA_00007.mp4
# Moved HAVE_0gks6ceq4eQ_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/HAVE_0gks6ceq4eQ_00005.mp4
# Moved HAD_3uSQlcGCHUU_00017.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/HAD_3uSQlcGCHUU_00017.mp4
# Moved SO_m6X1i8khmt8_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/SO_m6X1i8khmt8_00002.mp4
# Moved JUST_8nt3edWLgIg_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/JUST_8nt3edWLgIg_00003.mp4
# Moved SOCIAL_2UStOghblfE_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/SOCIAL_2UStOghblfE_00001.mp4
# Moved I_kEKzl6fub2w_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/I_kEKzl6fub2w_00002.mp4
# Moved GOT_jcp5vvxtEaU_00012.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/GOT_jcp5vvxtEaU_00012.mp4
# Moved THINGS_9RMx31GnNXY_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THINGS_9RMx31GnNXY_00002.mp4
# Moved ME_LEx6K4P4GJc_00010.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ME_LEx6K4P4GJc_00010.mp4
# Moved OF_wlR1ojoiue0_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/OF_wlR1ojoiue0_00005.mp4
# Moved WE_TGZMSmcuiXM_00009.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WE_TGZMSmcuiXM_00009.mp4
# Moved DO_GMynksvCcUI_00008.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/DO_GMynksvCcUI_00008.mp4
# Moved OUR_Ip2SQa50uBI_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/OUR_Ip2SQa50uBI_00005.mp4
# Moved ME_uJr4wGcLNsA_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ME_uJr4wGcLNsA_00001.mp4
# Moved AND_HSercnrqeN4_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/AND_HSercnrqeN4_00004.mp4
# Moved IT_s0YjL9rZyR0_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IT_s0YjL9rZyR0_00005.mp4
# Moved CAN_PSlBlZ3hqKc_00012.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/CAN_PSlBlZ3hqKc_00012.mp4
# Moved THIS_4v4XxlfVk3o_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THIS_4v4XxlfVk3o_00001.mp4
# Moved I_TGZMSmcuiXM_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/I_TGZMSmcuiXM_00004.mp4
# Moved THESE_SmLeSPk3ddE_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THESE_SmLeSPk3ddE_00001.mp4
# Moved IT_TGZMSmcuiXM_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IT_TGZMSmcuiXM_00002.mp4
# Moved AND_RplnSVTzvnU_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/AND_RplnSVTzvnU_00002.mp4
# Moved SO_FxtSMZKMdes_00014.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/SO_FxtSMZKMdes_00014.mp4
# Moved A_LEx6K4P4GJc_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/A_LEx6K4P4GJc_00005.mp4
# Moved LIKE_JSSc7hYKstI_00014.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/LIKE_JSSc7hYKstI_00014.mp4
# Moved I_FmpIMt95ndU_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/I_FmpIMt95ndU_00005.mp4
# Moved HER_dYNc3P4jSt4_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/HER_dYNc3P4jSt4_00004.mp4
# Moved ACTIVIST_pFDoCLf96Kg_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ACTIVIST_pFDoCLf96Kg_00001.mp4
# Moved I_mxNpNuogqsY_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/I_mxNpNuogqsY_00004.mp4
# Moved A_wG4RnDNWtJo_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/A_wG4RnDNWtJo_00001.mp4
# Moved TO_MNuOmTQdFjA_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/TO_MNuOmTQdFjA_00001.mp4
# Moved ME_6Waurx8eS1o_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ME_6Waurx8eS1o_00003.mp4
# Moved THEY_6wNif5SlN08_00012.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THEY_6wNif5SlN08_00012.mp4
# Moved ALL_GIbz9ms9Z9k_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ALL_GIbz9ms9Z9k_00004.mp4
# Moved WHAT_psN1DORYYV0_00020.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WHAT_psN1DORYYV0_00020.mp4
# Moved AUTHORS_vhVWzkbAW4I_00007.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/AUTHORS_vhVWzkbAW4I_00007.mp4
# Moved SO_jcp5vvxtEaU_00010.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/SO_jcp5vvxtEaU_00010.mp4
# Moved AN_VzyjDRSAWzE_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/AN_VzyjDRSAWzE_00001.mp4
# Moved I'VE_GSf6nijSSdA_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/I'VE_GSf6nijSSdA_00002.mp4
# Moved DOESN'T_qWNae7vYK6s_00006.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/DOESN'T_qWNae7vYK6s_00006.mp4
# Moved AT_ni4FV5zL6lM_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/AT_ni4FV5zL6lM_00003.mp4
# Moved SOMETHING_Ht2fzax9wV0_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/SOMETHING_Ht2fzax9wV0_00001.mp4
# Moved I'M_0Fi83BHQsMA_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/I'M_0Fi83BHQsMA_00004.mp4
# Moved TO_fxbCHn6gE3U_00007.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/TO_fxbCHn6gE3U_00007.mp4
# Moved US_S2Dj9M71JAc_00007.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/US_S2Dj9M71JAc_00007.mp4
# Moved IT_psN1DORYYV0_00016.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IT_psN1DORYYV0_00016.mp4
# Moved AN_1PNX6MSdVsk_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/AN_1PNX6MSdVsk_00005.mp4
# Moved YOU_Ht2fzax9wV0_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/YOU_Ht2fzax9wV0_00001.mp4
# Moved THAT_uJr4wGcLNsA_00010.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THAT_uJr4wGcLNsA_00010.mp4
# Moved BUT_BImnT7lcLDE_00006.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/BUT_BImnT7lcLDE_00006.mp4
# Moved FOR_l5vZHuAtDZA_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/FOR_l5vZHuAtDZA_00001.mp4
# Moved THINGS_BImnT7lcLDE_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THINGS_BImnT7lcLDE_00001.mp4
# Moved AND_dYNc3P4jSt4_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/AND_dYNc3P4jSt4_00004.mp4
# Moved ME_LEx6K4P4GJc_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ME_LEx6K4P4GJc_00001.mp4
# Moved FOR_vhVWzkbAW4I_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/FOR_vhVWzkbAW4I_00005.mp4
# Moved ABOUT_mc0vhSseGk4_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ABOUT_mc0vhSseGk4_00001.mp4
# Moved OF_ODLgS00f9BE_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/OF_ODLgS00f9BE_00002.mp4
# Moved WE_gVfgkFaswn4_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WE_gVfgkFaswn4_00002.mp4
# Moved NOT_RDSSLJG7oi8_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/NOT_RDSSLJG7oi8_00001.mp4
# Moved DO_FxtSMZKMdes_00014.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/DO_FxtSMZKMdes_00014.mp4
# Moved IS_bS6SiVz1R0o_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IS_bS6SiVz1R0o_00001.mp4
# Moved ACTUALLY_pFDoCLf96Kg_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ACTUALLY_pFDoCLf96Kg_00001.mp4
# Moved IT'S_mgcjr1yz7ow_00015.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IT'S_mgcjr1yz7ow_00015.mp4
# Moved INTELLIGENCE_8nt3edWLgIg_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/INTELLIGENCE_8nt3edWLgIg_00005.mp4
# Moved NOT_RAR4cz9wkUk_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/NOT_RAR4cz9wkUk_00001.mp4
# Moved SO_SFnMTHhKdkw_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/SO_SFnMTHhKdkw_00005.mp4
# Moved DO_n3kNlFMXslo_00013.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/DO_n3kNlFMXslo_00013.mp4
# Moved MEN_V4sSabKqyMU_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/MEN_V4sSabKqyMU_00004.mp4
# Moved NOT_t7Xr3AsBEK4_00007.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/NOT_t7Xr3AsBEK4_00007.mp4
# Moved YOUTH_ROgFmb3oTLo_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/YOUTH_ROgFmb3oTLo_00004.mp4
# Moved FROM_RDSSLJG7oi8_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/FROM_RDSSLJG7oi8_00001.mp4
# Moved BELIEVE_Li4S1yyrsTI_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/BELIEVE_Li4S1yyrsTI_00001.mp4
# Moved YOUR_cmpu58yv8Sg_00007.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/YOUR_cmpu58yv8Sg_00007.mp4
# Moved MORE_n3kNlFMXslo_00010.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/MORE_n3kNlFMXslo_00010.mp4
# Moved IT'S_OzA6jRYjVQs_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IT'S_OzA6jRYjVQs_00001.mp4
# Moved AIRPLANE_psN1DORYYV0_00012.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/AIRPLANE_psN1DORYYV0_00012.mp4
# Moved ARMY_TGZMSmcuiXM_00013.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ARMY_TGZMSmcuiXM_00013.mp4
# Moved WE_qsJYrwzfd6w_00006.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WE_qsJYrwzfd6w_00006.mp4
# Moved YOU'RE_Gmai4zkKNcM_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/YOU'RE_Gmai4zkKNcM_00004.mp4
# Moved WHEN_lmyZMtPVodo_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WHEN_lmyZMtPVodo_00001.mp4
# Moved REALLY_hQigUH0vZSE_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/REALLY_hQigUH0vZSE_00001.mp4
# Moved WOULD_YyXRYgjQXX0_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WOULD_YyXRYgjQXX0_00002.mp4
# Moved IN_iPE2SiCCo0w_00008.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IN_iPE2SiCCo0w_00008.mp4
# Moved ONE_S2Dj9M71JAc_00006.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ONE_S2Dj9M71JAc_00006.mp4
# Moved THAT_NoCOagL69Ss_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THAT_NoCOagL69Ss_00001.mp4
# Moved NOT_LiUClSItcy0_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/NOT_LiUClSItcy0_00005.mp4
# Moved WHEN_VxESitIllxE_00007.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WHEN_VxESitIllxE_00007.mp4
# Moved GET_1bnzVjOJ6NM_00017.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/GET_1bnzVjOJ6NM_00017.mp4
# Moved OTHER_hiIcwt88o94_00018.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/OTHER_hiIcwt88o94_00018.mp4
# Moved THEY_VAJS5J21Rd0_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THEY_VAJS5J21Rd0_00001.mp4
# Moved HAD_YzGjO5aHShQ_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/HAD_YzGjO5aHShQ_00002.mp4
# Moved WENT_CgNx9Bgac1I_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WENT_CgNx9Bgac1I_00002.mp4
# Moved BY_gVfgkFaswn4_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/BY_gVfgkFaswn4_00001.mp4
# Moved JUST_yNhu0MGS2MA_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/JUST_yNhu0MGS2MA_00001.mp4
# Moved WAS_MvXZzKZ3JYQ_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WAS_MvXZzKZ3JYQ_00001.mp4
# Moved BY_QeIrdqU0o9s_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/BY_QeIrdqU0o9s_00002.mp4
# Moved THE_RplnSVTzvnU_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THE_RplnSVTzvnU_00003.mp4
# Moved WE_s0YjL9rZyR0_00007.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WE_s0YjL9rZyR0_00007.mp4
# Moved YOU'RE_VAJS5J21Rd0_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/YOU'RE_VAJS5J21Rd0_00004.mp4
# Moved INTERNAL_cmpu58yv8Sg_00007.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/INTERNAL_cmpu58yv8Sg_00007.mp4
# Moved A_E0oPnS7rUwE_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/A_E0oPnS7rUwE_00001.mp4
# Moved A_XESFPEFpHt4_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/A_XESFPEFpHt4_00003.mp4
# Moved SO_1bnzVjOJ6NM_00023.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/SO_1bnzVjOJ6NM_00023.mp4
# Moved SOME_TRajLqEaWhQ_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/SOME_TRajLqEaWhQ_00002.mp4
# Moved WAS_jtVIDBs60S8_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WAS_jtVIDBs60S8_00001.mp4
# Moved YOU_eNAHVnkll5M_00011.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/YOU_eNAHVnkll5M_00011.mp4
# Moved WE_VSLurJfOSiA_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WE_VSLurJfOSiA_00005.mp4
# Moved PEOPLE_c64M1tZyWPM_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/PEOPLE_c64M1tZyWPM_00002.mp4
# Moved OUR_ClfBxWPkBKU_00008.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/OUR_ClfBxWPkBKU_00008.mp4
# Moved MY_ddxHlkIuHqg_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/MY_ddxHlkIuHqg_00002.mp4
# Moved BUT_PYHd7rpOTe8_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/BUT_PYHd7rpOTe8_00002.mp4
# Moved THEY_Sv5QitqbxJw_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THEY_Sv5QitqbxJw_00004.mp4
# Moved SO_mc0vhSseGk4_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/SO_mc0vhSseGk4_00001.mp4
# Moved NOT_5P04stEjJ9E_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/NOT_5P04stEjJ9E_00003.mp4
# Moved WE_RplnSVTzvnU_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WE_RplnSVTzvnU_00003.mp4
# Moved I_jbHpF7EySck_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/I_jbHpF7EySck_00002.mp4
# Moved AROUND_VsjTVGIw4z8_00006.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/AROUND_VsjTVGIw4z8_00006.mp4
# Moved THAT'S_BhMKmovNjvc_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THAT'S_BhMKmovNjvc_00001.mp4
# Moved SO_1bnzVjOJ6NM_00013.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/SO_1bnzVjOJ6NM_00013.mp4
# Moved NEED_FxtSMZKMdes_00017.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/NEED_FxtSMZKMdes_00017.mp4
# Moved ISSUE_jcp5vvxtEaU_00012.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ISSUE_jcp5vvxtEaU_00012.mp4
# Moved WHAT_VfAiNX7jn9A_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WHAT_VfAiNX7jn9A_00004.mp4
# Moved KNOW_O0JDDyqtSVY_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/KNOW_O0JDDyqtSVY_00001.mp4
# Moved CAN_Ip2SQa50uBI_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/CAN_Ip2SQa50uBI_00003.mp4
# Moved DOING_SS8TSf2srSw_00008.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/DOING_SS8TSf2srSw_00008.mp4
# Moved ALL_FKxaL8Iau8Q_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ALL_FKxaL8Iau8Q_00003.mp4
# Moved TO_1bnzVjOJ6NM_00013.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/TO_1bnzVjOJ6NM_00013.mp4
# Moved I'M_2SlBiFZ85d0_00008.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/I'M_2SlBiFZ85d0_00008.mp4
# Moved DOWN_s0YjL9rZyR0_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/DOWN_s0YjL9rZyR0_00003.mp4
# Moved ON_FD6CqD1kV8s_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ON_FD6CqD1kV8s_00005.mp4
# Moved THE_fxbCHn6gE3U_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THE_fxbCHn6gE3U_00001.mp4
# Moved THEY_IWdzrZdRa38_00007.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THEY_IWdzrZdRa38_00007.mp4
# Moved THE_jcp5vvxtEaU_00011.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THE_jcp5vvxtEaU_00011.mp4
# Moved WERE_OM6XIICmSqo_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WERE_OM6XIICmSqo_00002.mp4
# Moved OR_eVFYhbHpfqU_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/OR_eVFYhbHpfqU_00003.mp4
# Moved SO_DsrxbqFo41k_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/SO_DsrxbqFo41k_00002.mp4
# Moved ADJUST_ZnCSUBmeRxw_00007.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ADJUST_ZnCSUBmeRxw_00007.mp4
# Moved WERE_oYp5XuGYqqY_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WERE_oYp5XuGYqqY_00002.mp4
# Moved AND_F3OhcpKSUBc_00006.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/AND_F3OhcpKSUBc_00006.mp4
# Moved OUT_GGScU5ESei4_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/OUT_GGScU5ESei4_00005.mp4
# Moved THAT_0gks6ceq4eQ_00008.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THAT_0gks6ceq4eQ_00008.mp4
# Moved YOU_5Yj3nGv0kn8_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/YOU_5Yj3nGv0kn8_00001.mp4
# Moved THIS_SE97Kgi0sR4_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THIS_SE97Kgi0sR4_00003.mp4
# Moved HOW_TGZMSmcuiXM_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/HOW_TGZMSmcuiXM_00003.mp4
# Moved TO_uzKBGtf0i0M_00007.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/TO_uzKBGtf0i0M_00007.mp4
# Moved OFTEN_DsrxbqFo41k_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/OFTEN_DsrxbqFo41k_00002.mp4
# Moved ARE_IjbTiRbeNpM_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ARE_IjbTiRbeNpM_00004.mp4
# Moved THAT_PhVP1tNeGyY_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THAT_PhVP1tNeGyY_00001.mp4
# Moved CAN_n3kNlFMXslo_00006.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/CAN_n3kNlFMXslo_00006.mp4
# Moved A_gVfgkFaswn4_00006.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/A_gVfgkFaswn4_00006.mp4
# Moved YOU_psN1DORYYV0_00019.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/YOU_psN1DORYYV0_00019.mp4
# Moved NOT_iPE2SiCCo0w_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/NOT_iPE2SiCCo0w_00002.mp4
# Moved OF_dYNc3P4jSt4_00008.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/OF_dYNc3P4jSt4_00008.mp4
# Moved JUST_npNYP2vzaPo_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/JUST_npNYP2vzaPo_00002.mp4
# Moved WHAT'S_JFQLvbVJVMg_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WHAT'S_JFQLvbVJVMg_00003.mp4
# Moved MAKE_VsjTVGIw4z8_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/MAKE_VsjTVGIw4z8_00005.mp4
# Moved THEM_ZnCSUBmeRxw_00007.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THEM_ZnCSUBmeRxw_00007.mp4
# Moved YOU_psN1DORYYV0_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/YOU_psN1DORYYV0_00005.mp4
# Moved WE_Q6U69HbAF9Y_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WE_Q6U69HbAF9Y_00002.mp4
# Moved THIS_XFnGhrCS3Gs_00008.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THIS_XFnGhrCS3Gs_00008.mp4
# Moved MY_k2hQL9Zrokk_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/MY_k2hQL9Zrokk_00001.mp4
# Moved NOW_gVfgkFaswn4_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/NOW_gVfgkFaswn4_00003.mp4
# Moved THIS_xukDIWFMU9Y_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THIS_xukDIWFMU9Y_00002.mp4
# Moved DON'T_WTFi99e4RXU_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/DON'T_WTFi99e4RXU_00001.mp4
# Moved AM_FxtSMZKMdes_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/AM_FxtSMZKMdes_00005.mp4
# Moved INTERNET_LEx6K4P4GJc_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/INTERNET_LEx6K4P4GJc_00001.mp4
# Moved NOT_vhVWzkbAW4I_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/NOT_vhVWzkbAW4I_00005.mp4
# Moved INTERFACE_YzGjO5aHShQ_00017.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/INTERFACE_YzGjO5aHShQ_00017.mp4
# Moved TO_DsrxbqFo41k_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/TO_DsrxbqFo41k_00002.mp4
# Moved IS_zuYzOn0U2PY_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IS_zuYzOn0U2PY_00002.mp4
# Moved A_eNAHVnkll5M_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/A_eNAHVnkll5M_00005.mp4
# Moved WELL_U6FvJ6jMGHU_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WELL_U6FvJ6jMGHU_00002.mp4
# Moved AFTER_qsJYrwzfd6w_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/AFTER_qsJYrwzfd6w_00004.mp4
# Moved WILLING_IS4IK8CiLg8_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WILLING_IS4IK8CiLg8_00002.mp4
# Moved THE_5b5BDoddOLA_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THE_5b5BDoddOLA_00004.mp4
# Moved THEN_VxESitIllxE_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THEN_VxESitIllxE_00001.mp4
# Moved DO_2UStOghblfE_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/DO_2UStOghblfE_00004.mp4
# Moved MY_uJr4wGcLNsA_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/MY_uJr4wGcLNsA_00003.mp4
# Moved IN_c64M1tZyWPM_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IN_c64M1tZyWPM_00004.mp4
# Moved SHE_fxbCHn6gE3U_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/SHE_fxbCHn6gE3U_00003.mp4
# Moved KNOW_SSzRfSJTNW4_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/KNOW_SSzRfSJTNW4_00005.mp4
# Moved THAT'S_F3OhcpKSUBc_00007.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THAT'S_F3OhcpKSUBc_00007.mp4
# Moved IS_jPf0LjZAS14_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IS_jPf0LjZAS14_00001.mp4
# Moved WE_SaouBn7IKIo_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WE_SaouBn7IKIo_00001.mp4
# Moved IN_V1yW5IsnSjo_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IN_V1yW5IsnSjo_00005.mp4
# Moved NOT_E0oPnS7rUwE_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/NOT_E0oPnS7rUwE_00003.mp4
# Moved IT_7OMLSs8t1ng_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IT_7OMLSs8t1ng_00001.mp4
# Moved IS_mgcjr1yz7ow_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IS_mgcjr1yz7ow_00002.mp4
# Moved THIS_TVtgb153S6I_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THIS_TVtgb153S6I_00002.mp4
# Moved THERE_JcJ3MfJNm6g_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THERE_JcJ3MfJNm6g_00001.mp4
# Moved OF_0ZfSOArXbGQ_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/OF_0ZfSOArXbGQ_00003.mp4
# Moved THE_CdZJ0SMbh10_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THE_CdZJ0SMbh10_00001.mp4
# Moved AND_FxtSMZKMdes_00007.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/AND_FxtSMZKMdes_00007.mp4
# Moved ANSWER_mgcjr1yz7ow_00016.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ANSWER_mgcjr1yz7ow_00016.mp4
# Moved WILL_LiUClSItcy0_00008.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WILL_LiUClSItcy0_00008.mp4
# Moved TOP_U6FvJ6jMGHU_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/TOP_U6FvJ6jMGHU_00003.mp4
# Moved WE_gVfgkFaswn4_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WE_gVfgkFaswn4_00003.mp4
# Moved A_tiSiSM3pk5M_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/A_tiSiSM3pk5M_00002.mp4
# Moved THE_9uOMectkCCs_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THE_9uOMectkCCs_00005.mp4
# Moved VERY_JHk9YVjhk7c_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/VERY_JHk9YVjhk7c_00001.mp4
# Moved HE_F3OhcpKSUBc_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/HE_F3OhcpKSUBc_00004.mp4
# Moved SO_eNAHVnkll5M_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/SO_eNAHVnkll5M_00004.mp4
# Moved WHERE_UAj1hsXp18c_00024.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WHERE_UAj1hsXp18c_00024.mp4
# Moved AND_ZJNESMhIxQ0_00021.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/AND_ZJNESMhIxQ0_00021.mp4
# Moved IMAGINE_ZnCSUBmeRxw_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IMAGINE_ZnCSUBmeRxw_00004.mp4
# Moved THAT_SWiwSBLXS3k_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THAT_SWiwSBLXS3k_00001.mp4
# Moved WENT_V4sSabKqyMU_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WENT_V4sSabKqyMU_00002.mp4
# Moved GETTING_gVfgkFaswn4_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/GETTING_gVfgkFaswn4_00001.mp4
# Moved THE_UMhLBPPtlrY_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THE_UMhLBPPtlrY_00004.mp4
# Moved US_JSSc7hYKstI_00015.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/US_JSSc7hYKstI_00015.mp4
# Moved DON'T_DOgsYATbVSs_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/DON'T_DOgsYATbVSs_00004.mp4
# Moved WE_jPf0LjZAS14_00008.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WE_jPf0LjZAS14_00008.mp4
# Moved ME_AsSd2nmoKNA_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ME_AsSd2nmoKNA_00002.mp4
# Moved I'M_t7Xr3AsBEK4_00008.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/I'M_t7Xr3AsBEK4_00008.mp4
# Moved THIS_xTkKSJSqUSI_00008.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THIS_xTkKSJSqUSI_00008.mp4
# Moved TO_YzGjO5aHShQ_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/TO_YzGjO5aHShQ_00002.mp4
# Moved HAD_ClfBxWPkBKU_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/HAD_ClfBxWPkBKU_00003.mp4
# Moved KNOWS_wzkFoetpSSM_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/KNOWS_wzkFoetpSSM_00002.mp4
# Moved I_OIlSXRCSBSI_00007.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/I_OIlSXRCSBSI_00007.mp4
# Moved TO_LiUClSItcy0_00009.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/TO_LiUClSItcy0_00009.mp4
# Moved CAN_XESFPEFpHt4_00011.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/CAN_XESFPEFpHt4_00011.mp4
# Moved THIS_ZnCSUBmeRxw_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THIS_ZnCSUBmeRxw_00004.mp4
# Moved IT'S_TGZMSmcuiXM_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IT'S_TGZMSmcuiXM_00004.mp4
# Moved THINK_ODLgS00f9BE_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THINK_ODLgS00f9BE_00002.mp4
# Moved HAD_MvXZzKZ3JYQ_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/HAD_MvXZzKZ3JYQ_00001.mp4
# Moved AND_FD6CqD1kV8s_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/AND_FD6CqD1kV8s_00001.mp4
# Moved I_2UStOghblfE_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/I_2UStOghblfE_00002.mp4
# Moved HELPS_81Ub0SMxZQo_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/HELPS_81Ub0SMxZQo_00003.mp4
# Moved MORE_mc0vhSseGk4_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/MORE_mc0vhSseGk4_00001.mp4
# Moved A_ni4FV5zL6lM_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/A_ni4FV5zL6lM_00003.mp4
# Moved TO_jcp5vvxtEaU_00012.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/TO_jcp5vvxtEaU_00012.mp4
# ...
# Moved YOU_3uSQlcGCHUU_00012.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/YOU_3uSQlcGCHUU_00012.mp4
# Moved WE_jcp5vvxtEaU_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WE_jcp5vvxtEaU_00002.mp4
# Moved IRRECONCILABLE_87AEeLpodnE_00008.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IRRECONCILABLE_87AEeLpodnE_00008.mp4
# Moved A_gVfgkFaswn4_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/A_gVfgkFaswn4_00003.mp4
# Moved WHEN_ZJNESMhIxQ0_00023.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WHEN_ZJNESMhIxQ0_00023.mp4
# Moved HAVE_x95nwilkaio_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/HAVE_x95nwilkaio_00002.mp4
# Moved MY_KPNn880KWfU_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/MY_KPNn880KWfU_00003.mp4
# Moved AND_NA7krbsdXFA_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/AND_NA7krbsdXFA_00003.mp4
# Moved ALL_81Ub0SMxZQo_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ALL_81Ub0SMxZQo_00003.mp4
# Moved THE_uqS6T6TAu74_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THE_uqS6T6TAu74_00001.mp4
# Moved IMPOSSIBLE_gSycQufrgK4_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IMPOSSIBLE_gSycQufrgK4_00001.mp4
# Moved GO_ka8L1YMR88U_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/GO_ka8L1YMR88U_00005.mp4
# Moved GO_nCg2NcGYu34_00008.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/GO_nCg2NcGYu34_00008.mp4
# Moved GO_XESFPEFpHt4_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/GO_XESFPEFpHt4_00004.mp4
# Moved AS_ROgFmb3oTLo_00010.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/AS_ROgFmb3oTLo_00010.mp4
# Moved THEM_PYHd7rpOTe8_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THEM_PYHd7rpOTe8_00003.mp4
# Moved HAVE_8nt3edWLgIg_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/HAVE_8nt3edWLgIg_00004.mp4
# Moved A_s0YjL9rZyR0_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/A_s0YjL9rZyR0_00003.mp4
# Moved YOU_6ra1MIKlYB0_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/YOU_6ra1MIKlYB0_00002.mp4
# Moved THEIR_x95nwilkaio_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THEIR_x95nwilkaio_00002.mp4
# Moved FOR_VIgzTLDyObo_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/FOR_VIgzTLDyObo_00002.mp4
# Moved WE_GIbz9ms9Z9k_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WE_GIbz9ms9Z9k_00004.mp4
# Moved WE'RE_2SlBiFZ85d0_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WE'RE_2SlBiFZ85d0_00004.mp4
# Moved YOU_BImnT7lcLDE_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/YOU_BImnT7lcLDE_00003.mp4
# Moved DOG_8vNIrPeRGlM_00010.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/DOG_8vNIrPeRGlM_00010.mp4
# Moved OF_F3OhcpKSUBc_00006.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/OF_F3OhcpKSUBc_00006.mp4
# Moved WITH_xTkKSJSqUSI_00020.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WITH_xTkKSJSqUSI_00020.mp4
# Moved ARE_7qT3RpaBlJo_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ARE_7qT3RpaBlJo_00002.mp4
# Moved TO_GMynksvCcUI_00008.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/TO_GMynksvCcUI_00008.mp4
# Moved AGAIN_YzGjO5aHShQ_00006.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/AGAIN_YzGjO5aHShQ_00006.mp4
# Moved DO_UtBsl3j0YRQ_00006.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/DO_UtBsl3j0YRQ_00006.mp4
# Moved ALREADY_SSzRfSJTNW4_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ALREADY_SSzRfSJTNW4_00005.mp4
# Moved THEY_BImnT7lcLDE_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THEY_BImnT7lcLDE_00002.mp4
# Moved I_t2gbcVaZ448_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/I_t2gbcVaZ448_00004.mp4
# Moved NOT_1US4jjWtua8_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/NOT_1US4jjWtua8_00005.mp4
# Moved INDIVIDUALS_3nSEitPb7BU_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/INDIVIDUALS_3nSEitPb7BU_00001.mp4
# Moved MEDIOCRE_q2gO4DKVpa8_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/MEDIOCRE_q2gO4DKVpa8_00002.mp4
# Moved TO_PSlBlZ3hqKc_00007.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/TO_PSlBlZ3hqKc_00007.mp4
# Moved IS_hiIcwt88o94_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IS_hiIcwt88o94_00003.mp4
# Moved ACCESS_PSlBlZ3hqKc_00007.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ACCESS_PSlBlZ3hqKc_00007.mp4
# Moved OF_hQigUH0vZSE_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/OF_hQigUH0vZSE_00001.mp4
# Moved WENT_DsrxbqFo41k_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WENT_DsrxbqFo41k_00002.mp4
# Moved THAT_0gks6ceq4eQ_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THAT_0gks6ceq4eQ_00005.mp4
# Moved A_qWNae7vYK6s_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/A_qWNae7vYK6s_00002.mp4
# Moved AIM_1PNX6MSdVsk_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/AIM_1PNX6MSdVsk_00005.mp4
# Moved BUT_7kkRkhAXZGg_00007.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/BUT_7kkRkhAXZGg_00007.mp4
# Moved WOULD_XESFPEFpHt4_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WOULD_XESFPEFpHt4_00001.mp4
# Moved FOR_Mt0PiXLvYlU_00011.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/FOR_Mt0PiXLvYlU_00011.mp4
# Moved IT_4AYE3w5TWHs_00006.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IT_4AYE3w5TWHs_00006.mp4
# Moved THEY_TGZMSmcuiXM_00013.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THEY_TGZMSmcuiXM_00013.mp4
# Moved WHY_V1yW5IsnSjo_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WHY_V1yW5IsnSjo_00003.mp4
# Moved WAS_XESFPEFpHt4_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WAS_XESFPEFpHt4_00003.mp4
# Moved THAT_fIICVeGW4RY_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THAT_fIICVeGW4RY_00004.mp4
# Moved ON_UAj1hsXp18c_00017.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ON_UAj1hsXp18c_00017.mp4
# Moved I'M_RDSSLJG7oi8_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/I'M_RDSSLJG7oi8_00001.mp4
# Moved A_OwgWkUIm9Gc_00009.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/A_OwgWkUIm9Gc_00009.mp4
# Moved WE_fscaRh2OtXk_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WE_fscaRh2OtXk_00004.mp4
# Moved IT'S_VzyjDRSAWzE_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IT'S_VzyjDRSAWzE_00001.mp4
# Moved WERE_SaouBn7IKIo_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WERE_SaouBn7IKIo_00001.mp4
# Moved AGAIN_1bnzVjOJ6NM_00017.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/AGAIN_1bnzVjOJ6NM_00017.mp4
# Moved TO_tiSiSM3pk5M_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/TO_tiSiSM3pk5M_00002.mp4
# Moved TO_9RMx31GnNXY_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/TO_9RMx31GnNXY_00002.mp4
# Moved WILL_8UhqkX2VAmo_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WILL_8UhqkX2VAmo_00001.mp4
# Moved MAKE_Ht2fzax9wV0_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/MAKE_Ht2fzax9wV0_00002.mp4
# Moved THE_MsLuQM5V3FA_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THE_MsLuQM5V3FA_00001.mp4
# Moved ARE_5Yj3nGv0kn8_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ARE_5Yj3nGv0kn8_00001.mp4
# Moved SOCIAL_Bs86giWcjLA_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/SOCIAL_Bs86giWcjLA_00004.mp4
# Moved WHAT_81Ub0SMxZQo_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WHAT_81Ub0SMxZQo_00002.mp4
# Moved YOU_xTkKSJSqUSI_00020.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/YOU_xTkKSJSqUSI_00020.mp4
# Moved NOT_3uSQlcGCHUU_00011.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/NOT_3uSQlcGCHUU_00011.mp4
# Moved I_8nt3edWLgIg_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/I_8nt3edWLgIg_00005.mp4
# Moved BEHIND_Us70DN2XSfM_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/BEHIND_Us70DN2XSfM_00003.mp4
# Moved AND_hiIcwt88o94_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/AND_hiIcwt88o94_00003.mp4
# Moved ACTUALLY_O6Vayv9FCLM_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ACTUALLY_O6Vayv9FCLM_00001.mp4
# Moved AT_Li4S1yyrsTI_00011.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/AT_Li4S1yyrsTI_00011.mp4
# Moved A_jcp5vvxtEaU_00010.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/A_jcp5vvxtEaU_00010.mp4
# Moved HAVE_j7fRIGphgtk_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/HAVE_j7fRIGphgtk_00004.mp4
# Moved GOLD_5riPKdpuoiI_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/GOLD_5riPKdpuoiI_00002.mp4
# Moved WAS_m6X1i8khmt8_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WAS_m6X1i8khmt8_00001.mp4
# Moved HE_6Waurx8eS1o_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/HE_6Waurx8eS1o_00003.mp4
# Moved THE_hiIcwt88o94_00018.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THE_hiIcwt88o94_00018.mp4
# Moved HAVE_KuWXfjyGhk0_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/HAVE_KuWXfjyGhk0_00005.mp4
# Moved SOURCE_qsJYrwzfd6w_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/SOURCE_qsJYrwzfd6w_00004.mp4
# Moved THEM_jcp5vvxtEaU_00011.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THEM_jcp5vvxtEaU_00011.mp4
# Moved THE_LiUClSItcy0_00008.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THE_LiUClSItcy0_00008.mp4
# Moved TOO_vhVWzkbAW4I_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/TOO_vhVWzkbAW4I_00005.mp4
# Moved OF_x95nwilkaio_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/OF_x95nwilkaio_00003.mp4
# Moved GONE_OwgWkUIm9Gc_00008.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/GONE_OwgWkUIm9Gc_00008.mp4
# Moved HAVE_1K5SycZjGhI_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/HAVE_1K5SycZjGhI_00001.mp4
# Moved WE_o1Z4F4e2Bw4_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/WE_o1Z4F4e2Bw4_00003.mp4
# Moved GET_AsSd2nmoKNA_00002.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/GET_AsSd2nmoKNA_00002.mp4
# Moved TO_Gmai4zkKNcM_00007.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/TO_Gmai4zkKNcM_00007.mp4
# Moved IF_RiM5aSvaNkg_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IF_RiM5aSvaNkg_00003.mp4
# Moved MY_fxbCHn6gE3U_00005.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/MY_fxbCHn6gE3U_00005.mp4
# Moved ABOUT_xkFTZcUPjBg_00003.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ABOUT_xkFTZcUPjBg_00003.mp4
# Moved MESSAGE_LiUClSItcy0_00008.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/MESSAGE_LiUClSItcy0_00008.mp4
# Moved IS_LIy2oVJtJsA_00006.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/IS_LIy2oVJtJsA_00006.mp4
# Moved THAT_IjbTiRbeNpM_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THAT_IjbTiRbeNpM_00001.mp4
# Moved ANYTHING_MNuOmTQdFjA_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ANYTHING_MNuOmTQdFjA_00001.mp4
# Moved A_eNAHVnkll5M_00011.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/A_eNAHVnkll5M_00011.mp4
# Moved THERE'S_jcp5vvxtEaU_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/THERE'S_jcp5vvxtEaU_00004.mp4
# Moved GOT_iqEHuBST2qQ_00001.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/GOT_iqEHuBST2qQ_00001.mp4
# Moved BUT_ZnCSUBmeRxw_00004.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/BUT_ZnCSUBmeRxw_00004.mp4
# Moved ARE_0gks6ceq4eQ_00009.mp4 to ../../../datasets/lrs3_task4/speech_unit_type/words/uncropped_words_combined/test_filtered/ARE_0gks6ceq4eQ_00009.mp4
# Total moved: 5072
